# %% [markdown]
# # Facial Keypoints Detection
# ## W207 Final Project December 2017
# ### Arunima Kayath, Kathleen Wang, Anamika Sinha & Scott A. George

# %% [markdown]
# In this project, we attempted to optimize a neural network for facial keypoints detection. This notebook has three types of networks we tried for this purpose, and their variations.
# Net 1 - Simple network with 1 or 2 hidden layers.
# Net 2 - Convolutional Neural network with 3 convolution layers, and 2 hidden layers -one network for all 30 facial keypoints. Variations we tried with net 2 were :
#     a. Data Augmentation (flipping the images horizontally and vertically)
#     b. Implementing momentum increase and learning rate decay(4 different options were tried though only one is shown in the notebook)
#     c. Using a Leaky Relu as the activation function instead of Relu
#     d. Different combinations of filter sizes for each of the convolution layers.
# Net 3 - CNN as above, but 6 different networks for 6 subsets of the 30 keypoints. This also allows us to leverage the extra data available for some of the keypoints.
#
# In addition to this, we also tried different data pre-processing. In the time we had, we were only able to try the effect of pre-processing with net 1.

# %%
import os

import numpy as np
from pandas.io.parsers import read_csv
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from decimal import *
import tensorflow as tf
import time
from datetime import datetime
import matplotlib.pyplot as plt
from tensorflow.contrib.layers import fully_connected

# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# %% [markdown]
# ## Loading Data

# %%
scott = False
aws = False
tensorboard_log = False

if scott:
    FROOT = ''
    FTRAIN = '/data/facial/training.csv'
    FTEST = '/data/facial/test.csv'
elif aws:
    FROOT = ''
    FTRAIN = '/data/training.csv'
    FTEST = '/data/test.csv'
else:
    FROOT = os.getcwd() # Path to your project folder
    FTRAIN = '~/notebooks/training.csv'
    FTEST = '~/notebooks/test.csv'

if tensorboard_log:
    root_logdir = FROOT + "tf_logs"
    
os.makedirs( FROOT + "/models/", exist_ok=True)

# %% [markdown]
# Helper function to load data

# %%
np.random.seed(0)
def load(test = False, cols = None):
    '''Loads data from FTEST if *test* is true, otherwise from FTRAIN.' 
    Pass a list of *cols* if you are only interested in a
    subset of the target columns'''
    
    fname = FTEST if test else FTRAIN
    df = read_csv(os.path.expanduser(fname)) #load pandas dataframe

    
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im,sep=' ')) 
    #image column has pixel values separated by space; convert the values to numpy arrays
    
    if cols: #get a subset of columns
        df = df[list(cols) + ['Image']]
        
    print('Count of observations in training data by features')
    print(df.count()) #prints number of values for each column
    df = df.dropna() #drop all rows that have missing values in them
    
    X = np.vstack(df['Image'].values)/255
    X = X.astype(np.float32)
    
    if not test:
        y  = df[df.columns[:-1]].values
        y = (y-48)/48
        shuffle = np.random.permutation(np.arange(X.shape[0]))
        X, y = X[shuffle], y[shuffle]
        y = y.astype(np.float32)
    else:
        y = None
    print('done')
        
    return X,y

# %%
np.random.seed(0)
X, y = load()

print('Total training data')
print("X.shape = = {}; X.min == {:.3f}; X.max == {:.3f}".format(X.shape, X.min(),X.max()))
print("y.shape = = {}; y.min == {:.3f}; y.max == {:.3f}".format(y.shape, y.min(),y.max()))
# Out:
# Count of observations in training data by features
# left_eye_center_x            7039
# left_eye_center_y            7039
# right_eye_center_x           7036
# right_eye_center_y           7036
# left_eye_inner_corner_x      2271
# left_eye_inner_corner_y      2271
# left_eye_outer_corner_x      2267
# left_eye_outer_corner_y      2267
# right_eye_inner_corner_x     2268
# right_eye_inner_corner_y     2268
# right_eye_outer_corner_x     2268
# right_eye_outer_corner_y     2268
# left_eyebrow_inner_end_x     2270
# left_eyebrow_inner_end_y     2270
# left_eyebrow_outer_end_x     2225
# left_eyebrow_outer_end_y     2225
# right_eyebrow_inner_end_x    2270
# right_eyebrow_inner_end_y    2270
# right_eyebrow_outer_end_x    2236
# right_eyebrow_outer_end_y    2236
# nose_tip_x                   7049
# nose_tip_y                   7049
# mouth_left_corner_x          2269
# mouth_left_corner_y          2269
# mouth_right_corner_x         2270
# mouth_right_corner_y         2270
# mouth_center_top_lip_x       2275
# mouth_center_top_lip_y       2275
# mouth_center_bottom_lip_x    7016
# mouth_center_bottom_lip_y    7016
# Image                        7049
# dtype: int64
# done
# Total training data
# X.shape = = (2140, 9216); X.min == 0.000; X.max == 1.000
# y.shape = = (2140, 30); y.min == -0.920; y.max == 0.996

# %% [markdown]
# Save 20% data to be used as dev data, carve out dev data and load test data

# %%
np.random.seed(0)
dev_size = 0.2
#setting aside a 20% sample for validation

x_train, x_dev, y_train, y_dev = train_test_split(X, y, test_size = dev_size)

x_test, _ = load(test=True)

print('Training data split into train and dev data')
print("x_train.shape = = {}; x_train.min == {:.3f}; x_train.max == {:.3f}".format(x_train.shape, x_train.min(),x_train.max()))
print("y_train.shape = = {}; y_train.min == {:.3f}; y_train.max == {:.3f}".format(y_train.shape, y_train.min(),y_train.max()))
print("x_dev.shape = = {}; x_dev.min == {:.3f}; x_dev.max == {:.3f}".format(x_dev.shape, x_dev.min(),x_dev.max()))
print("y_dev.shape = = {}; y_dev.min == {:.3f}; y_dev.max == {:.3f}".format(y_dev.shape, y_dev.min(),y_dev.max()))
# Out:
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1712, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1712, 30); y_train.min == -0.916; y_train.max == 0.996
# x_dev.shape = = (428, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (428, 30); y_dev.min == -0.920; y_dev.max == 0.980

# %% [markdown]
# # KNN Baseline

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import pandas as pd
neighbors =  [1,2,3,4,5,6,7]
row = 0
result_knn = pd.DataFrame(columns=['k_neighbours','keypoint','mse'])
print('starting')
for i in neighbors:
    knn = KNeighborsRegressor(i)
    for j in range(30):
        knn.fit(x_train, y_train[:,j])
        knn_predicted_labels = knn.predict(x_dev)
        mse = mean_squared_error(y_dev[:,j], knn_predicted_labels)
        result_knn.loc[row]= [int(i), int(j+1),  mse]
        row += 1
print("Using K-nearest neighbour, here are the mean square error(mse) for each keypoint prediction for the kth neighbour that produces the minimum mse")
min_index = [result_knn[result_knn.keypoint==i+1].mse.idxmin()  for i in range(30)]
net_loss = np.sqrt(result_knn.groupby('k_neighbours')['mse'].sum()/30)
print(net_loss)
# Out:
# starting
# Using K-nearest neighbour, here are the mean square error(mse) for each keypoint prediction for the kth neighbour that produces the minimum mse
# k_neighbours
# 1.0    0.058709
# 2.0    0.053747
# 3.0    0.052523
# 4.0    0.051666
# 5.0    0.051650
# Name: mse, dtype: float64

# %% [markdown]
# ## Helper functions for neural nets
#
# ### 1. plot_sample: plots sample pictures

# %%
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

# %%
np.random.seed(1)
def shuffle_run_batch(Xnp, ynp, Xdev, ydev, batch_size, epoch):
    """function takes training and dev data, shuffle the train data and run TF optimizer in batches for a given epoch
    It returns the average loss for training and eval of all the batches ran in the epoch.
    It expects to run with tensorboard."""

    shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xnp, ynp = Xnp[shuffle], ynp[shuffle]

    # initialize variables to hold loss information for each epoch
    #loss_train = 0
    #loss_dev = 0
    batches = Xnp.shape[0]//batch_size


    for i in range(int(batches)): #run through most of the data points in each epoch
        X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:], ynp[i*batch_size:(i+1)*batch_size]
        if tensorboard_log:
            if i % 10 == 0:
                train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, training: True})
                dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, training: False})
                step = epoch * batches + i
                train_writer.add_summary(train_summary_str, step)
                dev_writer.add_summary(dev_summary_str, step)

        sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})

    

        loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
        loss_dev = loss.eval(feed_dict = {X:Xdev,y:ydev, training:False})

    
    return loss_train, loss_dev

# %%
# *might* need to double check correctly formatted input
def plot_loss (train_loss_data, dev_loss_data):
    
    plt.figure()
    plt.plot(train_loss_data[:,1], label="train")
    plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.yscale("log")
    plt.show()

# %%
# *might* need to double check correctly formatted input
def plot_pred (x_dev, y_pred):
    
    fig = plt.figure(figsize=(16, 16))
    fig.subplots_adjust(
        left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(4):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        plot_sample(x_dev[i], y_pred[i], ax)
    plt.show

# %% [markdown]
# ## First model: 1 hidden layer simple neural net

# %% [markdown]
# Define parameters

# %%
learning_rate = 0.01
momentum = 0.9

n_epochs = 1501 #Although net 1 reaches steady state sooner, standarsized to this many epochs for all nets for comparison
batch_size = 50


n_inputs = X.shape[1] 
n_hidden1 = 100
n_outputs = 30

# %% [markdown]
# Construct the tensorflow graph for the first network

# %%
#Net 1 - network with 1 hidden layer.
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)


with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    pred_keypoints = fully_connected(hidden1,n_outputs,activation_fn = None,scope = 'outputs')
    
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()


train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))

time_start = time.time()
time_1000_start = time.time()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        
        # note this is includes the for-loop for batching
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)
                    
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            
        if epoch%50 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                  'Dev loss:%0.3f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
            
    time_end = time.time()  
    y_pred = sess.run(pred_keypoints,feed_dict = {X: x_test})
    print('Total time taken:',time_end-time_start)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
    
#Plotting loss, and sample predictions
plt.figure()
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred) #updated this to be x_test instead of x_dev, since the predictions are being made on x_test

#Saving loss and test predictions
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net1_baseline.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net1_baseline_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')
# Out:
# 0 Train loss:0.133 Dev loss:0.132 ratio train/dev:1.01
# 50 Train loss:0.067 Dev loss:0.072 ratio train/dev:0.93
# 100 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.94
# 150 Train loss:0.051 Dev loss:0.060 ratio train/dev:0.85
# 200 Train loss:0.047 Dev loss:0.057 ratio train/dev:0.82
# 250 Train loss:0.045 Dev loss:0.057 ratio train/dev:0.80
# 300 Train loss:0.046 Dev loss:0.055 ratio train/dev:0.83
# 350 Train loss:0.044 Dev loss:0.055 ratio train/dev:0.80
# 400 Train loss:0.043 Dev loss:0.055 ratio train/dev:0.79
# 450 Train loss:0.042 Dev loss:0.054 ratio train/dev:0.78
# 500 Train loss:0.042 Dev loss:0.053 ratio train/dev:0.78
# 550 Train loss:0.037 Dev loss:0.053 ratio train/dev:0.70
# 600 Train loss:0.040 Dev loss:0.053 ratio train/dev:0.75
# 650 Train loss:0.035 Dev loss:0.053 ratio train/dev:0.66
# 700 Train loss:0.036 Dev loss:0.053 ratio train/dev:0.69
# 750 Train loss:0.032 Dev loss:0.052 ratio train/dev:0.60
# 800 Train loss:0.037 Dev loss:0.053 ratio train/dev:0.71
# 850 Train loss:0.031 Dev loss:0.052 ratio train/dev:0.59
# 900 Train loss:0.034 Dev loss:0.052 ratio train/dev:0.66
# 950 Train loss:0.034 Dev loss:0.052 ratio train/dev:0.65
# 1000 Train loss:0.034 Dev loss:0.052 ratio train/dev:0.65
# 1050 Train loss:0.032 Dev loss:0.052 ratio train/dev:0.61
# 1100 Train loss:0.030 Dev loss:0.052 ratio train/dev:0.58
# 1150 Train loss:0.036 Dev loss:0.052 ratio train/dev:0.69
# 1200 Train loss:0.031 Dev loss:0.052 ratio train/dev:0.60
# 1250 Train loss:0.034 Dev loss:0.052 ratio train/dev:0.65
# 1300 Train loss:0.033 Dev loss:0.052 ratio train/dev:0.64
# 1350 Train loss:0.033 Dev loss:0.052 ratio train/dev:0.64
# 1400 Train loss:0.028 Dev loss:0.052 ratio train/dev:0.55
# 1450 Train loss:0.030 Dev loss:0.052 ratio train/dev:0.57
# 1500 Train loss:0.029 Dev loss:0.052 ratio train/dev:0.56
# Total time taken: 291.0524101257324

# %% [markdown]
# # Fully Connected Network(Net 1) with 2 hidden layers

# %%
#Net 1 with 2 hidden layers
n_hidden2 = 60
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)
    
with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    hidden2 = fully_connected(hidden1,n_hidden2,scope = 'hidden2')
    pred_keypoints = fully_connected(hidden2,n_outputs,activation_fn = None,scope = 'outputs')
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()


train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))

time_start = time.time()
time_1000_start = time.time()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        
        # note this is includes the for-loop for batching
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)
                    
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            
        if epoch%50 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                  'Dev loss:%0.3f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
            
            
    time_end = time.time()  
    
    y_pred = sess.run(pred_keypoints,feed_dict = {X: x_test})
   
    print('Total time taken:',time_end-time_start)
    
if tensorboard_log:
    train_writer.close()
    dev_writer.close()
    
plt.figure()
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

#Saving loss and test predictions
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net1_2hidden_layers.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net1__2hidden_layers_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')
# Out:
# 0 Train loss:0.129 Dev loss:0.125 ratio train/dev:1.04
# 50 Train loss:0.058 Dev loss:0.062 ratio train/dev:0.93
# 100 Train loss:0.055 Dev loss:0.057 ratio train/dev:0.98
# 150 Train loss:0.048 Dev loss:0.055 ratio train/dev:0.88
# 200 Train loss:0.044 Dev loss:0.053 ratio train/dev:0.83
# 250 Train loss:0.040 Dev loss:0.052 ratio train/dev:0.77
# 300 Train loss:0.043 Dev loss:0.051 ratio train/dev:0.83
# 350 Train loss:0.041 Dev loss:0.051 ratio train/dev:0.81
# 400 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.76
# 450 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.75
# 500 Train loss:0.037 Dev loss:0.050 ratio train/dev:0.74
# 550 Train loss:0.032 Dev loss:0.050 ratio train/dev:0.64
# 600 Train loss:0.035 Dev loss:0.050 ratio train/dev:0.71
# 650 Train loss:0.030 Dev loss:0.049 ratio train/dev:0.62
# 700 Train loss:0.031 Dev loss:0.050 ratio train/dev:0.63
# 750 Train loss:0.027 Dev loss:0.049 ratio train/dev:0.55
# 800 Train loss:0.032 Dev loss:0.049 ratio train/dev:0.64
# 850 Train loss:0.027 Dev loss:0.049 ratio train/dev:0.54
# 900 Train loss:0.029 Dev loss:0.050 ratio train/dev:0.59
# 950 Train loss:0.026 Dev loss:0.050 ratio train/dev:0.53
# 1000 Train loss:0.030 Dev loss:0.050 ratio train/dev:0.61
# 1050 Train loss:0.027 Dev loss:0.050 ratio train/dev:0.55
# 1100 Train loss:0.025 Dev loss:0.050 ratio train/dev:0.50
# 1150 Train loss:0.029 Dev loss:0.050 ratio train/dev:0.58
# 1200 Train loss:0.025 Dev loss:0.050 ratio train/dev:0.51
# 1250 Train loss:0.028 Dev loss:0.050 ratio train/dev:0.57
# 1300 Train loss:0.026 Dev loss:0.050 ratio train/dev:0.53
# 1350 Train loss:0.026 Dev loss:0.050 ratio train/dev:0.53
# 1400 Train loss:0.024 Dev loss:0.050 ratio train/dev:0.48
# 1450 Train loss:0.023 Dev loss:0.050 ratio train/dev:0.47
# 1500 Train loss:0.022 Dev loss:0.050 ratio train/dev:0.44
# Total time taken: 297.5092387199402

# %% [markdown]
# Helper function to pre-process the data in different ways. Three types of pre-processing were tried:
#     a. Max_range : Stretches each image to the maximum pixel range eg is the lowest and highest pixel in an image is 0.2,0.7, then these will be stretched by dividing all the pixels by (0.7-0.2) = 0.5
#     b. Gaussian_blur : Gaussian blur of 3X3
#     c. Mean_center : Subtract the mean image from all the images.

# %%
#Function to pre-process the data in different ways
def preprocess_image(x,type):
    x1 = np.zeros(x.shape)
    mean_x = np.mean(x,axis=1)
    max_x = np.max(x,axis=1)
    min_x = np.min(x,axis=1)
    std_x = np.std(x,axis=1)
    delta_x_arr = max_x - min_x
    
    if type == 'None': #No pre-processing baseline
        x1 = x
    
    if type == 'Max_range': #Divide all x's in a row by the max in the range
        for i in range(x.shape[0]):
            delta_x = max_x[i] - min_x[i]
            x1[i,:] = (x[i,:])/delta_x
        

    if type == 'Gaussian_blur': #3X3 gaussian blur of the image
        #print(len(x))
        for k in range(len(x)):
            tmp_array = x[k].reshape(96,96)
            tmp_array_copy = tmp_array
            for i in range(tmp_array.shape[0]-1):
                for j in range(tmp_array.shape[1] -1):
                    if (i > 0 and j > 0):
                        sub_arr = tmp_array[i-1:i+1,j-1:j+1]
                        sum8 = (1/4)*tmp_array[i,j]+(1/8)*(tmp_array[i-1,j]+tmp_array[i+1,j]+tmp_array[i,j-1]+tmp_array[i,j+1])\
                        + (1/16)*(tmp_array[i-1,j-1]+tmp_array[i-1,j+1]+tmp_array[i+1,j-1]+tmp_array[i+1,j+1])
                        tmp_array_copy[i,j] = sum8
            tmp_array = tmp_array_copy.reshape(9216)
            x1[k] = tmp_array
            
    if type == 'Mean_center': #Take out the mean image from all images (effectively taking out the mean of each feature)
        feature_mean = np.mean(x,axis=0)
        #print('feature_mean_shape',feature_mean.shape)
        for i in range(x.shape[1]):
            x1[:,i] = x[:,i]-feature_mean[i]
   
    return x1

# %% [markdown]
# Neural net with 1 hidden layer and trying all of the above 3 variations of preprocessed input

# %%
#net 1 with 1 hidden layer and preprocessed input
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)


with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    pred_keypoints = fully_connected(hidden1,n_outputs,activation_fn = None,scope = 'outputs')
    
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()

preprocess_types = ('None','Max_range','Mean_center','Gaussian_blur')

train_loss_data = np.zeros((n_epochs,len(preprocess_types)+1))
dev_loss_data = np.zeros((n_epochs,len(preprocess_types)+1))

time_start = time.time()
time_1000_start = time.time()

preprocess_types = ('None','Max_range','Mean_center','Gaussian_blur')

with tf.Session() as sess:
    
    i = 0
    for type in preprocess_types:
        sess.run(tf.global_variables_initializer())
        #modify the train and dev data to be digitized to just 10 pixel values
        x_train_preprocess = preprocess_image(x_train,type)
        x_dev_preprocess = preprocess_image(x_dev,type)
        x_test_preprocess = preprocess_image(x_test,type)
        for epoch in range(n_epochs):

            loss_train,loss_dev = shuffle_run_batch (x_train_preprocess, y_train, x_dev_preprocess, y_dev, batch_size, epoch)

            train_loss_data[epoch,0] = epoch
            dev_loss_data[epoch,0] = epoch
            train_loss_data[epoch,i+1] = np.sqrt(loss_train)
            dev_loss_data[epoch,i+1] = np.sqrt(loss_dev)
            
            if epoch%50 == 0:
                print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                      'Dev loss:%0.3f'%np.sqrt(loss_dev),
                      'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
        i+=1
        y_pred = sess.run(pred_keypoints,feed_dict = {X: x_dev_preprocess})
                     
        plt.figure()
        plot_loss(train_loss_data,dev_loss_data)
        plot_pred (x_dev_preprocess, y_pred) 
    
    #Saving loss and test predictions
    train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
    with open('net1_preprocess_aws.csv', 'wb') as fp:
        np.savetxt(fp, train_dev_loss,fmt = '%0.4f') 
                 
time_end = time.time()    
print('Total time taken:',time_end-time_start)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# 0 Train loss:0.128 Dev loss:0.124 ratio train/dev:1.03
# 50 Train loss:0.068 Dev loss:0.073 ratio train/dev:0.93
# 100 Train loss:0.057 Dev loss:0.064 ratio train/dev:0.90
# 150 Train loss:0.050 Dev loss:0.060 ratio train/dev:0.83
# 200 Train loss:0.045 Dev loss:0.058 ratio train/dev:0.78
# 250 Train loss:0.043 Dev loss:0.056 ratio train/dev:0.76
# 300 Train loss:0.044 Dev loss:0.056 ratio train/dev:0.80
# 350 Train loss:0.042 Dev loss:0.055 ratio train/dev:0.77
# 400 Train loss:0.040 Dev loss:0.054 ratio train/dev:0.73
# 450 Train loss:0.040 Dev loss:0.054 ratio train/dev:0.73
# 500 Train loss:0.040 Dev loss:0.053 ratio train/dev:0.75
# 550 Train loss:0.035 Dev loss:0.053 ratio train/dev:0.65
# 600 Train loss:0.037 Dev loss:0.053 ratio train/dev:0.69
# 650 Train loss:0.033 Dev loss:0.053 ratio train/dev:0.63
# 700 Train loss:0.034 Dev loss:0.053 ratio train/dev:0.64
# 750 Train loss:0.028 Dev loss:0.052 ratio train/dev:0.53
# 800 Train loss:0.035 Dev loss:0.053 ratio train/dev:0.65
# 850 Train loss:0.028 Dev loss:0.053 ratio train/dev:0.53
# 900 Train loss:0.031 Dev loss:0.052 ratio train/dev:0.58
# 950 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.58
# 1000 Train loss:0.032 Dev loss:0.053 ratio train/dev:0.61
# 1050 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.59
# 1100 Train loss:0.028 Dev loss:0.053 ratio train/dev:0.53
# 1150 Train loss:0.032 Dev loss:0.053 ratio train/dev:0.60
# 1200 Train loss:0.029 Dev loss:0.053 ratio train/dev:0.54
# 1250 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.58
# 1300 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.59
# 1350 Train loss:0.030 Dev loss:0.053 ratio train/dev:0.57
# 1400 Train loss:0.028 Dev loss:0.053 ratio train/dev:0.53
# 1450 Train loss:0.027 Dev loss:0.053 ratio train/dev:0.51
# 1500 Train loss:0.027 Dev loss:0.053 ratio train/dev:0.50
# 0 Train loss:0.131 Dev loss:0.132 ratio train/dev:0.99
# 50 Train loss:0.071 Dev loss:0.071 ratio train/dev:1.01
# 100 Train loss:0.057 Dev loss:0.062 ratio train/dev:0.92
# 150 Train loss:0.052 Dev loss:0.060 ratio train/dev:0.87
# 200 Train loss:0.043 Dev loss:0.056 ratio train/dev:0.76
# 250 Train loss:0.042 Dev loss:0.055 ratio train/dev:0.76
# 300 Train loss:0.039 Dev loss:0.054 ratio train/dev:0.72
# 350 Train loss:0.039 Dev loss:0.054 ratio train/dev:0.71
# 400 Train loss:0.041 Dev loss:0.053 ratio train/dev:0.77
# 450 Train loss:0.036 Dev loss:0.053 ratio train/dev:0.69
# 500 Train loss:0.037 Dev loss:0.053 ratio train/dev:0.70
# 550 Train loss:0.032 Dev loss:0.052 ratio train/dev:0.62
# 600 Train loss:0.037 Dev loss:0.052 ratio train/dev:0.72
# 650 Train loss:0.032 Dev loss:0.052 ratio train/dev:0.62
# 700 Train loss:0.036 Dev loss:0.052 ratio train/dev:0.70
# 750 Train loss:0.033 Dev loss:0.052 ratio train/dev:0.63
# 800 Train loss:0.031 Dev loss:0.052 ratio train/dev:0.59
# 850 Train loss:0.034 Dev loss:0.052 ratio train/dev:0.65
# 900 Train loss:0.033 Dev loss:0.052 ratio train/dev:0.64
# 950 Train loss:0.031 Dev loss:0.052 ratio train/dev:0.60
# 1000 Train loss:0.030 Dev loss:0.052 ratio train/dev:0.58
# 1050 Train loss:0.033 Dev loss:0.052 ratio train/dev:0.63
# 1100 Train loss:0.029 Dev loss:0.052 ratio train/dev:0.55
# 1150 Train loss:0.031 Dev loss:0.052 ratio train/dev:0.59
# 1200 Train loss:0.030 Dev loss:0.052 ratio train/dev:0.57
# 1250 Train loss:0.028 Dev loss:0.052 ratio train/dev:0.54
# 1300 Train loss:0.029 Dev loss:0.052 ratio train/dev:0.55
# 1350 Train loss:0.026 Dev loss:0.052 ratio train/dev:0.50
# 1400 Train loss:0.030 Dev loss:0.052 ratio train/dev:0.58
# 1450 Train loss:0.027 Dev loss:0.052 ratio train/dev:0.52
# 1500 Train loss:0.028 Dev loss:0.052 ratio train/dev:0.54
# 0 Train loss:0.218 Dev loss:0.211 ratio train/dev:1.03
# 50 Train loss:0.057 Dev loss:0.088 ratio train/dev:0.65
# 100 Train loss:0.042 Dev loss:0.081 ratio train/dev:0.52
# 150 Train loss:0.037 Dev loss:0.079 ratio train/dev:0.47
# 200 Train loss:0.033 Dev loss:0.077 ratio train/dev:0.43
# 250 Train loss:0.031 Dev loss:0.076 ratio train/dev:0.41
# 300 Train loss:0.030 Dev loss:0.076 ratio train/dev:0.39
# 350 Train loss:0.027 Dev loss:0.075 ratio train/dev:0.36
# 400 Train loss:0.026 Dev loss:0.075 ratio train/dev:0.34
# 450 Train loss:0.024 Dev loss:0.074 ratio train/dev:0.32
# 500 Train loss:0.024 Dev loss:0.074 ratio train/dev:0.32
# 550 Train loss:0.023 Dev loss:0.074 ratio train/dev:0.31
# 600 Train loss:0.021 Dev loss:0.074 ratio train/dev:0.29
# 650 Train loss:0.019 Dev loss:0.074 ratio train/dev:0.26
# 700 Train loss:0.020 Dev loss:0.074 ratio train/dev:0.27
# 750 Train loss:0.019 Dev loss:0.074 ratio train/dev:0.26
# 800 Train loss:0.019 Dev loss:0.073 ratio train/dev:0.26
# 850 Train loss:0.017 Dev loss:0.073 ratio train/dev:0.23
# 900 Train loss:0.018 Dev loss:0.073 ratio train/dev:0.25
# 950 Train loss:0.017 Dev loss:0.073 ratio train/dev:0.23
# 1000 Train loss:0.015 Dev loss:0.073 ratio train/dev:0.21
# 1050 Train loss:0.016 Dev loss:0.073 ratio train/dev:0.22
# 1100 Train loss:0.016 Dev loss:0.073 ratio train/dev:0.22
# 1150 Train loss:0.015 Dev loss:0.073 ratio train/dev:0.20
# 1200 Train loss:0.015 Dev loss:0.073 ratio train/dev:0.20
# 1250 Train loss:0.015 Dev loss:0.073 ratio train/dev:0.21
# 1300 Train loss:0.014 Dev loss:0.073 ratio train/dev:0.19
# 1350 Train loss:0.014 Dev loss:0.073 ratio train/dev:0.20
# 1400 Train loss:0.014 Dev loss:0.073 ratio train/dev:0.19
# 1450 Train loss:0.015 Dev loss:0.073 ratio train/dev:0.20
# 1500 Train loss:0.013 Dev loss:0.073 ratio train/dev:0.17
# 0 Train loss:0.130 Dev loss:0.124 ratio train/dev:1.05
# 50 Train loss:0.072 Dev loss:0.069 ratio train/dev:1.03
# 100 Train loss:0.062 Dev loss:0.062 ratio train/dev:0.99
# 150 Train loss:0.053 Dev loss:0.059 ratio train/dev:0.89
# 200 Train loss:0.049 Dev loss:0.057 ratio train/dev:0.86
# 250 Train loss:0.050 Dev loss:0.055 ratio train/dev:0.92
# 300 Train loss:0.045 Dev loss:0.054 ratio train/dev:0.83
# 350 Train loss:0.047 Dev loss:0.054 ratio train/dev:0.87
# 400 Train loss:0.044 Dev loss:0.052 ratio train/dev:0.84
# 450 Train loss:0.044 Dev loss:0.053 ratio train/dev:0.84
# 500 Train loss:0.043 Dev loss:0.051 ratio train/dev:0.84
# 550 Train loss:0.039 Dev loss:0.052 ratio train/dev:0.74
# 600 Train loss:0.038 Dev loss:0.051 ratio train/dev:0.74
# 650 Train loss:0.042 Dev loss:0.051 ratio train/dev:0.82
# 700 Train loss:0.041 Dev loss:0.051 ratio train/dev:0.81
# 750 Train loss:0.036 Dev loss:0.051 ratio train/dev:0.71
# 800 Train loss:0.042 Dev loss:0.051 ratio train/dev:0.83
# 850 Train loss:0.034 Dev loss:0.050 ratio train/dev:0.68
# 900 Train loss:0.040 Dev loss:0.050 ratio train/dev:0.80
# 950 Train loss:0.039 Dev loss:0.050 ratio train/dev:0.78
# 1000 Train loss:0.038 Dev loss:0.051 ratio train/dev:0.74
# 1050 Train loss:0.036 Dev loss:0.051 ratio train/dev:0.71
# 1100 Train loss:0.035 Dev loss:0.050 ratio train/dev:0.69
# 1150 Train loss:0.036 Dev loss:0.051 ratio train/dev:0.69
# 1200 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.77
# 1250 Train loss:0.031 Dev loss:0.050 ratio train/dev:0.62
# 1300 Train loss:0.035 Dev loss:0.051 ratio train/dev:0.70
# 1350 Train loss:0.036 Dev loss:0.051 ratio train/dev:0.71
# 1400 Train loss:0.033 Dev loss:0.050 ratio train/dev:0.65
# 1450 Train loss:0.030 Dev loss:0.050 ratio train/dev:0.61
# 1500 Train loss:0.034 Dev loss:0.051 ratio train/dev:0.67
# Total time taken: 2402.174376964569

# %% [markdown]
# ## Second model: Convolutional Neural Network

# %% [markdown]
# ### 1. Base convolutional NN:
# ### Optimizer = MomentumOptimizer
# Define parameters

# %%
learning_rate = 0.01
momentum = 0.9
# optimizer used
optimize_func = tf.train.MomentumOptimizer
# (learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

n_epochs = 1501 #Standardizing to 1000 epochs for all networks (except some coarse testing)
batch_size = 128

n_inputs = X.shape[1] 
n_outputs = 30


# Convolutional Layer 1.
filter_size1 = 3          # Convolution filters are 3 x 3 pixels.
num_filters1 = 32         # There are 32 of these filters.
dropout_keep_prob1 = 1


# Convolutional Layer 2.
filter_size2 = 2          # Convolution filters are 2 x 2 pixels.
num_filters2 = 64         # There are 64 of these filters.
dropout_keep_prob2 = 1


# Convolutional Layer 3.
filter_size3 = 2          # Convolution filters are 2 x 2 pixels.
num_filters3 = 128         # There are 128 of these filters.
dropout_keep_prob3 = 1


# Fully-connected layer.
fc_size4 = 1000             # Number of output neurons in fully-connected layer1.
dropout_keep_prob4 = 1      # Drop about keep robability if drop outs are applied
fc_size5 = 1000             # Number of output neurons in fully-connected layer2.
dropout_keep_prob5 = 1
dropout_keep_prob6 = 1

# %% [markdown]
# ### Define helper function to:
# ### 1) create convoluted layer variables
# ### 2) create dense layer and
# ### 3) flatten a conv layer for the dense layer

# %%
#Defining a leaky relu activation function using the relu activation function in tensorflow.
def lrelu(x, alpha=0.05):
  return tf.nn.relu(x) - alpha * tf.nn.relu(-x)

# %%
#Building a convolutional layer
#Note : uncomment the layer = lrelu(layer) when running that option.


def new_conv_relu_layer(input, filter_size, num_filters, is_training, dropout_keep_prob = 1):
    """Takes parameters and set up a convoluted layer with possible pooling
    It returns the layer as well as the weights"""

    weights = tf.get_variable( 'weights', 
        shape = [filter_size, filter_size, input.get_shape()[3], num_filters],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    
    biases = tf.get_variable( 'biases',
        shape = [num_filters],
        initializer=tf.constant_initializer(0.0)
      )
    
    conv = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')
    
    
    layer = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')


    layer += biases

    layer = tf.nn.max_pool(value=layer, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1],padding='SAME')

    #layer = tf.nn.relu(layer)
    layer = lrelu(layer)
    
    # apply drop out by specifying a drop_out_keep_prob
    layer = tf.cond(is_training, lambda: tf.nn.dropout(layer, keep_prob = dropout_keep_prob), lambda: layer)
    
    return layer, weights

# %%
#Building a fully connected layer, with relu
#Note : uncomment the layer = lrelu(layer) when running that option.

def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu,
                 is_training ,
                 dropout_keep_prob = 1):       # no relu for the output dense layer

    # Create new weights and biases.
    weights = tf.get_variable( 'weights', 
        shape = [num_inputs, num_outputs],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    
    biases = tf.get_variable( 'biases',
        shape = [num_outputs],
        initializer=tf.constant_initializer(0.0)
      )
        

    layer = tf.matmul(input, weights) + biases
    
    if use_relu:
        #layer = tf.nn.relu(layer)
        layer = lrelu(layer)
    
    layer = tf.cond(is_training, lambda: tf.nn.dropout(layer, keep_prob = dropout_keep_prob), lambda: layer)

    return layer

# %%
# build flatten layer function to flatten conv layer for the fully connected layer
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(layer, [-1, num_features])
    return layer_flat, num_features

# %%
#Base net 2 - Convolutional Neural Network
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            print('Epoch',epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
    
    if (epoch+1)%200 == 0:
            train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
            with open('net2_basic.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')

#Plot a graph of the train vs test loss data and some sample predictions:    
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

#Save the loss output and test predictions to an excel file.
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net2_base.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net2_base_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# Epoch 0 Train loss:0.173 Dev loss:0.174 ratio train/dev:0.99
# Epoch 20 Train loss:0.073 Dev loss:0.068 ratio train/dev:1.07
# Epoch 40 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.06
# Epoch 60 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# Epoch 80 Train loss:0.061 Dev loss:0.064 ratio train/dev:0.95
# Epoch 100 Train loss:0.059 Dev loss:0.064 ratio train/dev:0.92
# Epoch 120 Train loss:0.064 Dev loss:0.063 ratio train/dev:1.01
# Epoch 140 Train loss:0.065 Dev loss:0.063 ratio train/dev:1.04
# Epoch 160 Train loss:0.059 Dev loss:0.062 ratio train/dev:0.95
# Epoch 180 Train loss:0.061 Dev loss:0.061 ratio train/dev:0.99
# Epoch 200 Train loss:0.057 Dev loss:0.061 ratio train/dev:0.93
# Epoch 220 Train loss:0.064 Dev loss:0.060 ratio train/dev:1.06
# Epoch 240 Train loss:0.060 Dev loss:0.059 ratio train/dev:1.01
# Epoch 260 Train loss:0.053 Dev loss:0.059 ratio train/dev:0.90
# Epoch 280 Train loss:0.057 Dev loss:0.058 ratio train/dev:0.99
# Epoch 300 Train loss:0.053 Dev loss:0.057 ratio train/dev:0.93
# Epoch 320 Train loss:0.056 Dev loss:0.056 ratio train/dev:1.00
# Epoch 340 Train loss:0.054 Dev loss:0.055 ratio train/dev:0.98
# Epoch 360 Train loss:0.050 Dev loss:0.054 ratio train/dev:0.93
# Epoch 380 Train loss:0.051 Dev loss:0.053 ratio train/dev:0.96
# Epoch 400 Train loss:0.050 Dev loss:0.052 ratio train/dev:0.95
# Epoch 420 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.93
# Epoch 440 Train loss:0.047 Dev loss:0.051 ratio train/dev:0.93
# Epoch 460 Train loss:0.046 Dev loss:0.050 ratio train/dev:0.92
# Epoch 480 Train loss:0.043 Dev loss:0.049 ratio train/dev:0.87
# Epoch 500 Train loss:0.049 Dev loss:0.049 ratio train/dev:1.00
# Epoch 520 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.90
# Epoch 540 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.91
# Epoch 560 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.92
# Epoch 580 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.92
# Epoch 600 Train loss:0.045 Dev loss:0.046 ratio train/dev:0.98
# Epoch 620 Train loss:0.040 Dev loss:0.046 ratio train/dev:0.88
# Epoch 640 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.89
# Epoch 660 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.89
# Epoch 680 Train loss:0.038 Dev loss:0.045 ratio train/dev:0.85
# Epoch 700 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.85
# Epoch 720 Train loss:0.035 Dev loss:0.044 ratio train/dev:0.80
# Epoch 740 Train loss:0.034 Dev loss:0.044 ratio train/dev:0.78
# Epoch 760 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.92
# Epoch 780 Train loss:0.034 Dev loss:0.044 ratio train/dev:0.78
# Epoch 800 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.85
# Epoch 820 Train loss:0.034 Dev loss:0.043 ratio train/dev:0.79
# Epoch 840 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.85
# Epoch 860 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.87
# Epoch 880 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.89
# Epoch 900 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.85
# Epoch 920 Train loss:0.034 Dev loss:0.043 ratio train/dev:0.80
# Epoch 940 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.82
# Epoch 960 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.77
# Epoch 980 Train loss:0.034 Dev loss:0.042 ratio train/dev:0.81
# Epoch 1000 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.86
# Epoch 1020 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.79
# Epoch 1040 Train loss:0.031 Dev loss:0.042 ratio train/dev:0.74
# Epoch 1060 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.84
# Epoch 1080 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.79
# Epoch 1100 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.84
# Epoch 1120 Train loss:0.031 Dev loss:0.042 ratio train/dev:0.73
# Epoch 1140 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.78
# Epoch 1160 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.80
# Epoch 1180 Train loss:0.029 Dev loss:0.041 ratio train/dev:0.71
# Epoch 1200 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1220 Train loss:0.029 Dev loss:0.041 ratio train/dev:0.70
# Epoch 1240 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1260 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.78
# Epoch 1280 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.81
# Epoch 1300 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.77
# Epoch 1320 Train loss:0.031 Dev loss:0.041 ratio train/dev:0.76
# Epoch 1340 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1360 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.74
# Epoch 1380 Train loss:0.028 Dev loss:0.041 ratio train/dev:0.68
# Epoch 1400 Train loss:0.029 Dev loss:0.041 ratio train/dev:0.72
# Epoch 1420 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.74
# Epoch 1440 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1460 Train loss:0.028 Dev loss:0.041 ratio train/dev:0.68
# Epoch 1480 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.74
# Epoch 1500 Train loss:0.026 Dev loss:0.040 ratio train/dev:0.65
# Total time taken: 3636.441341161728

# %% [markdown]
# Helper function to flip the images and the keypoints. Takes one image at a time.

# %%
#Helper function to flip the images and the keypoints. Takes one image at a time.
def flip_horizontal(x,y):
    img = x.reshape(96,96)
    img1 = np.zeros(img.shape)
    #print(y.shape[0])
    y1 = y
    #print(y)
    for i in range(img.shape[1]):
        img1[:,95-i] = img[:,i]
        x1 = img1.reshape(9216)
    
    y1[::2] = y1[::2] * -1
    #print(y1)
    flip_indices = [
        (0, 2), (1, 3),
        (4, 8), (5, 9), (6, 10), (7, 11),
        (12, 16), (13, 17), (14, 18), (15, 19),
        (22, 24), (23, 25)]
    for a, b in flip_indices:
                y1[a], y1[b] = (y1[b], y1[a])
    #print(y1)
    return x1,y1

# %% [markdown]
# Function to create a shuffled batch with data augmentation with horizontal flip

# %%
#Function to create a shuffled batch with data augmentation with horizontal flip
np.random.seed(1)
def shuffle_run_batch_data_aug(Xnp, ynp, Xdev, ydev, batch_size, epoch):
    """function takes training and dev data, shuffle the train data and run TF optimizer in batches for a given epoch
    It returns the average loss for training and eval of all the batches ran in the epoch.
    It expects to run with tensorboard."""

     #Data augmentation with horizontal flips
    Xflip = np.zeros(Xnp.shape) #Array to store the horizontally flipped faces
    yflip = np.zeros(ynp.shape)

    for i in range(Xnp.shape[0]):
        Xflip[i],yflip[i] = flip_horizontal(Xnp[i],ynp[i])
        
    shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xnp, ynp = Xnp[shuffle], ynp[shuffle]
    shuffle1 = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xflip,yflip = Xflip[shuffle1],yflip[shuffle1]

    # initialize variables to hold loss information for each epoch
    #loss_train = 0
    #loss_dev = 0
    batches = Xnp.shape[0]//batch_size


    for i in range(int(batches)): #run through most of the data points in each epoch
        X_batch = np.vstack((Xnp[i*batch_size//2:(i+1)*batch_size//2,:],Xflip[i*batch_size//2:(i+1)*batch_size//2,:]))
        y_batch = np.vstack((ynp[i*batch_size//2:(i+1)*batch_size//2],yflip[i*batch_size//2:(i+1)*batch_size//2]))
        if tensorboard_log:
            if i % 10 == 0:
                train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, current_epoch:epoch,training: True})
                dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, current_epoch:epoch,training: False})
                step = epoch * batches + i
                train_writer.add_summary(train_summary_str, step)
                dev_writer.add_summary(dev_summary_str, step)

        sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})

    

        loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
        loss_dev = loss.eval(feed_dict = {X:Xdev,y:ydev, training:False})

    
    return loss_train, loss_dev

# %% [markdown]
# ## Convolutional Neural Network(Net 2 architecture) with data augmentation(horizontal flip)

# %%
#Convolutional Neural Network with data augmentation(horizontal flip)
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch_data_aug (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

#Plot a graph of the train vs test loss data:
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

#Save the loss output and test predictions to an excel file.
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net2_data_aug.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net2_data_aug_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# 0 Train loss:0.1225 Dev loss:0.1222 ratio train/dev:1.00
# 20 Train loss:0.0700 Dev loss:0.0694 ratio train/dev:1.01
# 40 Train loss:0.0654 Dev loss:0.0665 ratio train/dev:0.98
# 60 Train loss:0.0689 Dev loss:0.0660 ratio train/dev:1.04
# 80 Train loss:0.0676 Dev loss:0.0655 ratio train/dev:1.03
# 100 Train loss:0.0669 Dev loss:0.0653 ratio train/dev:1.02
# 120 Train loss:0.0637 Dev loss:0.0649 ratio train/dev:0.98
# 140 Train loss:0.0609 Dev loss:0.0645 ratio train/dev:0.94
# 160 Train loss:0.0685 Dev loss:0.0642 ratio train/dev:1.07
# 180 Train loss:0.0647 Dev loss:0.0638 ratio train/dev:1.01
# 200 Train loss:0.0640 Dev loss:0.0635 ratio train/dev:1.01
# 220 Train loss:0.0647 Dev loss:0.0630 ratio train/dev:1.03
# 240 Train loss:0.0592 Dev loss:0.0627 ratio train/dev:0.94
# 260 Train loss:0.0688 Dev loss:0.0623 ratio train/dev:1.10
# 280 Train loss:0.0597 Dev loss:0.0618 ratio train/dev:0.96
# 300 Train loss:0.0586 Dev loss:0.0615 ratio train/dev:0.95
# 320 Train loss:0.0540 Dev loss:0.0610 ratio train/dev:0.89
# 340 Train loss:0.0616 Dev loss:0.0606 ratio train/dev:1.02
# 360 Train loss:0.0578 Dev loss:0.0600 ratio train/dev:0.96
# 380 Train loss:0.0542 Dev loss:0.0596 ratio train/dev:0.91
# 400 Train loss:0.0561 Dev loss:0.0592 ratio train/dev:0.95
# 420 Train loss:0.0585 Dev loss:0.0587 ratio train/dev:1.00
# 440 Train loss:0.0564 Dev loss:0.0583 ratio train/dev:0.97
# 460 Train loss:0.0577 Dev loss:0.0579 ratio train/dev:1.00
# 480 Train loss:0.0580 Dev loss:0.0573 ratio train/dev:1.01
# 500 Train loss:0.0554 Dev loss:0.0571 ratio train/dev:0.97
# 520 Train loss:0.0559 Dev loss:0.0567 ratio train/dev:0.99
# 540 Train loss:0.0574 Dev loss:0.0564 ratio train/dev:1.02
# 560 Train loss:0.0549 Dev loss:0.0559 ratio train/dev:0.98
# 580 Train loss:0.0541 Dev loss:0.0557 ratio train/dev:0.97
# 600 Train loss:0.0555 Dev loss:0.0554 ratio train/dev:1.00
# 620 Train loss:0.0520 Dev loss:0.0552 ratio train/dev:0.94
# 640 Train loss:0.0503 Dev loss:0.0549 ratio train/dev:0.92
# 660 Train loss:0.0525 Dev loss:0.0549 ratio train/dev:0.96
# 680 Train loss:0.0515 Dev loss:0.0547 ratio train/dev:0.94
# 700 Train loss:0.0531 Dev loss:0.0545 ratio train/dev:0.97
# 720 Train loss:0.0514 Dev loss:0.0541 ratio train/dev:0.95
# 740 Train loss:0.0520 Dev loss:0.0541 ratio train/dev:0.96
# 760 Train loss:0.0481 Dev loss:0.0542 ratio train/dev:0.89
# 780 Train loss:0.0549 Dev loss:0.0536 ratio train/dev:1.03
# 800 Train loss:0.0527 Dev loss:0.0535 ratio train/dev:0.98
# 820 Train loss:0.0465 Dev loss:0.0537 ratio train/dev:0.87
# 840 Train loss:0.0468 Dev loss:0.0534 ratio train/dev:0.88
# 860 Train loss:0.0464 Dev loss:0.0532 ratio train/dev:0.87
# 880 Train loss:0.0451 Dev loss:0.0530 ratio train/dev:0.85
# 900 Train loss:0.0501 Dev loss:0.0530 ratio train/dev:0.95
# 920 Train loss:0.0522 Dev loss:0.0530 ratio train/dev:0.99
# 940 Train loss:0.0512 Dev loss:0.0529 ratio train/dev:0.97
# 960 Train loss:0.0454 Dev loss:0.0527 ratio train/dev:0.86
# 980 Train loss:0.0501 Dev loss:0.0526 ratio train/dev:0.95
# 1000 Train loss:0.0511 Dev loss:0.0525 ratio train/dev:0.97
# 1020 Train loss:0.0456 Dev loss:0.0526 ratio train/dev:0.87
# 1040 Train loss:0.0492 Dev loss:0.0524 ratio train/dev:0.94
# 1060 Train loss:0.0472 Dev loss:0.0523 ratio train/dev:0.90
# 1080 Train loss:0.0494 Dev loss:0.0523 ratio train/dev:0.94
# 1100 Train loss:0.0455 Dev loss:0.0522 ratio train/dev:0.87
# 1120 Train loss:0.0437 Dev loss:0.0524 ratio train/dev:0.84
# 1140 Train loss:0.0403 Dev loss:0.0521 ratio train/dev:0.77
# 1160 Train loss:0.0421 Dev loss:0.0521 ratio train/dev:0.81
# 1180 Train loss:0.0522 Dev loss:0.0520 ratio train/dev:1.00
# 1200 Train loss:0.0507 Dev loss:0.0519 ratio train/dev:0.98
# 1220 Train loss:0.0460 Dev loss:0.0521 ratio train/dev:0.88
# 1240 Train loss:0.0469 Dev loss:0.0517 ratio train/dev:0.91
# 1260 Train loss:0.0462 Dev loss:0.0517 ratio train/dev:0.89
# 1280 Train loss:0.0469 Dev loss:0.0518 ratio train/dev:0.91
# 1300 Train loss:0.0473 Dev loss:0.0517 ratio train/dev:0.92
# 1320 Train loss:0.0512 Dev loss:0.0516 ratio train/dev:0.99
# 1340 Train loss:0.0464 Dev loss:0.0519 ratio train/dev:0.89
# 1360 Train loss:0.0437 Dev loss:0.0516 ratio train/dev:0.85
# 1380 Train loss:0.0520 Dev loss:0.0514 ratio train/dev:1.01
# 1400 Train loss:0.0485 Dev loss:0.0516 ratio train/dev:0.94
# 1420 Train loss:0.0476 Dev loss:0.0516 ratio train/dev:0.92
# 1440 Train loss:0.0465 Dev loss:0.0514 ratio train/dev:0.91
# 1460 Train loss:0.0509 Dev loss:0.0514 ratio train/dev:0.99
# 1480 Train loss:0.0473 Dev loss:0.0514 ratio train/dev:0.92
# 1500 Train loss:0.0464 Dev loss:0.0513 ratio train/dev:0.90
# Total time taken: 4380.553019762039

# %% [markdown]
# ## CNN with data augmentation and increasing momentum(does not include horizontal flip)

# %%
#Tried a few variations. Only one variation is shown here. Output of the rest will be shown in the presentation.

np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    current_epoch = tf.Variable(0.0)
    m_min = 0.9
    m_max = 0.99
    momentum = m_min + (m_max-m_min)*current_epoch/n_epochs
    lr_min = 0.1
    lr_max = 0.3
    learning_rate = tf.train.exponential_decay(0.08, current_epoch, decay_steps=n_epochs, decay_rate=0.03)
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)
    

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    print('starting') 
    
    for epoch in range(n_epochs):
        loss_train,loss_dev = shuffle_run_batch_data_aug (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%20 == 0:
            m = momentum.eval(feed_dict = {current_epoch:epoch})
            lr = learning_rate.eval(feed_dict = {current_epoch:epoch})
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev),'momentum:%0.4f'%m,'learning rate:%0.4f'%lr)
            
        if (epoch+1)%200 == 0:
            train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
            with open('net2_data_aug_momentum_lr_change_2.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
            with open('net2_data_aug_momentum_lr_change_2_test_pred.csv','wb') as fs:
                np.savetxt(fs,y_pred,fmt = '%0.4f')
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

#Plot a graph of the train vs test loss data:
    
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# starting
# 0 Train loss:0.0819 Dev loss:0.0833 ratio train/dev:0.98 momentum:0.9000 learning rate:0.0800
# 20 Train loss:0.0645 Dev loss:0.0644 ratio train/dev:1.00 momentum:0.9012 learning rate:0.0763
# 40 Train loss:0.0598 Dev loss:0.0616 ratio train/dev:0.97 momentum:0.9024 learning rate:0.0729
# 60 Train loss:0.0606 Dev loss:0.0586 ratio train/dev:1.03 momentum:0.9036 learning rate:0.0695
# 80 Train loss:0.0562 Dev loss:0.0560 ratio train/dev:1.00 momentum:0.9048 learning rate:0.0664
# 100 Train loss:0.0546 Dev loss:0.0536 ratio train/dev:1.02 momentum:0.9060 learning rate:0.0633
# 120 Train loss:0.0494 Dev loss:0.0527 ratio train/dev:0.94 momentum:0.9072 learning rate:0.0604
# 140 Train loss:0.0456 Dev loss:0.0518 ratio train/dev:0.88 momentum:0.9084 learning rate:0.0577
# 160 Train loss:0.0542 Dev loss:0.0513 ratio train/dev:1.06 momentum:0.9096 learning rate:0.0551
# 180 Train loss:0.0504 Dev loss:0.0510 ratio train/dev:0.99 momentum:0.9108 learning rate:0.0525
# 200 Train loss:0.0499 Dev loss:0.0508 ratio train/dev:0.98 momentum:0.9120 learning rate:0.0501
# 220 Train loss:0.0481 Dev loss:0.0503 ratio train/dev:0.96 momentum:0.9132 learning rate:0.0479
# 240 Train loss:0.0416 Dev loss:0.0501 ratio train/dev:0.83 momentum:0.9144 learning rate:0.0457
# 260 Train loss:0.0518 Dev loss:0.0503 ratio train/dev:1.03 momentum:0.9156 learning rate:0.0436
# 280 Train loss:0.0431 Dev loss:0.0495 ratio train/dev:0.87 momentum:0.9168 learning rate:0.0416
# 300 Train loss:0.0439 Dev loss:0.0505 ratio train/dev:0.87 momentum:0.9180 learning rate:0.0397
# 320 Train loss:0.0395 Dev loss:0.0492 ratio train/dev:0.80 momentum:0.9192 learning rate:0.0379
# 340 Train loss:0.0460 Dev loss:0.0492 ratio train/dev:0.94 momentum:0.9204 learning rate:0.0362
# 360 Train loss:0.0425 Dev loss:0.0491 ratio train/dev:0.87 momentum:0.9216 learning rate:0.0345
# 380 Train loss:0.0417 Dev loss:0.0489 ratio train/dev:0.85 momentum:0.9228 learning rate:0.0329
# 400 Train loss:0.0430 Dev loss:0.0486 ratio train/dev:0.89 momentum:0.9240 learning rate:0.0314
# 420 Train loss:0.0431 Dev loss:0.0489 ratio train/dev:0.88 momentum:0.9252 learning rate:0.0300
# 440 Train loss:0.0447 Dev loss:0.0485 ratio train/dev:0.92 momentum:0.9264 learning rate:0.0286
# 460 Train loss:0.0443 Dev loss:0.0487 ratio train/dev:0.91 momentum:0.9276 learning rate:0.0273
# 480 Train loss:0.0440 Dev loss:0.0485 ratio train/dev:0.91 momentum:0.9288 learning rate:0.0261
# 500 Train loss:0.0423 Dev loss:0.0485 ratio train/dev:0.87 momentum:0.9300 learning rate:0.0249
# 520 Train loss:0.0422 Dev loss:0.0481 ratio train/dev:0.88 momentum:0.9312 learning rate:0.0237
# 540 Train loss:0.0452 Dev loss:0.0482 ratio train/dev:0.94 momentum:0.9324 learning rate:0.0227
# 560 Train loss:0.0448 Dev loss:0.0482 ratio train/dev:0.93 momentum:0.9336 learning rate:0.0216
# 580 Train loss:0.0434 Dev loss:0.0481 ratio train/dev:0.90 momentum:0.9348 learning rate:0.0206
# 600 Train loss:0.0438 Dev loss:0.0479 ratio train/dev:0.91 momentum:0.9360 learning rate:0.0197
# 620 Train loss:0.0422 Dev loss:0.0479 ratio train/dev:0.88 momentum:0.9372 learning rate:0.0188
# 640 Train loss:0.0395 Dev loss:0.0478 ratio train/dev:0.83 momentum:0.9384 learning rate:0.0179
# 660 Train loss:0.0405 Dev loss:0.0479 ratio train/dev:0.84 momentum:0.9396 learning rate:0.0171
# 680 Train loss:0.0414 Dev loss:0.0477 ratio train/dev:0.87 momentum:0.9408 learning rate:0.0163
# 700 Train loss:0.0451 Dev loss:0.0477 ratio train/dev:0.95 momentum:0.9420 learning rate:0.0156
# 720 Train loss:0.0428 Dev loss:0.0479 ratio train/dev:0.89 momentum:0.9432 learning rate:0.0149
# 740 Train loss:0.0421 Dev loss:0.0477 ratio train/dev:0.88 momentum:0.9444 learning rate:0.0142
# 760 Train loss:0.0366 Dev loss:0.0478 ratio train/dev:0.77 momentum:0.9456 learning rate:0.0136
# 780 Train loss:0.0433 Dev loss:0.0476 ratio train/dev:0.91 momentum:0.9468 learning rate:0.0129
# 800 Train loss:0.0441 Dev loss:0.0476 ratio train/dev:0.93 momentum:0.9480 learning rate:0.0123
# 820 Train loss:0.0372 Dev loss:0.0478 ratio train/dev:0.78 momentum:0.9492 learning rate:0.0118
# 840 Train loss:0.0376 Dev loss:0.0478 ratio train/dev:0.79 momentum:0.9504 learning rate:0.0112
# 860 Train loss:0.0376 Dev loss:0.0475 ratio train/dev:0.79 momentum:0.9516 learning rate:0.0107
# 880 Train loss:0.0367 Dev loss:0.0474 ratio train/dev:0.77 momentum:0.9528 learning rate:0.0102
# 900 Train loss:0.0403 Dev loss:0.0475 ratio train/dev:0.85 momentum:0.9540 learning rate:0.0098
# 920 Train loss:0.0437 Dev loss:0.0474 ratio train/dev:0.92 momentum:0.9552 learning rate:0.0093
# 940 Train loss:0.0412 Dev loss:0.0473 ratio train/dev:0.87 momentum:0.9564 learning rate:0.0089
# 960 Train loss:0.0369 Dev loss:0.0474 ratio train/dev:0.78 momentum:0.9576 learning rate:0.0085
# 980 Train loss:0.0425 Dev loss:0.0475 ratio train/dev:0.90 momentum:0.9588 learning rate:0.0081
# 1000 Train loss:0.0429 Dev loss:0.0476 ratio train/dev:0.90 momentum:0.9600 learning rate:0.0077
# 1020 Train loss:0.0362 Dev loss:0.0474 ratio train/dev:0.76 momentum:0.9612 learning rate:0.0074
# 1040 Train loss:0.0411 Dev loss:0.0473 ratio train/dev:0.87 momentum:0.9624 learning rate:0.0070
# 1060 Train loss:0.0387 Dev loss:0.0473 ratio train/dev:0.82 momentum:0.9636 learning rate:0.0067
# 1080 Train loss:0.0404 Dev loss:0.0476 ratio train/dev:0.85 momentum:0.9648 learning rate:0.0064
# 1100 Train loss:0.0355 Dev loss:0.0473 ratio train/dev:0.75 momentum:0.9660 learning rate:0.0061
# 1120 Train loss:0.0353 Dev loss:0.0473 ratio train/dev:0.75 momentum:0.9672 learning rate:0.0058
# 1140 Train loss:0.0328 Dev loss:0.0472 ratio train/dev:0.69 momentum:0.9684 learning rate:0.0056
# 1160 Train loss:0.0349 Dev loss:0.0472 ratio train/dev:0.74 momentum:0.9696 learning rate:0.0053
# 1180 Train loss:0.0424 Dev loss:0.0472 ratio train/dev:0.90 momentum:0.9708 learning rate:0.0051
# 1200 Train loss:0.0415 Dev loss:0.0473 ratio train/dev:0.88 momentum:0.9720 learning rate:0.0048
# 1220 Train loss:0.0370 Dev loss:0.0472 ratio train/dev:0.78 momentum:0.9732 learning rate:0.0046
# 1240 Train loss:0.0383 Dev loss:0.0474 ratio train/dev:0.81 momentum:0.9744 learning rate:0.0044
# 1260 Train loss:0.0370 Dev loss:0.0472 ratio train/dev:0.78 momentum:0.9755 learning rate:0.0042
# 1280 Train loss:0.0379 Dev loss:0.0472 ratio train/dev:0.80 momentum:0.9767 learning rate:0.0040
# 1300 Train loss:0.0391 Dev loss:0.0472 ratio train/dev:0.83 momentum:0.9779 learning rate:0.0038
# 1320 Train loss:0.0427 Dev loss:0.0471 ratio train/dev:0.91 momentum:0.9791 learning rate:0.0037
# 1340 Train loss:0.0382 Dev loss:0.0471 ratio train/dev:0.81 momentum:0.9803 learning rate:0.0035
# 1360 Train loss:0.0347 Dev loss:0.0470 ratio train/dev:0.74 momentum:0.9815 learning rate:0.0033
# 1380 Train loss:0.0432 Dev loss:0.0470 ratio train/dev:0.92 momentum:0.9827 learning rate:0.0032
# 1400 Train loss:0.0409 Dev loss:0.0471 ratio train/dev:0.87 momentum:0.9839 learning rate:0.0030
# 1420 Train loss:0.0396 Dev loss:0.0471 ratio train/dev:0.84 momentum:0.9851 learning rate:0.0029
# 1440 Train loss:0.0393 Dev loss:0.0471 ratio train/dev:0.83 momentum:0.9863 learning rate:0.0028
# 1460 Train loss:0.0431 Dev loss:0.0471 ratio train/dev:0.92 momentum:0.9875 learning rate:0.0026
# 1480 Train loss:0.0394 Dev loss:0.0471 ratio train/dev:0.84 momentum:0.9887 learning rate:0.0025
# 1500 Train loss:0.0394 Dev loss:0.0471 ratio train/dev:0.84 momentum:0.9899 learning rate:0.0024
# Total time taken: 4373.679690361023

# %% [markdown]
# ## CNN with Leaky Relu Activation (alpha = 0.05)

# %%
#Note - in order to run this - we have to uncomment the line layer = lrelu(layer) in function new_conv_relu_layer and new_fc_layer
# and comment the line: layer = tf.nn.relu(layer)
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    current_epoch = tf.Variable(0.0)
    momentum = 0.9
    learning_rate = 0.01
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
        if (epoch+1)%200 == 0:
            train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
            with open('net2_basic_leaky_relu_momentum3.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
                
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
            #Save the loss output and test predictions to an excel file.
    
    train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
    with open('net2_basic_leaky_relu_momentum3.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
    with open('net2_basic_leaky_relu_momentum3_test_pred','wb') as fs:
        np.savetxt(fs,y_pred,fmt = '%0.4f')

#Plot a graph of the train vs test loss data:    
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# 0 Train loss:0.1989 Dev loss:0.2000 ratio train/dev:0.99
# 20 Train loss:0.0727 Dev loss:0.0683 ratio train/dev:1.06
# 40 Train loss:0.0695 Dev loss:0.0656 ratio train/dev:1.06
# 60 Train loss:0.0644 Dev loss:0.0649 ratio train/dev:0.99
# 80 Train loss:0.0609 Dev loss:0.0643 ratio train/dev:0.95
# 100 Train loss:0.0589 Dev loss:0.0638 ratio train/dev:0.92
# 120 Train loss:0.0637 Dev loss:0.0631 ratio train/dev:1.01
# 140 Train loss:0.0652 Dev loss:0.0625 ratio train/dev:1.04
# 160 Train loss:0.0588 Dev loss:0.0618 ratio train/dev:0.95
# 180 Train loss:0.0607 Dev loss:0.0611 ratio train/dev:0.99
# 200 Train loss:0.0563 Dev loss:0.0605 ratio train/dev:0.93
# 220 Train loss:0.0630 Dev loss:0.0597 ratio train/dev:1.06
# 240 Train loss:0.0594 Dev loss:0.0588 ratio train/dev:1.01
# 260 Train loss:0.0527 Dev loss:0.0581 ratio train/dev:0.91
# 280 Train loss:0.0563 Dev loss:0.0572 ratio train/dev:0.98
# 300 Train loss:0.0530 Dev loss:0.0561 ratio train/dev:0.94
# 320 Train loss:0.0544 Dev loss:0.0551 ratio train/dev:0.99
# 340 Train loss:0.0534 Dev loss:0.0542 ratio train/dev:0.99
# 360 Train loss:0.0498 Dev loss:0.0532 ratio train/dev:0.94
# 380 Train loss:0.0501 Dev loss:0.0521 ratio train/dev:0.96
# 400 Train loss:0.0485 Dev loss:0.0512 ratio train/dev:0.95
# 420 Train loss:0.0465 Dev loss:0.0502 ratio train/dev:0.93
# 440 Train loss:0.0459 Dev loss:0.0494 ratio train/dev:0.93
# 460 Train loss:0.0450 Dev loss:0.0486 ratio train/dev:0.92
# 480 Train loss:0.0424 Dev loss:0.0480 ratio train/dev:0.88
# 500 Train loss:0.0481 Dev loss:0.0474 ratio train/dev:1.01
# 520 Train loss:0.0433 Dev loss:0.0468 ratio train/dev:0.93
# 540 Train loss:0.0423 Dev loss:0.0463 ratio train/dev:0.91
# 560 Train loss:0.0431 Dev loss:0.0459 ratio train/dev:0.94
# 580 Train loss:0.0420 Dev loss:0.0455 ratio train/dev:0.92
# 600 Train loss:0.0444 Dev loss:0.0451 ratio train/dev:0.98
# 620 Train loss:0.0400 Dev loss:0.0448 ratio train/dev:0.89
# 640 Train loss:0.0401 Dev loss:0.0446 ratio train/dev:0.90
# 660 Train loss:0.0397 Dev loss:0.0444 ratio train/dev:0.89
# 680 Train loss:0.0377 Dev loss:0.0440 ratio train/dev:0.86
# 700 Train loss:0.0379 Dev loss:0.0438 ratio train/dev:0.87
# 720 Train loss:0.0356 Dev loss:0.0436 ratio train/dev:0.82
# 740 Train loss:0.0337 Dev loss:0.0435 ratio train/dev:0.77
# 760 Train loss:0.0397 Dev loss:0.0432 ratio train/dev:0.92
# 780 Train loss:0.0336 Dev loss:0.0431 ratio train/dev:0.78
# 800 Train loss:0.0365 Dev loss:0.0429 ratio train/dev:0.85
# 820 Train loss:0.0339 Dev loss:0.0427 ratio train/dev:0.79
# 840 Train loss:0.0357 Dev loss:0.0426 ratio train/dev:0.84
# 860 Train loss:0.0368 Dev loss:0.0424 ratio train/dev:0.87
# 880 Train loss:0.0373 Dev loss:0.0423 ratio train/dev:0.88
# 900 Train loss:0.0355 Dev loss:0.0422 ratio train/dev:0.84
# 920 Train loss:0.0334 Dev loss:0.0421 ratio train/dev:0.79
# 940 Train loss:0.0347 Dev loss:0.0420 ratio train/dev:0.83
# 960 Train loss:0.0321 Dev loss:0.0420 ratio train/dev:0.76
# 980 Train loss:0.0335 Dev loss:0.0418 ratio train/dev:0.80
# 1000 Train loss:0.0361 Dev loss:0.0417 ratio train/dev:0.87
# 1020 Train loss:0.0332 Dev loss:0.0416 ratio train/dev:0.80
# 1040 Train loss:0.0305 Dev loss:0.0416 ratio train/dev:0.73
# 1060 Train loss:0.0349 Dev loss:0.0414 ratio train/dev:0.84
# 1080 Train loss:0.0327 Dev loss:0.0414 ratio train/dev:0.79
# 1100 Train loss:0.0344 Dev loss:0.0413 ratio train/dev:0.83
# 1120 Train loss:0.0300 Dev loss:0.0412 ratio train/dev:0.73
# 1140 Train loss:0.0316 Dev loss:0.0411 ratio train/dev:0.77
# 1160 Train loss:0.0327 Dev loss:0.0411 ratio train/dev:0.80
# 1180 Train loss:0.0289 Dev loss:0.0410 ratio train/dev:0.70
# 1200 Train loss:0.0297 Dev loss:0.0410 ratio train/dev:0.72
# 1220 Train loss:0.0285 Dev loss:0.0410 ratio train/dev:0.70
# 1240 Train loss:0.0296 Dev loss:0.0408 ratio train/dev:0.73
# 1260 Train loss:0.0318 Dev loss:0.0408 ratio train/dev:0.78
# 1280 Train loss:0.0323 Dev loss:0.0408 ratio train/dev:0.79
# 1300 Train loss:0.0311 Dev loss:0.0407 ratio train/dev:0.76
# 1320 Train loss:0.0306 Dev loss:0.0407 ratio train/dev:0.75
# 1340 Train loss:0.0295 Dev loss:0.0407 ratio train/dev:0.73
# 1360 Train loss:0.0292 Dev loss:0.0406 ratio train/dev:0.72
# 1380 Train loss:0.0268 Dev loss:0.0405 ratio train/dev:0.66
# 1400 Train loss:0.0292 Dev loss:0.0405 ratio train/dev:0.72
# 1420 Train loss:0.0298 Dev loss:0.0404 ratio train/dev:0.74
# 1440 Train loss:0.0284 Dev loss:0.0404 ratio train/dev:0.70
# 1460 Train loss:0.0268 Dev loss:0.0404 ratio train/dev:0.66
# 1480 Train loss:0.0293 Dev loss:0.0404 ratio train/dev:0.73
# 1500 Train loss:0.0259 Dev loss:0.0403 ratio train/dev:0.64
# Total time taken: 4373.5466504096985

# %% [markdown]
# Helper Function to create CNN with different filter sizes as parameters

# %%
#Function to create CNN with filter sizes as parameters
def createCNN(input,i,filter_size1=3,filter_size2=2,filter_size3=2):
    np.random.seed(1)
    #First convolutional layer
    with tf.variable_scope('conv1'+str(i)):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'+str(i)):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'+str(i)):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'+str(i)):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'+str(i)):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'+str(i)):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6) 
    return layer_f6

# %% [markdown]
# ## Trying different CNN filter sizes.
# Filter sizes (convolution layer1,2,3) of (3,2,2),(8,4,2),(20,10,2),(2,4,8),(4,12,2)
# Concept is to try different filter sizers, and also different ordering of the filter sizes

# %%
#trying different CNN filter sizes.
#Trying filter sizes (convolution layer1,2,3) of (3,2,2),(8,4,2),(20,10,2),(2,4,8),(4,12,2)
#Concept is to try different filter sizers, and also different ordering of the filter sizes
graph_base = tf.Graph()
n_epochs = 251 #Using fewer epochs to do coarse testing of several options. Should test with around 300-400 epochs
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1])
    
    best_loss = 0.2
    best_filter = np.array((3,2,2))
    filters = np.array(((3,2,2),(8,4,2),(20,10,2),(2,4,8),(4,12,2)))
    print('number of filter variations:',filters.shape[0])
    train_loss_data = np.zeros((n_epochs,filters.shape[0]+1))
    dev_loss_data = np.zeros((n_epochs,filters.shape[0]+1))
    
    for i in range(filters.shape[0]):
       
        filter_size1 = filters[i,0]         
        filter_size2 = filters[i,1]         
        filter_size3 = filters[i,2]  
        print('convolution filters',filter_size1,filter_size2,filter_size3)

        layer_f6 = createCNN(x_image,i,filter_size1,filter_size2,filter_size3)
        
        #loss function
        with tf.name_scope('loss'):
            loss = tf.reduce_mean(np.square(layer_f6 - y))
            sqrt_loss = tf.sqrt(loss)

        #for tensorboard
        with tf.name_scope('summaries'):
            sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


        # optimizer
        current_epoch = tf.Variable(0.0)
        m_min = 0.9
        m_max = 0.99
        momentum = m_min + (m_max-m_min)*current_epoch/n_epochs
        lr_min = 0.1
        lr_max = 0.3
        #Note set initial learning rate to 0.06
        learning_rate = tf.train.exponential_decay(0.06, current_epoch, decay_steps=n_epochs, decay_rate=0.03)
        optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

        y_pred = np.zeros((x_test.shape[0],y.shape[1]))

        # logger
        if tensorboard_log:
            train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
            dev_writer =  tf.summary.FileWriter(logdir + '/dev')


        time_start = time.time()
        time_1000_start = time.time()


        with tf.Session(graph=graph_base) as sess:
            sess.run(tf.global_variables_initializer())
            print('starting') 

            for epoch in range(n_epochs):

                loss_train,loss_dev = shuffle_run_batch(x_train, y_train, x_dev, y_dev, batch_size, epoch)

                train_loss_data[epoch,0] = epoch
                dev_loss_data[epoch,0] = epoch
                train_loss_data[epoch,i+1] = np.sqrt(loss_train)
                dev_loss_data[epoch,i+1] = np.sqrt(loss_dev)

                if epoch%10 == 0:
                    m = momentum.eval(feed_dict = {current_epoch:epoch})
                    lr = learning_rate.eval(feed_dict = {current_epoch:epoch})
                    print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                          'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev),'momentum:%0.4f'%m,'learning rate:%0.4f'%lr)
                    
            if loss_dev < best_loss:
                best_loss = loss_dev
                best_filter = np.array((filter_size1,filter_size2,filter_size3))
                print('best filter:',best_filter.shape,best_filter)

            time_end = time.time()
            print('Total time taken for filter %d:'%i,time_end-time_start)
    
            for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
                    X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
                    y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
                    
        
    train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
    with open('net2_cnn_filter_sizes2.csv', 'wb') as fp:
        np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
    
    #Plot a graph of the train vs test loss data:
    plot_loss(train_loss_data, dev_loss_data) #need to figure a way to plot all the losses for all variations

    if tensorboard_log:
        train_writer.close()
        dev_writer.close()
# Out:
# number of filter variations: 5
# convolution filters 3 2 2
# starting
# 0 Train loss:0.0836 Dev loss:0.0807 ratio train/dev:1.04 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0681 Dev loss:0.0654 ratio train/dev:1.04 momentum:0.9036 learning rate:0.0522
# 20 Train loss:0.0680 Dev loss:0.0644 ratio train/dev:1.06 momentum:0.9072 learning rate:0.0454
# 30 Train loss:0.0684 Dev loss:0.0627 ratio train/dev:1.09 momentum:0.9108 learning rate:0.0395
# 40 Train loss:0.0630 Dev loss:0.0607 ratio train/dev:1.04 momentum:0.9143 learning rate:0.0343
# 50 Train loss:0.0557 Dev loss:0.0583 ratio train/dev:0.96 momentum:0.9179 learning rate:0.0298
# 60 Train loss:0.0545 Dev loss:0.0555 ratio train/dev:0.98 momentum:0.9215 learning rate:0.0259
# 70 Train loss:0.0518 Dev loss:0.0523 ratio train/dev:0.99 momentum:0.9251 learning rate:0.0226
# 80 Train loss:0.0441 Dev loss:0.0497 ratio train/dev:0.89 momentum:0.9287 learning rate:0.0196
# 90 Train loss:0.0468 Dev loss:0.0478 ratio train/dev:0.98 momentum:0.9323 learning rate:0.0171
# 100 Train loss:0.0376 Dev loss:0.0462 ratio train/dev:0.81 momentum:0.9359 learning rate:0.0148
# 110 Train loss:0.0389 Dev loss:0.0452 ratio train/dev:0.86 momentum:0.9394 learning rate:0.0129
# 120 Train loss:0.0399 Dev loss:0.0445 ratio train/dev:0.89 momentum:0.9430 learning rate:0.0112
# 130 Train loss:0.0404 Dev loss:0.0436 ratio train/dev:0.93 momentum:0.9466 learning rate:0.0098
# 140 Train loss:0.0384 Dev loss:0.0429 ratio train/dev:0.90 momentum:0.9502 learning rate:0.0085
# 150 Train loss:0.0340 Dev loss:0.0427 ratio train/dev:0.79 momentum:0.9538 learning rate:0.0074
# 160 Train loss:0.0345 Dev loss:0.0421 ratio train/dev:0.82 momentum:0.9574 learning rate:0.0064
# 170 Train loss:0.0335 Dev loss:0.0416 ratio train/dev:0.81 momentum:0.9610 learning rate:0.0056
# 180 Train loss:0.0325 Dev loss:0.0412 ratio train/dev:0.79 momentum:0.9645 learning rate:0.0049
# 190 Train loss:0.0319 Dev loss:0.0409 ratio train/dev:0.78 momentum:0.9681 learning rate:0.0042
# 200 Train loss:0.0308 Dev loss:0.0408 ratio train/dev:0.75 momentum:0.9717 learning rate:0.0037
# 210 Train loss:0.0324 Dev loss:0.0407 ratio train/dev:0.80 momentum:0.9753 learning rate:0.0032
# 220 Train loss:0.0319 Dev loss:0.0406 ratio train/dev:0.79 momentum:0.9789 learning rate:0.0028
# 230 Train loss:0.0283 Dev loss:0.0402 ratio train/dev:0.70 momentum:0.9825 learning rate:0.0024
# 240 Train loss:0.0285 Dev loss:0.0405 ratio train/dev:0.70 momentum:0.9861 learning rate:0.0021
# 250 Train loss:0.0290 Dev loss:0.0403 ratio train/dev:0.72 momentum:0.9896 learning rate:0.0018
# best filter: (3,) [3 2 2]
# Total time taken for filter 0: 747.9435045719147
# convolution filters 8 4 2
# starting
# 0 Train loss:0.0846 Dev loss:0.0816 ratio train/dev:1.04 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0669 Dev loss:0.0643 ratio train/dev:1.04 momentum:0.9036 learning rate:0.0522
# 20 Train loss:0.0654 Dev loss:0.0620 ratio train/dev:1.06 momentum:0.9072 learning rate:0.0454
# 30 Train loss:0.0628 Dev loss:0.0589 ratio train/dev:1.07 momentum:0.9108 learning rate:0.0395
# 40 Train loss:0.0559 Dev loss:0.0548 ratio train/dev:1.02 momentum:0.9143 learning rate:0.0343
# 50 Train loss:0.0469 Dev loss:0.0509 ratio train/dev:0.92 momentum:0.9179 learning rate:0.0298
# 60 Train loss:0.0456 Dev loss:0.0478 ratio train/dev:0.95 momentum:0.9215 learning rate:0.0259
# 70 Train loss:0.0428 Dev loss:0.0460 ratio train/dev:0.93 momentum:0.9251 learning rate:0.0226
# 80 Train loss:0.0367 Dev loss:0.0450 ratio train/dev:0.82 momentum:0.9287 learning rate:0.0196
# 90 Train loss:0.0428 Dev loss:0.0481 ratio train/dev:0.89 momentum:0.9323 learning rate:0.0171
# 100 Train loss:0.0326 Dev loss:0.0430 ratio train/dev:0.76 momentum:0.9359 learning rate:0.0148
# 110 Train loss:0.0339 Dev loss:0.0425 ratio train/dev:0.80 momentum:0.9394 learning rate:0.0129
# 120 Train loss:0.0337 Dev loss:0.0420 ratio train/dev:0.80 momentum:0.9430 learning rate:0.0112
# 130 Train loss:0.0348 Dev loss:0.0415 ratio train/dev:0.84 momentum:0.9466 learning rate:0.0098
# 140 Train loss:0.0342 Dev loss:0.0411 ratio train/dev:0.83 momentum:0.9502 learning rate:0.0085
# 150 Train loss:0.0303 Dev loss:0.0415 ratio train/dev:0.73 momentum:0.9538 learning rate:0.0074
# 160 Train loss:0.0310 Dev loss:0.0410 ratio train/dev:0.76 momentum:0.9574 learning rate:0.0064
# 170 Train loss:0.0293 Dev loss:0.0403 ratio train/dev:0.73 momentum:0.9610 learning rate:0.0056
# 180 Train loss:0.0293 Dev loss:0.0403 ratio train/dev:0.73 momentum:0.9645 learning rate:0.0049
# 190 Train loss:0.0279 Dev loss:0.0401 ratio train/dev:0.70 momentum:0.9681 learning rate:0.0042
# 200 Train loss:0.0276 Dev loss:0.0399 ratio train/dev:0.69 momentum:0.9717 learning rate:0.0037
# 210 Train loss:0.0292 Dev loss:0.0398 ratio train/dev:0.73 momentum:0.9753 learning rate:0.0032
# 220 Train loss:0.0271 Dev loss:0.0395 ratio train/dev:0.69 momentum:0.9789 learning rate:0.0028
# 230 Train loss:0.0249 Dev loss:0.0401 ratio train/dev:0.62 momentum:0.9825 learning rate:0.0024
# 240 Train loss:0.0245 Dev loss:0.0394 ratio train/dev:0.62 momentum:0.9861 learning rate:0.0021
# 250 Train loss:0.0249 Dev loss:0.0392 ratio train/dev:0.64 momentum:0.9896 learning rate:0.0018
# best filter: (3,) [8 4 2]
# Total time taken for filter 1: 869.8162658214569
# convolution filters 20 10 2
# starting
# 0 Train loss:0.1110 Dev loss:0.1083 ratio train/dev:1.02 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0635 Dev loss:0.0621 ratio train/dev:1.02 momentum:0.9036 learning rate:0.0522
# 20 Train loss:0.0625 Dev loss:0.0605 ratio train/dev:1.03 momentum:0.9072 learning rate:0.0454
# 30 Train loss:0.0601 Dev loss:0.0594 ratio train/dev:1.01 momentum:0.9108 learning rate:0.0395
# 40 Train loss:0.0550 Dev loss:0.0541 ratio train/dev:1.02 momentum:0.9143 learning rate:0.0343
# 50 Train loss:0.0476 Dev loss:0.0504 ratio train/dev:0.94 momentum:0.9179 learning rate:0.0298
# 60 Train loss:0.0470 Dev loss:0.0487 ratio train/dev:0.97 momentum:0.9215 learning rate:0.0259
# 70 Train loss:0.0463 Dev loss:0.0474 ratio train/dev:0.98 momentum:0.9251 learning rate:0.0226
# 80 Train loss:0.0383 Dev loss:0.0466 ratio train/dev:0.82 momentum:0.9287 learning rate:0.0196
# 90 Train loss:0.0447 Dev loss:0.0489 ratio train/dev:0.91 momentum:0.9323 learning rate:0.0171
# 100 Train loss:0.0350 Dev loss:0.0449 ratio train/dev:0.78 momentum:0.9359 learning rate:0.0148
# 110 Train loss:0.0370 Dev loss:0.0444 ratio train/dev:0.83 momentum:0.9394 learning rate:0.0129
# 120 Train loss:0.0378 Dev loss:0.0443 ratio train/dev:0.85 momentum:0.9430 learning rate:0.0112
# 130 Train loss:0.0369 Dev loss:0.0437 ratio train/dev:0.84 momentum:0.9466 learning rate:0.0098
# 140 Train loss:0.0368 Dev loss:0.0432 ratio train/dev:0.85 momentum:0.9502 learning rate:0.0085
# 150 Train loss:0.0329 Dev loss:0.0439 ratio train/dev:0.75 momentum:0.9538 learning rate:0.0074
# 160 Train loss:0.0343 Dev loss:0.0426 ratio train/dev:0.81 momentum:0.9574 learning rate:0.0064
# 170 Train loss:0.0316 Dev loss:0.0432 ratio train/dev:0.73 momentum:0.9610 learning rate:0.0056
# 180 Train loss:0.0328 Dev loss:0.0425 ratio train/dev:0.77 momentum:0.9645 learning rate:0.0049
# 190 Train loss:0.0301 Dev loss:0.0420 ratio train/dev:0.72 momentum:0.9681 learning rate:0.0042
# 200 Train loss:0.0288 Dev loss:0.0417 ratio train/dev:0.69 momentum:0.9717 learning rate:0.0037
# 210 Train loss:0.0309 Dev loss:0.0415 ratio train/dev:0.74 momentum:0.9753 learning rate:0.0032
# 220 Train loss:0.0290 Dev loss:0.0417 ratio train/dev:0.70 momentum:0.9789 learning rate:0.0028
# 230 Train loss:0.0273 Dev loss:0.0416 ratio train/dev:0.66 momentum:0.9825 learning rate:0.0024
# 240 Train loss:0.0283 Dev loss:0.0415 ratio train/dev:0.68 momentum:0.9861 learning rate:0.0021
# 250 Train loss:0.0269 Dev loss:0.0413 ratio train/dev:0.65 momentum:0.9896 learning rate:0.0018
# Total time taken for filter 2: 1380.4488117694855
# convolution filters 2 4 8
# starting
# 0 Train loss:0.0878 Dev loss:0.0854 ratio train/dev:1.03 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0680 Dev loss:0.0655 ratio train/dev:1.04 momentum:0.9036 learning rate:0.0522
# 20 Train loss:0.0681 Dev loss:0.0647 ratio train/dev:1.05 momentum:0.9072 learning rate:0.0454
# 30 Train loss:0.0688 Dev loss:0.0633 ratio train/dev:1.09 momentum:0.9108 learning rate:0.0395
# 40 Train loss:0.0635 Dev loss:0.0613 ratio train/dev:1.04 momentum:0.9143 learning rate:0.0343
# 50 Train loss:0.0561 Dev loss:0.0590 ratio train/dev:0.95 momentum:0.9179 learning rate:0.0298
# 60 Train loss:0.0545 Dev loss:0.0562 ratio train/dev:0.97 momentum:0.9215 learning rate:0.0259
# 70 Train loss:0.0520 Dev loss:0.0529 ratio train/dev:0.98 momentum:0.9251 learning rate:0.0226
# 80 Train loss:0.0438 Dev loss:0.0502 ratio train/dev:0.87 momentum:0.9287 learning rate:0.0196
# 90 Train loss:0.0501 Dev loss:0.0529 ratio train/dev:0.95 momentum:0.9323 learning rate:0.0171
# 100 Train loss:0.0376 Dev loss:0.0465 ratio train/dev:0.81 momentum:0.9359 learning rate:0.0148
# 110 Train loss:0.0382 Dev loss:0.0454 ratio train/dev:0.84 momentum:0.9394 learning rate:0.0129
# 120 Train loss:0.0391 Dev loss:0.0445 ratio train/dev:0.88 momentum:0.9430 learning rate:0.0112
# 130 Train loss:0.0391 Dev loss:0.0439 ratio train/dev:0.89 momentum:0.9466 learning rate:0.0098
# 140 Train loss:0.0380 Dev loss:0.0429 ratio train/dev:0.89 momentum:0.9502 learning rate:0.0085
# 150 Train loss:0.0336 Dev loss:0.0430 ratio train/dev:0.78 momentum:0.9538 learning rate:0.0074
# 160 Train loss:0.0339 Dev loss:0.0425 ratio train/dev:0.80 momentum:0.9574 learning rate:0.0064
# 170 Train loss:0.0320 Dev loss:0.0418 ratio train/dev:0.76 momentum:0.9610 learning rate:0.0056
# 180 Train loss:0.0324 Dev loss:0.0417 ratio train/dev:0.78 momentum:0.9645 learning rate:0.0049
# 190 Train loss:0.0301 Dev loss:0.0410 ratio train/dev:0.73 momentum:0.9681 learning rate:0.0042
# 200 Train loss:0.0299 Dev loss:0.0410 ratio train/dev:0.73 momentum:0.9717 learning rate:0.0037
# 210 Train loss:0.0308 Dev loss:0.0405 ratio train/dev:0.76 momentum:0.9753 learning rate:0.0032
# 220 Train loss:0.0293 Dev loss:0.0404 ratio train/dev:0.72 momentum:0.9789 learning rate:0.0028
# 230 Train loss:0.0269 Dev loss:0.0404 ratio train/dev:0.67 momentum:0.9825 learning rate:0.0024
# 240 Train loss:0.0270 Dev loss:0.0401 ratio train/dev:0.67 momentum:0.9861 learning rate:0.0021
# 250 Train loss:0.0278 Dev loss:0.0404 ratio train/dev:0.69 momentum:0.9896 learning rate:0.0018
# Total time taken for filter 3: 907.1492688655853
# convolution filters 4 12 2
# starting
# 0 Train loss:0.0901 Dev loss:0.0878 ratio train/dev:1.03 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0683 Dev loss:0.0658 ratio train/dev:1.04 momentum:0.9036 learning rate:0.0522
# 20 Train loss:0.0683 Dev loss:0.0649 ratio train/dev:1.05 momentum:0.9072 learning rate:0.0454
# 30 Train loss:0.0683 Dev loss:0.0632 ratio train/dev:1.08 momentum:0.9108 learning rate:0.0395
# 40 Train loss:0.0633 Dev loss:0.0611 ratio train/dev:1.04 momentum:0.9143 learning rate:0.0343
# 50 Train loss:0.0557 Dev loss:0.0587 ratio train/dev:0.95 momentum:0.9179 learning rate:0.0298
# 60 Train loss:0.0545 Dev loss:0.0560 ratio train/dev:0.97 momentum:0.9215 learning rate:0.0259
# 70 Train loss:0.0510 Dev loss:0.0520 ratio train/dev:0.98 momentum:0.9251 learning rate:0.0226
# 80 Train loss:0.0426 Dev loss:0.0497 ratio train/dev:0.86 momentum:0.9287 learning rate:0.0196
# 90 Train loss:0.0488 Dev loss:0.0520 ratio train/dev:0.94 momentum:0.9323 learning rate:0.0171
# 100 Train loss:0.0376 Dev loss:0.0464 ratio train/dev:0.81 momentum:0.9359 learning rate:0.0148
# 110 Train loss:0.0381 Dev loss:0.0455 ratio train/dev:0.84 momentum:0.9394 learning rate:0.0129
# 120 Train loss:0.0397 Dev loss:0.0447 ratio train/dev:0.89 momentum:0.9430 learning rate:0.0112
# 130 Train loss:0.0391 Dev loss:0.0441 ratio train/dev:0.89 momentum:0.9466 learning rate:0.0098
# 140 Train loss:0.0384 Dev loss:0.0434 ratio train/dev:0.89 momentum:0.9502 learning rate:0.0085
# 150 Train loss:0.0343 Dev loss:0.0442 ratio train/dev:0.78 momentum:0.9538 learning rate:0.0074
# 160 Train loss:0.0342 Dev loss:0.0428 ratio train/dev:0.80 momentum:0.9574 learning rate:0.0064
# 170 Train loss:0.0325 Dev loss:0.0430 ratio train/dev:0.76 momentum:0.9610 learning rate:0.0056
# 180 Train loss:0.0335 Dev loss:0.0429 ratio train/dev:0.78 momentum:0.9645 learning rate:0.0049
# 190 Train loss:0.0307 Dev loss:0.0420 ratio train/dev:0.73 momentum:0.9681 learning rate:0.0042
# 200 Train loss:0.0286 Dev loss:0.0412 ratio train/dev:0.69 momentum:0.9717 learning rate:0.0037
# 210 Train loss:0.0318 Dev loss:0.0416 ratio train/dev:0.76 momentum:0.9753 learning rate:0.0032
# 220 Train loss:0.0295 Dev loss:0.0408 ratio train/dev:0.72 momentum:0.9789 learning rate:0.0028
# 230 Train loss:0.0269 Dev loss:0.0410 ratio train/dev:0.65 momentum:0.9825 learning rate:0.0024
# 240 Train loss:0.0275 Dev loss:0.0409 ratio train/dev:0.67 momentum:0.9861 learning rate:0.0021
# 250 Train loss:0.0272 Dev loss:0.0407 ratio train/dev:0.67 momentum:0.9896 learning rate:0.0018
# Total time taken for filter 4: 948.9265310764313

# %% [markdown]
# # Individual Facial Parts Models

# %% [markdown]
# ## Individual model settings
#
# On examining the number of datapoints available for each feature, individual models are made by grouping similar features based on number of data points availabe. the main idea being to maximize use of data. Below is the reasoning behind combining different labels.
#
# 1. First I considered putting all eye data into one model, but as we can see above that left_eye_center_x, left_eye_center_y, right_eye_center_x , right_eye_center_y have more than 7000 data points while the remining
# eye data points only have 2267 - 2271 data points. So eye data points have been split into two models namely eye center and eye corner.
# left_eye_center_x            7039
# left_eye_center_y            7039
# right_eye_center_x           7036
# right_eye_center_y           7036
#
# #### Facial_group_models - Thirty keypoints have been grouped in six types to create specialized models
# #### These specialized models are eye_center, eye_corners, nose_tip, mouth_corner_top, mouth_bottom and eyebrow.

# %% [markdown]
# Net 2 as baseline and starting point for net 3
# Adds functionality to save the weights so they can be used to initialize the individual models in net3

# %%
#Net 2 as baseline and starting point for net 3
np.random.seed(1)
graph_base = tf.Graph()
n_epochs = 2001 # resetting n_epochs back to max after testing different filter sizes. needs to be consistent for this and net 3.
#changing keep_prob values
dropout_keep_prob1 = 1.0
dropout_keep_prob2 = 1.0
dropout_keep_prob3 = 1.0
dropout_keep_prob4 = 0.7
dropout_keep_prob5 = 0.7
#Setting filters to best value from trying with net 2
num_filters1 = 3
num_filters2 = 2
num_filters3 = 2

with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)
    
    current_epoch = tf.Variable(0)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    current_epoch = tf.Variable(0.0)
    m_min = 0.9
    m_max = 0.99
    momentum = m_min + (m_max-m_min)*current_epoch/n_epochs
    lr_min = 0.01
    lr_max = 0.03
    learning_rate = tf.train.exponential_decay(0.03, current_epoch, decay_steps=n_epochs, decay_rate=0.03)
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    #for saving model 
    saver = tf.train.Saver()
    
    print('starting')
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch(x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            m = momentum.eval(feed_dict = {current_epoch:epoch})
            lr = learning_rate.eval(feed_dict = {current_epoch:epoch})
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                          'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev),'momentum:%0.4f'%m,'learning rate:%0.4f'%lr)
                    
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    #Code to save models for future use
    #please give any unique name you want to give to the model for testing various paramaters.
    #It wil get appended to "basic_conv_net"
    unique_name = ""
    model_name = "basic_conv_net_" + unique_name
    model_path =  FROOT + "/models/"+ model_name + "/model.ckpt"
    train_history_path = FROOT + "/models/" + model_name + "/train_history"
    save_path = saver.save(sess, model_path)
    print("Model file: " + save_path)
    np.savez(train_history_path, train_loss_history = train_loss_data, valid_loss_history = dev_loss_data)
    print("Train history file: " + train_history_path)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
    print('done')

#Plot a graph of the train vs test loss data:
    

plot_loss (train_loss_data, dev_loss_data)
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net2_baseline_for_net3.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net2_baseline_for_net3_test_pred.csv','wb') as fs:
        np.savetxt(fs,y_pred,fmt = '%0.4f')

if tensorboard_log:
    train_writer.close()
    dev_writer.close()

plot_pred (x_test, y_pred)
# Out:
# starting
# 0 Train loss:0.1330 Dev loss:0.0952 ratio train/dev:1.40 momentum:0.9000 learning rate:0.0300
# 20 Train loss:0.0824 Dev loss:0.0668 ratio train/dev:1.23 momentum:0.9009 learning rate:0.0290
# 40 Train loss:0.0762 Dev loss:0.0665 ratio train/dev:1.15 momentum:0.9018 learning rate:0.0280
# 60 Train loss:0.0707 Dev loss:0.0661 ratio train/dev:1.07 momentum:0.9027 learning rate:0.0270
# 80 Train loss:0.0678 Dev loss:0.0661 ratio train/dev:1.03 momentum:0.9036 learning rate:0.0261
# 100 Train loss:0.0648 Dev loss:0.0658 ratio train/dev:0.99 momentum:0.9045 learning rate:0.0252
# 120 Train loss:0.0701 Dev loss:0.0656 ratio train/dev:1.07 momentum:0.9054 learning rate:0.0243
# 140 Train loss:0.0710 Dev loss:0.0654 ratio train/dev:1.08 momentum:0.9063 learning rate:0.0235
# 160 Train loss:0.0642 Dev loss:0.0652 ratio train/dev:0.98 momentum:0.9072 learning rate:0.0227
# 180 Train loss:0.0666 Dev loss:0.0650 ratio train/dev:1.03 momentum:0.9081 learning rate:0.0219
# 200 Train loss:0.0638 Dev loss:0.0647 ratio train/dev:0.98 momentum:0.9090 learning rate:0.0211
# 220 Train loss:0.0719 Dev loss:0.0644 ratio train/dev:1.12 momentum:0.9099 learning rate:0.0204
# 240 Train loss:0.0671 Dev loss:0.0641 ratio train/dev:1.05 momentum:0.9108 learning rate:0.0197
# 260 Train loss:0.0607 Dev loss:0.0636 ratio train/dev:0.95 momentum:0.9117 learning rate:0.0190
# 280 Train loss:0.0649 Dev loss:0.0632 ratio train/dev:1.03 momentum:0.9126 learning rate:0.0184
# 300 Train loss:0.0630 Dev loss:0.0625 ratio train/dev:1.01 momentum:0.9135 learning rate:0.0177
# 320 Train loss:0.0651 Dev loss:0.0619 ratio train/dev:1.05 momentum:0.9144 learning rate:0.0171
# 340 Train loss:0.0641 Dev loss:0.0611 ratio train/dev:1.05 momentum:0.9153 learning rate:0.0165
# 360 Train loss:0.0606 Dev loss:0.0603 ratio train/dev:1.01 momentum:0.9162 learning rate:0.0160
# 380 Train loss:0.0623 Dev loss:0.0594 ratio train/dev:1.05 momentum:0.9171 learning rate:0.0154
# 400 Train loss:0.0620 Dev loss:0.0586 ratio train/dev:1.06 momentum:0.9180 learning rate:0.0149
# 420 Train loss:0.0607 Dev loss:0.0577 ratio train/dev:1.05 momentum:0.9189 learning rate:0.0144
# 440 Train loss:0.0577 Dev loss:0.0568 ratio train/dev:1.01 momentum:0.9198 learning rate:0.0139
# 460 Train loss:0.0565 Dev loss:0.0560 ratio train/dev:1.01 momentum:0.9207 learning rate:0.0134
# 480 Train loss:0.0564 Dev loss:0.0553 ratio train/dev:1.02 momentum:0.9216 learning rate:0.0129
# 500 Train loss:0.0613 Dev loss:0.0546 ratio train/dev:1.12 momentum:0.9225 learning rate:0.0125
# 520 Train loss:0.0555 Dev loss:0.0539 ratio train/dev:1.03 momentum:0.9234 learning rate:0.0121
# 540 Train loss:0.0566 Dev loss:0.0533 ratio train/dev:1.06 momentum:0.9243 learning rate:0.0116
# 560 Train loss:0.0561 Dev loss:0.0528 ratio train/dev:1.06 momentum:0.9252 learning rate:0.0112
# 580 Train loss:0.0559 Dev loss:0.0523 ratio train/dev:1.07 momentum:0.9261 learning rate:0.0109
# 600 Train loss:0.0578 Dev loss:0.0518 ratio train/dev:1.12 momentum:0.9270 learning rate:0.0105
# 620 Train loss:0.0540 Dev loss:0.0514 ratio train/dev:1.05 momentum:0.9279 learning rate:0.0101
# 640 Train loss:0.0555 Dev loss:0.0509 ratio train/dev:1.09 momentum:0.9288 learning rate:0.0098
# 660 Train loss:0.0539 Dev loss:0.0505 ratio train/dev:1.07 momentum:0.9297 learning rate:0.0094
# 680 Train loss:0.0521 Dev loss:0.0502 ratio train/dev:1.04 momentum:0.9306 learning rate:0.0091
# 700 Train loss:0.0520 Dev loss:0.0498 ratio train/dev:1.04 momentum:0.9315 learning rate:0.0088
# 720 Train loss:0.0479 Dev loss:0.0495 ratio train/dev:0.97 momentum:0.9324 learning rate:0.0085
# 740 Train loss:0.0479 Dev loss:0.0492 ratio train/dev:0.97 momentum:0.9333 learning rate:0.0082
# 760 Train loss:0.0533 Dev loss:0.0489 ratio train/dev:1.09 momentum:0.9342 learning rate:0.0079
# 780 Train loss:0.0469 Dev loss:0.0486 ratio train/dev:0.96 momentum:0.9351 learning rate:0.0076
# 800 Train loss:0.0493 Dev loss:0.0484 ratio train/dev:1.02 momentum:0.9360 learning rate:0.0074
# 820 Train loss:0.0483 Dev loss:0.0481 ratio train/dev:1.00 momentum:0.9369 learning rate:0.0071
# 840 Train loss:0.0512 Dev loss:0.0479 ratio train/dev:1.07 momentum:0.9378 learning rate:0.0069
# 860 Train loss:0.0513 Dev loss:0.0477 ratio train/dev:1.08 momentum:0.9387 learning rate:0.0066
# 880 Train loss:0.0530 Dev loss:0.0475 ratio train/dev:1.12 momentum:0.9396 learning rate:0.0064
# 900 Train loss:0.0509 Dev loss:0.0472 ratio train/dev:1.08 momentum:0.9405 learning rate:0.0062
# 920 Train loss:0.0466 Dev loss:0.0470 ratio train/dev:0.99 momentum:0.9414 learning rate:0.0060
# 940 Train loss:0.0472 Dev loss:0.0469 ratio train/dev:1.01 momentum:0.9423 learning rate:0.0058
# 960 Train loss:0.0464 Dev loss:0.0467 ratio train/dev:0.99 momentum:0.9432 learning rate:0.0056
# 980 Train loss:0.0469 Dev loss:0.0465 ratio train/dev:1.01 momentum:0.9441 learning rate:0.0054
# 1000 Train loss:0.0497 Dev loss:0.0464 ratio train/dev:1.07 momentum:0.9450 learning rate:0.0052
# 1020 Train loss:0.0480 Dev loss:0.0462 ratio train/dev:1.04 momentum:0.9459 learning rate:0.0050
# 1040 Train loss:0.0432 Dev loss:0.0460 ratio train/dev:0.94 momentum:0.9468 learning rate:0.0048
# 1060 Train loss:0.0500 Dev loss:0.0459 ratio train/dev:1.09 momentum:0.9477 learning rate:0.0047
# 1080 Train loss:0.0464 Dev loss:0.0457 ratio train/dev:1.01 momentum:0.9486 learning rate:0.0045
# 1100 Train loss:0.0504 Dev loss:0.0456 ratio train/dev:1.11 momentum:0.9495 learning rate:0.0044
# 1120 Train loss:0.0445 Dev loss:0.0455 ratio train/dev:0.98 momentum:0.9504 learning rate:0.0042
# 1140 Train loss:0.0479 Dev loss:0.0453 ratio train/dev:1.06 momentum:0.9513 learning rate:0.0041
# 1160 Train loss:0.0471 Dev loss:0.0452 ratio train/dev:1.04 momentum:0.9522 learning rate:0.0039
# 1180 Train loss:0.0416 Dev loss:0.0451 ratio train/dev:0.92 momentum:0.9531 learning rate:0.0038
# 1200 Train loss:0.0440 Dev loss:0.0449 ratio train/dev:0.98 momentum:0.9540 learning rate:0.0037
# 1220 Train loss:0.0442 Dev loss:0.0448 ratio train/dev:0.99 momentum:0.9549 learning rate:0.0035
# 1240 Train loss:0.0443 Dev loss:0.0447 ratio train/dev:0.99 momentum:0.9558 learning rate:0.0034
# 1260 Train loss:0.0482 Dev loss:0.0446 ratio train/dev:1.08 momentum:0.9567 learning rate:0.0033
# 1280 Train loss:0.0469 Dev loss:0.0445 ratio train/dev:1.05 momentum:0.9576 learning rate:0.0032
# 1300 Train loss:0.0456 Dev loss:0.0444 ratio train/dev:1.03 momentum:0.9585 learning rate:0.0031
# 1320 Train loss:0.0473 Dev loss:0.0443 ratio train/dev:1.07 momentum:0.9594 learning rate:0.0030
# 1340 Train loss:0.0450 Dev loss:0.0442 ratio train/dev:1.02 momentum:0.9603 learning rate:0.0029
# 1360 Train loss:0.0455 Dev loss:0.0441 ratio train/dev:1.03 momentum:0.9612 learning rate:0.0028
# 1380 Train loss:0.0402 Dev loss:0.0440 ratio train/dev:0.91 momentum:0.9621 learning rate:0.0027
# 1400 Train loss:0.0441 Dev loss:0.0439 ratio train/dev:1.00 momentum:0.9630 learning rate:0.0026
# 1420 Train loss:0.0454 Dev loss:0.0438 ratio train/dev:1.04 momentum:0.9639 learning rate:0.0025
# 1440 Train loss:0.0431 Dev loss:0.0437 ratio train/dev:0.99 momentum:0.9648 learning rate:0.0024
# 1460 Train loss:0.0420 Dev loss:0.0436 ratio train/dev:0.96 momentum:0.9657 learning rate:0.0023
# 1480 Train loss:0.0426 Dev loss:0.0436 ratio train/dev:0.98 momentum:0.9666 learning rate:0.0022
# 1500 Train loss:0.0408 Dev loss:0.0435 ratio train/dev:0.94 momentum:0.9675 learning rate:0.0022
# 1520 Train loss:0.0437 Dev loss:0.0434 ratio train/dev:1.01 momentum:0.9684 learning rate:0.0021
# 1540 Train loss:0.0418 Dev loss:0.0433 ratio train/dev:0.96 momentum:0.9693 learning rate:0.0020
# 1560 Train loss:0.0367 Dev loss:0.0432 ratio train/dev:0.85 momentum:0.9702 learning rate:0.0019
# 1580 Train loss:0.0398 Dev loss:0.0432 ratio train/dev:0.92 momentum:0.9711 learning rate:0.0019
# 1600 Train loss:0.0452 Dev loss:0.0431 ratio train/dev:1.05 momentum:0.9720 learning rate:0.0018
# 1620 Train loss:0.0441 Dev loss:0.0430 ratio train/dev:1.03 momentum:0.9729 learning rate:0.0018
# 1640 Train loss:0.0401 Dev loss:0.0430 ratio train/dev:0.93 momentum:0.9738 learning rate:0.0017
# 1660 Train loss:0.0409 Dev loss:0.0429 ratio train/dev:0.95 momentum:0.9747 learning rate:0.0016
# 1680 Train loss:0.0412 Dev loss:0.0428 ratio train/dev:0.96 momentum:0.9756 learning rate:0.0016
# 1700 Train loss:0.0407 Dev loss:0.0427 ratio train/dev:0.95 momentum:0.9765 learning rate:0.0015
# 1720 Train loss:0.0423 Dev loss:0.0427 ratio train/dev:0.99 momentum:0.9774 learning rate:0.0015
# 1740 Train loss:0.0408 Dev loss:0.0426 ratio train/dev:0.96 momentum:0.9783 learning rate:0.0014
# 1760 Train loss:0.0455 Dev loss:0.0426 ratio train/dev:1.07 momentum:0.9792 learning rate:0.0014
# 1780 Train loss:0.0423 Dev loss:0.0425 ratio train/dev:1.00 momentum:0.9801 learning rate:0.0013
# 1800 Train loss:0.0390 Dev loss:0.0424 ratio train/dev:0.92 momentum:0.9810 learning rate:0.0013
# 1820 Train loss:0.0409 Dev loss:0.0424 ratio train/dev:0.97 momentum:0.9819 learning rate:0.0012
# 1840 Train loss:0.0437 Dev loss:0.0423 ratio train/dev:1.03 momentum:0.9828 learning rate:0.0012
# 1860 Train loss:0.0427 Dev loss:0.0422 ratio train/dev:1.01 momentum:0.9837 learning rate:0.0012
# 1880 Train loss:0.0410 Dev loss:0.0422 ratio train/dev:0.97 momentum:0.9846 learning rate:0.0011
# 1900 Train loss:0.0410 Dev loss:0.0421 ratio train/dev:0.97 momentum:0.9855 learning rate:0.0011
# 1920 Train loss:0.0430 Dev loss:0.0421 ratio train/dev:1.02 momentum:0.9864 learning rate:0.0010
# 1940 Train loss:0.0388 Dev loss:0.0420 ratio train/dev:0.92 momentum:0.9873 learning rate:0.0010
# 1960 Train loss:0.0380 Dev loss:0.0420 ratio train/dev:0.90 momentum:0.9882 learning rate:0.0010
# 1980 Train loss:0.0415 Dev loss:0.0419 ratio train/dev:0.99 momentum:0.9891 learning rate:0.0009
# 2000 Train loss:0.0416 Dev loss:0.0419 ratio train/dev:0.99 momentum:0.9900 learning rate:0.0009
# Total time taken: 873.9776909351349
# Model file: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/basic_conv_net_/train_history
# done

# %%
#Individual Facial Keypoints models
#Important to keep the same input as the baseline net 2 being used as starting point for weights
#n_epochs = 2001
# dropout_keep_prob1 = 0.9
# dropout_keep_prob2 = 0.8
# dropout_keep_prob3 = 0.8
# dropout_keep_prob4 = 0.7

# %%
#Uncomment the dict to run a particular model
facial_group_labels = [
   
    dict(
        name = "mouth_corner_top",
        columns = (
            'mouth_left_corner_x', 'mouth_left_corner_y',
            'mouth_right_corner_x', 'mouth_right_corner_y',
            'mouth_center_top_lip_x', 'mouth_center_top_lip_y',
            )),
     
     dict(
         name = "nose_tip",
         columns = (
             'nose_tip_x', 'nose_tip_y',
             )),

    dict(
        name = "mouth_bottom",
        columns = (
            'mouth_center_bottom_lip_x',
            'mouth_center_bottom_lip_y',
            )),

    dict(
        name = "eye_corner",
        columns = (
            'left_eye_inner_corner_x', 'left_eye_inner_corner_y',
            'right_eye_inner_corner_x', 'right_eye_inner_corner_y',
            'left_eye_outer_corner_x', 'left_eye_outer_corner_y',
            'right_eye_outer_corner_x', 'right_eye_outer_corner_y',
            )),

    dict(
        name = "eyebrow",
        columns = (
            'left_eyebrow_inner_end_x', 'left_eyebrow_inner_end_y',
            'right_eyebrow_inner_end_x', 'right_eyebrow_inner_end_y',
            'left_eyebrow_outer_end_x', 'left_eyebrow_outer_end_y',
            'right_eyebrow_outer_end_x', 'right_eyebrow_outer_end_y',
            )),
    
     dict(
        name = "eye_center",
        columns = (
            'left_eye_center_x', 'left_eye_center_y',
            'right_eye_center_x', 'right_eye_center_y',
            )),
    ]

# %%
def train_individual_model(facial_model_label):
    
    np.random.seed(1)
    graph_base = tf.Graph()
    
    X, y = load(cols = facial_model_label['columns'])
    num_keypoints = y.shape[1]
    
    
    
    np.random.seed(0)
    dev_size = 0.2
    #setting aside a 20% sample for validation

    x_train, x_dev, y_train, y_dev = train_test_split(X, y, test_size = dev_size)

    x_test, _ = load(test=True)

    print('Training data split into train and dev data')
    print("x_train.shape = = {}; x_train.min == {:.3f}; x_train.max == {:.3f}".format(x_train.shape, x_train.min(),x_train.max()))
    print("y_train.shape = = {}; y_train.min == {:.3f}; y_train.max == {:.3f}".format(y_train.shape, y_train.min(),y_train.max()))
    print("x_dev.shape = = {}; x_dev.min == {:.3f}; x_dev.max == {:.3f}".format(x_dev.shape, x_dev.min(),x_dev.max()))
    print("y_dev.shape = = {}; y_dev.min == {:.3f}; y_dev.max == {:.3f}".format(y_dev.shape, y_dev.min(),y_dev.max()))
    
    with graph_base.as_default():

        if tensorboard_log:
            now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
            logdir = "{}/run-{}/".format(root_logdir, now)

    
        X = tf.placeholder(tf.float32,[None,X.shape[1]])
        y = tf.placeholder(tf.float32,[None,y.shape[1]])
        training = tf.placeholder(tf.bool)
        current_epoch = tf.Variable(0)  # count the number of epochs
    
        #convert x into 4-D input
        #2nd and 3rd dimension is image width and height, final dimension is number of color channels
        x_image = tf.reshape(X,[-1,96,96,1]) 
    
        

        #First convolutional layer
        with tf.variable_scope('conv1'):
            layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

        #Second convolutional layer
        with tf.variable_scope('conv2'):
            layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

        #Thrid convolutional layer
        with tf.variable_scope('conv3'):
            layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

        #Flatten conv3 output for dense nn layer 1
        layer_flat, num_features = flatten_layer(layer_conv3)

        #Densely connected layer1
        with tf.variable_scope('fc4'):
            layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

        #Densely connected layer2
        with tf.variable_scope('fc5'):
            layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

        #Densely connected output layer
        with tf.variable_scope('fc6'):
            layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = num_keypoints,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


        #loss function
        with tf.name_scope('loss'):
            loss = tf.reduce_mean(np.square(layer_f6 - y))
            sqrt_loss = tf.sqrt(loss)
        
        #for tensorboard
        with tf.name_scope('summaries'):
            sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)
    
        # optimizer
        #making changes to learning rate and momentum for individual models
        # learning rate decay. - Idea is to start with high learning rate to speed up but decrease as we get closer to 
        #the local optimum so that we don't surpass it.
        learning_rate = tf.train.exponential_decay(0.08, current_epoch, decay_steps = n_epochs, decay_rate = 0.03)
        momentum = 0.9 + (0.99 - 0.9) * (current_epoch / n_epochs)
        optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

        train_loss_data = np.zeros((n_epochs,2))
        dev_loss_data = np.zeros((n_epochs,2))
        y_pred = np.zeros((x_test.shape[0],y.shape[1]))

        # logger
        if tensorboard_log:
            train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
            dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
    time_start = time.time()
    time_1000_start = time.time()

    
    with tf.Session(graph=graph_base) as sess:
        sess.run(tf.global_variables_initializer())
    
        #for saving model 
        saver = tf.train.Saver()
        
        #initializing weights from a previous session 
        initialising_model = "basic_conv_net_"
        print(" RESTORING SESSION FOR WEIGHTS INITIALIZATION")
        # Exclude output layer weights from variables we will restore
        variables_to_restore = [v for v in tf.global_variables() if "fc6" not in v.op.name]
        # Replace variables scope with that of the current model
        loader = tf.train.Saver({v.op.name.replace(facial_model_label['name'], initialising_model): v for v in variables_to_restore})
        load_path = FROOT + "/models/" + initialising_model + "/model.ckpt"
        loader.restore(sess, load_path)
        print(" Model loaded from: " + load_path)
    
        for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
            current_epoch = epoch
            shuffle = np.random.permutation(np.arange(x_train.shape[0])) #shuffle the training data in each epoch
            x_train, y_train = x_train[shuffle], y_train[shuffle]

            # initialize variables to hold loss information for each epoch
    
            batches = x_train.shape[0]//batch_size

            
            
            for i in range(int(batches)): #run through most of the data points in each epoch
        
                X_batch,y_batch = x_train[i*batch_size:(i+1)*batch_size,:], y_train[i*batch_size:(i+1)*batch_size]
                sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})
        
                if tensorboard_log:
                    if i % 10 == 0:
                        train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, training: True})
                        dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, training: False})
                        step = epoch * batches + i
                        train_writer.add_summary(train_summary_str, step)
                        dev_writer.add_summary(dev_summary_str, step)

            loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
            loss_dev = loss.eval(feed_dict = {X:x_dev,y:y_dev, training:False})
            train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
            dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            if epoch%20 == 0:
                print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
        time_end = time.time()
        print('Total time taken:',time_end-time_start)
    
        # Save model weights for future use.
        #please give any unique name you want to give to the model for testing various paramaters.
        #It wil get appended to ""basic_conv_net"
        model_name = "ind_model_" + facial_model_label['name'] + "_"
        model_path =  FROOT + "/models/"+ model_name + "/model.ckpt"
        train_history_path = FROOT + "/models/" + model_name + "/train_history"
        save_path = saver.save(sess, model_path)
        print("Model file: " + save_path)
        np.savez(train_history_path, train_loss_history = train_loss_data, valid_loss_history = dev_loss_data)
        print("Train history file: " + train_history_path)
    
        for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
            
    with open(model_name + 'net3_test_pred','wb') as fs:
        np.savetxt(fs,y_pred,fmt = '%0.4f')

    #Plot a graph of the train vs dev loss data:
    
    #plt.figure()
    plot_loss (train_loss_data, dev_loss_data)
    print("\n")
    plot_pred (x_dev, y_pred)
    print("\n")
    if tensorboard_log:
        train_writer.close()
        dev_writer.close()

# %%
start = time.time()

for facial_model_label in facial_group_labels:
    train_individual_model(facial_model_label)

time_stop = time.time()    
print(" Total time for all models: " , time_stop - start)
# Out:
# Count of observations in training data by features
# mouth_left_corner_x       2269
# mouth_left_corner_y       2269
# mouth_right_corner_x      2270
# mouth_right_corner_y      2270
# mouth_center_top_lip_x    2275
# mouth_center_top_lip_y    2275
# Image                     7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1808, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1808, 6); y_train.min == -0.942; y_train.max == 0.990
# x_dev.shape = = (452, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (452, 6); y_dev.min == -0.953; y_dev.max == 0.961
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.094 Dev loss:0.099 ratio train/dev:0.95
# 20 Train loss:0.088 Dev loss:0.090 ratio train/dev:0.98
# 40 Train loss:0.083 Dev loss:0.090 ratio train/dev:0.92
# 60 Train loss:0.074 Dev loss:0.066 ratio train/dev:1.13
# 80 Train loss:0.045 Dev loss:0.060 ratio train/dev:0.76
# 100 Train loss:0.048 Dev loss:0.058 ratio train/dev:0.83
# 120 Train loss:0.047 Dev loss:0.056 ratio train/dev:0.84
# 140 Train loss:0.043 Dev loss:0.056 ratio train/dev:0.78
# 160 Train loss:0.056 Dev loss:0.055 ratio train/dev:1.02
# 180 Train loss:0.040 Dev loss:0.054 ratio train/dev:0.75
# 200 Train loss:0.042 Dev loss:0.054 ratio train/dev:0.78
# 220 Train loss:0.042 Dev loss:0.053 ratio train/dev:0.80
# 240 Train loss:0.046 Dev loss:0.053 ratio train/dev:0.86
# 260 Train loss:0.038 Dev loss:0.053 ratio train/dev:0.71
# 280 Train loss:0.044 Dev loss:0.052 ratio train/dev:0.83
# 300 Train loss:0.038 Dev loss:0.052 ratio train/dev:0.73
# 320 Train loss:0.036 Dev loss:0.052 ratio train/dev:0.69
# 340 Train loss:0.039 Dev loss:0.052 ratio train/dev:0.75
# 360 Train loss:0.035 Dev loss:0.052 ratio train/dev:0.68
# 380 Train loss:0.039 Dev loss:0.051 ratio train/dev:0.76
# 400 Train loss:0.034 Dev loss:0.052 ratio train/dev:0.67
# 420 Train loss:0.035 Dev loss:0.051 ratio train/dev:0.68
# 440 Train loss:0.032 Dev loss:0.051 ratio train/dev:0.63
# 460 Train loss:0.033 Dev loss:0.051 ratio train/dev:0.65
# 480 Train loss:0.032 Dev loss:0.051 ratio train/dev:0.62
# 500 Train loss:0.031 Dev loss:0.051 ratio train/dev:0.61
# 520 Train loss:0.031 Dev loss:0.051 ratio train/dev:0.60
# 540 Train loss:0.034 Dev loss:0.051 ratio train/dev:0.67
# 560 Train loss:0.032 Dev loss:0.051 ratio train/dev:0.62
# 580 Train loss:0.030 Dev loss:0.051 ratio train/dev:0.59
# 600 Train loss:0.030 Dev loss:0.051 ratio train/dev:0.59
# 620 Train loss:0.037 Dev loss:0.051 ratio train/dev:0.73
# 640 Train loss:0.030 Dev loss:0.051 ratio train/dev:0.60
# 660 Train loss:0.030 Dev loss:0.051 ratio train/dev:0.59
# 680 Train loss:0.031 Dev loss:0.051 ratio train/dev:0.60
# 700 Train loss:0.031 Dev loss:0.051 ratio train/dev:0.61
# 720 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.58
# 740 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.57
# 760 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.57
# 780 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.57
# 800 Train loss:0.027 Dev loss:0.051 ratio train/dev:0.53
# 820 Train loss:0.031 Dev loss:0.051 ratio train/dev:0.60
# 840 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.58
# 860 Train loss:0.031 Dev loss:0.051 ratio train/dev:0.61
# 880 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.57
# 900 Train loss:0.030 Dev loss:0.051 ratio train/dev:0.59
# 920 Train loss:0.026 Dev loss:0.051 ratio train/dev:0.51
# 940 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.57
# 960 Train loss:0.030 Dev loss:0.051 ratio train/dev:0.59
# 980 Train loss:0.027 Dev loss:0.051 ratio train/dev:0.52
# 1000 Train loss:0.027 Dev loss:0.051 ratio train/dev:0.53
# 1020 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.50
# 1040 Train loss:0.026 Dev loss:0.050 ratio train/dev:0.52
# 1060 Train loss:0.027 Dev loss:0.051 ratio train/dev:0.53
# 1080 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.50
# 1100 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1120 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.57
# 1140 Train loss:0.026 Dev loss:0.051 ratio train/dev:0.51
# 1160 Train loss:0.027 Dev loss:0.051 ratio train/dev:0.53
# 1180 Train loss:0.030 Dev loss:0.051 ratio train/dev:0.60
# 1200 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.57
# 1220 Train loss:0.026 Dev loss:0.051 ratio train/dev:0.50
# 1240 Train loss:0.027 Dev loss:0.051 ratio train/dev:0.53
# 1260 Train loss:0.029 Dev loss:0.051 ratio train/dev:0.56
# 1280 Train loss:0.026 Dev loss:0.051 ratio train/dev:0.52
# 1300 Train loss:0.028 Dev loss:0.051 ratio train/dev:0.56
# 1320 Train loss:0.026 Dev loss:0.051 ratio train/dev:0.51
# 1340 Train loss:0.027 Dev loss:0.051 ratio train/dev:0.52
# 1360 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.50
# 1380 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.48
# 1400 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1420 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.48
# 1440 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1460 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1480 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.47
# 1500 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.46
# 1520 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.48
# 1540 Train loss:0.023 Dev loss:0.051 ratio train/dev:0.46
# 1560 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.48
# 1580 Train loss:0.023 Dev loss:0.051 ratio train/dev:0.46
# 1600 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1620 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1640 Train loss:0.023 Dev loss:0.051 ratio train/dev:0.46
# 1660 Train loss:0.023 Dev loss:0.051 ratio train/dev:0.45
# 1680 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.47
# 1700 Train loss:0.026 Dev loss:0.051 ratio train/dev:0.51
# 1720 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1740 Train loss:0.022 Dev loss:0.051 ratio train/dev:0.44
# 1760 Train loss:0.022 Dev loss:0.051 ratio train/dev:0.43
# 1780 Train loss:0.023 Dev loss:0.051 ratio train/dev:0.45
# 1800 Train loss:0.022 Dev loss:0.051 ratio train/dev:0.43
# 1820 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.48
# 1840 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.48
# 1860 Train loss:0.025 Dev loss:0.051 ratio train/dev:0.49
# 1880 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.47
# 1900 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.47
# 1920 Train loss:0.023 Dev loss:0.051 ratio train/dev:0.46
# 1940 Train loss:0.023 Dev loss:0.051 ratio train/dev:0.46
# 1960 Train loss:0.022 Dev loss:0.051 ratio train/dev:0.44
# 1980 Train loss:0.022 Dev loss:0.051 ratio train/dev:0.44
# 2000 Train loss:0.024 Dev loss:0.051 ratio train/dev:0.48
# Total time taken: 500.0346372127533
# Model file: /home/ubuntu/notebooks/models/ind_model_mouth_corner_top_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_mouth_corner_top_/train_history
# Count of observations in training data by features
# nose_tip_x    7049
# nose_tip_y    7049
# Image         7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (5639, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (5639, 2); y_train.min == -0.730; y_train.max == 0.955
# x_dev.shape = = (1410, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (1410, 2); y_dev.min == -0.682; y_dev.max == 0.999
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.101 Dev loss:0.086 ratio train/dev:1.17
# 20 Train loss:0.076 Dev loss:0.069 ratio train/dev:1.09
# 40 Train loss:0.083 Dev loss:0.068 ratio train/dev:1.23
# 60 Train loss:0.057 Dev loss:0.067 ratio train/dev:0.86
# 80 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.04
# 100 Train loss:0.047 Dev loss:0.066 ratio train/dev:0.72
# 120 Train loss:0.050 Dev loss:0.065 ratio train/dev:0.76
# 140 Train loss:0.054 Dev loss:0.065 ratio train/dev:0.82
# 160 Train loss:0.047 Dev loss:0.065 ratio train/dev:0.73
# 180 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.94
# 200 Train loss:0.051 Dev loss:0.065 ratio train/dev:0.79
# 220 Train loss:0.048 Dev loss:0.064 ratio train/dev:0.74
# 240 Train loss:0.039 Dev loss:0.064 ratio train/dev:0.61
# 260 Train loss:0.037 Dev loss:0.064 ratio train/dev:0.58
# 280 Train loss:0.041 Dev loss:0.064 ratio train/dev:0.63
# 300 Train loss:0.041 Dev loss:0.064 ratio train/dev:0.64
# 320 Train loss:0.043 Dev loss:0.064 ratio train/dev:0.67
# 340 Train loss:0.036 Dev loss:0.064 ratio train/dev:0.56
# 360 Train loss:0.036 Dev loss:0.064 ratio train/dev:0.56
# 380 Train loss:0.039 Dev loss:0.064 ratio train/dev:0.60
# 400 Train loss:0.032 Dev loss:0.064 ratio train/dev:0.50
# 420 Train loss:0.039 Dev loss:0.064 ratio train/dev:0.61
# 440 Train loss:0.036 Dev loss:0.064 ratio train/dev:0.56
# 460 Train loss:0.053 Dev loss:0.064 ratio train/dev:0.83
# 480 Train loss:0.033 Dev loss:0.064 ratio train/dev:0.51
# 500 Train loss:0.031 Dev loss:0.064 ratio train/dev:0.49
# 520 Train loss:0.033 Dev loss:0.064 ratio train/dev:0.52
# 540 Train loss:0.049 Dev loss:0.064 ratio train/dev:0.78
# 560 Train loss:0.033 Dev loss:0.064 ratio train/dev:0.51
# 580 Train loss:0.032 Dev loss:0.064 ratio train/dev:0.51
# 600 Train loss:0.030 Dev loss:0.064 ratio train/dev:0.47
# 620 Train loss:0.041 Dev loss:0.064 ratio train/dev:0.65
# 640 Train loss:0.029 Dev loss:0.064 ratio train/dev:0.46
# 660 Train loss:0.027 Dev loss:0.064 ratio train/dev:0.43
# 680 Train loss:0.030 Dev loss:0.064 ratio train/dev:0.47
# 700 Train loss:0.030 Dev loss:0.064 ratio train/dev:0.47
# 720 Train loss:0.030 Dev loss:0.064 ratio train/dev:0.48
# 740 Train loss:0.032 Dev loss:0.064 ratio train/dev:0.50
# 760 Train loss:0.029 Dev loss:0.064 ratio train/dev:0.45
# 780 Train loss:0.029 Dev loss:0.063 ratio train/dev:0.45
# 800 Train loss:0.031 Dev loss:0.064 ratio train/dev:0.48
# 820 Train loss:0.028 Dev loss:0.063 ratio train/dev:0.45
# 840 Train loss:0.027 Dev loss:0.063 ratio train/dev:0.43
# 860 Train loss:0.025 Dev loss:0.063 ratio train/dev:0.39
# 880 Train loss:0.028 Dev loss:0.063 ratio train/dev:0.44
# 900 Train loss:0.029 Dev loss:0.063 ratio train/dev:0.47
# 920 Train loss:0.029 Dev loss:0.063 ratio train/dev:0.46
# 940 Train loss:0.029 Dev loss:0.064 ratio train/dev:0.45
# 960 Train loss:0.027 Dev loss:0.063 ratio train/dev:0.42
# 980 Train loss:0.027 Dev loss:0.063 ratio train/dev:0.43
# 1000 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.40
# 1020 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.42
# 1040 Train loss:0.028 Dev loss:0.063 ratio train/dev:0.44
# 1060 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1080 Train loss:0.056 Dev loss:0.063 ratio train/dev:0.89
# 1100 Train loss:0.034 Dev loss:0.063 ratio train/dev:0.54
# 1120 Train loss:0.051 Dev loss:0.063 ratio train/dev:0.80
# 1140 Train loss:0.027 Dev loss:0.063 ratio train/dev:0.43
# 1160 Train loss:0.029 Dev loss:0.063 ratio train/dev:0.45
# 1180 Train loss:0.025 Dev loss:0.063 ratio train/dev:0.40
# 1200 Train loss:0.025 Dev loss:0.063 ratio train/dev:0.40
# 1220 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.40
# 1240 Train loss:0.028 Dev loss:0.063 ratio train/dev:0.45
# 1260 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.41
# 1280 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1300 Train loss:0.049 Dev loss:0.063 ratio train/dev:0.77
# 1320 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.42
# 1340 Train loss:0.025 Dev loss:0.063 ratio train/dev:0.39
# 1360 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.41
# 1380 Train loss:0.025 Dev loss:0.063 ratio train/dev:0.40
# 1400 Train loss:0.022 Dev loss:0.063 ratio train/dev:0.35
# 1420 Train loss:0.039 Dev loss:0.063 ratio train/dev:0.61
# 1440 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.39
# 1460 Train loss:0.036 Dev loss:0.063 ratio train/dev:0.57
# 1480 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.42
# 1500 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.36
# 1520 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1540 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.42
# 1560 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1580 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.41
# 1600 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.37
# 1620 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.37
# 1640 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.39
# 1660 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.36
# 1680 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.36
# 1700 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.36
# 1720 Train loss:0.032 Dev loss:0.063 ratio train/dev:0.52
# 1740 Train loss:0.020 Dev loss:0.063 ratio train/dev:0.31
# 1760 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1780 Train loss:0.021 Dev loss:0.063 ratio train/dev:0.34
# 1800 Train loss:0.026 Dev loss:0.063 ratio train/dev:0.41
# 1820 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1840 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.36
# 1860 Train loss:0.025 Dev loss:0.063 ratio train/dev:0.39
# 1880 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1900 Train loss:0.020 Dev loss:0.063 ratio train/dev:0.32
# 1920 Train loss:0.022 Dev loss:0.063 ratio train/dev:0.34
# 1940 Train loss:0.021 Dev loss:0.063 ratio train/dev:0.33
# 1960 Train loss:0.024 Dev loss:0.063 ratio train/dev:0.38
# 1980 Train loss:0.023 Dev loss:0.063 ratio train/dev:0.37
# 2000 Train loss:0.021 Dev loss:0.063 ratio train/dev:0.33
# Total time taken: 1567.023598909378
# Model file: /home/ubuntu/notebooks/models/ind_model_nose_tip_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_nose_tip_/train_history
# Count of observations in training data by features
# mouth_center_bottom_lip_x    7016
# mouth_center_bottom_lip_y    7016
# Image                        7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (5612, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (5612, 2); y_train.min == -0.739; y_train.max == 0.996
# x_dev.shape = = (1404, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (1404, 2); y_dev.min == -0.620; y_dev.max == 0.991
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.112 Dev loss:0.106 ratio train/dev:1.05
# 20 Train loss:0.059 Dev loss:0.080 ratio train/dev:0.74
# 40 Train loss:0.060 Dev loss:0.073 ratio train/dev:0.83
# 60 Train loss:0.060 Dev loss:0.071 ratio train/dev:0.84
# 80 Train loss:0.058 Dev loss:0.070 ratio train/dev:0.83
# 100 Train loss:0.052 Dev loss:0.071 ratio train/dev:0.73
# 120 Train loss:0.050 Dev loss:0.071 ratio train/dev:0.70
# 140 Train loss:0.047 Dev loss:0.071 ratio train/dev:0.66
# 160 Train loss:0.062 Dev loss:0.071 ratio train/dev:0.87
# 180 Train loss:0.046 Dev loss:0.071 ratio train/dev:0.65
# 200 Train loss:0.045 Dev loss:0.071 ratio train/dev:0.63
# 220 Train loss:0.049 Dev loss:0.070 ratio train/dev:0.69
# 240 Train loss:0.050 Dev loss:0.071 ratio train/dev:0.71
# 260 Train loss:0.040 Dev loss:0.071 ratio train/dev:0.57
# 280 Train loss:0.039 Dev loss:0.070 ratio train/dev:0.55
# 300 Train loss:0.038 Dev loss:0.070 ratio train/dev:0.54
# 320 Train loss:0.036 Dev loss:0.070 ratio train/dev:0.51
# 340 Train loss:0.037 Dev loss:0.070 ratio train/dev:0.53
# 360 Train loss:0.035 Dev loss:0.070 ratio train/dev:0.50
# 380 Train loss:0.037 Dev loss:0.070 ratio train/dev:0.53
# 400 Train loss:0.040 Dev loss:0.069 ratio train/dev:0.57
# 420 Train loss:0.037 Dev loss:0.069 ratio train/dev:0.53
# 440 Train loss:0.032 Dev loss:0.069 ratio train/dev:0.46
# 460 Train loss:0.035 Dev loss:0.069 ratio train/dev:0.51
# 480 Train loss:0.033 Dev loss:0.070 ratio train/dev:0.48
# 500 Train loss:0.035 Dev loss:0.069 ratio train/dev:0.51
# 520 Train loss:0.033 Dev loss:0.069 ratio train/dev:0.48
# 540 Train loss:0.033 Dev loss:0.069 ratio train/dev:0.48
# 560 Train loss:0.032 Dev loss:0.069 ratio train/dev:0.46
# 580 Train loss:0.031 Dev loss:0.069 ratio train/dev:0.45
# 600 Train loss:0.032 Dev loss:0.069 ratio train/dev:0.47
# 620 Train loss:0.028 Dev loss:0.069 ratio train/dev:0.40
# 640 Train loss:0.029 Dev loss:0.069 ratio train/dev:0.42
# 660 Train loss:0.033 Dev loss:0.069 ratio train/dev:0.47
# 680 Train loss:0.032 Dev loss:0.069 ratio train/dev:0.46
# 700 Train loss:0.031 Dev loss:0.069 ratio train/dev:0.46
# 720 Train loss:0.029 Dev loss:0.069 ratio train/dev:0.42
# 740 Train loss:0.030 Dev loss:0.069 ratio train/dev:0.44
# 760 Train loss:0.030 Dev loss:0.069 ratio train/dev:0.44
# 780 Train loss:0.028 Dev loss:0.069 ratio train/dev:0.40
# 800 Train loss:0.028 Dev loss:0.069 ratio train/dev:0.40
# 820 Train loss:0.027 Dev loss:0.069 ratio train/dev:0.39
# 840 Train loss:0.042 Dev loss:0.069 ratio train/dev:0.61
# 860 Train loss:0.032 Dev loss:0.069 ratio train/dev:0.47
# 880 Train loss:0.036 Dev loss:0.069 ratio train/dev:0.53
# 900 Train loss:0.028 Dev loss:0.069 ratio train/dev:0.40
# 920 Train loss:0.028 Dev loss:0.069 ratio train/dev:0.41
# 940 Train loss:0.031 Dev loss:0.069 ratio train/dev:0.45
# 960 Train loss:0.026 Dev loss:0.069 ratio train/dev:0.38
# 980 Train loss:0.029 Dev loss:0.069 ratio train/dev:0.42
# 1000 Train loss:0.028 Dev loss:0.068 ratio train/dev:0.40
# 1020 Train loss:0.028 Dev loss:0.068 ratio train/dev:0.40
# 1040 Train loss:0.028 Dev loss:0.069 ratio train/dev:0.41
# 1060 Train loss:0.027 Dev loss:0.069 ratio train/dev:0.39
# 1080 Train loss:0.029 Dev loss:0.069 ratio train/dev:0.42
# 1100 Train loss:0.027 Dev loss:0.069 ratio train/dev:0.39
# 1120 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.37
# 1140 Train loss:0.026 Dev loss:0.068 ratio train/dev:0.38
# 1160 Train loss:0.030 Dev loss:0.068 ratio train/dev:0.44
# 1180 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.37
# 1200 Train loss:0.027 Dev loss:0.069 ratio train/dev:0.40
# 1220 Train loss:0.029 Dev loss:0.068 ratio train/dev:0.43
# 1240 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.37
# 1260 Train loss:0.026 Dev loss:0.068 ratio train/dev:0.38
# 1280 Train loss:0.029 Dev loss:0.069 ratio train/dev:0.42
# 1300 Train loss:0.026 Dev loss:0.068 ratio train/dev:0.38
# 1320 Train loss:0.027 Dev loss:0.068 ratio train/dev:0.40
# 1340 Train loss:0.026 Dev loss:0.069 ratio train/dev:0.38
# 1360 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.36
# 1380 Train loss:0.028 Dev loss:0.068 ratio train/dev:0.41
# 1400 Train loss:0.027 Dev loss:0.068 ratio train/dev:0.39
# 1420 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.35
# 1440 Train loss:0.026 Dev loss:0.069 ratio train/dev:0.38
# 1460 Train loss:0.026 Dev loss:0.068 ratio train/dev:0.39
# 1480 Train loss:0.025 Dev loss:0.069 ratio train/dev:0.37
# 1500 Train loss:0.028 Dev loss:0.068 ratio train/dev:0.41
# 1520 Train loss:0.028 Dev loss:0.069 ratio train/dev:0.41
# 1540 Train loss:0.040 Dev loss:0.068 ratio train/dev:0.58
# 1560 Train loss:0.026 Dev loss:0.069 ratio train/dev:0.37
# 1580 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.35
# 1600 Train loss:0.026 Dev loss:0.068 ratio train/dev:0.39
# 1620 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.35
# 1640 Train loss:0.023 Dev loss:0.068 ratio train/dev:0.33
# 1660 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.36
# 1680 Train loss:0.037 Dev loss:0.068 ratio train/dev:0.54
# 1700 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.34
# 1720 Train loss:0.031 Dev loss:0.068 ratio train/dev:0.45
# 1740 Train loss:0.022 Dev loss:0.068 ratio train/dev:0.33
# 1760 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.35
# 1780 Train loss:0.022 Dev loss:0.068 ratio train/dev:0.32
# 1800 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.36
# 1820 Train loss:0.022 Dev loss:0.068 ratio train/dev:0.32
# 1840 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.35
# 1860 Train loss:0.022 Dev loss:0.068 ratio train/dev:0.33
# 1880 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.35
# 1900 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.37
# 1920 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.36
# 1940 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.37
# 1960 Train loss:0.024 Dev loss:0.068 ratio train/dev:0.35
# 1980 Train loss:0.022 Dev loss:0.068 ratio train/dev:0.32
# 2000 Train loss:0.025 Dev loss:0.068 ratio train/dev:0.37
# Total time taken: 1534.737539768219
# Model file: /home/ubuntu/notebooks/models/ind_model_mouth_bottom_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_mouth_bottom_/train_history
# Count of observations in training data by features
# left_eye_inner_corner_x     2271
# left_eye_inner_corner_y     2271
# right_eye_inner_corner_x    2268
# right_eye_inner_corner_y    2268
# left_eye_outer_corner_x     2267
# left_eye_outer_corner_y     2267
# right_eye_outer_corner_x    2268
# right_eye_outer_corner_y    2268
# Image                       7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1797, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1797, 8); y_train.min == -0.908; y_train.max == 0.985
# x_dev.shape = = (450, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (450, 8); y_dev.min == -0.917; y_dev.max == 0.781
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.088 Dev loss:0.084 ratio train/dev:1.05
# 20 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.93
# 40 Train loss:0.049 Dev loss:0.041 ratio train/dev:1.18
# 60 Train loss:0.040 Dev loss:0.038 ratio train/dev:1.07
# 80 Train loss:0.034 Dev loss:0.036 ratio train/dev:0.94
# 100 Train loss:0.035 Dev loss:0.036 ratio train/dev:0.98
# 120 Train loss:0.051 Dev loss:0.035 ratio train/dev:1.46
# 140 Train loss:0.033 Dev loss:0.035 ratio train/dev:0.96
# 160 Train loss:0.034 Dev loss:0.034 ratio train/dev:0.99
# 180 Train loss:0.051 Dev loss:0.034 ratio train/dev:1.50
# 200 Train loss:0.035 Dev loss:0.034 ratio train/dev:1.03
# 220 Train loss:0.056 Dev loss:0.034 ratio train/dev:1.66
# 240 Train loss:0.049 Dev loss:0.033 ratio train/dev:1.46
# 260 Train loss:0.029 Dev loss:0.033 ratio train/dev:0.87
# 280 Train loss:0.034 Dev loss:0.033 ratio train/dev:1.02
# 300 Train loss:0.035 Dev loss:0.033 ratio train/dev:1.06
# 320 Train loss:0.044 Dev loss:0.033 ratio train/dev:1.35
# 340 Train loss:0.029 Dev loss:0.032 ratio train/dev:0.89
# 360 Train loss:0.032 Dev loss:0.032 ratio train/dev:0.98
# 380 Train loss:0.025 Dev loss:0.032 ratio train/dev:0.77
# 400 Train loss:0.032 Dev loss:0.032 ratio train/dev:0.99
# 420 Train loss:0.026 Dev loss:0.032 ratio train/dev:0.81
# 440 Train loss:0.040 Dev loss:0.032 ratio train/dev:1.26
# 460 Train loss:0.027 Dev loss:0.032 ratio train/dev:0.86
# 480 Train loss:0.029 Dev loss:0.032 ratio train/dev:0.90
# 500 Train loss:0.026 Dev loss:0.032 ratio train/dev:0.83
# 520 Train loss:0.025 Dev loss:0.031 ratio train/dev:0.81
# 540 Train loss:0.028 Dev loss:0.031 ratio train/dev:0.89
# 560 Train loss:0.026 Dev loss:0.031 ratio train/dev:0.82
# 580 Train loss:0.033 Dev loss:0.031 ratio train/dev:1.04
# 600 Train loss:0.027 Dev loss:0.031 ratio train/dev:0.87
# 620 Train loss:0.028 Dev loss:0.031 ratio train/dev:0.89
# 640 Train loss:0.025 Dev loss:0.031 ratio train/dev:0.79
# 660 Train loss:0.026 Dev loss:0.031 ratio train/dev:0.83
# 680 Train loss:0.026 Dev loss:0.031 ratio train/dev:0.85
# 700 Train loss:0.026 Dev loss:0.031 ratio train/dev:0.85
# 720 Train loss:0.025 Dev loss:0.031 ratio train/dev:0.81
# 740 Train loss:0.032 Dev loss:0.031 ratio train/dev:1.05
# 760 Train loss:0.024 Dev loss:0.031 ratio train/dev:0.80
# 780 Train loss:0.024 Dev loss:0.031 ratio train/dev:0.79
# 800 Train loss:0.023 Dev loss:0.031 ratio train/dev:0.75
# 820 Train loss:0.024 Dev loss:0.031 ratio train/dev:0.80
# 840 Train loss:0.026 Dev loss:0.031 ratio train/dev:0.84
# 860 Train loss:0.029 Dev loss:0.031 ratio train/dev:0.97
# 880 Train loss:0.026 Dev loss:0.030 ratio train/dev:0.86
# 900 Train loss:0.024 Dev loss:0.030 ratio train/dev:0.80
# 920 Train loss:0.032 Dev loss:0.030 ratio train/dev:1.05
# 940 Train loss:0.024 Dev loss:0.030 ratio train/dev:0.80
# 960 Train loss:0.024 Dev loss:0.030 ratio train/dev:0.79
# 980 Train loss:0.023 Dev loss:0.030 ratio train/dev:0.75
# 1000 Train loss:0.024 Dev loss:0.030 ratio train/dev:0.80
# 1020 Train loss:0.024 Dev loss:0.030 ratio train/dev:0.80
# 1040 Train loss:0.023 Dev loss:0.030 ratio train/dev:0.77
# 1060 Train loss:0.024 Dev loss:0.030 ratio train/dev:0.79
# 1080 Train loss:0.025 Dev loss:0.030 ratio train/dev:0.82
# 1100 Train loss:0.023 Dev loss:0.030 ratio train/dev:0.77
# 1120 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.72
# 1140 Train loss:0.025 Dev loss:0.030 ratio train/dev:0.84
# 1160 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.69
# 1180 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.74
# 1200 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.70
# 1220 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.71
# 1240 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.74
# 1260 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.73
# 1280 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.74
# 1300 Train loss:0.023 Dev loss:0.030 ratio train/dev:0.77
# 1320 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.71
# 1340 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.72
# 1360 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.69
# 1380 Train loss:0.023 Dev loss:0.030 ratio train/dev:0.76
# 1400 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.73
# 1420 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.72
# 1440 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.73
# 1460 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.69
# 1480 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.73
# 1500 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.69
# 1520 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.71
# 1540 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.71
# 1560 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.71
# 1580 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.72
# 1600 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.68
# 1620 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.67
# 1640 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.72
# 1660 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.67
# 1680 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.74
# 1700 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.67
# 1720 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.66
# 1740 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.67
# 1760 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.66
# 1780 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.67
# 1800 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.75
# 1820 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.68
# 1840 Train loss:0.023 Dev loss:0.030 ratio train/dev:0.78
# 1860 Train loss:0.019 Dev loss:0.030 ratio train/dev:0.65
# 1880 Train loss:0.018 Dev loss:0.030 ratio train/dev:0.59
# 1900 Train loss:0.019 Dev loss:0.030 ratio train/dev:0.65
# 1920 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.68
# 1940 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.67
# 1960 Train loss:0.021 Dev loss:0.030 ratio train/dev:0.69
# 1980 Train loss:0.022 Dev loss:0.030 ratio train/dev:0.74
# 2000 Train loss:0.020 Dev loss:0.030 ratio train/dev:0.67
# Total time taken: 500.0023658275604
# Model file: /home/ubuntu/notebooks/models/ind_model_eye_corner_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_eye_corner_/train_history
# Count of observations in training data by features
# left_eyebrow_inner_end_x     2270
# left_eyebrow_inner_end_y     2270
# right_eyebrow_inner_end_x    2270
# right_eyebrow_inner_end_y    2270
# left_eyebrow_outer_end_x     2225
# left_eyebrow_outer_end_y     2225
# right_eyebrow_outer_end_x    2236
# right_eyebrow_outer_end_y    2236
# Image                        7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1752, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1752, 8); y_train.min == -0.920; y_train.max == 0.964
# x_dev.shape = = (438, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (438, 8); y_dev.min == -0.916; y_dev.max == 0.889
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.130 Dev loss:0.131 ratio train/dev:0.99
# 20 Train loss:0.069 Dev loss:0.072 ratio train/dev:0.96
# 40 Train loss:0.070 Dev loss:0.072 ratio train/dev:0.98
# 60 Train loss:0.069 Dev loss:0.072 ratio train/dev:0.97
# 80 Train loss:0.068 Dev loss:0.071 ratio train/dev:0.95
# 100 Train loss:0.054 Dev loss:0.062 ratio train/dev:0.88
# 120 Train loss:0.057 Dev loss:0.057 ratio train/dev:1.02
# 140 Train loss:0.048 Dev loss:0.055 ratio train/dev:0.88
# 160 Train loss:0.049 Dev loss:0.054 ratio train/dev:0.91
# 180 Train loss:0.049 Dev loss:0.053 ratio train/dev:0.93
# 200 Train loss:0.047 Dev loss:0.052 ratio train/dev:0.90
# 220 Train loss:0.043 Dev loss:0.052 ratio train/dev:0.83
# 240 Train loss:0.044 Dev loss:0.052 ratio train/dev:0.86
# 260 Train loss:0.043 Dev loss:0.051 ratio train/dev:0.85
# 280 Train loss:0.045 Dev loss:0.051 ratio train/dev:0.88
# 300 Train loss:0.046 Dev loss:0.051 ratio train/dev:0.90
# 320 Train loss:0.046 Dev loss:0.051 ratio train/dev:0.91
# 340 Train loss:0.043 Dev loss:0.050 ratio train/dev:0.86
# 360 Train loss:0.041 Dev loss:0.050 ratio train/dev:0.81
# 380 Train loss:0.039 Dev loss:0.050 ratio train/dev:0.79
# 400 Train loss:0.037 Dev loss:0.050 ratio train/dev:0.74
# 420 Train loss:0.050 Dev loss:0.050 ratio train/dev:1.01
# 440 Train loss:0.052 Dev loss:0.050 ratio train/dev:1.04
# 460 Train loss:0.041 Dev loss:0.050 ratio train/dev:0.82
# 480 Train loss:0.042 Dev loss:0.049 ratio train/dev:0.84
# 500 Train loss:0.046 Dev loss:0.049 ratio train/dev:0.93
# 520 Train loss:0.035 Dev loss:0.049 ratio train/dev:0.71
# 540 Train loss:0.039 Dev loss:0.049 ratio train/dev:0.79
# 560 Train loss:0.037 Dev loss:0.049 ratio train/dev:0.75
# 580 Train loss:0.034 Dev loss:0.049 ratio train/dev:0.69
# 600 Train loss:0.034 Dev loss:0.049 ratio train/dev:0.70
# 620 Train loss:0.035 Dev loss:0.049 ratio train/dev:0.71
# 640 Train loss:0.036 Dev loss:0.049 ratio train/dev:0.74
# 660 Train loss:0.037 Dev loss:0.049 ratio train/dev:0.76
# 680 Train loss:0.040 Dev loss:0.049 ratio train/dev:0.82
# 700 Train loss:0.035 Dev loss:0.049 ratio train/dev:0.73
# 720 Train loss:0.033 Dev loss:0.048 ratio train/dev:0.69
# 740 Train loss:0.034 Dev loss:0.048 ratio train/dev:0.70
# 760 Train loss:0.036 Dev loss:0.048 ratio train/dev:0.74
# 780 Train loss:0.034 Dev loss:0.048 ratio train/dev:0.71
# 800 Train loss:0.035 Dev loss:0.048 ratio train/dev:0.73
# 820 Train loss:0.032 Dev loss:0.048 ratio train/dev:0.67
# 840 Train loss:0.035 Dev loss:0.048 ratio train/dev:0.72
# 860 Train loss:0.033 Dev loss:0.048 ratio train/dev:0.69
# 880 Train loss:0.033 Dev loss:0.048 ratio train/dev:0.69
# 900 Train loss:0.034 Dev loss:0.048 ratio train/dev:0.71
# 920 Train loss:0.032 Dev loss:0.048 ratio train/dev:0.66
# 940 Train loss:0.031 Dev loss:0.048 ratio train/dev:0.65
# 960 Train loss:0.030 Dev loss:0.048 ratio train/dev:0.62
# 980 Train loss:0.034 Dev loss:0.048 ratio train/dev:0.70
# 1000 Train loss:0.033 Dev loss:0.048 ratio train/dev:0.68
# 1020 Train loss:0.031 Dev loss:0.048 ratio train/dev:0.65
# 1040 Train loss:0.031 Dev loss:0.048 ratio train/dev:0.65
# 1060 Train loss:0.031 Dev loss:0.048 ratio train/dev:0.64
# 1080 Train loss:0.032 Dev loss:0.048 ratio train/dev:0.68
# 1100 Train loss:0.029 Dev loss:0.048 ratio train/dev:0.62
# 1120 Train loss:0.030 Dev loss:0.048 ratio train/dev:0.63
# 1140 Train loss:0.031 Dev loss:0.048 ratio train/dev:0.66
# 1160 Train loss:0.031 Dev loss:0.048 ratio train/dev:0.64
# 1180 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.63
# 1200 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.64
# 1220 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.63
# 1240 Train loss:0.029 Dev loss:0.047 ratio train/dev:0.61
# 1260 Train loss:0.026 Dev loss:0.047 ratio train/dev:0.55
# 1280 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.63
# 1300 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.63
# 1320 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.64
# 1340 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.58
# 1360 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.59
# 1380 Train loss:0.029 Dev loss:0.047 ratio train/dev:0.61
# 1400 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.64
# 1420 Train loss:0.029 Dev loss:0.047 ratio train/dev:0.61
# 1440 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.60
# 1460 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.57
# 1480 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.58
# 1500 Train loss:0.030 Dev loss:0.047 ratio train/dev:0.64
# 1520 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.60
# 1540 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.58
# 1560 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.59
# 1580 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.59
# 1600 Train loss:0.026 Dev loss:0.047 ratio train/dev:0.55
# 1620 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.58
# 1640 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.57
# 1660 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.58
# 1680 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.57
# 1700 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.58
# 1720 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.58
# 1740 Train loss:0.029 Dev loss:0.047 ratio train/dev:0.62
# 1760 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.60
# 1780 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.57
# 1800 Train loss:0.026 Dev loss:0.047 ratio train/dev:0.54
# 1820 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.59
# 1840 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.56
# 1860 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.59
# 1880 Train loss:0.026 Dev loss:0.047 ratio train/dev:0.56
# 1900 Train loss:0.026 Dev loss:0.047 ratio train/dev:0.54
# 1920 Train loss:0.026 Dev loss:0.047 ratio train/dev:0.56
# 1940 Train loss:0.026 Dev loss:0.047 ratio train/dev:0.55
# 1960 Train loss:0.024 Dev loss:0.047 ratio train/dev:0.50
# 1980 Train loss:0.028 Dev loss:0.047 ratio train/dev:0.59
# 2000 Train loss:0.027 Dev loss:0.047 ratio train/dev:0.57
# Total time taken: 469.21222162246704
# Model file: /home/ubuntu/notebooks/models/ind_model_eyebrow_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_eyebrow_/train_history
# Count of observations in training data by features
# left_eye_center_x     7039
# left_eye_center_y     7039
# right_eye_center_x    7036
# right_eye_center_y    7036
# Image                 7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (5626, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (5626, 4); y_train.min == -0.986; y_train.max == 0.973
# x_dev.shape = = (1407, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (1407, 4); y_dev.min == -0.888; y_dev.max == 0.637
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.96
# 20 Train loss:0.068 Dev loss:0.051 ratio train/dev:1.34
# 40 Train loss:0.067 Dev loss:0.049 ratio train/dev:1.38
# 60 Train loss:0.038 Dev loss:0.047 ratio train/dev:0.80
# 80 Train loss:0.052 Dev loss:0.046 ratio train/dev:1.12
# 100 Train loss:0.036 Dev loss:0.046 ratio train/dev:0.79
# 120 Train loss:0.036 Dev loss:0.045 ratio train/dev:0.79
# 140 Train loss:0.038 Dev loss:0.045 ratio train/dev:0.84
# 160 Train loss:0.036 Dev loss:0.045 ratio train/dev:0.80
# 180 Train loss:0.035 Dev loss:0.044 ratio train/dev:0.79
# 200 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.86
# 220 Train loss:0.035 Dev loss:0.044 ratio train/dev:0.80
# 240 Train loss:0.035 Dev loss:0.044 ratio train/dev:0.80
# 260 Train loss:0.032 Dev loss:0.044 ratio train/dev:0.74
# 280 Train loss:0.029 Dev loss:0.044 ratio train/dev:0.67
# 300 Train loss:0.035 Dev loss:0.044 ratio train/dev:0.79
# 320 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.82
# 340 Train loss:0.032 Dev loss:0.044 ratio train/dev:0.74
# 360 Train loss:0.032 Dev loss:0.043 ratio train/dev:0.74
# 380 Train loss:0.032 Dev loss:0.043 ratio train/dev:0.74
# 400 Train loss:0.052 Dev loss:0.043 ratio train/dev:1.19
# 420 Train loss:0.032 Dev loss:0.043 ratio train/dev:0.73
# 440 Train loss:0.027 Dev loss:0.043 ratio train/dev:0.63
# 460 Train loss:0.029 Dev loss:0.043 ratio train/dev:0.68
# 480 Train loss:0.028 Dev loss:0.043 ratio train/dev:0.65
# 500 Train loss:0.030 Dev loss:0.043 ratio train/dev:0.69
# 520 Train loss:0.031 Dev loss:0.043 ratio train/dev:0.73
# 540 Train loss:0.031 Dev loss:0.043 ratio train/dev:0.71
# 560 Train loss:0.027 Dev loss:0.043 ratio train/dev:0.63
# 580 Train loss:0.029 Dev loss:0.043 ratio train/dev:0.67
# 600 Train loss:0.026 Dev loss:0.043 ratio train/dev:0.62
# 620 Train loss:0.028 Dev loss:0.043 ratio train/dev:0.66
# 640 Train loss:0.026 Dev loss:0.043 ratio train/dev:0.61
# 660 Train loss:0.030 Dev loss:0.043 ratio train/dev:0.70
# 680 Train loss:0.028 Dev loss:0.043 ratio train/dev:0.65
# 700 Train loss:0.028 Dev loss:0.043 ratio train/dev:0.65
# 720 Train loss:0.029 Dev loss:0.043 ratio train/dev:0.69
# 740 Train loss:0.029 Dev loss:0.042 ratio train/dev:0.69
# 760 Train loss:0.028 Dev loss:0.043 ratio train/dev:0.67
# 780 Train loss:0.028 Dev loss:0.042 ratio train/dev:0.66
# 800 Train loss:0.026 Dev loss:0.042 ratio train/dev:0.62
# 820 Train loss:0.026 Dev loss:0.042 ratio train/dev:0.61
# 840 Train loss:0.032 Dev loss:0.042 ratio train/dev:0.75
# 860 Train loss:0.025 Dev loss:0.042 ratio train/dev:0.59
# 880 Train loss:0.027 Dev loss:0.043 ratio train/dev:0.64
# 900 Train loss:0.025 Dev loss:0.042 ratio train/dev:0.59
# 920 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.57
# 940 Train loss:0.025 Dev loss:0.042 ratio train/dev:0.60
# 960 Train loss:0.029 Dev loss:0.042 ratio train/dev:0.69
# 980 Train loss:0.027 Dev loss:0.042 ratio train/dev:0.64
# 1000 Train loss:0.027 Dev loss:0.042 ratio train/dev:0.63
# 1020 Train loss:0.027 Dev loss:0.042 ratio train/dev:0.65
# 1040 Train loss:0.026 Dev loss:0.042 ratio train/dev:0.61
# 1060 Train loss:0.025 Dev loss:0.042 ratio train/dev:0.58
# 1080 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.58
# 1100 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.57
# 1120 Train loss:0.022 Dev loss:0.042 ratio train/dev:0.53
# 1140 Train loss:0.026 Dev loss:0.042 ratio train/dev:0.62
# 1160 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.54
# 1180 Train loss:0.027 Dev loss:0.042 ratio train/dev:0.64
# 1200 Train loss:0.025 Dev loss:0.042 ratio train/dev:0.59
# 1220 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.56
# 1240 Train loss:0.026 Dev loss:0.042 ratio train/dev:0.62
# 1260 Train loss:0.029 Dev loss:0.042 ratio train/dev:0.70
# 1280 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.57
# 1300 Train loss:0.029 Dev loss:0.042 ratio train/dev:0.70
# 1320 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.56
# 1340 Train loss:0.046 Dev loss:0.042 ratio train/dev:1.09
# 1360 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.58
# 1380 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.57
# 1400 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.83
# 1420 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.54
# 1440 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.58
# 1460 Train loss:0.029 Dev loss:0.042 ratio train/dev:0.69
# 1480 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.84
# 1500 Train loss:0.021 Dev loss:0.042 ratio train/dev:0.51
# 1520 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.57
# 1540 Train loss:0.025 Dev loss:0.042 ratio train/dev:0.60
# 1560 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.55
# 1580 Train loss:0.022 Dev loss:0.042 ratio train/dev:0.53
# 1600 Train loss:0.028 Dev loss:0.042 ratio train/dev:0.67
# 1620 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.55
# 1640 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.58
# 1660 Train loss:0.024 Dev loss:0.042 ratio train/dev:0.56
# 1680 Train loss:0.021 Dev loss:0.042 ratio train/dev:0.50
# 1700 Train loss:0.021 Dev loss:0.042 ratio train/dev:0.50
# 1720 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.54
# 1740 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.54
# 1760 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.56
# 1780 Train loss:0.019 Dev loss:0.042 ratio train/dev:0.46
# 1800 Train loss:0.025 Dev loss:0.042 ratio train/dev:0.59
# 1820 Train loss:0.021 Dev loss:0.042 ratio train/dev:0.51
# 1840 Train loss:0.021 Dev loss:0.042 ratio train/dev:0.49
# 1860 Train loss:0.023 Dev loss:0.042 ratio train/dev:0.56
# 1880 Train loss:0.020 Dev loss:0.042 ratio train/dev:0.47
# 1900 Train loss:0.022 Dev loss:0.042 ratio train/dev:0.53
# 1920 Train loss:0.022 Dev loss:0.042 ratio train/dev:0.52
# 1940 Train loss:0.022 Dev loss:0.042 ratio train/dev:0.52
# 1960 Train loss:0.019 Dev loss:0.042 ratio train/dev:0.45
# 1980 Train loss:0.020 Dev loss:0.042 ratio train/dev:0.48
# 2000 Train loss:0.022 Dev loss:0.042 ratio train/dev:0.52
# Total time taken: 1551.525372505188
# Model file: /home/ubuntu/notebooks/models/ind_model_eye_center_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_eye_center_/train_history
#  Total time for all models:  6231.244295597076

# %%
# Plots history of learning curves for individual features model. 
def plot_ind_model_curves(spec_name, color):
    
    train_history_path = FROOT + "/models/" + "ind_model_" + spec_name + "_"  + "/train_history"
    model_history = np.load(train_history_path + ".npz")
    train_loss = model_history["train_loss_history"][:,1]
    
    valid_loss = model_history["valid_loss_history"][:,1]
    
    x_axis = np.arange(n_epochs)
    
    label_name = spec_name.replace("_", " ")
    #plt.plot(x_axis[train_loss > 0], train_loss[train_loss > 0], color + "--", linewidth=2, label = label_name)
    #plt.plot(x_axis[valid_loss > 0], valid_loss[valid_loss > 0], color + "-", linewidth=2)
    plt.plot(x_axis[valid_loss > 0], valid_loss[valid_loss > 0], color + "--", linewidth=2, label = label_name)
    
    return valid_loss

# %%
#Get mean loss from individual models 

plt.figure(figsize=(12, 12))
colors = ["b", "g", "r", "c", "m", "y"]
weighted_valid_loss = np.zeros(n_epochs)
total_features = 0
for facial_model_label in facial_group_labels:
    valid_loss_ind = plot_ind_model_curves(facial_model_label['name'], colors[facial_group_labels.index(facial_model_label) % len(colors)])
    
    weighted_valid_loss += valid_loss_ind * len(facial_model_label['columns'])
    
    total_features += len(facial_model_label['columns'])
                               
    mean_loss = weighted_valid_loss/total_features

print("Mean loss from individual models: %0.4f"% mean_loss[-1])
x_axis = np.arange(n_epochs)
   

plt.plot(x_axis[mean_loss > 0], mean_loss[mean_loss > 0], "k" + "--", linewidth=2, label = "mean loss")
                                

plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
#plt.ylim(0.0003, 0.1)
plt.xlim(0, n_epochs)
plt.yscale("log")
plt.show()
# Out:
# Mean loss from individual models: 0.0448
