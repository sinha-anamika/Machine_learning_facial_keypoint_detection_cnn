# %%
import os

import numpy as np
from pandas.io.parsers import read_csv
from sklearn.utils import shuffle
from decimal import *
import tensorflow as tf
import time
import matplotlib.pyplot as plt

# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# %%
#getting the data

FTRAIN = '~/notebooks/training.csv'
FTEST = '~/notebooks/test.csv'

def load(test = False, cols = None):
    '''Loads data from FTEST if *test* is true, otherwise from FTRAIN.' 
    Pass a list of *cols* if you are only interested in a
    subset of the target columns'''
    
    fname = FTEST if test else FTRAIN
    df = read_csv(os.path.expanduser(fname)) #load pandas dataframe
    print(list(df)) #print the names of columns in the dataframe
    
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im,sep=' ')) 
    #image column has pixel values separated by space; convert the values to numpy arrays
    
    if cols: #get a subset of columns
        df = df[list(cols) + ['Image']]
        
    print('Count of observations in training data by features')
    print(df.count()) #prints number of values for each column
    df = df.dropna() #drop all rows that have missing values in them
    
    X = np.vstack(df['Image'].values)/255
    X = X.astype(np.float32)
    
    if not test:
        y  = df[df.columns[:-1]].values
        y = (y-48)/48
        shuffle = np.random.permutation(np.arange(X.shape[0]))
        X, y = X[shuffle], y[shuffle]
        y = y.astype(np.float32)
    else:
        y = None
        
    return X,y

Xnp,ynp = load()

print('Total training data')
print("Xnp.shape = = {}; Xnp.min == {:.3f}; Xnp.max == {:.3f}".format(Xnp.shape, Xnp.min(),Xnp.max()))
print("ynp.shape = = {}; ynp.min == {:.3f}; ynp.max == {:.3f}".format(ynp.shape, ynp.min(),ynp.max()))
dev_size = 0.2
Xdev,ydev = Xnp[int(Xnp.shape[0]*(1-dev_size)):,:],ynp[int(Xnp.shape[0]*(1-dev_size)):] #setting aside a 20% sample for validation
Xnp,ynp = Xnp[:int(Xnp.shape[0]*(1-dev_size)),:],ynp[:int(Xnp.shape[0]*(1-dev_size))]
X_test, _ = load(test=True)

print('Training data split into train and dev data')
print("Xnp.shape = = {}; Xnp.min == {:.3f}; Xnp.max == {:.3f}".format(Xnp.shape, Xnp.min(),Xnp.max()))
print("ynp.shape = = {}; ynp.min == {:.3f}; ynp.max == {:.3f}".format(ynp.shape, ynp.min(),ynp.max()))
print("Xdev.shape = = {}; Xdev.min == {:.3f}; Xdev.max == {:.3f}".format(Xdev.shape, Xdev.min(),Xdev.max()))
print("ydev.shape = = {}; ydev.min == {:.3f}; ydev.max == {:.3f}".format(ydev.shape, ydev.min(),ydev.max()))
# Out:
# ['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x', 'right_eye_center_y', 'left_eye_inner_corner_x', 'left_eye_inner_corner_y', 'left_eye_outer_corner_x', 'left_eye_outer_corner_y', 'right_eye_inner_corner_x', 'right_eye_inner_corner_y', 'right_eye_outer_corner_x', 'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x', 'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x', 'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x', 'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x', 'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y', 'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x', 'mouth_right_corner_y', 'mouth_center_top_lip_x', 'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x', 'mouth_center_bottom_lip_y', 'Image']
# Count of observations in training data by features
# left_eye_center_x            7039
# left_eye_center_y            7039
# right_eye_center_x           7036
# right_eye_center_y           7036
# left_eye_inner_corner_x      2271
# left_eye_inner_corner_y      2271
# left_eye_outer_corner_x      2267
# left_eye_outer_corner_y      2267
# right_eye_inner_corner_x     2268
# right_eye_inner_corner_y     2268
# right_eye_outer_corner_x     2268
# right_eye_outer_corner_y     2268
# left_eyebrow_inner_end_x     2270
# left_eyebrow_inner_end_y     2270
# left_eyebrow_outer_end_x     2225
# left_eyebrow_outer_end_y     2225
# right_eyebrow_inner_end_x    2270
# right_eyebrow_inner_end_y    2270
# right_eyebrow_outer_end_x    2236
# right_eyebrow_outer_end_y    2236
# nose_tip_x                   7049
# nose_tip_y                   7049
# mouth_left_corner_x          2269
# mouth_left_corner_y          2269
# mouth_right_corner_x         2270
# mouth_right_corner_y         2270
# mouth_center_top_lip_x       2275
# mouth_center_top_lip_y       2275
# mouth_center_bottom_lip_x    7016
# mouth_center_bottom_lip_y    7016
# Image                        7049
# dtype: int64
# Total training data
# Xnp.shape = = (2140, 9216); Xnp.min == 0.000; Xnp.max == 1.000
# ynp.shape = = (2140, 30); ynp.min == -0.920; ynp.max == 0.996
# ['ImageId', 'Image']
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# Training data split into train and dev data
# Xnp.shape = = (1712, 9216); Xnp.min == 0.000; Xnp.max == 1.000
# ynp.shape = = (1712, 30); ynp.min == -0.920; ynp.max == 0.996
# Xdev.shape = = (428, 9216); Xdev.min == 0.000; Xdev.max == 1.000
# ydev.shape = = (428, 30); ydev.min == -0.916; ydev.max == 0.977

# %%
from tensorflow.contrib.layers import fully_connected

tf.reset_default_graph()

n_inputs = Xnp.shape[1]
n_hidden1 = 100
n_hidden2 = 60
n_outputs = 30

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')

with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1') #uses default activation function of relu, can be changed.
    #hidden2 = fully_connected(hidden1,n_hidden2,scope = 'hidden2') #took this layer out as we have too few data points to esimtate this many parameters
    pred_keypoints = fully_connected(hidden1,n_outputs,activation_fn = None,scope = 'outputs')
    
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))
    
    
learning_rate = 0.01
momentum = 0.9


with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum) #works better than gradientdescentoptimizer
    training_op = optimizer.minimize(loss)
    
init = tf.global_variables_initializer()

n_epochs = 401
batch_size = 50
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))

time_start = time.time()
time_1000_start = time.time()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xnp, ynp = Xnp[shuffle], ynp[shuffle]
        for i in range(int(Xnp.shape[0]//batch_size)): #run through most of the data points in each epoch
            X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:],ynp[i*batch_size:(i+1)*batch_size]
            #print(i,X_batch[1,1],y_batch[1])
            sess.run(training_op,feed_dict = {X:X_batch,y:y_batch})
            loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch})
            loss_dev = loss.eval(feed_dict = {X:Xdev,y:ydev})
            train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
            dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
            
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        if epoch == 25:
            y_pred_25 = sess.run(pred_keypoints,feed_dict = {X:X_test})
        elif epoch == 75:    
            y_pred_75 = sess.run(pred_keypoints,feed_dict = {X:X_test})
    time_end = time.time()  
    y_pred = sess.run(pred_keypoints,feed_dict = {X:X_test})
   
    print('Total time taken:',time_end-time_start)
    
#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(15, 18))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(10):
    ax = fig.add_subplot(4, 5, i + 1 + 5*int(i/5), xticks=[], yticks=[],title = 'epoch 25')
    plot_sample(X_test[i], y_pred_25[i], ax)
    ax = fig.add_subplot(4,5,i+6+ 5*int(i/5),xticks=[],yticks=[],title = 'epoch 200')
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# 0 Train loss:0.132 Dev loss:0.135 ratio train/dev:0.98
# 10 Train loss:0.095 Dev loss:0.093 ratio train/dev:1.02
# 20 Train loss:0.084 Dev loss:0.090 ratio train/dev:0.93
# 30 Train loss:0.073 Dev loss:0.082 ratio train/dev:0.89
# 40 Train loss:0.064 Dev loss:0.078 ratio train/dev:0.82
# 50 Train loss:0.061 Dev loss:0.074 ratio train/dev:0.83
# 60 Train loss:0.062 Dev loss:0.071 ratio train/dev:0.87
# 70 Train loss:0.057 Dev loss:0.070 ratio train/dev:0.81
# 80 Train loss:0.055 Dev loss:0.067 ratio train/dev:0.82
# 90 Train loss:0.057 Dev loss:0.067 ratio train/dev:0.85
# 100 Train loss:0.053 Dev loss:0.065 ratio train/dev:0.81
# 110 Train loss:0.055 Dev loss:0.064 ratio train/dev:0.86
# 120 Train loss:0.051 Dev loss:0.063 ratio train/dev:0.81
# 130 Train loss:0.052 Dev loss:0.065 ratio train/dev:0.79
# 140 Train loss:0.056 Dev loss:0.063 ratio train/dev:0.89
# 150 Train loss:0.048 Dev loss:0.062 ratio train/dev:0.78
# 160 Train loss:0.048 Dev loss:0.060 ratio train/dev:0.81
# 170 Train loss:0.044 Dev loss:0.060 ratio train/dev:0.73
# 180 Train loss:0.041 Dev loss:0.059 ratio train/dev:0.69
# 190 Train loss:0.042 Dev loss:0.059 ratio train/dev:0.72
# 200 Train loss:0.042 Dev loss:0.058 ratio train/dev:0.72
# 210 Train loss:0.043 Dev loss:0.058 ratio train/dev:0.75
# 220 Train loss:0.043 Dev loss:0.058 ratio train/dev:0.74
# 230 Train loss:0.043 Dev loss:0.058 ratio train/dev:0.75
# 240 Train loss:0.040 Dev loss:0.057 ratio train/dev:0.70
# 250 Train loss:0.043 Dev loss:0.057 ratio train/dev:0.75
# 260 Train loss:0.042 Dev loss:0.057 ratio train/dev:0.75
# 270 Train loss:0.045 Dev loss:0.057 ratio train/dev:0.79
# 280 Train loss:0.045 Dev loss:0.056 ratio train/dev:0.79
# 290 Train loss:0.042 Dev loss:0.056 ratio train/dev:0.75
# 300 Train loss:0.043 Dev loss:0.056 ratio train/dev:0.77
# 310 Train loss:0.042 Dev loss:0.055 ratio train/dev:0.76
# 320 Train loss:0.041 Dev loss:0.056 ratio train/dev:0.73
# 330 Train loss:0.040 Dev loss:0.055 ratio train/dev:0.72
# 340 Train loss:0.039 Dev loss:0.055 ratio train/dev:0.71
# 350 Train loss:0.038 Dev loss:0.055 ratio train/dev:0.70
# 360 Train loss:0.039 Dev loss:0.055 ratio train/dev:0.71
# 370 Train loss:0.038 Dev loss:0.055 ratio train/dev:0.69
# 380 Train loss:0.036 Dev loss:0.055 ratio train/dev:0.66
# 390 Train loss:0.041 Dev loss:0.055 ratio train/dev:0.75
# 400 Train loss:0.037 Dev loss:0.054 ratio train/dev:0.68
# Total time taken: 166.45707488059998

# %%
#Building a convolutional neural network
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    return tf.Variable(initial)

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides = [1,1,1,1],padding = 'SAME')

def max_pool_2X2(x):
    return(tf.nn.max_pool(x,ksize = [1,2,2,1],strides = [1,2,2,1],padding = 'SAME'))

#input data
x = tf.placeholder(tf.float32,[None,Xnp.shape[1]])
y = tf.placeholder(tf.float32,[None,ynp.shape[1]])

#First convolutional layer
W_conv1 = weight_variable([3,3,1,32]) #first two dimensions are patch size, next is channels, and last is the number of output channels
b_conv1 = bias_variable([32]) #bias vector has a component for each output channel

X_image = tf.reshape(x,[-1,96,96,1]) #2nd and 3rd dimension is image width and height, final dimension is number of color channels

h_conv1 = tf.nn.relu(conv2d(X_image,W_conv1) + b_conv1)
h_pool1 = max_pool_2X2(h_conv1) #reduces image size to 48X48

#Second covolutional layer
W_conv2 = weight_variable([2,2,32,64]) # 64 features for each 2X2 patch
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
h_pool2 = max_pool_2X2(h_conv2)  #reduces image size to 24X24

#Third convolutional layer
W_conv3 = weight_variable([2,2,64,128]) # 128 features for each 2X2 patch
b_conv3 = bias_variable([128])

h_conv3 = tf.nn.relu(conv2d(h_pool2,W_conv3) + b_conv3)
h_pool3 = max_pool_2X2(h_conv3)  #reduces image size to 24X24


#Densely connected layer
W_fc1 = weight_variable([12*12*128,512]) #fully connected layer with 1024 neurons to allow processing the entire image
b_fc1 = bias_variable([512])

# W_fc2 = weight_variable([512,512]) #fully connected layer with 1024 neurons to allow processing the entire image
# b_fc2 = bias_variable([512])

h_pool3_flat = tf.reshape(h_pool3,[-1,12*12*128])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat,W_fc1) + b_fc1)

#Dropout
#keep_prob = tf.placeholder(tf.float32) # variable to turn on dropout during training, and turn off during test
#h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

#Readout layer
W_fc2 = weight_variable([512,30])
b_fc2 = bias_variable([30])

y_conv = tf.matmul(h_fc1,W_fc2) + b_fc2

#loss function
loss = tf.reduce_mean(np.square(y_conv - y))

#optimizer
#train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
learning_rate = 0.001
momentum = 0.9
optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum,use_nesterov = True) 
train_step = optimizer.minimize(loss)

n_epochs = 201
batch_size = 100
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))
y_pred = np.zeros((X_test.shape[0],ynp.shape[1]))


time_start = time.time()
time_1000_start = time.time()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xnp, ynp = Xnp[shuffle], ynp[shuffle]
        
        for i in range(int(Xnp.shape[0]//batch_size)-4): #run through most of the data points in each epoch
            X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:],ynp[i*batch_size:(i+1)*batch_size]
            #print(i,X_batch[1,1],y_batch[1])
            sess.run(train_step,feed_dict = {x:X_batch,y:y_batch})
            loss_train = loss.eval(feed_dict = {x:X_batch,y:y_batch})
            loss_dev = loss.eval(feed_dict = {x:Xdev,y:ydev})
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%5 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    for i in range(int(X_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = X_test[i*batch_size:(i+1)*batch_size,:]
            y_pred[i*batch_size:(i+1)*batch_size] = sess.run(y_conv,feed_dict = {x:X_batch})
   


#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(16, 16))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# 0 Train loss:0.329 Dev loss:0.330 ratio train/dev:1.00
# 5 Train loss:0.147 Dev loss:0.150 ratio train/dev:0.98
# 10 Train loss:0.131 Dev loss:0.131 ratio train/dev:1.00
# 15 Train loss:0.116 Dev loss:0.121 ratio train/dev:0.96
# 20 Train loss:0.108 Dev loss:0.114 ratio train/dev:0.95
# 25 Train loss:0.109 Dev loss:0.109 ratio train/dev:1.00
# 30 Train loss:0.102 Dev loss:0.105 ratio train/dev:0.97
# 35 Train loss:0.100 Dev loss:0.102 ratio train/dev:0.98
# 40 Train loss:0.100 Dev loss:0.099 ratio train/dev:1.01
# 45 Train loss:0.094 Dev loss:0.096 ratio train/dev:0.98
# 50 Train loss:0.097 Dev loss:0.095 ratio train/dev:1.02
# 55 Train loss:0.089 Dev loss:0.093 ratio train/dev:0.96
# 60 Train loss:0.092 Dev loss:0.092 ratio train/dev:1.01
# 65 Train loss:0.093 Dev loss:0.090 ratio train/dev:1.03
# 70 Train loss:0.089 Dev loss:0.089 ratio train/dev:1.01
# 75 Train loss:0.086 Dev loss:0.088 ratio train/dev:0.98
# 80 Train loss:0.082 Dev loss:0.087 ratio train/dev:0.95
# 85 Train loss:0.084 Dev loss:0.086 ratio train/dev:0.97
# 90 Train loss:0.085 Dev loss:0.085 ratio train/dev:1.00
# 95 Train loss:0.082 Dev loss:0.084 ratio train/dev:0.97
# 100 Train loss:0.079 Dev loss:0.083 ratio train/dev:0.95
# 105 Train loss:0.082 Dev loss:0.083 ratio train/dev:0.99
# 110 Train loss:0.082 Dev loss:0.082 ratio train/dev:1.00
# 115 Train loss:0.080 Dev loss:0.082 ratio train/dev:0.98
# 120 Train loss:0.078 Dev loss:0.081 ratio train/dev:0.96
# 125 Train loss:0.080 Dev loss:0.081 ratio train/dev:0.99
# 130 Train loss:0.078 Dev loss:0.080 ratio train/dev:0.97
# 135 Train loss:0.081 Dev loss:0.080 ratio train/dev:1.02
# 140 Train loss:0.080 Dev loss:0.079 ratio train/dev:1.01
# 145 Train loss:0.078 Dev loss:0.079 ratio train/dev:0.99
# 150 Train loss:0.074 Dev loss:0.079 ratio train/dev:0.93
# 155 Train loss:0.075 Dev loss:0.078 ratio train/dev:0.95
# 160 Train loss:0.074 Dev loss:0.078 ratio train/dev:0.95
# 165 Train loss:0.074 Dev loss:0.078 ratio train/dev:0.95
# 170 Train loss:0.073 Dev loss:0.077 ratio train/dev:0.95
# 175 Train loss:0.074 Dev loss:0.077 ratio train/dev:0.96
# 180 Train loss:0.079 Dev loss:0.077 ratio train/dev:1.02
# 185 Train loss:0.069 Dev loss:0.077 ratio train/dev:0.90
# 190 Train loss:0.073 Dev loss:0.076 ratio train/dev:0.96
# 195 Train loss:0.072 Dev loss:0.076 ratio train/dev:0.95
# 200 Train loss:0.082 Dev loss:0.076 ratio train/dev:1.08
# Total time taken: 1066.5264339447021

# %%
#CNN with more stochastic batch training ie each batch is reshuffled instead of reshuffling and then doing a full pass through the data
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    return tf.Variable(initial)

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides = [1,1,1,1],padding = 'SAME')

def max_pool_2X2(x):
    return(tf.nn.max_pool(x,ksize = [1,2,2,1],strides = [1,2,2,1],padding = 'SAME'))

#input data
x = tf.placeholder(tf.float32,[None,Xnp.shape[1]])
y = tf.placeholder(tf.float32,[None,ynp.shape[1]])

#First convolutional layer
W_conv1 = weight_variable([3,3,1,32]) #first two dimensions are patch size, next is channels, and last is the number of output channels
b_conv1 = bias_variable([32]) #bias vector has a component for each output channel

X_image = tf.reshape(x,[-1,96,96,1]) #2nd and 3rd dimension is image width and height, final dimension is number of color channels

h_conv1 = tf.nn.relu(conv2d(X_image,W_conv1) + b_conv1)
h_pool1 = max_pool_2X2(h_conv1) #reduces image size to 48X48

#Second covolutional layer
W_conv2 = weight_variable([2,2,32,64]) # 64 features for each 2X2 patch
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
h_pool2 = max_pool_2X2(h_conv2)  #reduces image size to 24X24

#Third convolutional layer
W_conv3 = weight_variable([2,2,64,128]) # 128 features for each 2X2 patch
b_conv3 = bias_variable([128])

h_conv3 = tf.nn.relu(conv2d(h_pool2,W_conv3) + b_conv3)
h_pool3 = max_pool_2X2(h_conv3)  #reduces image size to 24X24


#Densely connected layer
W_fc1 = weight_variable([12*12*128,512]) #fully connected layer with 1024 neurons to allow processing the entire image
b_fc1 = bias_variable([512])

# W_fc2 = weight_variable([512,512]) #fully connected layer with 1024 neurons to allow processing the entire image
# b_fc2 = bias_variable([512])

h_pool3_flat = tf.reshape(h_pool3,[-1,12*12*128])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat,W_fc1) + b_fc1)

#Dropout
#keep_prob = tf.placeholder(tf.float32) # variable to turn on dropout during training, and turn off during test
#h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

#Readout layer
W_fc2 = weight_variable([512,30])
b_fc2 = bias_variable([30])

y_conv = tf.matmul(h_fc1,W_fc2) + b_fc2

#loss function
loss = tf.reduce_mean(np.square(y_conv - y))

#optimizer
#train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
learning_rate = 0.005
momentum = 0.9
optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum,use_nesterov = True) 
train_step = optimizer.minimize(loss)

n_epochs = 2500
batch_size = 128
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))
y_pred = np.zeros((X_test.shape[0],ynp.shape[1]))


time_start = time.time()
time_1000_start = time.time()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xnp, ynp = Xnp[shuffle], ynp[shuffle]
        X_batch,y_batch = Xnp[:batch_size,:],ynp[:batch_size]
        sess.run(train_step,feed_dict = {x:X_batch,y:y_batch})
        loss_train = loss.eval(feed_dict = {x:X_batch,y:y_batch})
        loss_dev = loss.eval(feed_dict = {x:Xdev,y:ydev})
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%5 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    for i in range(int(X_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = X_test[i*batch_size:(i+1)*batch_size,:]
            y_pred[i*batch_size:(i+1)*batch_size] = sess.run(y_conv,feed_dict = {x:X_batch})
   


#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(16, 16))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# 0 Train loss:6.345 Dev loss:6.294 ratio train/dev:1.01
# 5 Train loss:0.325 Dev loss:0.323 ratio train/dev:1.01
# 10 Train loss:0.199 Dev loss:0.201 ratio train/dev:0.99
# 15 Train loss:0.162 Dev loss:0.160 ratio train/dev:1.01
# 20 Train loss:0.129 Dev loss:0.129 ratio train/dev:0.99
# 25 Train loss:0.117 Dev loss:0.118 ratio train/dev:0.99
# 30 Train loss:0.105 Dev loss:0.107 ratio train/dev:0.99
# 35 Train loss:0.105 Dev loss:0.101 ratio train/dev:1.04
# 40 Train loss:0.095 Dev loss:0.097 ratio train/dev:0.98
# 45 Train loss:0.093 Dev loss:0.093 ratio train/dev:1.01
# 50 Train loss:0.092 Dev loss:0.090 ratio train/dev:1.02
# 55 Train loss:0.087 Dev loss:0.088 ratio train/dev:0.99
# 60 Train loss:0.082 Dev loss:0.086 ratio train/dev:0.96
# 65 Train loss:0.084 Dev loss:0.084 ratio train/dev:0.99
# 70 Train loss:0.085 Dev loss:0.083 ratio train/dev:1.02
# 75 Train loss:0.082 Dev loss:0.082 ratio train/dev:1.00
# 80 Train loss:0.085 Dev loss:0.081 ratio train/dev:1.05
# 85 Train loss:0.080 Dev loss:0.081 ratio train/dev:0.99
# 90 Train loss:0.083 Dev loss:0.080 ratio train/dev:1.05
# 95 Train loss:0.076 Dev loss:0.079 ratio train/dev:0.97
# 100 Train loss:0.078 Dev loss:0.078 ratio train/dev:1.00
# 105 Train loss:0.075 Dev loss:0.078 ratio train/dev:0.96
# 110 Train loss:0.081 Dev loss:0.077 ratio train/dev:1.04
# 115 Train loss:0.082 Dev loss:0.077 ratio train/dev:1.07
# 120 Train loss:0.077 Dev loss:0.076 ratio train/dev:1.01
# 125 Train loss:0.079 Dev loss:0.076 ratio train/dev:1.03
# 130 Train loss:0.077 Dev loss:0.076 ratio train/dev:1.02
# 135 Train loss:0.077 Dev loss:0.075 ratio train/dev:1.02
# 140 Train loss:0.075 Dev loss:0.075 ratio train/dev:1.00
# 145 Train loss:0.077 Dev loss:0.075 ratio train/dev:1.02
# 150 Train loss:0.073 Dev loss:0.075 ratio train/dev:0.98
# 155 Train loss:0.079 Dev loss:0.074 ratio train/dev:1.06
# 160 Train loss:0.074 Dev loss:0.074 ratio train/dev:1.00
# 165 Train loss:0.075 Dev loss:0.074 ratio train/dev:1.02
# 170 Train loss:0.076 Dev loss:0.073 ratio train/dev:1.04
# 175 Train loss:0.079 Dev loss:0.073 ratio train/dev:1.08
# 180 Train loss:0.076 Dev loss:0.073 ratio train/dev:1.05
# 185 Train loss:0.075 Dev loss:0.073 ratio train/dev:1.04
# 190 Train loss:0.075 Dev loss:0.073 ratio train/dev:1.03
# 195 Train loss:0.073 Dev loss:0.073 ratio train/dev:1.00
# 200 Train loss:0.071 Dev loss:0.072 ratio train/dev:0.99
# 205 Train loss:0.073 Dev loss:0.072 ratio train/dev:1.01
# 210 Train loss:0.071 Dev loss:0.072 ratio train/dev:0.99
# 215 Train loss:0.069 Dev loss:0.072 ratio train/dev:0.96
# 220 Train loss:0.071 Dev loss:0.072 ratio train/dev:0.99
# 225 Train loss:0.074 Dev loss:0.071 ratio train/dev:1.03
# 230 Train loss:0.075 Dev loss:0.071 ratio train/dev:1.04
# 235 Train loss:0.075 Dev loss:0.071 ratio train/dev:1.05
# 240 Train loss:0.074 Dev loss:0.071 ratio train/dev:1.03
# 245 Train loss:0.073 Dev loss:0.071 ratio train/dev:1.03
# 250 Train loss:0.074 Dev loss:0.071 ratio train/dev:1.05
# 255 Train loss:0.073 Dev loss:0.071 ratio train/dev:1.03
# 260 Train loss:0.072 Dev loss:0.070 ratio train/dev:1.03
# 265 Train loss:0.072 Dev loss:0.070 ratio train/dev:1.02
# 270 Train loss:0.069 Dev loss:0.070 ratio train/dev:0.98
# 275 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.95
# 280 Train loss:0.071 Dev loss:0.070 ratio train/dev:1.02
# 285 Train loss:0.069 Dev loss:0.070 ratio train/dev:0.98
# 290 Train loss:0.070 Dev loss:0.070 ratio train/dev:1.00
# 295 Train loss:0.073 Dev loss:0.070 ratio train/dev:1.05
# 300 Train loss:0.069 Dev loss:0.070 ratio train/dev:0.99
# 305 Train loss:0.073 Dev loss:0.070 ratio train/dev:1.05
# 310 Train loss:0.070 Dev loss:0.070 ratio train/dev:1.00
# 315 Train loss:0.071 Dev loss:0.070 ratio train/dev:1.02
# 320 Train loss:0.069 Dev loss:0.069 ratio train/dev:1.00
# 325 Train loss:0.070 Dev loss:0.069 ratio train/dev:1.02
# 330 Train loss:0.071 Dev loss:0.069 ratio train/dev:1.02
# 335 Train loss:0.071 Dev loss:0.069 ratio train/dev:1.03
# 340 Train loss:0.069 Dev loss:0.069 ratio train/dev:1.01
# 345 Train loss:0.070 Dev loss:0.069 ratio train/dev:1.01
# 350 Train loss:0.074 Dev loss:0.069 ratio train/dev:1.08
# 355 Train loss:0.069 Dev loss:0.069 ratio train/dev:1.00
# 360 Train loss:0.071 Dev loss:0.069 ratio train/dev:1.03
# 365 Train loss:0.072 Dev loss:0.069 ratio train/dev:1.05
# 370 Train loss:0.068 Dev loss:0.069 ratio train/dev:0.99
# 375 Train loss:0.074 Dev loss:0.069 ratio train/dev:1.07
# 380 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.96
# 385 Train loss:0.071 Dev loss:0.068 ratio train/dev:1.04
# 390 Train loss:0.070 Dev loss:0.068 ratio train/dev:1.03
# 395 Train loss:0.067 Dev loss:0.068 ratio train/dev:0.98
# 400 Train loss:0.068 Dev loss:0.069 ratio train/dev:1.00
# 405 Train loss:0.067 Dev loss:0.068 ratio train/dev:0.98
# 410 Train loss:0.073 Dev loss:0.068 ratio train/dev:1.07
# 415 Train loss:0.069 Dev loss:0.068 ratio train/dev:1.02
# 420 Train loss:0.066 Dev loss:0.068 ratio train/dev:0.96
# 425 Train loss:0.073 Dev loss:0.068 ratio train/dev:1.07
# 430 Train loss:0.072 Dev loss:0.068 ratio train/dev:1.06
# 435 Train loss:0.070 Dev loss:0.068 ratio train/dev:1.04
# 440 Train loss:0.071 Dev loss:0.068 ratio train/dev:1.05
# 445 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.96
# 450 Train loss:0.068 Dev loss:0.068 ratio train/dev:1.01
# 455 Train loss:0.070 Dev loss:0.068 ratio train/dev:1.04
# 460 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.95
# 465 Train loss:0.069 Dev loss:0.068 ratio train/dev:1.01
# 470 Train loss:0.069 Dev loss:0.068 ratio train/dev:1.02
# 475 Train loss:0.069 Dev loss:0.068 ratio train/dev:1.02
# 480 Train loss:0.070 Dev loss:0.068 ratio train/dev:1.04
# 485 Train loss:0.067 Dev loss:0.067 ratio train/dev:0.99
# 490 Train loss:0.073 Dev loss:0.068 ratio train/dev:1.09
# 495 Train loss:0.067 Dev loss:0.068 ratio train/dev:1.00
# 500 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.03
# 505 Train loss:0.071 Dev loss:0.068 ratio train/dev:1.05
# 510 Train loss:0.072 Dev loss:0.068 ratio train/dev:1.07
# 515 Train loss:0.067 Dev loss:0.067 ratio train/dev:0.99
# 520 Train loss:0.068 Dev loss:0.067 ratio train/dev:1.01
# 525 Train loss:0.068 Dev loss:0.067 ratio train/dev:1.02
# 530 Train loss:0.068 Dev loss:0.067 ratio train/dev:1.01
# 535 Train loss:0.073 Dev loss:0.067 ratio train/dev:1.09
# 540 Train loss:0.065 Dev loss:0.067 ratio train/dev:0.97
# 545 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.03
# 550 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.02
# 555 Train loss:0.068 Dev loss:0.067 ratio train/dev:1.01
# 560 Train loss:0.068 Dev loss:0.067 ratio train/dev:1.01
# 565 Train loss:0.072 Dev loss:0.067 ratio train/dev:1.08
# 570 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.03
# 575 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.02
# 580 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.03
# 585 Train loss:0.065 Dev loss:0.067 ratio train/dev:0.97
# 590 Train loss:0.064 Dev loss:0.067 ratio train/dev:0.95
# 595 Train loss:0.072 Dev loss:0.067 ratio train/dev:1.07
# 600 Train loss:0.066 Dev loss:0.067 ratio train/dev:0.99
# 605 Train loss:0.068 Dev loss:0.067 ratio train/dev:1.02
# 610 Train loss:0.065 Dev loss:0.067 ratio train/dev:0.97
# 615 Train loss:0.064 Dev loss:0.067 ratio train/dev:0.95
# 620 Train loss:0.066 Dev loss:0.067 ratio train/dev:0.98
# 625 Train loss:0.071 Dev loss:0.067 ratio train/dev:1.06
# 630 Train loss:0.068 Dev loss:0.067 ratio train/dev:1.03
# 635 Train loss:0.071 Dev loss:0.067 ratio train/dev:1.06
# 640 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.03
# 645 Train loss:0.067 Dev loss:0.067 ratio train/dev:1.00
# 650 Train loss:0.072 Dev loss:0.067 ratio train/dev:1.08
# 655 Train loss:0.066 Dev loss:0.067 ratio train/dev:1.00
# 660 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.05
# 665 Train loss:0.069 Dev loss:0.067 ratio train/dev:1.04
# 670 Train loss:0.067 Dev loss:0.067 ratio train/dev:1.01
# 675 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 680 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.06
# 685 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.02
# 690 Train loss:0.065 Dev loss:0.067 ratio train/dev:0.98
# 695 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.05
# 700 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.05
# 705 Train loss:0.074 Dev loss:0.066 ratio train/dev:1.12
# 710 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.04
# 715 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.96
# 720 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 725 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.03
# 730 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.01
# 735 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.05
# 740 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.00
# 745 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.04
# 750 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.04
# 755 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.96
# 760 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 765 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.96
# 770 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.00
# 775 Train loss:0.062 Dev loss:0.066 ratio train/dev:0.94
# 780 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.00
# 785 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.00
# 790 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.01
# 795 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.00
# 800 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 805 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.98
# 810 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 815 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 820 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.06
# 825 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.02
# 830 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 835 Train loss:0.071 Dev loss:0.066 ratio train/dev:1.07
# 840 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 845 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 850 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.01
# 855 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.95
# 860 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 865 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.96
# 870 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 875 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.02
# 880 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 885 Train loss:0.072 Dev loss:0.066 ratio train/dev:1.09
# 890 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 895 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.04
# 900 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.98
# 905 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 910 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.04
# 915 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.00
# 920 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.06
# 925 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 930 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.01
# 935 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 940 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 945 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 950 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.06
# 955 Train loss:0.062 Dev loss:0.066 ratio train/dev:0.94
# 960 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 965 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 970 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.04
# 975 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 980 Train loss:0.075 Dev loss:0.066 ratio train/dev:1.13
# 985 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.05
# 990 Train loss:0.071 Dev loss:0.066 ratio train/dev:1.08
# 995 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.01
# 1000 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 1005 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.07
# 1010 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 1015 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.00
# 1020 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.01
# 1025 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 1030 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.95
# 1035 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 1040 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 1045 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.98
# 1050 Train loss:0.071 Dev loss:0.066 ratio train/dev:1.09
# 1055 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 1060 Train loss:0.071 Dev loss:0.066 ratio train/dev:1.08
# 1065 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 1070 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.98
# 1075 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 1080 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.05
# 1085 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 1090 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1095 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.05
# 1100 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 1105 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.97
# 1110 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1115 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 1120 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.06
# 1125 Train loss:0.068 Dev loss:0.066 ratio train/dev:1.03
# 1130 Train loss:0.065 Dev loss:0.065 ratio train/dev:0.99
# 1135 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1140 Train loss:0.071 Dev loss:0.066 ratio train/dev:1.08
# 1145 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.05
# 1150 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 1155 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.98
# 1160 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 1165 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1170 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.97
# 1175 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.07
# 1180 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 1185 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.07
# 1190 Train loss:0.072 Dev loss:0.065 ratio train/dev:1.09
# 1195 Train loss:0.067 Dev loss:0.066 ratio train/dev:1.02
# 1200 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1205 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1210 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.97
# 1215 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1220 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.01
# 1225 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1230 Train loss:0.065 Dev loss:0.065 ratio train/dev:0.99
# 1235 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1240 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1245 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.96
# 1250 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 1255 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1260 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 1265 Train loss:0.059 Dev loss:0.066 ratio train/dev:0.90
# 1270 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.99
# 1275 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1280 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1285 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1290 Train loss:0.071 Dev loss:0.065 ratio train/dev:1.08
# 1295 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1300 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1305 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 1310 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.07
# 1315 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1320 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.96
# 1325 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1330 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1335 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1340 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1345 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 1350 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1355 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1360 Train loss:0.070 Dev loss:0.066 ratio train/dev:1.07
# 1365 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1370 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 1375 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1380 Train loss:0.073 Dev loss:0.065 ratio train/dev:1.12
# 1385 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1390 Train loss:0.072 Dev loss:0.065 ratio train/dev:1.11
# 1395 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.05
# 1400 Train loss:0.062 Dev loss:0.066 ratio train/dev:0.95
# 1405 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1410 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 1415 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 1420 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 1425 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.96
# 1430 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1435 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.97
# 1440 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1445 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.00
# 1450 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1455 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1460 Train loss:0.072 Dev loss:0.065 ratio train/dev:1.11
# 1465 Train loss:0.075 Dev loss:0.065 ratio train/dev:1.15
# 1470 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1475 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1480 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1485 Train loss:0.059 Dev loss:0.065 ratio train/dev:0.91
# 1490 Train loss:0.059 Dev loss:0.065 ratio train/dev:0.91
# 1495 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.96
# 1500 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1505 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 1510 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.94
# 1515 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.94
# 1520 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1525 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1530 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1535 Train loss:0.071 Dev loss:0.065 ratio train/dev:1.09
# 1540 Train loss:0.071 Dev loss:0.065 ratio train/dev:1.09
# 1545 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1550 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1555 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1560 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1565 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 1570 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1575 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 1580 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1585 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 1590 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.96
# 1595 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.98
# 1600 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 1605 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1610 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1615 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 1620 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 1625 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1630 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1635 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1640 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1645 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1650 Train loss:0.065 Dev loss:0.065 ratio train/dev:0.99
# 1655 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 1660 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.96
# 1665 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 1670 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 1675 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1680 Train loss:0.071 Dev loss:0.065 ratio train/dev:1.09
# 1685 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1690 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1695 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 1700 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 1705 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 1710 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 1715 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.96
# 1720 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 1725 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 1730 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 1735 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.09
# 1740 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 1745 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1750 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.07
# 1755 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1760 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 1765 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1770 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1775 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1780 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1785 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1790 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1795 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1800 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 1805 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.02
# 1810 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 1815 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1820 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1825 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 1830 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1835 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 1840 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.98
# 1845 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1850 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1855 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 1860 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1865 Train loss:0.072 Dev loss:0.065 ratio train/dev:1.10
# 1870 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1875 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1880 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 1885 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.03
# 1890 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 1895 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 1900 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.07
# 1905 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# 1910 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1915 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1920 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 1925 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 1930 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 1935 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 1940 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1945 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# 1950 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1955 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1960 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1965 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 1970 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1975 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 1980 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.96
# 1985 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1990 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 1995 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2000 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2005 Train loss:0.060 Dev loss:0.065 ratio train/dev:0.93
# 2010 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2015 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 2020 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# 2025 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 2030 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2035 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 2040 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2045 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2050 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 2055 Train loss:0.073 Dev loss:0.065 ratio train/dev:1.12
# 2060 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2065 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 2070 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 2075 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 2080 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 2085 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2090 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 2095 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 2100 Train loss:0.072 Dev loss:0.065 ratio train/dev:1.11
# 2105 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.98
# 2110 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.06
# 2115 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 2120 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2125 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 2130 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.09
# 2135 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2140 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 2145 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2150 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 2155 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2160 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2165 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 2170 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.93
# 2175 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 2180 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2185 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2190 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 2195 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2200 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 2205 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2210 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2215 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.98
# 2220 Train loss:0.072 Dev loss:0.065 ratio train/dev:1.11
# 2225 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2230 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 2235 Train loss:0.071 Dev loss:0.065 ratio train/dev:1.09
# 2240 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 2245 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.09
# 2250 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2255 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 2260 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 2265 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2270 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 2275 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.98
# 2280 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# 2285 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 2290 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2295 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 2300 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.98
# 2305 Train loss:0.064 Dev loss:0.065 ratio train/dev:1.00
# 2310 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 2315 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 2320 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 2325 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.08
# 2330 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# 2335 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2340 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.96
# 2345 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 2350 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2355 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.03
# 2360 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2365 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.98
# 2370 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 2375 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 2380 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2385 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 2390 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 2395 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.98
# 2400 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2405 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2410 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 2415 Train loss:0.070 Dev loss:0.065 ratio train/dev:1.09
# 2420 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.04
# 2425 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.06
# 2430 Train loss:0.064 Dev loss:0.065 ratio train/dev:1.00
# 2435 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.01
# 2440 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.94
# 2445 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# 2450 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 2455 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.02
# 2460 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 2465 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.04
# 2470 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 2475 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.95
# 2480 Train loss:0.064 Dev loss:0.065 ratio train/dev:1.00
# 2485 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 2490 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# 2495 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.01
# Total time taken: 1192.7269353866577

# %%
#CNN - trying Xavier_initializer
def weight_variable(shape):
    #initial = tf.truncated_normal(shape,stddev=0.1)
    weights = tf.get_variable('weights21',shape = shape, initializer = tf.contrib.layers.xavier_initializer()) #Alternative initializer
    return weights

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    return tf.Variable(initial)

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides = [1,1,1,1],padding = 'SAME')

def max_pool_2X2(x):
    return(tf.nn.max_pool(x,ksize = [1,2,2,1],strides = [1,2,2,1],padding = 'SAME'))

#input data
x = tf.placeholder(tf.float32,[None,Xnp.shape[1]])
y = tf.placeholder(tf.float32,[None,ynp.shape[1]])

#First convolutional layer
with tf.variable_scope('conv1'):
    W_conv1 = weight_variable([3,3,1,32]) #first two dimensions are patch size, next is channels, and last is the number of output channels
    b_conv1 = bias_variable([32]) #bias vector has a component for each output channel

    X_image = tf.reshape(x,[-1,96,96,1]) #2nd and 3rd dimension is image width and height, final dimension is number of color channels

with tf.variable_scope('pool1'):
    h_conv1 = tf.nn.relu(conv2d(X_image,W_conv1) + b_conv1)
    h_pool1 = max_pool_2X2(h_conv1) #reduces image size to 48X48

#Second covolutional layer
with tf.variable_scope('conv2'):
    W_conv2 = weight_variable([2,2,32,64]) # 64 features for each 2X2 patch
    b_conv2 = bias_variable([64])

with tf.variable_scope('pool2'):
    h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
    h_pool2 = max_pool_2X2(h_conv2)  #reduces image size to 24X24

#Third covolutional layer
with tf.variable_scope('conv3'):
    W_conv3 = weight_variable([2,2,64,128]) # 64 features for each 2X2 patch
    b_conv3 = bias_variable([128])

with tf.variable_scope('pool3'):
    h_conv3 = tf.nn.relu(conv2d(h_pool2,W_conv3) + b_conv3)
    h_pool3 = max_pool_2X2(h_conv3)  #reduces image size to 24X24


#Densely connected layer 1
with tf.variable_scope('fc4'):
    W_fc1 = weight_variable([12*12*128,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc1 = bias_variable([512])

    h_pool3_flat = tf.reshape(h_pool3,[-1,12*12*128])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat,W_fc1) + b_fc1)

#Densely connected layer 2
with tf.variable_scope('fc5'):
    W_fc2 = weight_variable([512,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc2 = bias_variable([512])
    h_fc2 = tf.nn.relu(tf.matmul(h_fc1,W_fc2) + b_fc2)

#Dropout
#keep_prob = tf.placeholder(tf.float32) # variable to turn on dropout during training, and turn off during test
#h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

#Readout layer
with tf.variable_scope('out'):
    W_fc3 = weight_variable([512,30])
    b_fc3 = bias_variable([30])

    y_conv = tf.matmul(h_fc2,W_fc3) + b_fc3

#loss function
loss = tf.reduce_mean(np.square(y_conv - y))

#optimizer
#train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
learning_rate = 0.001
momentum = 0.9
optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum,use_nesterov = True) 
train_step = optimizer.minimize(loss)

n_epochs = 201
batch_size = 100
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))
y_pred = np.zeros((X_test.shape[0],ynp.shape[1]))


time_start = time.time()
time_1000_start = time.time()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        print('starting epoch:',epoch)
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xnp, ynp = Xnp[shuffle], ynp[shuffle]
        
        for i in range(int(Xnp.shape[0]//batch_size)): #run through most of the data points in each epoch
            X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:],ynp[i*batch_size:(i+1)*batch_size]
            #print(i,X_batch[1,1],y_batch[1])
            sess.run(train_step,feed_dict = {x:X_batch,y:y_batch})
            loss_train = loss.eval(feed_dict = {x:X_batch,y:y_batch})
            loss_dev = loss.eval(feed_dict = {x:Xdev,y:ydev})
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%1 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    for i in range(int(X_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = X_test[i*batch_size:(i+1)*batch_size,:]
            y_pred[i*batch_size:(i+1)*batch_size] = sess.run(y_conv,feed_dict = {x:X_batch})
   
print('Total time taken:',time_end-time_start)

#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(16, 16))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# starting epoch: 0
# 0 Train loss:0.101 Dev loss:0.105 ratio train/dev:0.96
# starting epoch: 1
# 1 Train loss:0.078 Dev loss:0.081 ratio train/dev:0.96
# starting epoch: 2
# 2 Train loss:0.065 Dev loss:0.073 ratio train/dev:0.89
# starting epoch: 3
# 3 Train loss:0.073 Dev loss:0.073 ratio train/dev:1.00
# starting epoch: 4
# 4 Train loss:0.070 Dev loss:0.072 ratio train/dev:0.97
# starting epoch: 5
# 5 Train loss:0.069 Dev loss:0.072 ratio train/dev:0.96
# starting epoch: 6
# 6 Train loss:0.068 Dev loss:0.072 ratio train/dev:0.95
# starting epoch: 7
# 7 Train loss:0.068 Dev loss:0.072 ratio train/dev:0.94
# starting epoch: 8
# 8 Train loss:0.068 Dev loss:0.072 ratio train/dev:0.94
# starting epoch: 9
# 9 Train loss:0.065 Dev loss:0.072 ratio train/dev:0.91
# starting epoch: 10
# 10 Train loss:0.072 Dev loss:0.072 ratio train/dev:1.00
# starting epoch: 11
# 11 Train loss:0.068 Dev loss:0.072 ratio train/dev:0.96
# starting epoch: 12
# 12 Train loss:0.066 Dev loss:0.072 ratio train/dev:0.92
# starting epoch: 13
# 13 Train loss:0.064 Dev loss:0.071 ratio train/dev:0.89
# starting epoch: 14
# 14 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.93
# starting epoch: 15
# 15 Train loss:0.065 Dev loss:0.071 ratio train/dev:0.91
# starting epoch: 16
# 16 Train loss:0.072 Dev loss:0.071 ratio train/dev:1.00
# starting epoch: 17
# 17 Train loss:0.070 Dev loss:0.071 ratio train/dev:0.98
# starting epoch: 18
# 18 Train loss:0.069 Dev loss:0.071 ratio train/dev:0.97
# starting epoch: 19
# 19 Train loss:0.065 Dev loss:0.071 ratio train/dev:0.91
# starting epoch: 20
# 20 Train loss:0.070 Dev loss:0.071 ratio train/dev:0.99
# starting epoch: 21
# 21 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.94
# starting epoch: 22
# 22 Train loss:0.066 Dev loss:0.071 ratio train/dev:0.93
# starting epoch: 23
# 23 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.94
# starting epoch: 24
# 24 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.94
# starting epoch: 25
# 25 Train loss:0.063 Dev loss:0.071 ratio train/dev:0.89
# starting epoch: 26
# 26 Train loss:0.069 Dev loss:0.071 ratio train/dev:0.98
# starting epoch: 27
# 27 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.94
# starting epoch: 28
# 28 Train loss:0.064 Dev loss:0.071 ratio train/dev:0.90
# starting epoch: 29
# 29 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.95
# starting epoch: 30
# 30 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.95
# starting epoch: 31
# 31 Train loss:0.065 Dev loss:0.071 ratio train/dev:0.92
# starting epoch: 32
# 32 Train loss:0.062 Dev loss:0.071 ratio train/dev:0.88
# starting epoch: 33
# 33 Train loss:0.062 Dev loss:0.070 ratio train/dev:0.88
# starting epoch: 34
# 34 Train loss:0.065 Dev loss:0.070 ratio train/dev:0.92
# starting epoch: 35
# 35 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.94
# starting epoch: 36
# 36 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.93
# starting epoch: 37
# 37 Train loss:0.065 Dev loss:0.070 ratio train/dev:0.92
# starting epoch: 38
# 38 Train loss:0.064 Dev loss:0.070 ratio train/dev:0.91
# starting epoch: 39
# 39 Train loss:0.068 Dev loss:0.070 ratio train/dev:0.96
# starting epoch: 40
# 40 Train loss:0.067 Dev loss:0.070 ratio train/dev:0.95
# starting epoch: 41
# 41 Train loss:0.072 Dev loss:0.070 ratio train/dev:1.02
# starting epoch: 42
# 42 Train loss:0.068 Dev loss:0.070 ratio train/dev:0.97
# starting epoch: 43
# 43 Train loss:0.061 Dev loss:0.070 ratio train/dev:0.87
# starting epoch: 44
# 44 Train loss:0.065 Dev loss:0.070 ratio train/dev:0.93
# starting epoch: 45
# 45 Train loss:0.074 Dev loss:0.070 ratio train/dev:1.06
# starting epoch: 46
# 46 Train loss:0.069 Dev loss:0.070 ratio train/dev:0.98
# starting epoch: 47
# 47 Train loss:0.069 Dev loss:0.070 ratio train/dev:0.98
# starting epoch: 48
# 48 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.94
# starting epoch: 49
# 49 Train loss:0.068 Dev loss:0.070 ratio train/dev:0.97
# starting epoch: 50
# 50 Train loss:0.068 Dev loss:0.070 ratio train/dev:0.98
# starting epoch: 51
# 51 Train loss:0.067 Dev loss:0.070 ratio train/dev:0.96
# starting epoch: 52
# 52 Train loss:0.068 Dev loss:0.070 ratio train/dev:0.97
# starting epoch: 53
# 53 Train loss:0.065 Dev loss:0.070 ratio train/dev:0.93
# starting epoch: 54
# 54 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.95
# starting epoch: 55
# 55 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.95
# starting epoch: 56
# 56 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.95
# starting epoch: 57
# 57 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.95
# starting epoch: 58
# 58 Train loss:0.064 Dev loss:0.070 ratio train/dev:0.91
# starting epoch: 59
# 59 Train loss:0.061 Dev loss:0.070 ratio train/dev:0.87
# starting epoch: 60
# 60 Train loss:0.065 Dev loss:0.070 ratio train/dev:0.94
# starting epoch: 61
# 61 Train loss:0.060 Dev loss:0.070 ratio train/dev:0.87
# starting epoch: 62
# 62 Train loss:0.063 Dev loss:0.070 ratio train/dev:0.90
# starting epoch: 63
# 63 Train loss:0.063 Dev loss:0.070 ratio train/dev:0.90
# starting epoch: 64
# 64 Train loss:0.067 Dev loss:0.070 ratio train/dev:0.96
# starting epoch: 65
# 65 Train loss:0.067 Dev loss:0.070 ratio train/dev:0.96
# starting epoch: 66
# 66 Train loss:0.065 Dev loss:0.070 ratio train/dev:0.93
# starting epoch: 67
# 67 Train loss:0.064 Dev loss:0.070 ratio train/dev:0.93
# starting epoch: 68
# 68 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.96
# starting epoch: 69
# 69 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.95
# starting epoch: 70
# 70 Train loss:0.061 Dev loss:0.069 ratio train/dev:0.88
# starting epoch: 71
# 71 Train loss:0.068 Dev loss:0.069 ratio train/dev:0.98
# starting epoch: 72
# 72 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 73
# 73 Train loss:0.068 Dev loss:0.069 ratio train/dev:0.98
# starting epoch: 74
# 74 Train loss:0.069 Dev loss:0.069 ratio train/dev:1.00
# starting epoch: 75
# 75 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.92
# starting epoch: 76
# 76 Train loss:0.067 Dev loss:0.069 ratio train/dev:0.97
# starting epoch: 77
# 77 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.93
# starting epoch: 78
# 78 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.95
# starting epoch: 79
# 79 Train loss:0.059 Dev loss:0.069 ratio train/dev:0.86
# starting epoch: 80
# 80 Train loss:0.068 Dev loss:0.069 ratio train/dev:0.98
# starting epoch: 81
# 81 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 82
# 82 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 83
# 83 Train loss:0.069 Dev loss:0.069 ratio train/dev:1.00
# starting epoch: 84
# 84 Train loss:0.060 Dev loss:0.069 ratio train/dev:0.87
# starting epoch: 85
# 85 Train loss:0.063 Dev loss:0.069 ratio train/dev:0.91
# starting epoch: 86
# 86 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.95
# starting epoch: 87
# 87 Train loss:0.068 Dev loss:0.069 ratio train/dev:0.99
# starting epoch: 88
# 88 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 89
# 89 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 90
# 90 Train loss:0.062 Dev loss:0.069 ratio train/dev:0.89
# starting epoch: 91
# 91 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 92
# 92 Train loss:0.061 Dev loss:0.069 ratio train/dev:0.88
# starting epoch: 93
# 93 Train loss:0.063 Dev loss:0.069 ratio train/dev:0.91
# starting epoch: 94
# 94 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 95
# 95 Train loss:0.059 Dev loss:0.069 ratio train/dev:0.86
# starting epoch: 96
# 96 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.95
# starting epoch: 97
# 97 Train loss:0.069 Dev loss:0.069 ratio train/dev:1.01
# starting epoch: 98
# 98 Train loss:0.067 Dev loss:0.069 ratio train/dev:0.98
# starting epoch: 99
# 99 Train loss:0.068 Dev loss:0.069 ratio train/dev:0.98
# starting epoch: 100
# 100 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 101
# 101 Train loss:0.068 Dev loss:0.069 ratio train/dev:0.99
# starting epoch: 102
# 102 Train loss:0.063 Dev loss:0.069 ratio train/dev:0.91
# starting epoch: 103
# 103 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 104
# 104 Train loss:0.063 Dev loss:0.069 ratio train/dev:0.92
# starting epoch: 105
# 105 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.93
# starting epoch: 106
# 106 Train loss:0.063 Dev loss:0.069 ratio train/dev:0.92
# starting epoch: 107
# 107 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.93
# starting epoch: 108
# 108 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.93
# starting epoch: 109
# 109 Train loss:0.062 Dev loss:0.069 ratio train/dev:0.90
# starting epoch: 110
# 110 Train loss:0.067 Dev loss:0.069 ratio train/dev:0.97
# starting epoch: 111
# 111 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.96
# starting epoch: 112
# 112 Train loss:0.067 Dev loss:0.069 ratio train/dev:0.97
# starting epoch: 113
# 113 Train loss:0.063 Dev loss:0.069 ratio train/dev:0.93
# starting epoch: 114
# 114 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.96
# starting epoch: 115
# 115 Train loss:0.061 Dev loss:0.069 ratio train/dev:0.88
# starting epoch: 116
# 116 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.94
# starting epoch: 117
# 117 Train loss:0.063 Dev loss:0.069 ratio train/dev:0.92
# starting epoch: 118
# 118 Train loss:0.061 Dev loss:0.068 ratio train/dev:0.90
# starting epoch: 119
# 119 Train loss:0.070 Dev loss:0.069 ratio train/dev:1.02
# starting epoch: 120
# 120 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 121
# 121 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.95
# starting epoch: 122
# 122 Train loss:0.068 Dev loss:0.068 ratio train/dev:0.99
# starting epoch: 123
# 123 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.93
# starting epoch: 124
# 124 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.95
# starting epoch: 125
# 125 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.93
# starting epoch: 126
# 126 Train loss:0.067 Dev loss:0.068 ratio train/dev:0.97
# starting epoch: 127
# 127 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.90
# starting epoch: 128
# 128 Train loss:0.066 Dev loss:0.068 ratio train/dev:0.96
# starting epoch: 129
# 129 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.93
# starting epoch: 130
# 130 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 131
# 131 Train loss:0.067 Dev loss:0.068 ratio train/dev:0.99
# starting epoch: 132
# 132 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.91
# starting epoch: 133
# 133 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.93
# starting epoch: 134
# 134 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 135
# 135 Train loss:0.061 Dev loss:0.068 ratio train/dev:0.90
# starting epoch: 136
# 136 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.93
# starting epoch: 137
# 137 Train loss:0.066 Dev loss:0.068 ratio train/dev:0.97
# starting epoch: 138
# 138 Train loss:0.066 Dev loss:0.068 ratio train/dev:0.97
# starting epoch: 139
# 139 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.95
# starting epoch: 140
# 140 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 141
# 141 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.96
# starting epoch: 142
# 142 Train loss:0.061 Dev loss:0.068 ratio train/dev:0.89
# starting epoch: 143
# 143 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 144
# 144 Train loss:0.068 Dev loss:0.068 ratio train/dev:0.99
# starting epoch: 145
# 145 Train loss:0.060 Dev loss:0.068 ratio train/dev:0.89
# starting epoch: 146
# 146 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.91
# starting epoch: 147
# 147 Train loss:0.070 Dev loss:0.068 ratio train/dev:1.04
# starting epoch: 148
# 148 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 149
# 149 Train loss:0.067 Dev loss:0.068 ratio train/dev:0.98
# starting epoch: 150
# 150 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.96
# starting epoch: 151
# 151 Train loss:0.060 Dev loss:0.068 ratio train/dev:0.89
# starting epoch: 152
# 152 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 153
# 153 Train loss:0.066 Dev loss:0.068 ratio train/dev:0.96
# starting epoch: 154
# 154 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 155
# 155 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 156
# 156 Train loss:0.058 Dev loss:0.068 ratio train/dev:0.85
# starting epoch: 157
# 157 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 158
# 158 Train loss:0.061 Dev loss:0.068 ratio train/dev:0.90
# starting epoch: 159
# 159 Train loss:0.060 Dev loss:0.068 ratio train/dev:0.88
# starting epoch: 160
# 160 Train loss:0.067 Dev loss:0.068 ratio train/dev:0.99
# starting epoch: 161
# 161 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 162
# 162 Train loss:0.061 Dev loss:0.068 ratio train/dev:0.90
# starting epoch: 163
# 163 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.93
# starting epoch: 164
# 164 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 165
# 165 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 166
# 166 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.91
# starting epoch: 167
# 167 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.92
# starting epoch: 168
# 168 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 169
# 169 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.96
# starting epoch: 170
# 170 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.96
# starting epoch: 171
# 171 Train loss:0.059 Dev loss:0.068 ratio train/dev:0.87
# starting epoch: 172
# 172 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.97
# starting epoch: 173
# 173 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.91
# starting epoch: 174
# 174 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.93
# starting epoch: 175
# 175 Train loss:0.060 Dev loss:0.068 ratio train/dev:0.89
# starting epoch: 176
# 176 Train loss:0.067 Dev loss:0.068 ratio train/dev:0.99
# starting epoch: 177
# 177 Train loss:0.060 Dev loss:0.068 ratio train/dev:0.89
# starting epoch: 178
# 178 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.95
# starting epoch: 179
# 179 Train loss:0.059 Dev loss:0.068 ratio train/dev:0.87
# starting epoch: 180
# 180 Train loss:0.066 Dev loss:0.068 ratio train/dev:0.98
# starting epoch: 181
# 181 Train loss:0.057 Dev loss:0.068 ratio train/dev:0.85
# starting epoch: 182
# 182 Train loss:0.066 Dev loss:0.068 ratio train/dev:0.97
# starting epoch: 183
# 183 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# starting epoch: 184
# 184 Train loss:0.060 Dev loss:0.068 ratio train/dev:0.89
# starting epoch: 185
# 185 Train loss:0.066 Dev loss:0.067 ratio train/dev:0.98
# starting epoch: 186
# 186 Train loss:0.062 Dev loss:0.067 ratio train/dev:0.92
# starting epoch: 187
# 187 Train loss:0.064 Dev loss:0.067 ratio train/dev:0.95
# starting epoch: 188
# 188 Train loss:0.063 Dev loss:0.067 ratio train/dev:0.93
# starting epoch: 189
# 189 Train loss:0.063 Dev loss:0.067 ratio train/dev:0.93
# starting epoch: 190
# 190 Train loss:0.063 Dev loss:0.067 ratio train/dev:0.93
# starting epoch: 191
# 191 Train loss:0.063 Dev loss:0.067 ratio train/dev:0.93
# starting epoch: 192
# 192 Train loss:0.067 Dev loss:0.067 ratio train/dev:0.99
# starting epoch: 193
# 193 Train loss:0.061 Dev loss:0.067 ratio train/dev:0.91
# starting epoch: 194
# 194 Train loss:0.064 Dev loss:0.067 ratio train/dev:0.95
# starting epoch: 195
# 195 Train loss:0.066 Dev loss:0.067 ratio train/dev:0.98
# starting epoch: 196
# 196 Train loss:0.058 Dev loss:0.067 ratio train/dev:0.86
# starting epoch: 197
# 197 Train loss:0.065 Dev loss:0.067 ratio train/dev:0.96
# starting epoch: 198
# 198 Train loss:0.063 Dev loss:0.067 ratio train/dev:0.93
# starting epoch: 199
# 199 Train loss:0.061 Dev loss:0.067 ratio train/dev:0.91
# starting epoch: 200
# 200 Train loss:0.062 Dev loss:0.067 ratio train/dev:0.92
# Total time taken: 609.4698555469513

# %%
#CNN - Adding dropout., second hidden layer
def weight_variable(shape):
    #initial = tf.truncated_normal(shape,stddev=0.1)
    weights = tf.get_variable('weights2',shape = shape, initializer = tf.glorot_uniform_initializer()) #Alternative initializer
    return weights

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    #bias = tf.get_variable('bias2',shape = shape, initializer = tf.glorot_uniform_initializer()) #Alternative initializer
    return tf.Variable(initial)
    #return bias

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides = [1,1,1,1],padding = 'SAME')

def max_pool_2X2(x):
    return(tf.nn.max_pool(x,ksize = [1,2,2,1],strides = [1,2,2,1],padding = 'SAME'))

#input data
x = tf.placeholder(tf.float32,[None,Xnp.shape[1]])
y = tf.placeholder(tf.float32,[None,ynp.shape[1]])

#First convolutional layer
with tf.variable_scope('conv1'):
    W_conv1 = weight_variable([3,3,1,32]) #first two dimensions are patch size, next is channels, and last is the number of output channels
    b_conv1 = bias_variable([32]) #bias vector has a component for each output channel

    X_image = tf.reshape(x,[-1,96,96,1]) #2nd and 3rd dimension is image width and height, final dimension is number of color channels

with tf.variable_scope('pool1'):
    h_conv1 = tf.nn.relu(conv2d(X_image,W_conv1) + b_conv1)
    h_pool1 = max_pool_2X2(h_conv1) #reduces image size to 48X48

#Second covolutional layer
with tf.variable_scope('conv2'):
    W_conv2 = weight_variable([2,2,32,64]) # 64 features for each 2X2 patch
    b_conv2 = bias_variable([64])

with tf.variable_scope('pool2'):
    h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
    h_pool2 = max_pool_2X2(h_conv2)  #reduces image size to 24X24

#Third covolutional layer
with tf.variable_scope('conv3'):
    W_conv3 = weight_variable([2,2,64,128]) # 64 features for each 2X2 patch
    b_conv3 = bias_variable([128])

with tf.variable_scope('pool3'):
    h_conv3 = tf.nn.relu(conv2d(h_pool2,W_conv3) + b_conv3)
    h_pool3 = max_pool_2X2(h_conv3)  #reduces image size to 24X24


#Densely connected layer 1
with tf.variable_scope('fc4'):
    W_fc1 = weight_variable([12*12*128,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc1 = bias_variable([512])

    h_pool3_flat = tf.reshape(h_pool3,[-1,12*12*128])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat,W_fc1) + b_fc1)
    
#Dropout
keep_prob = tf.placeholder(tf.float32) # variable to turn on dropout during training, and turn off during test
h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

#Densely connected layer 2
with tf.variable_scope('fc5'):
    W_fc2 = weight_variable([512,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc2 = bias_variable([512])
    h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop,W_fc2) + b_fc2)

#Readout layer
with tf.variable_scope('out'):
    W_fc3 = weight_variable([512,30])
    b_fc3 = bias_variable([30])

    y_conv = tf.matmul(h_fc2,W_fc3) + b_fc3

#loss function
loss = tf.reduce_mean(np.square(y_conv - y))

#optimizer
#train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
learning_rate = 0.01
momentum = 0.9
optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum) 
train_step = optimizer.minimize(loss)

n_epochs = 1101
batch_size = 128
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))
y_pred = np.zeros((X_test.shape[0],ynp.shape[1]))


time_start = time.time()
print('starting')
time_1000_start = time.time()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xnp, ynp = Xnp[shuffle], ynp[shuffle]
        
        for i in range(int(Xnp.shape[0]//batch_size)): #run through most of the data points in each epoch
            X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:],ynp[i*batch_size:(i+1)*batch_size]
            #X_batch,y_batch = Xnp[:batch_size,:],ynp[:batch_size]
            #print(i,X_batch[1,1],y_batch[1])
            sess.run(train_step,feed_dict = {x:X_batch,y:y_batch,keep_prob:0.5})
            loss_train = loss.eval(feed_dict = {x:X_batch,y:y_batch,keep_prob:1.0})
        loss_dev = loss.eval(feed_dict = {x:Xdev,y:ydev,keep_prob:1.0})
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    for i in range(int(X_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = X_test[i*batch_size:(i+1)*batch_size,:]
            y_pred[i*batch_size:(i+1)*batch_size] = sess.run(y_conv,feed_dict = {x:X_batch,keep_prob:1.0})
   
print('Total time taken:',time_end-time_start)

#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(16, 16))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# starting
# 0 Train loss:0.146 Dev loss:0.148 ratio train/dev:0.99
# 10 Train loss:0.065 Dev loss:0.068 ratio train/dev:0.96
# 20 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.97
# 30 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.96
# 40 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 50 Train loss:0.068 Dev loss:0.065 ratio train/dev:1.05
# 60 Train loss:0.062 Dev loss:0.064 ratio train/dev:0.96
# 70 Train loss:0.065 Dev loss:0.064 ratio train/dev:1.02
# 80 Train loss:0.061 Dev loss:0.064 ratio train/dev:0.96
# 90 Train loss:0.058 Dev loss:0.064 ratio train/dev:0.92
# 100 Train loss:0.066 Dev loss:0.063 ratio train/dev:1.04
# 110 Train loss:0.059 Dev loss:0.063 ratio train/dev:0.94
# 120 Train loss:0.059 Dev loss:0.062 ratio train/dev:0.95
# 130 Train loss:0.058 Dev loss:0.062 ratio train/dev:0.93
# 140 Train loss:0.057 Dev loss:0.062 ratio train/dev:0.93
# 150 Train loss:0.056 Dev loss:0.061 ratio train/dev:0.91
# 160 Train loss:0.057 Dev loss:0.061 ratio train/dev:0.94
# 170 Train loss:0.058 Dev loss:0.060 ratio train/dev:0.96
# 180 Train loss:0.062 Dev loss:0.060 ratio train/dev:1.04
# 190 Train loss:0.057 Dev loss:0.060 ratio train/dev:0.95
# 200 Train loss:0.059 Dev loss:0.059 ratio train/dev:0.99
# 210 Train loss:0.057 Dev loss:0.059 ratio train/dev:0.97
# 220 Train loss:0.059 Dev loss:0.058 ratio train/dev:1.02
# 230 Train loss:0.057 Dev loss:0.058 ratio train/dev:0.99
# 240 Train loss:0.054 Dev loss:0.058 ratio train/dev:0.93
# 250 Train loss:0.054 Dev loss:0.057 ratio train/dev:0.95
# 260 Train loss:0.051 Dev loss:0.057 ratio train/dev:0.90
# 270 Train loss:0.056 Dev loss:0.057 ratio train/dev:0.99
# 280 Train loss:0.056 Dev loss:0.056 ratio train/dev:1.01
# 290 Train loss:0.055 Dev loss:0.056 ratio train/dev:0.98
# 300 Train loss:0.056 Dev loss:0.056 ratio train/dev:1.01
# 310 Train loss:0.054 Dev loss:0.055 ratio train/dev:0.98
# 320 Train loss:0.053 Dev loss:0.055 ratio train/dev:0.97
# 330 Train loss:0.056 Dev loss:0.054 ratio train/dev:1.04
# 340 Train loss:0.049 Dev loss:0.054 ratio train/dev:0.91
# 350 Train loss:0.051 Dev loss:0.054 ratio train/dev:0.96
# 360 Train loss:0.054 Dev loss:0.053 ratio train/dev:1.01
# 370 Train loss:0.047 Dev loss:0.053 ratio train/dev:0.89
# 380 Train loss:0.051 Dev loss:0.053 ratio train/dev:0.97
# 390 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.91
# 400 Train loss:0.049 Dev loss:0.052 ratio train/dev:0.94
# 410 Train loss:0.046 Dev loss:0.052 ratio train/dev:0.90
# 420 Train loss:0.052 Dev loss:0.051 ratio train/dev:1.01
# 430 Train loss:0.048 Dev loss:0.051 ratio train/dev:0.94
# 440 Train loss:0.046 Dev loss:0.051 ratio train/dev:0.90
# 450 Train loss:0.046 Dev loss:0.051 ratio train/dev:0.90
# 460 Train loss:0.049 Dev loss:0.050 ratio train/dev:0.98
# 470 Train loss:0.050 Dev loss:0.050 ratio train/dev:1.01
# 480 Train loss:0.045 Dev loss:0.050 ratio train/dev:0.91
# 490 Train loss:0.045 Dev loss:0.050 ratio train/dev:0.90
# 500 Train loss:0.044 Dev loss:0.049 ratio train/dev:0.88
# 510 Train loss:0.041 Dev loss:0.049 ratio train/dev:0.83
# 520 Train loss:0.047 Dev loss:0.049 ratio train/dev:0.97
# 530 Train loss:0.046 Dev loss:0.049 ratio train/dev:0.94
# 540 Train loss:0.048 Dev loss:0.049 ratio train/dev:1.00
# 550 Train loss:0.049 Dev loss:0.048 ratio train/dev:1.00
# 560 Train loss:0.042 Dev loss:0.048 ratio train/dev:0.87
# 570 Train loss:0.044 Dev loss:0.048 ratio train/dev:0.92
# 580 Train loss:0.048 Dev loss:0.048 ratio train/dev:0.99
# 590 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.91
# 600 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.91
# 610 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.90
# 620 Train loss:0.039 Dev loss:0.047 ratio train/dev:0.83
# 630 Train loss:0.040 Dev loss:0.047 ratio train/dev:0.85
# 640 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.91
# 650 Train loss:0.041 Dev loss:0.047 ratio train/dev:0.88
# 660 Train loss:0.041 Dev loss:0.046 ratio train/dev:0.89
# 670 Train loss:0.042 Dev loss:0.046 ratio train/dev:0.91
# 680 Train loss:0.041 Dev loss:0.046 ratio train/dev:0.89
# 690 Train loss:0.041 Dev loss:0.046 ratio train/dev:0.89
# 700 Train loss:0.042 Dev loss:0.046 ratio train/dev:0.91
# 710 Train loss:0.040 Dev loss:0.046 ratio train/dev:0.88
# 720 Train loss:0.039 Dev loss:0.046 ratio train/dev:0.85
# 730 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.93
# 740 Train loss:0.041 Dev loss:0.045 ratio train/dev:0.90
# 750 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.89
# 760 Train loss:0.041 Dev loss:0.045 ratio train/dev:0.91
# 770 Train loss:0.041 Dev loss:0.045 ratio train/dev:0.90
# 780 Train loss:0.041 Dev loss:0.045 ratio train/dev:0.92
# 790 Train loss:0.039 Dev loss:0.045 ratio train/dev:0.87
# 800 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.93
# 810 Train loss:0.039 Dev loss:0.045 ratio train/dev:0.88
# 820 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.86
# 830 Train loss:0.037 Dev loss:0.044 ratio train/dev:0.83
# 840 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.91
# 850 Train loss:0.042 Dev loss:0.044 ratio train/dev:0.95
# 860 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.90
# 870 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.86
# 880 Train loss:0.037 Dev loss:0.044 ratio train/dev:0.85
# 890 Train loss:0.041 Dev loss:0.044 ratio train/dev:0.93
# 900 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.91
# 910 Train loss:0.037 Dev loss:0.044 ratio train/dev:0.84
# 920 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.91
# 930 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.90
# 940 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.87
# 950 Train loss:0.041 Dev loss:0.043 ratio train/dev:0.95
# 960 Train loss:0.035 Dev loss:0.043 ratio train/dev:0.81
# 970 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.85
# 980 Train loss:0.040 Dev loss:0.043 ratio train/dev:0.92
# 990 Train loss:0.035 Dev loss:0.043 ratio train/dev:0.83
# 1000 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.85
# 1010 Train loss:0.040 Dev loss:0.043 ratio train/dev:0.93
# 1020 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.90
# 1030 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.89
# 1040 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.87
# 1050 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.91
# 1060 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.90
# 1070 Train loss:0.039 Dev loss:0.042 ratio train/dev:0.93
# 1080 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.91
# 1090 Train loss:0.039 Dev loss:0.042 ratio train/dev:0.92
# 1100 Train loss:0.034 Dev loss:0.042 ratio train/dev:0.81
# Total time taken: 1801.8801546096802

# %%
#CNN - Xavier initializer with dropout. Use this cell to standardize code for net 2
def weight_variable(shape):
    #initial = tf.truncated_normal(shape,stddev=0.1)
    weights = tf.get_variable('weights6',shape = shape, initializer = tf.contrib.layers.xavier_initializer()) #Alternative initializer
    return weights

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    #bias = tf.get_variable('bias2',shape = shape, initializer = tf.glorot_uniform_initializer()) #Alternative initializer
    return tf.Variable(initial)
    #return bias

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides = [1,1,1,1],padding = 'SAME')

def max_pool_2X2(x):
    return(tf.nn.max_pool(x,ksize = [1,2,2,1],strides = [1,2,2,1],padding = 'SAME'))

#input data
x = tf.placeholder(tf.float32,[None,Xnp.shape[1]])
y = tf.placeholder(tf.float32,[None,ynp.shape[1]])

#First convolutional layer
with tf.variable_scope('conv1'):
    W_conv1 = weight_variable([3,3,1,32]) #first two dimensions are patch size, next is channels, and last is the number of output channels
    b_conv1 = bias_variable([32]) #bias vector has a component for each output channel

    X_image = tf.reshape(x,[-1,96,96,1]) #2nd and 3rd dimension is image width and height, final dimension is number of color channels

with tf.variable_scope('pool1'):
    h_conv1 = tf.nn.relu(conv2d(X_image,W_conv1) + b_conv1)
    h_pool1 = max_pool_2X2(h_conv1) #reduces image size to 48X48

#Second covolutional layer
with tf.variable_scope('conv2'):
    W_conv2 = weight_variable([2,2,32,64]) # 64 features for each 2X2 patch
    b_conv2 = bias_variable([64])

with tf.variable_scope('pool2'):
    h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
    h_pool2 = max_pool_2X2(h_conv2)  #reduces image size to 24X24

#Third covolutional layer
with tf.variable_scope('conv3'):
    W_conv3 = weight_variable([2,2,64,128]) # 64 features for each 2X2 patch
    b_conv3 = bias_variable([128])

with tf.variable_scope('pool3'):
    h_conv3 = tf.nn.relu(conv2d(h_pool2,W_conv3) + b_conv3)
    h_pool3 = max_pool_2X2(h_conv3)  #reduces image size to 24X24


#Densely connected layer 1
with tf.variable_scope('fc4'):
    W_fc1 = weight_variable([12*12*128,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc1 = bias_variable([512])

    h_pool3_flat = tf.reshape(h_pool3,[-1,12*12*128])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat,W_fc1) + b_fc1)
    
#Dropout
keep_prob = tf.placeholder(tf.float32) # variable to turn on dropout during training, and turn off during test
h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

#Densely connected layer 2
with tf.variable_scope('fc5'):
    W_fc2 = weight_variable([512,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc2 = bias_variable([512])
    h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop,W_fc2) + b_fc2)

#Readout layer
with tf.variable_scope('out'):
    W_fc3 = weight_variable([512,30])
    b_fc3 = bias_variable([30])

    y_conv = tf.matmul(h_fc2,W_fc3) + b_fc3

#loss function
loss = tf.reduce_mean(np.square(y_conv - y))

#optimizer
#train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
learning_rate = 0.01
momentum = 0.9
optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum) 
train_step = optimizer.minimize(loss)

n_epochs = 1101
batch_size = 128
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))
y_pred = np.zeros((X_test.shape[0],ynp.shape[1]))


time_start = time.time()
print('starting')
time_1000_start = time.time()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xnp, ynp = Xnp[shuffle], ynp[shuffle]
        
        for i in range(int(Xnp.shape[0]//batch_size)): #run through most of the data points in each epoch
            X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:],ynp[i*batch_size:(i+1)*batch_size]
            #X_batch,y_batch = Xnp[:batch_size,:],ynp[:batch_size]
            #print(i,X_batch[1,1],y_batch[1])
            sess.run(train_step,feed_dict = {x:X_batch,y:y_batch,keep_prob:0.5})
            loss_train = loss.eval(feed_dict = {x:X_batch,y:y_batch,keep_prob:1.0})
        loss_dev = loss.eval(feed_dict = {x:Xdev,y:ydev,keep_prob:1.0})
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    for i in range(int(X_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = X_test[i*batch_size:(i+1)*batch_size,:]
            y_pred[i*batch_size:(i+1)*batch_size] = sess.run(y_conv,feed_dict = {x:X_batch,keep_prob:1.0})
   
print('Total time taken:',time_end-time_start)

#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(16, 16))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# starting
# 0 Train loss:0.141 Dev loss:0.143 ratio train/dev:0.99
# 10 Train loss:0.070 Dev loss:0.067 ratio train/dev:1.04
# 20 Train loss:0.063 Dev loss:0.066 ratio train/dev:0.94
# 30 Train loss:0.062 Dev loss:0.066 ratio train/dev:0.95
# 40 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.94
# 50 Train loss:0.066 Dev loss:0.065 ratio train/dev:1.03
# 60 Train loss:0.064 Dev loss:0.064 ratio train/dev:0.99
# 70 Train loss:0.066 Dev loss:0.064 ratio train/dev:1.03
# 80 Train loss:0.062 Dev loss:0.064 ratio train/dev:0.97
# 90 Train loss:0.063 Dev loss:0.064 ratio train/dev:1.00
# 100 Train loss:0.066 Dev loss:0.063 ratio train/dev:1.05
# 110 Train loss:0.062 Dev loss:0.063 ratio train/dev:0.98
# 120 Train loss:0.061 Dev loss:0.063 ratio train/dev:0.98
# 130 Train loss:0.066 Dev loss:0.062 ratio train/dev:1.06
# 140 Train loss:0.059 Dev loss:0.062 ratio train/dev:0.96
# 150 Train loss:0.061 Dev loss:0.061 ratio train/dev:0.99
# 160 Train loss:0.056 Dev loss:0.061 ratio train/dev:0.92
# 170 Train loss:0.060 Dev loss:0.061 ratio train/dev:0.98
# 180 Train loss:0.059 Dev loss:0.060 ratio train/dev:0.98
# 190 Train loss:0.063 Dev loss:0.060 ratio train/dev:1.06
# 200 Train loss:0.056 Dev loss:0.059 ratio train/dev:0.94
# 210 Train loss:0.059 Dev loss:0.059 ratio train/dev:1.01
# 220 Train loss:0.057 Dev loss:0.059 ratio train/dev:0.97
# 230 Train loss:0.054 Dev loss:0.058 ratio train/dev:0.92
# 240 Train loss:0.050 Dev loss:0.058 ratio train/dev:0.87
# 250 Train loss:0.054 Dev loss:0.058 ratio train/dev:0.95
# 260 Train loss:0.054 Dev loss:0.057 ratio train/dev:0.95
# 270 Train loss:0.053 Dev loss:0.057 ratio train/dev:0.93
# 280 Train loss:0.056 Dev loss:0.056 ratio train/dev:1.00
# 290 Train loss:0.055 Dev loss:0.056 ratio train/dev:0.98
# 300 Train loss:0.055 Dev loss:0.055 ratio train/dev:1.00
# 310 Train loss:0.053 Dev loss:0.055 ratio train/dev:0.97
# 320 Train loss:0.052 Dev loss:0.055 ratio train/dev:0.95
# 330 Train loss:0.053 Dev loss:0.054 ratio train/dev:0.97
# 340 Train loss:0.052 Dev loss:0.054 ratio train/dev:0.97
# 350 Train loss:0.049 Dev loss:0.054 ratio train/dev:0.92
# 360 Train loss:0.049 Dev loss:0.053 ratio train/dev:0.91
# 370 Train loss:0.054 Dev loss:0.053 ratio train/dev:1.02
# 380 Train loss:0.052 Dev loss:0.053 ratio train/dev:0.99
# 390 Train loss:0.050 Dev loss:0.052 ratio train/dev:0.95
# 400 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.92
# 410 Train loss:0.048 Dev loss:0.051 ratio train/dev:0.94
# 420 Train loss:0.051 Dev loss:0.051 ratio train/dev:1.00
# 430 Train loss:0.053 Dev loss:0.051 ratio train/dev:1.04
# 440 Train loss:0.049 Dev loss:0.051 ratio train/dev:0.96
# 450 Train loss:0.054 Dev loss:0.050 ratio train/dev:1.07
# 460 Train loss:0.048 Dev loss:0.050 ratio train/dev:0.97
# 470 Train loss:0.045 Dev loss:0.050 ratio train/dev:0.90
# 480 Train loss:0.048 Dev loss:0.050 ratio train/dev:0.96
# 490 Train loss:0.049 Dev loss:0.049 ratio train/dev:1.00
# 500 Train loss:0.043 Dev loss:0.049 ratio train/dev:0.88
# 510 Train loss:0.047 Dev loss:0.049 ratio train/dev:0.96
# 520 Train loss:0.047 Dev loss:0.049 ratio train/dev:0.97
# 530 Train loss:0.045 Dev loss:0.048 ratio train/dev:0.93
# 540 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.89
# 550 Train loss:0.045 Dev loss:0.048 ratio train/dev:0.95
# 560 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.90
# 570 Train loss:0.047 Dev loss:0.047 ratio train/dev:0.98
# 580 Train loss:0.052 Dev loss:0.047 ratio train/dev:1.11
# 590 Train loss:0.044 Dev loss:0.047 ratio train/dev:0.93
# 600 Train loss:0.042 Dev loss:0.047 ratio train/dev:0.91
# 610 Train loss:0.042 Dev loss:0.047 ratio train/dev:0.89
# 620 Train loss:0.041 Dev loss:0.046 ratio train/dev:0.89
# 630 Train loss:0.042 Dev loss:0.046 ratio train/dev:0.91
# 640 Train loss:0.044 Dev loss:0.047 ratio train/dev:0.93
# 650 Train loss:0.044 Dev loss:0.046 ratio train/dev:0.95
# 660 Train loss:0.045 Dev loss:0.046 ratio train/dev:0.97
# 670 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.94
# 680 Train loss:0.048 Dev loss:0.046 ratio train/dev:1.06
# 690 Train loss:0.037 Dev loss:0.045 ratio train/dev:0.82
# 700 Train loss:0.044 Dev loss:0.045 ratio train/dev:0.97
# 710 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.94
# 720 Train loss:0.044 Dev loss:0.045 ratio train/dev:0.98
# 730 Train loss:0.044 Dev loss:0.045 ratio train/dev:0.98
# 740 Train loss:0.042 Dev loss:0.044 ratio train/dev:0.96
# 750 Train loss:0.037 Dev loss:0.045 ratio train/dev:0.83
# 760 Train loss:0.043 Dev loss:0.044 ratio train/dev:0.96
# 770 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.91
# 780 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.86
# 790 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.87
# 800 Train loss:0.044 Dev loss:0.044 ratio train/dev:1.01
# 810 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.91
# 820 Train loss:0.039 Dev loss:0.044 ratio train/dev:0.90
# 830 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.86
# 840 Train loss:0.040 Dev loss:0.043 ratio train/dev:0.93
# 850 Train loss:0.035 Dev loss:0.043 ratio train/dev:0.80
# 860 Train loss:0.043 Dev loss:0.043 ratio train/dev:0.98
# 870 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.87
# 880 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.91
# 890 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.84
# 900 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.88
# 910 Train loss:0.041 Dev loss:0.043 ratio train/dev:0.96
# 920 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.86
# 930 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.90
# 940 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.90
# 950 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.91
# 960 Train loss:0.039 Dev loss:0.042 ratio train/dev:0.92
# 970 Train loss:0.042 Dev loss:0.042 ratio train/dev:1.01
# 980 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.90
# 990 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.90
# 1000 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.87
# 1010 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.90
# 1020 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.92
# 1030 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.88
# 1040 Train loss:0.039 Dev loss:0.042 ratio train/dev:0.94
# 1050 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.92
# 1060 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.90
# 1070 Train loss:0.034 Dev loss:0.042 ratio train/dev:0.82
# 1080 Train loss:0.036 Dev loss:0.041 ratio train/dev:0.87
# 1090 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.88
# 1100 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.77
# Total time taken: 1802.7465720176697

# %%
#CNN - back to glorot, increased the size of the filter in the second layer.
def weight_variable(shape):
    #initial = tf.truncated_normal(shape,stddev=0.1)
    weights = tf.get_variable('weights',shape = shape, initializer = tf.glorot_uniform_initializer()) #Alternative initializer
    return weights

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    #bias = tf.get_variable('bias2',shape = shape, initializer = tf.glorot_uniform_initializer()) #Alternative initializer
    return tf.Variable(initial)
    #return bias

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides = [1,1,1,1],padding = 'SAME')

def max_pool_2X2(x):
    return(tf.nn.max_pool(x,ksize = [1,2,2,1],strides = [1,2,2,1],padding = 'SAME'))

#input data
x = tf.placeholder(tf.float32,[None,Xnp.shape[1]])
y = tf.placeholder(tf.float32,[None,ynp.shape[1]])

#First convolutional layer
with tf.variable_scope('conv1'):
    W_conv1 = weight_variable([3,3,1,32]) #first two dimensions are patch size, next is channels, and last is the number of output channels
    b_conv1 = bias_variable([32]) #bias vector has a component for each output channel

    X_image = tf.reshape(x,[-1,96,96,1]) #2nd and 3rd dimension is image width and height, final dimension is number of color channels

with tf.variable_scope('pool1'):
    h_conv1 = tf.nn.relu(conv2d(X_image,W_conv1) + b_conv1)
    h_pool1 = max_pool_2X2(h_conv1) #reduces image size to 48X48

#Second covolutional layer
with tf.variable_scope('conv2'):
    W_conv2 = weight_variable([10,10,32,64]) # 64 features for each 2X2 patch
    b_conv2 = bias_variable([64])

with tf.variable_scope('pool2'):
    h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
    h_pool2 = max_pool_2X2(h_conv2)  #reduces image size to 24X24

#Third covolutional layer
with tf.variable_scope('conv3'):
    W_conv3 = weight_variable([2,2,64,128]) # 64 features for each 2X2 patch
    b_conv3 = bias_variable([128])

with tf.variable_scope('pool3'):
    h_conv3 = tf.nn.relu(conv2d(h_pool2,W_conv3) + b_conv3)
    h_pool3 = max_pool_2X2(h_conv3)  #reduces image size to 24X24


#Densely connected layer 1
with tf.variable_scope('fc4'):
    W_fc1 = weight_variable([12*12*128,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc1 = bias_variable([512])

    h_pool3_flat = tf.reshape(h_pool3,[-1,12*12*128])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat,W_fc1) + b_fc1)
    
#Dropout
keep_prob = tf.placeholder(tf.float32) # variable to turn on dropout during training, and turn off during test
h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

#Densely connected layer 2
with tf.variable_scope('fc5'):
    W_fc2 = weight_variable([512,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc2 = bias_variable([512])
    h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop,W_fc2) + b_fc2)

#Readout layer
with tf.variable_scope('out'):
    W_fc3 = weight_variable([512,30])
    b_fc3 = bias_variable([30])

    y_conv = tf.matmul(h_fc2,W_fc3) + b_fc3

#loss function
loss = tf.reduce_mean(np.square(y_conv - y))

#optimizer
#train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
learning_rate = 0.01
momentum = 0.9
optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum) 
train_step = optimizer.minimize(loss)

n_epochs = 151
batch_size = 128
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))
y_pred = np.zeros((X_test.shape[0],ynp.shape[1]))


time_start = time.time()
print('starting')
time_1000_start = time.time()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xnp, ynp = Xnp[shuffle], ynp[shuffle]
        
        for i in range(int(Xnp.shape[0]//batch_size)): #run through most of the data points in each epoch
            X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:],ynp[i*batch_size:(i+1)*batch_size]
            #X_batch,y_batch = Xnp[:batch_size,:],ynp[:batch_size]
            #print(i,X_batch[1,1],y_batch[1])
            sess.run(train_step,feed_dict = {x:X_batch,y:y_batch,keep_prob:0.5})
            loss_train = loss.eval(feed_dict = {x:X_batch,y:y_batch,keep_prob:1.0})
        loss_dev = loss.eval(feed_dict = {x:Xdev,y:ydev,keep_prob:1.0})
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    for i in range(int(X_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = X_test[i*batch_size:(i+1)*batch_size,:]
            y_pred[i*batch_size:(i+1)*batch_size] = sess.run(y_conv,feed_dict = {x:X_batch,keep_prob:1.0})
   
print('Total time taken:',time_end-time_start)

#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(16, 16))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# starting
# 0 Train loss:0.104 Dev loss:0.106 ratio train/dev:0.98
# 10 Train loss:0.066 Dev loss:0.070 ratio train/dev:0.94
# 20 Train loss:0.067 Dev loss:0.069 ratio train/dev:0.97
# 30 Train loss:0.063 Dev loss:0.068 ratio train/dev:0.93
# 40 Train loss:0.062 Dev loss:0.067 ratio train/dev:0.92
# 50 Train loss:0.062 Dev loss:0.068 ratio train/dev:0.91
# 60 Train loss:0.060 Dev loss:0.067 ratio train/dev:0.89
# 70 Train loss:0.062 Dev loss:0.066 ratio train/dev:0.94
# 80 Train loss:0.066 Dev loss:0.066 ratio train/dev:1.01
# 90 Train loss:0.057 Dev loss:0.066 ratio train/dev:0.88
# 100 Train loss:0.065 Dev loss:0.065 ratio train/dev:1.00
# 110 Train loss:0.058 Dev loss:0.065 ratio train/dev:0.90
# 120 Train loss:0.059 Dev loss:0.065 ratio train/dev:0.91
# 130 Train loss:0.063 Dev loss:0.064 ratio train/dev:0.98
# 140 Train loss:0.060 Dev loss:0.064 ratio train/dev:0.94
# 150 Train loss:0.057 Dev loss:0.063 ratio train/dev:0.90
# Total time taken: 321.5946807861328

# %%
def flip_horizontal(x,y):
    img = x.reshape(96,96)
    img1 = np.zeros(img.shape)
    #print(y.shape[0])
    y1 = y
    #print(y)
    for i in range(img.shape[1]):
        img1[:,95-i] = img[:,i]
        x1 = img1.reshape(9216)
    
    y1[::2] = y1[::2] * -1
    #print(y1)
    flip_indices = [
        (0, 2), (1, 3),
        (4, 8), (5, 9), (6, 10), (7, 11),
        (12, 16), (13, 17), (14, 18), (15, 19),
        (22, 24), (23, 25)]
    for a, b in flip_indices:
                y1[a], y1[b] = (y1[b], y1[a])
    #print(y1)
    return x1,y1

#CNN - with data augmentation + previous
def weight_variable(shape):
    #initial = tf.truncated_normal(shape,stddev=0.1)
    weights = tf.get_variable('weights8',shape = shape, initializer = tf.glorot_uniform_initializer()) #Alternative initializer
    return weights

def bias_variable(shape):
    initial = tf.constant(0.1,shape = shape)
    #bias = tf.get_variable('bias2',shape = shape, initializer = tf.glorot_uniform_initializer()) #Alternative initializer
    return tf.Variable(initial)
    #return bias

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides = [1,1,1,1],padding = 'SAME')

def max_pool_2X2(x):
    return(tf.nn.max_pool(x,ksize = [1,2,2,1],strides = [1,2,2,1],padding = 'SAME'))

#input data
x = tf.placeholder(tf.float32,[None,Xnp.shape[1]])
y = tf.placeholder(tf.float32,[None,ynp.shape[1]])

#First convolutional layer
with tf.variable_scope('conv1'):
    W_conv1 = weight_variable([3,3,1,32]) #first two dimensions are patch size, next is channels, and last is the number of output channels
    b_conv1 = bias_variable([32]) #bias vector has a component for each output channel

    X_image = tf.reshape(x,[-1,96,96,1]) #2nd and 3rd dimension is image width and height, final dimension is number of color channels

with tf.variable_scope('pool1'):
    h_conv1 = tf.nn.relu(conv2d(X_image,W_conv1) + b_conv1)
    h_pool1 = max_pool_2X2(h_conv1) #reduces image size to 48X48

#Second covolutional layer
with tf.variable_scope('conv2'):
    W_conv2 = weight_variable([2,2,32,64]) # 64 features for each 2X2 patch
    b_conv2 = bias_variable([64])

with tf.variable_scope('pool2'):
    h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
    h_pool2 = max_pool_2X2(h_conv2)  #reduces image size to 24X24

#Third covolutional layer
with tf.variable_scope('conv3'):
    W_conv3 = weight_variable([2,2,64,128]) # 64 features for each 2X2 patch
    b_conv3 = bias_variable([128])

with tf.variable_scope('pool3'):
    h_conv3 = tf.nn.relu(conv2d(h_pool2,W_conv3) + b_conv3)
    h_pool3 = max_pool_2X2(h_conv3)  #reduces image size to 24X24


#Densely connected layer 1
with tf.variable_scope('fc4'):
    W_fc1 = weight_variable([12*12*128,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc1 = bias_variable([512])

    h_pool3_flat = tf.reshape(h_pool3,[-1,12*12*128])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat,W_fc1) + b_fc1)
    
#Dropout
keep_prob = tf.placeholder(tf.float32) # variable to turn on dropout during training, and turn off during test
h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

#Densely connected layer 2
with tf.variable_scope('fc5'):
    W_fc2 = weight_variable([512,512]) #fully connected layer with 1024 neurons to allow processing the entire image
    b_fc2 = bias_variable([512])
    h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop,W_fc2) + b_fc2)

#Readout layer
with tf.variable_scope('out'):
    W_fc3 = weight_variable([512,30])
    b_fc3 = bias_variable([30])

    y_conv = tf.matmul(h_fc2,W_fc3) + b_fc3

#loss function
loss = tf.reduce_mean(np.square(y_conv - y))

#optimizer
#train_step = tf.train.AdamOptimizer(1e-4).minimize(loss)
learning_rate = 0.01
momentum = 0.9
optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum) 
train_step = optimizer.minimize(loss)

#Data augmentation with horizontal flips
Xflips = np.zeros(Xnp.shape) #Array to store the horizontally flipped faces
yflips = np.zeros(ynp.shape)

for i in range(Xnp.shape[0]):
    Xflips[i],yflips[i] = flip_horizontal(Xnp[i],ynp[i])

Xaug = np.vstack((Xnp,Xflips))
yaug = np.vstack((ynp,yflips))

print('Augmented matrix shape:',Xaug.shape,yaug.shape)

n_epochs = 2001
batch_size = 128
train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))
y_pred = np.zeros((X_test.shape[0],ynp.shape[1]))


time_start = time.time()
print('starting')
time_1000_start = time.time()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
        Xaug, yaug = Xaug[shuffle], yaug[shuffle]
        
        for i in range(int(Xaug.shape[0]//batch_size)-5): #run through most of the data points in each epoch
            X_batch,y_batch = Xaug[i*batch_size:(i+1)*batch_size,:],yaug[i*batch_size:(i+1)*batch_size]
            #X_batch,y_batch = Xnp[:batch_size,:],ynp[:batch_size]
            #print(i,X_batch[1,1],y_batch[1])
            sess.run(train_step,feed_dict = {x:X_batch,y:y_batch,keep_prob:0.5})
            loss_train = loss.eval(feed_dict = {x:X_batch,y:y_batch,keep_prob:1.0})
        loss_dev = loss.eval(feed_dict = {x:Xdev,y:ydev,keep_prob:1.0})
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    for i in range(int(X_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = X_test[i*batch_size:(i+1)*batch_size,:]
            y_pred[i*batch_size:(i+1)*batch_size] = sess.run(y_conv,feed_dict = {x:X_batch,keep_prob:1.0})
   
print('Total time taken:',time_end-time_start)

#Plot a graph of the train vs test loss data:
    
plt.plot(train_loss_data[:,1], label="train")
plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
plt.yscale("log")
plt.show()

#Examine a few test cases to see accuracy of prediction:
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

fig = plt.figure(figsize=(16, 16))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_pred[i], ax)

plt.show()
# Out:
# Augmented matrix shape: (3424, 9216) (3424, 30)
# starting
# 0 Train loss:0.149 Dev loss:0.151 ratio train/dev:0.99
# 10 Train loss:0.066 Dev loss:0.069 ratio train/dev:0.95
# 20 Train loss:0.069 Dev loss:0.068 ratio train/dev:1.02
# 30 Train loss:0.065 Dev loss:0.067 ratio train/dev:0.98
# 40 Train loss:0.064 Dev loss:0.066 ratio train/dev:0.96
# 50 Train loss:0.061 Dev loss:0.066 ratio train/dev:0.93
# 60 Train loss:0.060 Dev loss:0.065 ratio train/dev:0.92
# 70 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.07
# 80 Train loss:0.061 Dev loss:0.065 ratio train/dev:0.94
# 90 Train loss:0.062 Dev loss:0.065 ratio train/dev:0.96
# 100 Train loss:0.064 Dev loss:0.064 ratio train/dev:0.99
# 110 Train loss:0.064 Dev loss:0.064 ratio train/dev:0.99
# 120 Train loss:0.065 Dev loss:0.064 ratio train/dev:1.02
# 130 Train loss:0.068 Dev loss:0.064 ratio train/dev:1.07
# 140 Train loss:0.065 Dev loss:0.064 ratio train/dev:1.01
# 150 Train loss:0.057 Dev loss:0.063 ratio train/dev:0.90
# 160 Train loss:0.063 Dev loss:0.063 ratio train/dev:1.00
# 170 Train loss:0.058 Dev loss:0.063 ratio train/dev:0.93
# 180 Train loss:0.057 Dev loss:0.063 ratio train/dev:0.90
# 190 Train loss:0.060 Dev loss:0.063 ratio train/dev:0.96
# 200 Train loss:0.061 Dev loss:0.063 ratio train/dev:0.97
# 210 Train loss:0.060 Dev loss:0.062 ratio train/dev:0.96
# 220 Train loss:0.060 Dev loss:0.062 ratio train/dev:0.97
# 230 Train loss:0.062 Dev loss:0.062 ratio train/dev:1.01
# 240 Train loss:0.062 Dev loss:0.062 ratio train/dev:1.00
# 250 Train loss:0.063 Dev loss:0.062 ratio train/dev:1.03
# 260 Train loss:0.057 Dev loss:0.061 ratio train/dev:0.94
# 270 Train loss:0.060 Dev loss:0.061 ratio train/dev:0.98
# 280 Train loss:0.062 Dev loss:0.061 ratio train/dev:1.02
# 290 Train loss:0.056 Dev loss:0.060 ratio train/dev:0.93
# 300 Train loss:0.055 Dev loss:0.060 ratio train/dev:0.92
# 310 Train loss:0.056 Dev loss:0.060 ratio train/dev:0.93
# 320 Train loss:0.052 Dev loss:0.060 ratio train/dev:0.86
# 330 Train loss:0.061 Dev loss:0.060 ratio train/dev:1.02
# 340 Train loss:0.059 Dev loss:0.059 ratio train/dev:0.99
# 350 Train loss:0.056 Dev loss:0.059 ratio train/dev:0.95
# 360 Train loss:0.056 Dev loss:0.059 ratio train/dev:0.94
# 370 Train loss:0.056 Dev loss:0.059 ratio train/dev:0.95
# 380 Train loss:0.058 Dev loss:0.059 ratio train/dev:1.00
# 390 Train loss:0.054 Dev loss:0.058 ratio train/dev:0.92
# 400 Train loss:0.055 Dev loss:0.058 ratio train/dev:0.94
# 410 Train loss:0.056 Dev loss:0.058 ratio train/dev:0.96
# 420 Train loss:0.055 Dev loss:0.058 ratio train/dev:0.95
# 430 Train loss:0.053 Dev loss:0.057 ratio train/dev:0.92
# 440 Train loss:0.058 Dev loss:0.057 ratio train/dev:1.02
# 450 Train loss:0.060 Dev loss:0.057 ratio train/dev:1.05
# 460 Train loss:0.053 Dev loss:0.057 ratio train/dev:0.92
# 470 Train loss:0.053 Dev loss:0.056 ratio train/dev:0.93
# 480 Train loss:0.058 Dev loss:0.057 ratio train/dev:1.02
# 490 Train loss:0.054 Dev loss:0.056 ratio train/dev:0.97
# 500 Train loss:0.052 Dev loss:0.056 ratio train/dev:0.93
# 510 Train loss:0.053 Dev loss:0.056 ratio train/dev:0.96
# 520 Train loss:0.053 Dev loss:0.055 ratio train/dev:0.96
# 530 Train loss:0.060 Dev loss:0.055 ratio train/dev:1.10
# 540 Train loss:0.052 Dev loss:0.055 ratio train/dev:0.93
# 550 Train loss:0.050 Dev loss:0.055 ratio train/dev:0.92
# 560 Train loss:0.052 Dev loss:0.054 ratio train/dev:0.96
# 570 Train loss:0.048 Dev loss:0.054 ratio train/dev:0.88
# 580 Train loss:0.049 Dev loss:0.054 ratio train/dev:0.90
# 590 Train loss:0.053 Dev loss:0.054 ratio train/dev:0.98
# 600 Train loss:0.051 Dev loss:0.054 ratio train/dev:0.95
# 610 Train loss:0.050 Dev loss:0.053 ratio train/dev:0.94
# 620 Train loss:0.051 Dev loss:0.053 ratio train/dev:0.96
# 630 Train loss:0.050 Dev loss:0.053 ratio train/dev:0.94
# 640 Train loss:0.053 Dev loss:0.053 ratio train/dev:1.00
# 650 Train loss:0.051 Dev loss:0.053 ratio train/dev:0.96
# 660 Train loss:0.053 Dev loss:0.053 ratio train/dev:1.00
# 670 Train loss:0.051 Dev loss:0.052 ratio train/dev:0.98
# 680 Train loss:0.054 Dev loss:0.052 ratio train/dev:1.02
# 690 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.93
# 700 Train loss:0.047 Dev loss:0.052 ratio train/dev:0.91
# 710 Train loss:0.050 Dev loss:0.051 ratio train/dev:0.96
# 720 Train loss:0.048 Dev loss:0.051 ratio train/dev:0.94
# 730 Train loss:0.044 Dev loss:0.051 ratio train/dev:0.86
# 740 Train loss:0.052 Dev loss:0.051 ratio train/dev:1.02
# 750 Train loss:0.046 Dev loss:0.051 ratio train/dev:0.91
# 760 Train loss:0.048 Dev loss:0.050 ratio train/dev:0.96
# 770 Train loss:0.049 Dev loss:0.050 ratio train/dev:0.98
# 780 Train loss:0.052 Dev loss:0.050 ratio train/dev:1.05
# 790 Train loss:0.047 Dev loss:0.050 ratio train/dev:0.94
# 800 Train loss:0.047 Dev loss:0.050 ratio train/dev:0.93
# 810 Train loss:0.050 Dev loss:0.050 ratio train/dev:1.01
# 820 Train loss:0.047 Dev loss:0.050 ratio train/dev:0.95
# 830 Train loss:0.046 Dev loss:0.049 ratio train/dev:0.93
# 840 Train loss:0.051 Dev loss:0.049 ratio train/dev:1.03
# 850 Train loss:0.045 Dev loss:0.049 ratio train/dev:0.91
# 860 Train loss:0.044 Dev loss:0.049 ratio train/dev:0.90
# 870 Train loss:0.048 Dev loss:0.049 ratio train/dev:0.99
# 880 Train loss:0.046 Dev loss:0.049 ratio train/dev:0.94
# 890 Train loss:0.043 Dev loss:0.049 ratio train/dev:0.89
# 900 Train loss:0.046 Dev loss:0.049 ratio train/dev:0.95
# 910 Train loss:0.042 Dev loss:0.049 ratio train/dev:0.87
# 920 Train loss:0.044 Dev loss:0.048 ratio train/dev:0.91
# 930 Train loss:0.048 Dev loss:0.048 ratio train/dev:1.00
# 940 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.91
# 950 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.91
# 960 Train loss:0.044 Dev loss:0.048 ratio train/dev:0.92
# 970 Train loss:0.045 Dev loss:0.048 ratio train/dev:0.94
# 980 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.91
# 990 Train loss:0.041 Dev loss:0.047 ratio train/dev:0.88
# 1000 Train loss:0.045 Dev loss:0.047 ratio train/dev:0.95
# 1010 Train loss:0.048 Dev loss:0.047 ratio train/dev:1.01
# 1020 Train loss:0.045 Dev loss:0.047 ratio train/dev:0.95
# 1030 Train loss:0.045 Dev loss:0.047 ratio train/dev:0.96
# 1040 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.93
# 1050 Train loss:0.045 Dev loss:0.046 ratio train/dev:0.96
# 1060 Train loss:0.040 Dev loss:0.046 ratio train/dev:0.86
# 1070 Train loss:0.041 Dev loss:0.046 ratio train/dev:0.89
# 1080 Train loss:0.044 Dev loss:0.046 ratio train/dev:0.94
# 1090 Train loss:0.044 Dev loss:0.046 ratio train/dev:0.95
# 1100 Train loss:0.045 Dev loss:0.046 ratio train/dev:0.97
# 1110 Train loss:0.039 Dev loss:0.046 ratio train/dev:0.86
# 1120 Train loss:0.039 Dev loss:0.046 ratio train/dev:0.84
# 1130 Train loss:0.045 Dev loss:0.046 ratio train/dev:0.97
# 1140 Train loss:0.041 Dev loss:0.046 ratio train/dev:0.90
# 1150 Train loss:0.044 Dev loss:0.045 ratio train/dev:0.98
# 1160 Train loss:0.040 Dev loss:0.046 ratio train/dev:0.88
# 1170 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.89
# 1180 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.92
# 1190 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.93
# 1200 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.93
# 1210 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.90
# 1220 Train loss:0.041 Dev loss:0.045 ratio train/dev:0.90
# 1230 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.94
# 1240 Train loss:0.039 Dev loss:0.045 ratio train/dev:0.87
# 1250 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.90
# 1260 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.90
# 1270 Train loss:0.041 Dev loss:0.045 ratio train/dev:0.93
# 1280 Train loss:0.042 Dev loss:0.044 ratio train/dev:0.95
# 1290 Train loss:0.042 Dev loss:0.044 ratio train/dev:0.95
# 1300 Train loss:0.041 Dev loss:0.044 ratio train/dev:0.93
# 1310 Train loss:0.041 Dev loss:0.044 ratio train/dev:0.92
# 1320 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.87
# 1330 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.85
# 1340 Train loss:0.039 Dev loss:0.044 ratio train/dev:0.88
# 1350 Train loss:0.037 Dev loss:0.044 ratio train/dev:0.85
# 1360 Train loss:0.039 Dev loss:0.044 ratio train/dev:0.89
# 1370 Train loss:0.041 Dev loss:0.044 ratio train/dev:0.93
# 1380 Train loss:0.041 Dev loss:0.043 ratio train/dev:0.95
# 1390 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.92
# 1400 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.92
# 1410 Train loss:0.041 Dev loss:0.043 ratio train/dev:0.94
# 1420 Train loss:0.039 Dev loss:0.044 ratio train/dev:0.89
# 1430 Train loss:0.042 Dev loss:0.043 ratio train/dev:0.96
# 1440 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.83
# 1450 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.85
# 1460 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.87
# 1470 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.89
# 1480 Train loss:0.041 Dev loss:0.043 ratio train/dev:0.96
# 1490 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.89
# 1500 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.90
# 1510 Train loss:0.040 Dev loss:0.043 ratio train/dev:0.92
# 1520 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.85
# 1530 Train loss:0.040 Dev loss:0.043 ratio train/dev:0.94
# 1540 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.91
# 1550 Train loss:0.034 Dev loss:0.043 ratio train/dev:0.80
# 1560 Train loss:0.045 Dev loss:0.042 ratio train/dev:1.06
# 1570 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.89
# 1580 Train loss:0.040 Dev loss:0.043 ratio train/dev:0.95
# 1590 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.84
# 1600 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.88
# 1610 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.85
# 1620 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.85
# 1630 Train loss:0.040 Dev loss:0.042 ratio train/dev:0.94
# 1640 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.79
# 1650 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.88
# 1660 Train loss:0.040 Dev loss:0.042 ratio train/dev:0.95
# 1670 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.90
# 1680 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.88
# 1690 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.87
# 1700 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.90
# 1710 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.87
# 1720 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.91
# 1730 Train loss:0.039 Dev loss:0.042 ratio train/dev:0.93
# 1740 Train loss:0.038 Dev loss:0.042 ratio train/dev:0.91
# 1750 Train loss:0.039 Dev loss:0.042 ratio train/dev:0.93
# 1760 Train loss:0.038 Dev loss:0.041 ratio train/dev:0.91
# 1770 Train loss:0.036 Dev loss:0.041 ratio train/dev:0.88
# 1780 Train loss:0.038 Dev loss:0.041 ratio train/dev:0.92
# 1790 Train loss:0.038 Dev loss:0.041 ratio train/dev:0.92
# 1800 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.82
# 1810 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.88
# 1820 Train loss:0.035 Dev loss:0.041 ratio train/dev:0.85
# 1830 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.90
# 1840 Train loss:0.038 Dev loss:0.041 ratio train/dev:0.92
# 1850 Train loss:0.036 Dev loss:0.041 ratio train/dev:0.87
# 1860 Train loss:0.038 Dev loss:0.041 ratio train/dev:0.93
# 1870 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.89
# 1880 Train loss:0.035 Dev loss:0.041 ratio train/dev:0.85
# 1890 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.90
# 1900 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.91
# 1910 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.82
# 1920 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.89
# 1930 Train loss:0.040 Dev loss:0.041 ratio train/dev:0.97
# 1940 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.90
# 1950 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.83
# 1960 Train loss:0.036 Dev loss:0.041 ratio train/dev:0.88
# 1970 Train loss:0.036 Dev loss:0.041 ratio train/dev:0.87
# 1980 Train loss:0.035 Dev loss:0.041 ratio train/dev:0.86
# 1990 Train loss:0.034 Dev loss:0.040 ratio train/dev:0.84
# 2000 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.91
# Total time taken: 2219.6291205883026
