# %% [markdown]
# # Facial Keypoints Detection
# ## W207 Final Project December 2017
# ### Arunima Kayath, Kathleen Wang, Anamika Sinha & Scott A. George

# %%
import os

import numpy as np
from pandas.io.parsers import read_csv
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from decimal import *
import tensorflow as tf
import time
from datetime import datetime
import matplotlib.pyplot as plt
from tensorflow.contrib.layers import fully_connected

# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# %% [markdown]
# ## Loading Data

# %%
scott = False
aws = False
tensorboard_log = False

if scott:
    FROOT = ''
    FTRAIN = '/data/facial/training.csv'
    FTEST = '/data/facial/test.csv'
elif aws:
    FROOT = ''
    FTRAIN = '/data/training.csv'
    FTEST = '/data/test.csv'
else:
    FROOT = os.getcwd() # Path to your project folder
    FTRAIN = '~/notebooks/training.csv'
    FTEST = '~/notebooks/test.csv'

if tensorboard_log:
    root_logdir = FROOT + "tf_logs"

# %% [markdown]
# Helper function to load data

# %%
np.random.seed(0)
def load(test = False, cols = None):
    '''Loads data from FTEST if *test* is true, otherwise from FTRAIN.' 
    Pass a list of *cols* if you are only interested in a
    subset of the target columns'''
    
    fname = FTEST if test else FTRAIN
    df = read_csv(os.path.expanduser(fname)) #load pandas dataframe

    
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im,sep=' ')) 
    #image column has pixel values separated by space; convert the values to numpy arrays
    
    if cols: #get a subset of columns
        df = df[list(cols) + ['Image']]
        
    print('Count of observations in training data by features')
    print(df.count()) #prints number of values for each column
    df = df.dropna() #drop all rows that have missing values in them
    
    X = np.vstack(df['Image'].values)/255
    X = X.astype(np.float32)
    
    if not test:
        y  = df[df.columns[:-1]].values
        y = (y-48)/48
        shuffle = np.random.permutation(np.arange(X.shape[0]))
        X, y = X[shuffle], y[shuffle]
        y = y.astype(np.float32)
    else:
        y = None
    print('done')
        
    return X,y

# %%
np.random.seed(0)
X, y = load()

print('Total training data')
print("X.shape = = {}; X.min == {:.3f}; X.max == {:.3f}".format(X.shape, X.min(),X.max()))
print("y.shape = = {}; y.min == {:.3f}; y.max == {:.3f}".format(y.shape, y.min(),y.max()))
# Out:
# Count of observations in training data by features
# left_eye_center_x            7039
# left_eye_center_y            7039
# right_eye_center_x           7036
# right_eye_center_y           7036
# left_eye_inner_corner_x      2271
# left_eye_inner_corner_y      2271
# left_eye_outer_corner_x      2267
# left_eye_outer_corner_y      2267
# right_eye_inner_corner_x     2268
# right_eye_inner_corner_y     2268
# right_eye_outer_corner_x     2268
# right_eye_outer_corner_y     2268
# left_eyebrow_inner_end_x     2270
# left_eyebrow_inner_end_y     2270
# left_eyebrow_outer_end_x     2225
# left_eyebrow_outer_end_y     2225
# right_eyebrow_inner_end_x    2270
# right_eyebrow_inner_end_y    2270
# right_eyebrow_outer_end_x    2236
# right_eyebrow_outer_end_y    2236
# nose_tip_x                   7049
# nose_tip_y                   7049
# mouth_left_corner_x          2269
# mouth_left_corner_y          2269
# mouth_right_corner_x         2270
# mouth_right_corner_y         2270
# mouth_center_top_lip_x       2275
# mouth_center_top_lip_y       2275
# mouth_center_bottom_lip_x    7016
# mouth_center_bottom_lip_y    7016
# Image                        7049
# dtype: int64
# done
# Total training data
# X.shape = = (2140, 9216); X.min == 0.000; X.max == 1.000
# y.shape = = (2140, 30); y.min == -0.920; y.max == 0.996

# %% [markdown]
# Save 20% data to be used as dev data, carve out dev data and load test data

# %%
np.random.seed(0)
dev_size = 0.2
#setting aside a 20% sample for validation

x_train, x_dev, y_train, y_dev = train_test_split(X, y, test_size = dev_size)

x_test, _ = load(test=True)

print('Training data split into train and dev data')
print("x_train.shape = = {}; x_train.min == {:.3f}; x_train.max == {:.3f}".format(x_train.shape, x_train.min(),x_train.max()))
print("y_train.shape = = {}; y_train.min == {:.3f}; y_train.max == {:.3f}".format(y_train.shape, y_train.min(),y_train.max()))
print("x_dev.shape = = {}; x_dev.min == {:.3f}; x_dev.max == {:.3f}".format(x_dev.shape, x_dev.min(),x_dev.max()))
print("y_dev.shape = = {}; y_dev.min == {:.3f}; y_dev.max == {:.3f}".format(y_dev.shape, y_dev.min(),y_dev.max()))
# Out:
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1712, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1712, 30); y_train.min == -0.916; y_train.max == 0.996
# x_dev.shape = = (428, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (428, 30); y_dev.min == -0.920; y_dev.max == 0.980

# %% [markdown]
# ## Helper functions
#
# ### 1. plot_sample: plots sample pictures

# %%
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

# %%
np.random.seed(1)
def shuffle_run_batch(Xnp, ynp, Xdev, ydev, batch_size, epoch):
    """function takes training and dev data, shuffle the train data and run TF optimizer in batches for a given epoch
    It returns the average loss for training and eval of all the batches ran in the epoch.
    It expects to run with tensorboard."""

    shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xnp, ynp = Xnp[shuffle], ynp[shuffle]

    # initialize variables to hold loss information for each epoch
    #loss_train = 0
    #loss_dev = 0
    batches = Xnp.shape[0]//batch_size


    for i in range(int(batches)): #run through most of the data points in each epoch
        X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:], ynp[i*batch_size:(i+1)*batch_size]
        if tensorboard_log:
            if i % 10 == 0:
                train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, training: True})
                dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, training: False})
                step = epoch * batches + i
                train_writer.add_summary(train_summary_str, step)
                dev_writer.add_summary(dev_summary_str, step)

        sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})

    

        loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
        loss_dev = loss.eval(feed_dict = {X:Xdev,y:ydev, training:False})

    
    return loss_train, loss_dev

# %%
# *might* need to double check correctly formatted input
def plot_loss (train_loss_data, dev_loss_data):
    
    plt.plot(train_loss_data[:,1], label="train")
    plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.yscale("log")
    plt.show()

# %%
# *might* need to double check correctly formatted input
def plot_pred (x_dev, y_pred):
    
    fig = plt.figure(figsize=(16, 16))
    fig.subplots_adjust(
        left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(16):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        plot_sample(x_dev[i], y_pred[i], ax)
    plt.show

# %% [markdown]
# ## First model: 1 hidden layer simple neural net

# %% [markdown]
# Define parameters

# %%
learning_rate = 0.01
momentum = 0.9

n_epochs = 500
batch_size = 50


n_inputs = X.shape[1] 
n_hidden1 = 100
n_outputs = 30

# %% [markdown]
# Construct the tensorflow graph for the first network

# %%
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)


with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    pred_keypoints = fully_connected(hidden1,n_outputs,activation_fn = None,scope = 'outputs')
    
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()


train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))

time_start = time.time()
time_1000_start = time.time()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        
        # note this is includes the for-loop for batching
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)
                    
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                  'Dev loss:%0.3f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
            
            
    time_end = time.time()  
    
    y_pred = sess.run(pred_keypoints,feed_dict = {X: x_test})
   
    print('Total time taken:',time_end-time_start)
    
#train_writer.close()
#dev_writer.close()
    
plt.figure()
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred) #updated this to be x_test instead of x_dev, since the predictions are being made on x_test
# Out:
# 0 Train loss:0.125 Dev loss:0.125 ratio train/dev:1.00
# 10 Train loss:0.092 Dev loss:0.092 ratio train/dev:1.01
# 20 Train loss:0.077 Dev loss:0.084 ratio train/dev:0.92
# 30 Train loss:0.074 Dev loss:0.078 ratio train/dev:0.95
# 40 Train loss:0.068 Dev loss:0.076 ratio train/dev:0.90
# 50 Train loss:0.064 Dev loss:0.072 ratio train/dev:0.88
# 60 Train loss:0.062 Dev loss:0.071 ratio train/dev:0.87
# 70 Train loss:0.056 Dev loss:0.067 ratio train/dev:0.83
# 80 Train loss:0.051 Dev loss:0.066 ratio train/dev:0.77
# 90 Train loss:0.056 Dev loss:0.064 ratio train/dev:0.87
# 100 Train loss:0.058 Dev loss:0.066 ratio train/dev:0.89
# 110 Train loss:0.055 Dev loss:0.063 ratio train/dev:0.87
# 120 Train loss:0.048 Dev loss:0.062 ratio train/dev:0.78
# 130 Train loss:0.053 Dev loss:0.061 ratio train/dev:0.87
# 140 Train loss:0.051 Dev loss:0.060 ratio train/dev:0.84
# 150 Train loss:0.048 Dev loss:0.060 ratio train/dev:0.80
# 160 Train loss:0.043 Dev loss:0.059 ratio train/dev:0.73
# 170 Train loss:0.048 Dev loss:0.059 ratio train/dev:0.81
# 180 Train loss:0.044 Dev loss:0.058 ratio train/dev:0.76
# 190 Train loss:0.042 Dev loss:0.058 ratio train/dev:0.73
# 200 Train loss:0.044 Dev loss:0.057 ratio train/dev:0.76
# 210 Train loss:0.042 Dev loss:0.057 ratio train/dev:0.73
# 220 Train loss:0.042 Dev loss:0.057 ratio train/dev:0.75
# 230 Train loss:0.039 Dev loss:0.056 ratio train/dev:0.70
# 240 Train loss:0.038 Dev loss:0.056 ratio train/dev:0.67
# 250 Train loss:0.042 Dev loss:0.057 ratio train/dev:0.74
# 260 Train loss:0.043 Dev loss:0.055 ratio train/dev:0.77
# 270 Train loss:0.039 Dev loss:0.055 ratio train/dev:0.70
# 280 Train loss:0.042 Dev loss:0.055 ratio train/dev:0.76
# 290 Train loss:0.036 Dev loss:0.055 ratio train/dev:0.66
# 300 Train loss:0.041 Dev loss:0.055 ratio train/dev:0.75
# 310 Train loss:0.037 Dev loss:0.055 ratio train/dev:0.68
# 320 Train loss:0.041 Dev loss:0.055 ratio train/dev:0.75
# 330 Train loss:0.039 Dev loss:0.055 ratio train/dev:0.71
# 340 Train loss:0.040 Dev loss:0.054 ratio train/dev:0.75
# 350 Train loss:0.040 Dev loss:0.054 ratio train/dev:0.74
# 360 Train loss:0.034 Dev loss:0.054 ratio train/dev:0.63
# 370 Train loss:0.035 Dev loss:0.054 ratio train/dev:0.65
# 380 Train loss:0.037 Dev loss:0.054 ratio train/dev:0.67
# 390 Train loss:0.038 Dev loss:0.055 ratio train/dev:0.70
# 400 Train loss:0.036 Dev loss:0.054 ratio train/dev:0.68
# 410 Train loss:0.036 Dev loss:0.053 ratio train/dev:0.68
# 420 Train loss:0.034 Dev loss:0.053 ratio train/dev:0.63
# 430 Train loss:0.038 Dev loss:0.054 ratio train/dev:0.70
# 440 Train loss:0.033 Dev loss:0.053 ratio train/dev:0.62
# 450 Train loss:0.038 Dev loss:0.054 ratio train/dev:0.70
# 460 Train loss:0.040 Dev loss:0.054 ratio train/dev:0.74
# 470 Train loss:0.035 Dev loss:0.053 ratio train/dev:0.65
# 480 Train loss:0.032 Dev loss:0.053 ratio train/dev:0.60
# 490 Train loss:0.035 Dev loss:0.053 ratio train/dev:0.66
# Total time taken: 106.28440046310425

# %%
#Net 1 with 2 hidden layers
n_hidden2 = 60
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)
    
with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    hidden2 = fully_connected(hidden1,n_hidden2,scope = 'hidden2')
    pred_keypoints = fully_connected(hidden2,n_outputs,activation_fn = None,scope = 'outputs')
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()


train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))

time_start = time.time()
time_1000_start = time.time()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        
        # note this is includes the for-loop for batching
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)
                    
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                  'Dev loss:%0.3f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
            
            
    time_end = time.time()  
    
    y_pred = sess.run(pred_keypoints,feed_dict = {X: x_test})
   
    print('Total time taken:',time_end-time_start)
    
#train_writer.close()
#dev_writer.close()
    
plt.figure()
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)
# Out:
# 0 Train loss:0.126 Dev loss:0.125 ratio train/dev:1.01
# 10 Train loss:0.091 Dev loss:0.088 ratio train/dev:1.02
# 20 Train loss:0.071 Dev loss:0.079 ratio train/dev:0.91
# 30 Train loss:0.076 Dev loss:0.073 ratio train/dev:1.03
# 40 Train loss:0.063 Dev loss:0.070 ratio train/dev:0.91
# 50 Train loss:0.062 Dev loss:0.067 ratio train/dev:0.93
# 60 Train loss:0.060 Dev loss:0.065 ratio train/dev:0.93
# 70 Train loss:0.055 Dev loss:0.065 ratio train/dev:0.85
# 80 Train loss:0.049 Dev loss:0.062 ratio train/dev:0.79
# 90 Train loss:0.057 Dev loss:0.061 ratio train/dev:0.94
# 100 Train loss:0.058 Dev loss:0.060 ratio train/dev:0.96
# 110 Train loss:0.057 Dev loss:0.060 ratio train/dev:0.95
# 120 Train loss:0.047 Dev loss:0.059 ratio train/dev:0.80
# 130 Train loss:0.053 Dev loss:0.058 ratio train/dev:0.92
# 140 Train loss:0.052 Dev loss:0.057 ratio train/dev:0.90
# 150 Train loss:0.050 Dev loss:0.057 ratio train/dev:0.87
# 160 Train loss:0.046 Dev loss:0.057 ratio train/dev:0.81
# 170 Train loss:0.050 Dev loss:0.056 ratio train/dev:0.90
# 180 Train loss:0.047 Dev loss:0.055 ratio train/dev:0.85
# 190 Train loss:0.044 Dev loss:0.056 ratio train/dev:0.80
# 200 Train loss:0.046 Dev loss:0.055 ratio train/dev:0.84
# 210 Train loss:0.044 Dev loss:0.054 ratio train/dev:0.82
# 220 Train loss:0.044 Dev loss:0.054 ratio train/dev:0.81
# 230 Train loss:0.043 Dev loss:0.054 ratio train/dev:0.79
# 240 Train loss:0.040 Dev loss:0.054 ratio train/dev:0.74
# 250 Train loss:0.043 Dev loss:0.054 ratio train/dev:0.80
# 260 Train loss:0.044 Dev loss:0.053 ratio train/dev:0.82
# 270 Train loss:0.041 Dev loss:0.053 ratio train/dev:0.78
# 280 Train loss:0.042 Dev loss:0.053 ratio train/dev:0.80
# 290 Train loss:0.038 Dev loss:0.053 ratio train/dev:0.73
# 300 Train loss:0.044 Dev loss:0.053 ratio train/dev:0.84
# 310 Train loss:0.039 Dev loss:0.052 ratio train/dev:0.75
# 320 Train loss:0.043 Dev loss:0.052 ratio train/dev:0.83
# 330 Train loss:0.040 Dev loss:0.052 ratio train/dev:0.78
# 340 Train loss:0.043 Dev loss:0.052 ratio train/dev:0.83
# 350 Train loss:0.043 Dev loss:0.052 ratio train/dev:0.82
# 360 Train loss:0.038 Dev loss:0.052 ratio train/dev:0.73
# 370 Train loss:0.037 Dev loss:0.052 ratio train/dev:0.71
# 380 Train loss:0.040 Dev loss:0.051 ratio train/dev:0.77
# 390 Train loss:0.040 Dev loss:0.051 ratio train/dev:0.77
# 400 Train loss:0.040 Dev loss:0.051 ratio train/dev:0.78
# 410 Train loss:0.039 Dev loss:0.051 ratio train/dev:0.76
# 420 Train loss:0.036 Dev loss:0.051 ratio train/dev:0.71
# 430 Train loss:0.040 Dev loss:0.051 ratio train/dev:0.78
# 440 Train loss:0.035 Dev loss:0.051 ratio train/dev:0.69
# 450 Train loss:0.039 Dev loss:0.051 ratio train/dev:0.77
# 460 Train loss:0.041 Dev loss:0.051 ratio train/dev:0.80
# 470 Train loss:0.038 Dev loss:0.051 ratio train/dev:0.73
# 480 Train loss:0.034 Dev loss:0.051 ratio train/dev:0.67
# 490 Train loss:0.037 Dev loss:0.051 ratio train/dev:0.73
# Total time taken: 107.0983452796936

# %% [markdown]
# ## Second model: Convolutional Neural Network

# %% [markdown]
# ### 1. Base convolutional NN:
# ### optimizer = MomentumOptimizer,
# Define parameters

# %%
learning_rate = 0.01
momentum = 0.9
# optimizer used
optimize_func = tf.train.MomentumOptimizer
# (learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

n_epochs = 2501
batch_size = 128

n_inputs = X.shape[1] 
n_outputs = 30


# Convolutional Layer 1.
filter_size1 = 3          # Convolution filters are 3 x 3 pixels.
num_filters1 = 32         # There are 32 of these filters.
dropout_keep_prob1 = 1


# Convolutional Layer 2.
filter_size2 = 2          # Convolution filters are 2 x 2 pixels.
num_filters2 = 64         # There are 64 of these filters.
dropout_keep_prob2 = 1


# Convolutional Layer 3.
filter_size3 = 2          # Convolution filters are 2 x 2 pixels.
num_filters3 = 128         # There are 128 of these filters.
dropout_keep_prob3 = 1


# Fully-connected layer.
fc_size4 = 1000             # Number of output neurons in fully-connected layer1.
dropout_keep_prob4 = 1      # Drop about keep robability if drop outs are applied
fc_size5 = 1000             # Number of output neurons in fully-connected layer2.
dropout_keep_prob5 = 1
dropout_keep_prob6 = 1



# # data_augmentation = False
# # learning_rate_decay = True
# # momentum_increase = True
# dropout = True

#model_name = "3con_2fc_b" + str(batch_size) + "_e" + str(num_epochs - 1)
# if data_augmentation:
#     model_name += "_aug"
# if learning_rate_decay:
#     model_name += "_lrdec"
# if momentum_increase:
#     model_name += "_mominc"
# if dropout:
#     model_name += "_dr"

# %% [markdown]
# ### Define helper function to:
# ### 1) create convoluted layer variables
# ### 2) create dense layer and
# ### 3) flatten a conv layer for the dense layer

# %%
#Building a convolutional layer

def new_conv_relu_layer(input, filter_size, num_filters, is_training, dropout_keep_prob = 1):
    """Takes parameters and set up a convoluted layer with possible pooling
    It returns the layer as well as the weights"""

    weights = tf.get_variable( 'weights', 
        shape = [filter_size, filter_size, input.get_shape()[3], num_filters],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    
    biases = tf.get_variable( 'biases',
        shape = [num_filters],
        initializer=tf.constant_initializer(0.0)
      )
    
    conv = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')
    
    
    layer = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')


    layer += biases

    layer = tf.nn.max_pool(value=layer, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1],padding='SAME')

    layer = tf.nn.relu(layer)    
    
    # apply drop out by specifying a drop_out_keep_prob
    layer = tf.cond(is_training, lambda: tf.nn.dropout(layer, keep_prob = dropout_keep_prob), lambda: layer)
    
    return layer, weights

# %%
#Building a fully connected layer, with relu
def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu,
                 is_training ,
                 dropout_keep_prob = 1):       # no relu for the output dense layer

    # Create new weights and biases.
    weights = tf.get_variable( 'weights', 
        shape = [num_inputs, num_outputs],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    
    biases = tf.get_variable( 'biases',
        shape = [num_outputs],
        initializer=tf.constant_initializer(0.0)
      )
        

    layer = tf.matmul(input, weights) + biases
    
    if use_relu:
        layer = tf.nn.relu(layer)
    
    layer = tf.cond(is_training, lambda: tf.nn.dropout(layer, keep_prob = dropout_keep_prob), lambda: layer)

    return layer

# %%
# build flatten layer function to flatten conv layer for the fully connected layer
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(layer, [-1, num_features])
    return layer_flat, num_features

# %%
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

#Plot a graph of the train vs test loss data:
    

plot_loss (train_loss_data, dev_loss_data)


#train_writer.close()
#dev_writer.close()
plot_pred (x_test, y_pred)

# #Examine a few test cases to see accuracy of prediction:
# def plot_sample(x, y, axis):
#     img = x.reshape(96, 96)
#     axis.imshow(img, cmap='gray')
#     axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

# fig = plt.figure(figsize=(16, 16))
# fig.subplots_adjust(
#     left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# for i in range(16):
#     ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
#     plot_sample(X_test[i], y_pred[i], ax)

# plt.show()
# Out:
# 0 Train loss:0.201 Dev loss:0.201 ratio train/dev:1.00
# 10 Train loss:0.073 Dev loss:0.071 ratio train/dev:1.03
# 20 Train loss:0.072 Dev loss:0.067 ratio train/dev:1.06
# 30 Train loss:0.073 Dev loss:0.066 ratio train/dev:1.10
# 40 Train loss:0.069 Dev loss:0.065 ratio train/dev:1.06
# 50 Train loss:0.063 Dev loss:0.065 ratio train/dev:0.97
# 60 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# 70 Train loss:0.067 Dev loss:0.065 ratio train/dev:1.03
# 80 Train loss:0.061 Dev loss:0.064 ratio train/dev:0.95
# 90 Train loss:0.066 Dev loss:0.064 ratio train/dev:1.03
# 100 Train loss:0.059 Dev loss:0.064 ratio train/dev:0.93
# 110 Train loss:0.062 Dev loss:0.064 ratio train/dev:0.97
# 120 Train loss:0.064 Dev loss:0.063 ratio train/dev:1.01
# 130 Train loss:0.066 Dev loss:0.063 ratio train/dev:1.05
# 140 Train loss:0.066 Dev loss:0.063 ratio train/dev:1.04
# 150 Train loss:0.059 Dev loss:0.063 ratio train/dev:0.95
# 160 Train loss:0.059 Dev loss:0.062 ratio train/dev:0.96
# 170 Train loss:0.064 Dev loss:0.062 ratio train/dev:1.04
# 180 Train loss:0.061 Dev loss:0.062 ratio train/dev:1.00
# 190 Train loss:0.058 Dev loss:0.061 ratio train/dev:0.95
# 200 Train loss:0.057 Dev loss:0.061 ratio train/dev:0.94
# 210 Train loss:0.061 Dev loss:0.061 ratio train/dev:1.00
# 220 Train loss:0.064 Dev loss:0.060 ratio train/dev:1.06
# 230 Train loss:0.057 Dev loss:0.060 ratio train/dev:0.95
# 240 Train loss:0.061 Dev loss:0.060 ratio train/dev:1.02
# 250 Train loss:0.058 Dev loss:0.059 ratio train/dev:0.97
# 260 Train loss:0.054 Dev loss:0.059 ratio train/dev:0.92
# 270 Train loss:0.057 Dev loss:0.058 ratio train/dev:0.97
# 280 Train loss:0.058 Dev loss:0.058 ratio train/dev:1.00
# 290 Train loss:0.055 Dev loss:0.058 ratio train/dev:0.95
# 300 Train loss:0.054 Dev loss:0.057 ratio train/dev:0.95
# 310 Train loss:0.058 Dev loss:0.057 ratio train/dev:1.03
# 320 Train loss:0.056 Dev loss:0.056 ratio train/dev:1.00
# 330 Train loss:0.051 Dev loss:0.056 ratio train/dev:0.92
# 340 Train loss:0.055 Dev loss:0.055 ratio train/dev:1.00
# 350 Train loss:0.053 Dev loss:0.055 ratio train/dev:0.96
# 360 Train loss:0.051 Dev loss:0.054 ratio train/dev:0.94
# 370 Train loss:0.051 Dev loss:0.054 ratio train/dev:0.96
# 380 Train loss:0.051 Dev loss:0.053 ratio train/dev:0.97
# 390 Train loss:0.049 Dev loss:0.053 ratio train/dev:0.93
# 400 Train loss:0.050 Dev loss:0.052 ratio train/dev:0.96
# 410 Train loss:0.047 Dev loss:0.052 ratio train/dev:0.91
# 420 Train loss:0.048 Dev loss:0.051 ratio train/dev:0.94
# 430 Train loss:0.052 Dev loss:0.050 ratio train/dev:1.02
# 440 Train loss:0.047 Dev loss:0.050 ratio train/dev:0.94
# 450 Train loss:0.048 Dev loss:0.049 ratio train/dev:0.96
# 460 Train loss:0.045 Dev loss:0.049 ratio train/dev:0.92
# 470 Train loss:0.046 Dev loss:0.049 ratio train/dev:0.95
# 480 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.89
# 490 Train loss:0.044 Dev loss:0.048 ratio train/dev:0.92
# 500 Train loss:0.048 Dev loss:0.047 ratio train/dev:1.02
# 510 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.91
# 520 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.92
# 530 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.93
# 540 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.92
# 550 Train loss:0.039 Dev loss:0.046 ratio train/dev:0.84
# 560 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.95
# 570 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.94
# 580 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.94
# 590 Train loss:0.042 Dev loss:0.045 ratio train/dev:0.92
# 600 Train loss:0.045 Dev loss:0.045 ratio train/dev:1.01
# 610 Train loss:0.039 Dev loss:0.045 ratio train/dev:0.88
# 620 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.90
# 630 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.91
# 640 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.91
# 650 Train loss:0.039 Dev loss:0.044 ratio train/dev:0.89
# 660 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.91
# 670 Train loss:0.039 Dev loss:0.044 ratio train/dev:0.90
# 680 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.87
# 690 Train loss:0.039 Dev loss:0.044 ratio train/dev:0.89
# 700 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.87
# 710 Train loss:0.040 Dev loss:0.043 ratio train/dev:0.92
# 720 Train loss:0.035 Dev loss:0.043 ratio train/dev:0.82
# 730 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.84
# 740 Train loss:0.034 Dev loss:0.043 ratio train/dev:0.79
# 750 Train loss:0.035 Dev loss:0.043 ratio train/dev:0.81
# 760 Train loss:0.039 Dev loss:0.043 ratio train/dev:0.92
# 770 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.84
# 780 Train loss:0.034 Dev loss:0.043 ratio train/dev:0.79
# 790 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.86
# 800 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.87
# 810 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.87
# 820 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.82
# 830 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.85
# 840 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.85
# 850 Train loss:0.040 Dev loss:0.042 ratio train/dev:0.96
# 860 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.89
# 870 Train loss:0.034 Dev loss:0.042 ratio train/dev:0.82
# 880 Train loss:0.037 Dev loss:0.042 ratio train/dev:0.90
# 890 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.79
# 900 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.85
# 910 Train loss:0.034 Dev loss:0.042 ratio train/dev:0.83
# 920 Train loss:0.034 Dev loss:0.042 ratio train/dev:0.81
# 930 Train loss:0.037 Dev loss:0.041 ratio train/dev:0.88
# 940 Train loss:0.035 Dev loss:0.041 ratio train/dev:0.84
# 950 Train loss:0.031 Dev loss:0.041 ratio train/dev:0.74
# 960 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.79
# 970 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.81
# 980 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.82
# 990 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.84
# 1000 Train loss:0.036 Dev loss:0.041 ratio train/dev:0.88
# 1010 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.82
# 1020 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.82
# 1030 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.82
# 1040 Train loss:0.031 Dev loss:0.041 ratio train/dev:0.75
# 1050 Train loss:0.031 Dev loss:0.041 ratio train/dev:0.77
# 1060 Train loss:0.035 Dev loss:0.041 ratio train/dev:0.86
# 1070 Train loss:0.031 Dev loss:0.041 ratio train/dev:0.75
# 1080 Train loss:0.034 Dev loss:0.041 ratio train/dev:0.82
# 1090 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.79
# 1100 Train loss:0.035 Dev loss:0.041 ratio train/dev:0.85
# 1110 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.80
# 1120 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.74
# 1130 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.81
# 1140 Train loss:0.033 Dev loss:0.040 ratio train/dev:0.81
# 1150 Train loss:0.031 Dev loss:0.040 ratio train/dev:0.76
# 1160 Train loss:0.033 Dev loss:0.040 ratio train/dev:0.82
# 1170 Train loss:0.031 Dev loss:0.040 ratio train/dev:0.76
# 1180 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.72
# 1190 Train loss:0.031 Dev loss:0.040 ratio train/dev:0.76
# 1200 Train loss:0.030 Dev loss:0.040 ratio train/dev:0.74
# 1210 Train loss:0.031 Dev loss:0.040 ratio train/dev:0.78
# 1220 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.72
# 1230 Train loss:0.033 Dev loss:0.040 ratio train/dev:0.82
# 1240 Train loss:0.030 Dev loss:0.040 ratio train/dev:0.74
# 1250 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.74
# 1260 Train loss:0.032 Dev loss:0.040 ratio train/dev:0.81
# 1270 Train loss:0.028 Dev loss:0.040 ratio train/dev:0.69
# 1280 Train loss:0.032 Dev loss:0.040 ratio train/dev:0.81
# 1290 Train loss:0.032 Dev loss:0.040 ratio train/dev:0.80
# 1300 Train loss:0.031 Dev loss:0.040 ratio train/dev:0.78
# 1310 Train loss:0.032 Dev loss:0.040 ratio train/dev:0.79
# 1320 Train loss:0.031 Dev loss:0.040 ratio train/dev:0.77
# 1330 Train loss:0.028 Dev loss:0.040 ratio train/dev:0.70
# 1340 Train loss:0.030 Dev loss:0.040 ratio train/dev:0.75
# 1350 Train loss:0.028 Dev loss:0.040 ratio train/dev:0.70
# 1360 Train loss:0.030 Dev loss:0.040 ratio train/dev:0.74
# 1370 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.74
# 1380 Train loss:0.027 Dev loss:0.040 ratio train/dev:0.69
# 1390 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.72
# 1400 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.74
# 1410 Train loss:0.030 Dev loss:0.040 ratio train/dev:0.76
# 1420 Train loss:0.031 Dev loss:0.040 ratio train/dev:0.77
# 1430 Train loss:0.030 Dev loss:0.040 ratio train/dev:0.76
# 1440 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.73
# 1450 Train loss:0.028 Dev loss:0.040 ratio train/dev:0.71
# 1460 Train loss:0.027 Dev loss:0.040 ratio train/dev:0.69
# 1470 Train loss:0.029 Dev loss:0.040 ratio train/dev:0.74
# 1480 Train loss:0.030 Dev loss:0.040 ratio train/dev:0.75
# 1490 Train loss:0.029 Dev loss:0.039 ratio train/dev:0.73
# 1500 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1510 Train loss:0.030 Dev loss:0.039 ratio train/dev:0.76
# 1520 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.72
# 1530 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.69
# 1540 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.70
# 1550 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.69
# 1560 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.64
# 1570 Train loss:0.031 Dev loss:0.039 ratio train/dev:0.78
# 1580 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1590 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.70
# 1600 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.70
# 1610 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.69
# 1620 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.69
# 1630 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.71
# 1640 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.65
# 1650 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.67
# 1660 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.65
# 1670 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1680 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.67
# 1690 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.65
# 1700 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.67
# 1710 Train loss:0.029 Dev loss:0.039 ratio train/dev:0.73
# 1720 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1730 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.70
# 1740 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1750 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.73
# 1760 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.73
# 1770 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.69
# 1780 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.72
# 1790 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.65
# 1800 Train loss:0.024 Dev loss:0.039 ratio train/dev:0.62
# 1810 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.67
# 1820 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.63
# 1830 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.68
# 1840 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.68
# 1850 Train loss:0.024 Dev loss:0.039 ratio train/dev:0.63
# 1860 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.69
# 1870 Train loss:0.028 Dev loss:0.039 ratio train/dev:0.71
# 1880 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.64
# 1890 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1900 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.67
# 1910 Train loss:0.024 Dev loss:0.039 ratio train/dev:0.62
# 1920 Train loss:0.027 Dev loss:0.039 ratio train/dev:0.70
# 1930 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.64
# 1940 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.64
# 1950 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1960 Train loss:0.025 Dev loss:0.039 ratio train/dev:0.63
# 1970 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.66
# 1980 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.68
# 1990 Train loss:0.024 Dev loss:0.039 ratio train/dev:0.61
# 2000 Train loss:0.026 Dev loss:0.039 ratio train/dev:0.68
# Total time taken: 4895.616111755371

# %%
def flip_horizontal(x,y):
    img = x.reshape(96,96)
    img1 = np.zeros(img.shape)
    #print(y.shape[0])
    y1 = y
    #print(y)
    for i in range(img.shape[1]):
        img1[:,95-i] = img[:,i]
        x1 = img1.reshape(9216)
    
    y1[::2] = y1[::2] * -1
    #print(y1)
    flip_indices = [
        (0, 2), (1, 3),
        (4, 8), (5, 9), (6, 10), (7, 11),
        (12, 16), (13, 17), (14, 18), (15, 19),
        (22, 24), (23, 25)]
    for a, b in flip_indices:
                y1[a], y1[b] = (y1[b], y1[a])
    #print(y1)
    return x1,y1

# %%
np.random.seed(1)
def shuffle_run_batch_data_aug(Xnp, ynp, Xdev, ydev, batch_size, epoch):
    """function takes training and dev data, shuffle the train data and run TF optimizer in batches for a given epoch
    It returns the average loss for training and eval of all the batches ran in the epoch.
    It expects to run with tensorboard."""

     #Data augmentation with horizontal flips
    Xflip = np.zeros(Xnp.shape) #Array to store the horizontally flipped faces
    yflip = np.zeros(ynp.shape)

    for i in range(Xnp.shape[0]):
        Xflip[i],yflip[i] = flip_horizontal(Xnp[i],ynp[i])
        
    shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xnp, ynp = Xnp[shuffle], ynp[shuffle]
    shuffle1 = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xflip,yflip = Xflip[shuffle1],yflip[shuffle1]

    # initialize variables to hold loss information for each epoch
    #loss_train = 0
    #loss_dev = 0
    batches = Xnp.shape[0]//batch_size


    for i in range(int(batches)): #run through most of the data points in each epoch
        X_batch = np.vstack((Xnp[i*batch_size//2:(i+1)*batch_size//2,:],Xflip[i*batch_size//2:(i+1)*batch_size//2,:]))
        y_batch = np.vstack((ynp[i*batch_size//2:(i+1)*batch_size//2],yflip[i*batch_size//2:(i+1)*batch_size//2]))
        if tensorboard_log:
            if i % 10 == 0:
                train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, training: True})
                dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, training: False})
                step = epoch * batches + i
                train_writer.add_summary(train_summary_str, step)
                dev_writer.add_summary(dev_summary_str, step)

        sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})

    

        loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
        loss_dev = loss.eval(feed_dict = {X:Xdev,y:ydev, training:False})

    
    return loss_train, loss_dev

# %%
#CNN with data augmentation(horizontal flip)
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch_data_aug (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

#Plot a graph of the train vs test loss data:
    

plot_loss (train_loss_data, dev_loss_data)


#train_writer.close()
#dev_writer.close()
plot_pred (x_test, y_pred)
# Out:
# 0 Train loss:0.2690 Dev loss:0.2697 ratio train/dev:1.00
# 10 Train loss:0.0699 Dev loss:0.0704 ratio train/dev:0.99
# 20 Train loss:0.0690 Dev loss:0.0678 ratio train/dev:1.02
# 30 Train loss:0.0648 Dev loss:0.0666 ratio train/dev:0.97
# 40 Train loss:0.0655 Dev loss:0.0659 ratio train/dev:0.99
# 50 Train loss:0.0674 Dev loss:0.0656 ratio train/dev:1.03
# 60 Train loss:0.0691 Dev loss:0.0654 ratio train/dev:1.06
# 70 Train loss:0.0661 Dev loss:0.0653 ratio train/dev:1.01
# 80 Train loss:0.0681 Dev loss:0.0651 ratio train/dev:1.05
# 90 Train loss:0.0650 Dev loss:0.0649 ratio train/dev:1.00
# 100 Train loss:0.0670 Dev loss:0.0647 ratio train/dev:1.04
# 110 Train loss:0.0618 Dev loss:0.0646 ratio train/dev:0.96
# 120 Train loss:0.0638 Dev loss:0.0644 ratio train/dev:0.99
# 130 Train loss:0.0685 Dev loss:0.0642 ratio train/dev:1.07
# 140 Train loss:0.0611 Dev loss:0.0641 ratio train/dev:0.95
# 150 Train loss:0.0672 Dev loss:0.0639 ratio train/dev:1.05
# 160 Train loss:0.0687 Dev loss:0.0637 ratio train/dev:1.08
# 170 Train loss:0.0674 Dev loss:0.0635 ratio train/dev:1.06
# 180 Train loss:0.0651 Dev loss:0.0634 ratio train/dev:1.03
# 190 Train loss:0.0638 Dev loss:0.0632 ratio train/dev:1.01
# 200 Train loss:0.0643 Dev loss:0.0630 ratio train/dev:1.02
# 210 Train loss:0.0600 Dev loss:0.0628 ratio train/dev:0.96
# 220 Train loss:0.0650 Dev loss:0.0626 ratio train/dev:1.04
# 230 Train loss:0.0599 Dev loss:0.0624 ratio train/dev:0.96
# 240 Train loss:0.0595 Dev loss:0.0622 ratio train/dev:0.96
# 250 Train loss:0.0662 Dev loss:0.0620 ratio train/dev:1.07
# 260 Train loss:0.0694 Dev loss:0.0618 ratio train/dev:1.12
# 270 Train loss:0.0633 Dev loss:0.0615 ratio train/dev:1.03
# 280 Train loss:0.0597 Dev loss:0.0613 ratio train/dev:0.97
# 290 Train loss:0.0599 Dev loss:0.0611 ratio train/dev:0.98
# 300 Train loss:0.0586 Dev loss:0.0609 ratio train/dev:0.96
# 310 Train loss:0.0595 Dev loss:0.0607 ratio train/dev:0.98
# 320 Train loss:0.0543 Dev loss:0.0605 ratio train/dev:0.90
# 330 Train loss:0.0599 Dev loss:0.0602 ratio train/dev:0.99
# 340 Train loss:0.0617 Dev loss:0.0601 ratio train/dev:1.03
# 350 Train loss:0.0579 Dev loss:0.0597 ratio train/dev:0.97
# 360 Train loss:0.0583 Dev loss:0.0595 ratio train/dev:0.98
# 370 Train loss:0.0565 Dev loss:0.0592 ratio train/dev:0.95
# 380 Train loss:0.0543 Dev loss:0.0591 ratio train/dev:0.92
# 390 Train loss:0.0579 Dev loss:0.0588 ratio train/dev:0.98
# 400 Train loss:0.0565 Dev loss:0.0585 ratio train/dev:0.97
# 410 Train loss:0.0598 Dev loss:0.0583 ratio train/dev:1.03
# 420 Train loss:0.0588 Dev loss:0.0581 ratio train/dev:1.01
# 430 Train loss:0.0583 Dev loss:0.0577 ratio train/dev:1.01
# 440 Train loss:0.0565 Dev loss:0.0576 ratio train/dev:0.98
# 450 Train loss:0.0510 Dev loss:0.0573 ratio train/dev:0.89
# 460 Train loss:0.0578 Dev loss:0.0571 ratio train/dev:1.01
# 470 Train loss:0.0503 Dev loss:0.0569 ratio train/dev:0.88
# 480 Train loss:0.0588 Dev loss:0.0566 ratio train/dev:1.04
# 490 Train loss:0.0597 Dev loss:0.0564 ratio train/dev:1.06
# 500 Train loss:0.0554 Dev loss:0.0562 ratio train/dev:0.99
# 510 Train loss:0.0546 Dev loss:0.0560 ratio train/dev:0.97
# 520 Train loss:0.0559 Dev loss:0.0557 ratio train/dev:1.00
# 530 Train loss:0.0522 Dev loss:0.0555 ratio train/dev:0.94
# 540 Train loss:0.0575 Dev loss:0.0554 ratio train/dev:1.04
# 550 Train loss:0.0549 Dev loss:0.0552 ratio train/dev:0.99
# 560 Train loss:0.0544 Dev loss:0.0550 ratio train/dev:0.99
# 570 Train loss:0.0558 Dev loss:0.0549 ratio train/dev:1.02
# 580 Train loss:0.0536 Dev loss:0.0547 ratio train/dev:0.98
# 590 Train loss:0.0542 Dev loss:0.0546 ratio train/dev:0.99
# 600 Train loss:0.0556 Dev loss:0.0543 ratio train/dev:1.02
# 610 Train loss:0.0534 Dev loss:0.0543 ratio train/dev:0.98
# 620 Train loss:0.0516 Dev loss:0.0541 ratio train/dev:0.95
# 630 Train loss:0.0529 Dev loss:0.0540 ratio train/dev:0.98
# 640 Train loss:0.0495 Dev loss:0.0538 ratio train/dev:0.92
# 650 Train loss:0.0510 Dev loss:0.0537 ratio train/dev:0.95
# 660 Train loss:0.0525 Dev loss:0.0536 ratio train/dev:0.98
# 670 Train loss:0.0522 Dev loss:0.0535 ratio train/dev:0.98
# 680 Train loss:0.0514 Dev loss:0.0534 ratio train/dev:0.96
# 690 Train loss:0.0502 Dev loss:0.0533 ratio train/dev:0.94
# 700 Train loss:0.0526 Dev loss:0.0531 ratio train/dev:0.99
# 710 Train loss:0.0491 Dev loss:0.0531 ratio train/dev:0.92
# 720 Train loss:0.0506 Dev loss:0.0530 ratio train/dev:0.95
# 730 Train loss:0.0532 Dev loss:0.0529 ratio train/dev:1.01
# 740 Train loss:0.0517 Dev loss:0.0529 ratio train/dev:0.98
# 750 Train loss:0.0493 Dev loss:0.0528 ratio train/dev:0.93
# 760 Train loss:0.0485 Dev loss:0.0527 ratio train/dev:0.92
# 770 Train loss:0.0482 Dev loss:0.0526 ratio train/dev:0.92
# 780 Train loss:0.0539 Dev loss:0.0525 ratio train/dev:1.03
# 790 Train loss:0.0495 Dev loss:0.0525 ratio train/dev:0.94
# 800 Train loss:0.0522 Dev loss:0.0524 ratio train/dev:1.00
# 810 Train loss:0.0502 Dev loss:0.0524 ratio train/dev:0.96
# 820 Train loss:0.0465 Dev loss:0.0523 ratio train/dev:0.89
# 830 Train loss:0.0495 Dev loss:0.0523 ratio train/dev:0.95
# 840 Train loss:0.0464 Dev loss:0.0522 ratio train/dev:0.89
# 850 Train loss:0.0493 Dev loss:0.0522 ratio train/dev:0.94
# 860 Train loss:0.0456 Dev loss:0.0521 ratio train/dev:0.87
# 870 Train loss:0.0500 Dev loss:0.0520 ratio train/dev:0.96
# 880 Train loss:0.0447 Dev loss:0.0519 ratio train/dev:0.86
# 890 Train loss:0.0506 Dev loss:0.0519 ratio train/dev:0.97
# 900 Train loss:0.0497 Dev loss:0.0518 ratio train/dev:0.96
# 910 Train loss:0.0472 Dev loss:0.0518 ratio train/dev:0.91
# 920 Train loss:0.0520 Dev loss:0.0518 ratio train/dev:1.00
# 930 Train loss:0.0481 Dev loss:0.0517 ratio train/dev:0.93
# 940 Train loss:0.0512 Dev loss:0.0516 ratio train/dev:0.99
# 950 Train loss:0.0483 Dev loss:0.0516 ratio train/dev:0.94
# 960 Train loss:0.0453 Dev loss:0.0515 ratio train/dev:0.88
# 970 Train loss:0.0453 Dev loss:0.0516 ratio train/dev:0.88
# 980 Train loss:0.0502 Dev loss:0.0515 ratio train/dev:0.97
# 990 Train loss:0.0472 Dev loss:0.0515 ratio train/dev:0.92
# 1000 Train loss:0.0506 Dev loss:0.0514 ratio train/dev:0.98
# 1010 Train loss:0.0472 Dev loss:0.0516 ratio train/dev:0.92
# 1020 Train loss:0.0451 Dev loss:0.0515 ratio train/dev:0.87
# 1030 Train loss:0.0503 Dev loss:0.0513 ratio train/dev:0.98
# 1040 Train loss:0.0488 Dev loss:0.0513 ratio train/dev:0.95
# 1050 Train loss:0.0440 Dev loss:0.0513 ratio train/dev:0.86
# 1060 Train loss:0.0473 Dev loss:0.0512 ratio train/dev:0.92
# 1070 Train loss:0.0463 Dev loss:0.0512 ratio train/dev:0.90
# 1080 Train loss:0.0494 Dev loss:0.0511 ratio train/dev:0.97
# 1090 Train loss:0.0449 Dev loss:0.0511 ratio train/dev:0.88
# 1100 Train loss:0.0448 Dev loss:0.0511 ratio train/dev:0.88
# 1110 Train loss:0.0434 Dev loss:0.0511 ratio train/dev:0.85
# 1120 Train loss:0.0435 Dev loss:0.0511 ratio train/dev:0.85
# 1130 Train loss:0.0491 Dev loss:0.0510 ratio train/dev:0.96
# 1140 Train loss:0.0401 Dev loss:0.0510 ratio train/dev:0.79
# 1150 Train loss:0.0467 Dev loss:0.0509 ratio train/dev:0.92
# 1160 Train loss:0.0415 Dev loss:0.0509 ratio train/dev:0.81
# 1170 Train loss:0.0466 Dev loss:0.0509 ratio train/dev:0.92
# 1180 Train loss:0.0515 Dev loss:0.0508 ratio train/dev:1.01
# 1190 Train loss:0.0469 Dev loss:0.0509 ratio train/dev:0.92
# 1200 Train loss:0.0503 Dev loss:0.0509 ratio train/dev:0.99
# 1210 Train loss:0.0443 Dev loss:0.0508 ratio train/dev:0.87
# 1220 Train loss:0.0457 Dev loss:0.0508 ratio train/dev:0.90
# 1230 Train loss:0.0439 Dev loss:0.0508 ratio train/dev:0.86
# 1240 Train loss:0.0468 Dev loss:0.0508 ratio train/dev:0.92
# 1250 Train loss:0.0439 Dev loss:0.0507 ratio train/dev:0.87
# 1260 Train loss:0.0455 Dev loss:0.0507 ratio train/dev:0.90
# 1270 Train loss:0.0500 Dev loss:0.0506 ratio train/dev:0.99
# 1280 Train loss:0.0460 Dev loss:0.0507 ratio train/dev:0.91
# 1290 Train loss:0.0456 Dev loss:0.0506 ratio train/dev:0.90
# 1300 Train loss:0.0466 Dev loss:0.0506 ratio train/dev:0.92
# 1310 Train loss:0.0463 Dev loss:0.0506 ratio train/dev:0.92
# 1320 Train loss:0.0512 Dev loss:0.0505 ratio train/dev:1.01
# 1330 Train loss:0.0453 Dev loss:0.0505 ratio train/dev:0.90
# 1340 Train loss:0.0460 Dev loss:0.0505 ratio train/dev:0.91
# 1350 Train loss:0.0484 Dev loss:0.0505 ratio train/dev:0.96
# 1360 Train loss:0.0433 Dev loss:0.0504 ratio train/dev:0.86
# 1370 Train loss:0.0462 Dev loss:0.0505 ratio train/dev:0.92
# 1380 Train loss:0.0516 Dev loss:0.0504 ratio train/dev:1.02
# 1390 Train loss:0.0477 Dev loss:0.0505 ratio train/dev:0.95
# 1400 Train loss:0.0483 Dev loss:0.0504 ratio train/dev:0.96
# 1410 Train loss:0.0436 Dev loss:0.0503 ratio train/dev:0.87
# 1420 Train loss:0.0477 Dev loss:0.0505 ratio train/dev:0.95
# 1430 Train loss:0.0436 Dev loss:0.0504 ratio train/dev:0.86
# 1440 Train loss:0.0461 Dev loss:0.0503 ratio train/dev:0.92
# 1450 Train loss:0.0469 Dev loss:0.0503 ratio train/dev:0.93
# 1460 Train loss:0.0503 Dev loss:0.0503 ratio train/dev:1.00
# 1470 Train loss:0.0442 Dev loss:0.0502 ratio train/dev:0.88
# 1480 Train loss:0.0466 Dev loss:0.0503 ratio train/dev:0.93
# 1490 Train loss:0.0450 Dev loss:0.0502 ratio train/dev:0.90
# 1500 Train loss:0.0462 Dev loss:0.0502 ratio train/dev:0.92
# 1510 Train loss:0.0483 Dev loss:0.0502 ratio train/dev:0.96
# 1520 Train loss:0.0451 Dev loss:0.0502 ratio train/dev:0.90
# 1530 Train loss:0.0429 Dev loss:0.0502 ratio train/dev:0.85
# 1540 Train loss:0.0450 Dev loss:0.0502 ratio train/dev:0.90
# 1550 Train loss:0.0415 Dev loss:0.0502 ratio train/dev:0.83
# 1560 Train loss:0.0474 Dev loss:0.0502 ratio train/dev:0.95
# 1570 Train loss:0.0446 Dev loss:0.0501 ratio train/dev:0.89
# 1580 Train loss:0.0455 Dev loss:0.0501 ratio train/dev:0.91
# 1590 Train loss:0.0509 Dev loss:0.0501 ratio train/dev:1.02
# 1600 Train loss:0.0447 Dev loss:0.0502 ratio train/dev:0.89
# 1610 Train loss:0.0505 Dev loss:0.0501 ratio train/dev:1.01
# 1620 Train loss:0.0505 Dev loss:0.0500 ratio train/dev:1.01
# 1630 Train loss:0.0463 Dev loss:0.0500 ratio train/dev:0.93
# 1640 Train loss:0.0452 Dev loss:0.0501 ratio train/dev:0.90
# 1650 Train loss:0.0449 Dev loss:0.0500 ratio train/dev:0.90
# 1660 Train loss:0.0477 Dev loss:0.0500 ratio train/dev:0.95
# 1670 Train loss:0.0473 Dev loss:0.0499 ratio train/dev:0.95
# 1680 Train loss:0.0479 Dev loss:0.0500 ratio train/dev:0.96
# 1690 Train loss:0.0459 Dev loss:0.0500 ratio train/dev:0.92
# 1700 Train loss:0.0516 Dev loss:0.0499 ratio train/dev:1.03
# 1710 Train loss:0.0488 Dev loss:0.0499 ratio train/dev:0.98
# 1720 Train loss:0.0444 Dev loss:0.0499 ratio train/dev:0.89
# 1730 Train loss:0.0463 Dev loss:0.0499 ratio train/dev:0.93
# 1740 Train loss:0.0443 Dev loss:0.0499 ratio train/dev:0.89
# 1750 Train loss:0.0458 Dev loss:0.0498 ratio train/dev:0.92
# 1760 Train loss:0.0493 Dev loss:0.0498 ratio train/dev:0.99
# 1770 Train loss:0.0413 Dev loss:0.0498 ratio train/dev:0.83
# 1780 Train loss:0.0429 Dev loss:0.0499 ratio train/dev:0.86
# 1790 Train loss:0.0439 Dev loss:0.0497 ratio train/dev:0.88
# 1800 Train loss:0.0455 Dev loss:0.0498 ratio train/dev:0.91
# 1810 Train loss:0.0469 Dev loss:0.0498 ratio train/dev:0.94
# 1820 Train loss:0.0413 Dev loss:0.0497 ratio train/dev:0.83
# 1830 Train loss:0.0458 Dev loss:0.0497 ratio train/dev:0.92
# 1840 Train loss:0.0457 Dev loss:0.0498 ratio train/dev:0.92
# 1850 Train loss:0.0444 Dev loss:0.0497 ratio train/dev:0.89
# 1860 Train loss:0.0460 Dev loss:0.0498 ratio train/dev:0.92
# 1870 Train loss:0.0430 Dev loss:0.0497 ratio train/dev:0.87
# 1880 Train loss:0.0485 Dev loss:0.0497 ratio train/dev:0.98
# 1890 Train loss:0.0478 Dev loss:0.0496 ratio train/dev:0.96
# 1900 Train loss:0.0453 Dev loss:0.0496 ratio train/dev:0.91
# 1910 Train loss:0.0458 Dev loss:0.0496 ratio train/dev:0.92
# 1920 Train loss:0.0412 Dev loss:0.0497 ratio train/dev:0.83
# 1930 Train loss:0.0422 Dev loss:0.0496 ratio train/dev:0.85
# 1940 Train loss:0.0456 Dev loss:0.0497 ratio train/dev:0.92
# 1950 Train loss:0.0446 Dev loss:0.0497 ratio train/dev:0.90
# 1960 Train loss:0.0428 Dev loss:0.0495 ratio train/dev:0.86
# 1970 Train loss:0.0485 Dev loss:0.0496 ratio train/dev:0.98
# 1980 Train loss:0.0471 Dev loss:0.0495 ratio train/dev:0.95
# 1990 Train loss:0.0415 Dev loss:0.0495 ratio train/dev:0.84
# 2000 Train loss:0.0438 Dev loss:0.0496 ratio train/dev:0.88
# 2010 Train loss:0.0435 Dev loss:0.0495 ratio train/dev:0.88
# 2020 Train loss:0.0483 Dev loss:0.0496 ratio train/dev:0.97
# 2030 Train loss:0.0406 Dev loss:0.0496 ratio train/dev:0.82
# 2040 Train loss:0.0421 Dev loss:0.0495 ratio train/dev:0.85
# 2050 Train loss:0.0436 Dev loss:0.0495 ratio train/dev:0.88
# 2060 Train loss:0.0439 Dev loss:0.0495 ratio train/dev:0.89
# 2070 Train loss:0.0442 Dev loss:0.0495 ratio train/dev:0.89
# 2080 Train loss:0.0433 Dev loss:0.0494 ratio train/dev:0.88
# 2090 Train loss:0.0460 Dev loss:0.0495 ratio train/dev:0.93
# 2100 Train loss:0.0450 Dev loss:0.0495 ratio train/dev:0.91
# 2110 Train loss:0.0444 Dev loss:0.0494 ratio train/dev:0.90
# 2120 Train loss:0.0414 Dev loss:0.0494 ratio train/dev:0.84
# 2130 Train loss:0.0418 Dev loss:0.0494 ratio train/dev:0.85
# 2140 Train loss:0.0465 Dev loss:0.0495 ratio train/dev:0.94
# 2150 Train loss:0.0444 Dev loss:0.0494 ratio train/dev:0.90
# 2160 Train loss:0.0421 Dev loss:0.0494 ratio train/dev:0.85
# 2170 Train loss:0.0466 Dev loss:0.0494 ratio train/dev:0.94
# 2180 Train loss:0.0432 Dev loss:0.0493 ratio train/dev:0.88
# 2190 Train loss:0.0451 Dev loss:0.0494 ratio train/dev:0.91
# 2200 Train loss:0.0455 Dev loss:0.0493 ratio train/dev:0.92
# 2210 Train loss:0.0462 Dev loss:0.0493 ratio train/dev:0.94
# 2220 Train loss:0.0458 Dev loss:0.0493 ratio train/dev:0.93
# 2230 Train loss:0.0470 Dev loss:0.0493 ratio train/dev:0.95
# 2240 Train loss:0.0469 Dev loss:0.0492 ratio train/dev:0.95
# 2250 Train loss:0.0430 Dev loss:0.0493 ratio train/dev:0.87
# 2260 Train loss:0.0427 Dev loss:0.0493 ratio train/dev:0.87
# 2270 Train loss:0.0431 Dev loss:0.0493 ratio train/dev:0.87
# 2280 Train loss:0.0418 Dev loss:0.0494 ratio train/dev:0.85
# 2290 Train loss:0.0458 Dev loss:0.0493 ratio train/dev:0.93
# 2300 Train loss:0.0466 Dev loss:0.0493 ratio train/dev:0.95
# 2310 Train loss:0.0436 Dev loss:0.0492 ratio train/dev:0.89
# 2320 Train loss:0.0429 Dev loss:0.0492 ratio train/dev:0.87
# 2330 Train loss:0.0404 Dev loss:0.0492 ratio train/dev:0.82
# 2340 Train loss:0.0461 Dev loss:0.0492 ratio train/dev:0.94
# 2350 Train loss:0.0486 Dev loss:0.0492 ratio train/dev:0.99
# 2360 Train loss:0.0416 Dev loss:0.0492 ratio train/dev:0.85
# 2370 Train loss:0.0449 Dev loss:0.0492 ratio train/dev:0.91
# 2380 Train loss:0.0474 Dev loss:0.0492 ratio train/dev:0.96
# 2390 Train loss:0.0393 Dev loss:0.0491 ratio train/dev:0.80
# 2400 Train loss:0.0388 Dev loss:0.0492 ratio train/dev:0.79
# 2410 Train loss:0.0438 Dev loss:0.0491 ratio train/dev:0.89
# 2420 Train loss:0.0414 Dev loss:0.0491 ratio train/dev:0.84
# 2430 Train loss:0.0442 Dev loss:0.0491 ratio train/dev:0.90
# 2440 Train loss:0.0469 Dev loss:0.0492 ratio train/dev:0.95
# 2450 Train loss:0.0444 Dev loss:0.0492 ratio train/dev:0.90
# 2460 Train loss:0.0449 Dev loss:0.0491 ratio train/dev:0.91
# 2470 Train loss:0.0465 Dev loss:0.0491 ratio train/dev:0.95
# 2480 Train loss:0.0478 Dev loss:0.0491 ratio train/dev:0.97
# 2490 Train loss:0.0426 Dev loss:0.0490 ratio train/dev:0.87
# 2500 Train loss:0.0472 Dev loss:0.0491 ratio train/dev:0.96
# Total time taken: 7422.682018041611

# %%
#CNN with data augmentation and increasing momentum
#CNN with data augmentation(horizontal flip)
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    current_epoch = tf.
    m_min = 0.9
    m_max = 0.99
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch_data_aug (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%10 == 0:
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

#Plot a graph of the train vs test loss data:
    

plot_loss (train_loss_data, dev_loss_data)


#train_writer.close()
#dev_writer.close()
plot_pred (x_test, y_pred)
