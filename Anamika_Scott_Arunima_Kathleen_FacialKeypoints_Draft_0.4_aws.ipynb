# %% [markdown]
# # Facial Keypoints Detection
# ## W207 Final Project December 2017
# ### Arunima Kayath, Kathleen Wang, Anamika Sinha & Scott A. George

# %% [markdown]
# In this project, we attempted to optimize a neural network for facial keypoints detection. This notebook has three types of networks we tried for this purpose, and their variations.
# Net 1 - Simple network with 1 or 2 hidden layers.
# Net 2 - Convolutional Neural network with 3 convolution layers, and 2 hidden layers -one network for all 30 facial keypoints. Variations we tried with net 2 were :
#     a. Data Augmentation (flipping the images horizontally and vertically)
#     b. Implementing momentum increase and learning rate decay(4 different options were tried though only one is shown in the notebook)
#     c. Using a Leaky Relu as the activation function instead of Relu
#     d. Different combinations of filter sizes for each of the convolution layers.
# Net 3 - CNN as above, but 6 different networks for 6 subsets of the 30 keypoints. This also allows us to leverage the extra data available for some of the keypoints.
#
# In addition to this, we also tried different data pre-processing. In the time we had, we were only able to try the effect of pre-processing with net 1.

# %%
import os

import numpy as np
from pandas.io.parsers import read_csv
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from decimal import *
import tensorflow as tf
import time
from datetime import datetime
import matplotlib.pyplot as plt
from tensorflow.contrib.layers import fully_connected

# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# %% [markdown]
# ## Loading Data

# %%
scott = False
aws = False
tensorboard_log = False

if scott:
    FROOT = ''
    FTRAIN = '/data/facial/training.csv'
    FTEST = '/data/facial/test.csv'
elif aws:
    FROOT = ''
    FTRAIN = '/data/training.csv'
    FTEST = '/data/test.csv'
else:
    FROOT = os.getcwd() # Path to your project folder
    FTRAIN = '~/notebooks/training.csv'
    FTEST = '~/notebooks/test.csv'

if tensorboard_log:
    root_logdir = FROOT + "tf_logs"
    
os.makedirs( FROOT + "/models/", exist_ok=True)

# %% [markdown]
# Helper function to load data

# %%
np.random.seed(0)
def load(test = False, cols = None):
    '''Loads data from FTEST if *test* is true, otherwise from FTRAIN.' 
    Pass a list of *cols* if you are only interested in a
    subset of the target columns'''
    
    fname = FTEST if test else FTRAIN
    df = read_csv(os.path.expanduser(fname)) #load pandas dataframe

    
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im,sep=' ')) 
    #image column has pixel values separated by space; convert the values to numpy arrays
    
    if cols: #get a subset of columns
        df = df[list(cols) + ['Image']]
        
    print('Count of observations in training data by features')
    print(df.count()) #prints number of values for each column
    df = df.dropna() #drop all rows that have missing values in them
    
    X = np.vstack(df['Image'].values)/255
    X = X.astype(np.float32)
    
    if not test:
        y  = df[df.columns[:-1]].values
        y = (y-48)/48
        shuffle = np.random.permutation(np.arange(X.shape[0]))
        X, y = X[shuffle], y[shuffle]
        y = y.astype(np.float32)
    else:
        y = None
    print('done')
        
    return X,y

# %%
np.random.seed(0)
X, y = load()

print('Total training data')
print("X.shape = = {}; X.min == {:.3f}; X.max == {:.3f}".format(X.shape, X.min(),X.max()))
print("y.shape = = {}; y.min == {:.3f}; y.max == {:.3f}".format(y.shape, y.min(),y.max()))
# Out:
# Count of observations in training data by features
# left_eye_center_x            7039
# left_eye_center_y            7039
# right_eye_center_x           7036
# right_eye_center_y           7036
# left_eye_inner_corner_x      2271
# left_eye_inner_corner_y      2271
# left_eye_outer_corner_x      2267
# left_eye_outer_corner_y      2267
# right_eye_inner_corner_x     2268
# right_eye_inner_corner_y     2268
# right_eye_outer_corner_x     2268
# right_eye_outer_corner_y     2268
# left_eyebrow_inner_end_x     2270
# left_eyebrow_inner_end_y     2270
# left_eyebrow_outer_end_x     2225
# left_eyebrow_outer_end_y     2225
# right_eyebrow_inner_end_x    2270
# right_eyebrow_inner_end_y    2270
# right_eyebrow_outer_end_x    2236
# right_eyebrow_outer_end_y    2236
# nose_tip_x                   7049
# nose_tip_y                   7049
# mouth_left_corner_x          2269
# mouth_left_corner_y          2269
# mouth_right_corner_x         2270
# mouth_right_corner_y         2270
# mouth_center_top_lip_x       2275
# mouth_center_top_lip_y       2275
# mouth_center_bottom_lip_x    7016
# mouth_center_bottom_lip_y    7016
# Image                        7049
# dtype: int64
# done
# Total training data
# X.shape = = (2140, 9216); X.min == 0.000; X.max == 1.000
# y.shape = = (2140, 30); y.min == -0.920; y.max == 0.996

# %% [markdown]
# Save 20% data to be used as dev data, carve out dev data and load test data

# %%
np.random.seed(0)
dev_size = 0.2
#setting aside a 20% sample for validation

x_train, x_dev, y_train, y_dev = train_test_split(X, y, test_size = dev_size)

x_test, _ = load(test=True)

print('Training data split into train and dev data')
print("x_train.shape = = {}; x_train.min == {:.3f}; x_train.max == {:.3f}".format(x_train.shape, x_train.min(),x_train.max()))
print("y_train.shape = = {}; y_train.min == {:.3f}; y_train.max == {:.3f}".format(y_train.shape, y_train.min(),y_train.max()))
print("x_dev.shape = = {}; x_dev.min == {:.3f}; x_dev.max == {:.3f}".format(x_dev.shape, x_dev.min(),x_dev.max()))
print("y_dev.shape = = {}; y_dev.min == {:.3f}; y_dev.max == {:.3f}".format(y_dev.shape, y_dev.min(),y_dev.max()))
# Out:
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1712, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1712, 30); y_train.min == -0.916; y_train.max == 0.996
# x_dev.shape = = (428, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (428, 30); y_dev.min == -0.920; y_dev.max == 0.980

# %% [markdown]
# ## Helper functions
#
# ### 1. plot_sample: plots sample pictures

# %%
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2] * 48 + 48, y[1::2] * 48 + 48, marker='x', s=10)

# %%
np.random.seed(1)
def shuffle_run_batch(Xnp, ynp, Xdev, ydev, batch_size, epoch):
    """function takes training and dev data, shuffle the train data and run TF optimizer in batches for a given epoch
    It returns the average loss for training and eval of all the batches ran in the epoch.
    It expects to run with tensorboard."""

    shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xnp, ynp = Xnp[shuffle], ynp[shuffle]

    # initialize variables to hold loss information for each epoch
    #loss_train = 0
    #loss_dev = 0
    batches = Xnp.shape[0]//batch_size


    for i in range(int(batches)): #run through most of the data points in each epoch
        X_batch,y_batch = Xnp[i*batch_size:(i+1)*batch_size,:], ynp[i*batch_size:(i+1)*batch_size]
        if tensorboard_log:
            if i % 10 == 0:
                train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, training: True})
                dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, training: False})
                step = epoch * batches + i
                train_writer.add_summary(train_summary_str, step)
                dev_writer.add_summary(dev_summary_str, step)

        sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})

    

        loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
        loss_dev = loss.eval(feed_dict = {X:Xdev,y:ydev, training:False})

    
    return loss_train, loss_dev

# %%
# *might* need to double check correctly formatted input
def plot_loss (train_loss_data, dev_loss_data):
    
    plt.plot(train_loss_data[:,1], label="train")
    plt.plot(dev_loss_data[:,1], linewidth=3, label="valid")
    plt.grid()
    plt.legend()
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.yscale("log")
    plt.show()

# %%
# *might* need to double check correctly formatted input
def plot_pred (x_dev, y_pred):
    
    fig = plt.figure(figsize=(16, 16))
    fig.subplots_adjust(
        left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(4):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        plot_sample(x_dev[i], y_pred[i], ax)
    plt.show

# %% [markdown]
# ## First model: 1 hidden layer simple neural net

# %% [markdown]
# Define parameters

# %%
learning_rate = 0.01
momentum = 0.9

n_epochs = 1201 #Although net 1 reaches steady state sooner, standarsized to this many epochs for all nets for comparison
batch_size = 50


n_inputs = X.shape[1] 
n_hidden1 = 100
n_outputs = 30

# %% [markdown]
# Construct the tensorflow graph for the first network

# %%
#Net 1 - network with 1 hidden layer.
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)


with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    pred_keypoints = fully_connected(hidden1,n_outputs,activation_fn = None,scope = 'outputs')
    
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()


train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))

time_start = time.time()
time_1000_start = time.time()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        
        # note this is includes the for-loop for batching
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)
                    
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            
        if epoch%50 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                  'Dev loss:%0.3f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
            
    time_end = time.time()  
    y_pred = sess.run(pred_keypoints,feed_dict = {X: x_test})
    print('Total time taken:',time_end-time_start)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
    
#Plotting loss, and sample predictions
plt.figure()
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred) #updated this to be x_test instead of x_dev, since the predictions are being made on x_test

#Saving loss and test predictions
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net1_baseline.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net1_baseline_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')
# Out:
# 0 Train loss:0.128 Dev loss:0.129 ratio train/dev:0.99
# 10 Train loss:0.093 Dev loss:0.091 ratio train/dev:1.01
# 20 Train loss:0.074 Dev loss:0.084 ratio train/dev:0.88
# 30 Train loss:0.079 Dev loss:0.080 ratio train/dev:0.99
# 40 Train loss:0.069 Dev loss:0.079 ratio train/dev:0.87
# 50 Train loss:0.064 Dev loss:0.070 ratio train/dev:0.91
# Total time taken: 10.033929347991943

# %% [markdown]
# # Fully Connected Network(Net 1) with 2 hidden layers

# %%
#Net 1 with 2 hidden layers
n_hidden2 = 60
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)
    
with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    hidden2 = fully_connected(hidden1,n_hidden2,scope = 'hidden2')
    pred_keypoints = fully_connected(hidden2,n_outputs,activation_fn = None,scope = 'outputs')
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()


train_loss_data = np.zeros((n_epochs,2))
dev_loss_data = np.zeros((n_epochs,2))

time_start = time.time()
time_1000_start = time.time()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        
        # note this is includes the for-loop for batching
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)
                    
        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            
        if epoch%50 == 0:
            print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                  'Dev loss:%0.3f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
            
            
    time_end = time.time()  
    
    y_pred = sess.run(pred_keypoints,feed_dict = {X: x_test})
   
    print('Total time taken:',time_end-time_start)
    
if tensorboard_log:
    train_writer.close()
    dev_writer.close()
    
plt.figure()
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

#Saving loss and test predictions
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net1_2hidden_layers.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net1__2hidden_layers_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')
# Out:
# 0 Train loss:0.118 Dev loss:0.121 ratio train/dev:0.97
# 50 Train loss:0.059 Dev loss:0.065 ratio train/dev:0.90
# Total time taken: 10.306360244750977

# %% [markdown]
# Helper function to pre-process the data in different ways. Three types of pre-processing were tried:
#     a. Max_range : Stretches each image to the maximum pixel range eg is the lowest and highest pixel in an image is 0.2,0.7, then these will be stretched by dividing all the pixels by (0.7-0.2) = 0.5
#     b. Gaussian_blur : Gaussian blur of 3X3
#     c. Mean_center : Subtract the mean image from all the images.

# %%
#Function to pre-process the data in different ways
def preprocess_image(x,type):
    x1 = np.zeros(x.shape)
    mean_x = np.mean(x,axis=1)
    max_x = np.max(x,axis=1)
    min_x = np.min(x,axis=1)
    std_x = np.std(x,axis=1)
    delta_x_arr = max_x - min_x
    
    if type == 'None': #No pre-processing baseline
        x1 = x
    
    if type == 'Max_range': #Divide all x's in a row by the max in the range
        for i in range(x.shape[0]):
            delta_x = max_x[i] - min_x[i]
            x1[i,:] = (x[i,:])/delta_x
        

    if type == 'Gaussian_blur': #3X3 gaussian blur of the image
        #print(len(x))
        for k in range(len(x)):
            tmp_array = x[k].reshape(96,96)
            tmp_array_copy = tmp_array
            for i in range(tmp_array.shape[0]-1):
                for j in range(tmp_array.shape[1] -1):
                    if (i > 0 and j > 0):
                        sub_arr = tmp_array[i-1:i+1,j-1:j+1]
                        sum8 = (1/4)*tmp_array[i,j]+(1/8)*(tmp_array[i-1,j]+tmp_array[i+1,j]+tmp_array[i,j-1]+tmp_array[i,j+1])\
                        + (1/16)*(tmp_array[i-1,j-1]+tmp_array[i-1,j+1]+tmp_array[i+1,j-1]+tmp_array[i+1,j+1])
                        tmp_array_copy[i,j] = sum8
            tmp_array = tmp_array_copy.reshape(9216)
            x1[k] = tmp_array
            
    if type == 'Mean_center': #Take out the mean image from all images (effectively taking out the mean of each feature)
        feature_mean = np.mean(x,axis=0)
        #print('feature_mean_shape',feature_mean.shape)
        for i in range(x.shape[1]):
            x1[:,i] = x[:,i]-feature_mean[i]
   
    return x1

# %% [markdown]
# Neural net with 1 hidden layer and trying all of the above 3 variations of preprocessed input

# %%
#net 1 with 1 hidden layer and preprocessed input
np.random.seed(1)
tf.reset_default_graph()

X = tf.placeholder(tf.float32,shape = (None,n_inputs),name = 'X')
y = tf.placeholder(tf.float32,shape = (None,n_outputs),name = 'y')
training = tf.placeholder(tf.bool)

if tensorboard_log:
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    logdir = "{}/run-{}/".format(root_logdir, now)


with tf.name_scope('dnn'):
    hidden1 = fully_connected(X,n_hidden1,scope = 'hidden1')
    pred_keypoints = fully_connected(hidden1,n_outputs,activation_fn = None,scope = 'outputs')
    
    
with tf.name_scope('loss'):
    loss = tf.reduce_mean(np.square(pred_keypoints - y))   
    sqrt_loss = tf.sqrt(loss)

with tf.name_scope('train'):
    optimizer = tf.train.MomentumOptimizer(learning_rate = learning_rate,momentum = momentum).minimize(loss) 
    #works better than gradientdescentoptimizer

#for tensorboard
with tf.name_scope('summaries'):
    sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


if tensorboard_log:
    train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
    dev_writer =  tf.summary.FileWriter(logdir + '/dev')
    
init = tf.global_variables_initializer()

preprocess_types = ('None','Max_range','Mean_center','Gaussian_blur')

train_loss_data = np.zeros((n_epochs,len(preprocess_types)+1))
dev_loss_data = np.zeros((n_epochs,len(preprocess_types)+1))

time_start = time.time()
time_1000_start = time.time()

preprocess_types = ('None','Max_range','Mean_center','Gaussian_blur')

with tf.Session() as sess:
    
    i = 0
    for type in preprocess_types:
        sess.run(tf.global_variables_initializer())
        #modify the train and dev data to be digitized to just 10 pixel values
        x_train_preprocess = preprocess_image(x_train,type)
        x_dev_preprocess = preprocess_image(x_dev,type)
        x_test_preprocess = preprocess_image(x_test,type)
        for epoch in range(n_epochs):

            loss_train,loss_dev = shuffle_run_batch (x_train_preprocess, y_train, x_dev_preprocess, y_dev, batch_size, epoch)

            train_loss_data[epoch,0] = epoch
            dev_loss_data[epoch,0] = epoch
            train_loss_data[epoch,i+1] = np.sqrt(loss_train)
            dev_loss_data[epoch,i+1] = np.sqrt(loss_dev)
            
            if epoch%50 == 0:
                print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),
                      'Dev loss:%0.3f'%np.sqrt(loss_dev),
                      'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
        i+=1
        y_pred = sess.run(pred_keypoints,feed_dict = {X: x_dev_preprocess})
                     
        plt.figure()
        plot_loss(train_loss_data,dev_loss_data)
        plot_pred (x_dev_preprocess, y_pred) 
    
    #Saving loss and test predictions
    train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
    with open('net1_preprocess_aws.csv', 'wb') as fp:
        np.savetxt(fp, train_dev_loss,fmt = '%0.4f') 
                 
time_end = time.time()    
print('Total time taken:',time_end-time_start)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# 0 Train loss:0.111 Dev loss:0.118 ratio train/dev:0.94
# 50 Train loss:0.068 Dev loss:0.073 ratio train/dev:0.93
# 0 Train loss:0.164 Dev loss:0.155 ratio train/dev:1.06
# 50 Train loss:0.063 Dev loss:0.071 ratio train/dev:0.88
# 0 Train loss:0.221 Dev loss:0.221 ratio train/dev:1.00
# 50 Train loss:0.058 Dev loss:0.089 ratio train/dev:0.65
# 0 Train loss:0.125 Dev loss:0.125 ratio train/dev:1.00
# 50 Train loss:0.070 Dev loss:0.071 ratio train/dev:0.98
# Total time taken: 400.66405391693115

# %% [markdown]
# ## Second model: Convolutional Neural Network

# %% [markdown]
# ### 1. Base convolutional NN:
# ### Optimizer = MomentumOptimizer
# Define parameters

# %%
learning_rate = 0.01
momentum = 0.9
# optimizer used
optimize_func = tf.train.MomentumOptimizer
# (learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

n_epochs = 1501 #Standardizing to 1000 epochs for all networks (except some coarse testing)
batch_size = 128

n_inputs = X.shape[1] 
n_outputs = 30


# Convolutional Layer 1.
filter_size1 = 3          # Convolution filters are 3 x 3 pixels.
num_filters1 = 32         # There are 32 of these filters.
dropout_keep_prob1 = 1


# Convolutional Layer 2.
filter_size2 = 2          # Convolution filters are 2 x 2 pixels.
num_filters2 = 64         # There are 64 of these filters.
dropout_keep_prob2 = 1


# Convolutional Layer 3.
filter_size3 = 2          # Convolution filters are 2 x 2 pixels.
num_filters3 = 128         # There are 128 of these filters.
dropout_keep_prob3 = 1


# Fully-connected layer.
fc_size4 = 1000             # Number of output neurons in fully-connected layer1.
dropout_keep_prob4 = 1      # Drop about keep robability if drop outs are applied
fc_size5 = 1000             # Number of output neurons in fully-connected layer2.
dropout_keep_prob5 = 1
dropout_keep_prob6 = 1

# %% [markdown]
# ### Define helper function to:
# ### 1) create convoluted layer variables
# ### 2) create dense layer and
# ### 3) flatten a conv layer for the dense layer

# %%
#Defining a leaky relu activation function using the relu activation function in tensorflow.
def lrelu(x, alpha=0.05):
  return tf.nn.relu(x) - alpha * tf.nn.relu(-x)

# %%
#Building a convolutional layer
#Note : uncomment the layer = lrelu(layer) when running that option.


def new_conv_relu_layer(input, filter_size, num_filters, is_training, dropout_keep_prob = 1):
    """Takes parameters and set up a convoluted layer with possible pooling
    It returns the layer as well as the weights"""

    weights = tf.get_variable( 'weights', 
        shape = [filter_size, filter_size, input.get_shape()[3], num_filters],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    
    biases = tf.get_variable( 'biases',
        shape = [num_filters],
        initializer=tf.constant_initializer(0.0)
      )
    
    conv = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')
    
    
    layer = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding='SAME')


    layer += biases

    layer = tf.nn.max_pool(value=layer, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1],padding='SAME')

    layer = tf.nn.relu(layer)
    #layer = lrelu(layer)
    
    # apply drop out by specifying a drop_out_keep_prob
    layer = tf.cond(is_training, lambda: tf.nn.dropout(layer, keep_prob = dropout_keep_prob), lambda: layer)
    
    return layer, weights

# %%
#Building a fully connected layer, with relu
#Note : uncomment the layer = lrelu(layer) when running that option.

def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu,
                 is_training ,
                 dropout_keep_prob = 1):       # no relu for the output dense layer

    # Create new weights and biases.
    weights = tf.get_variable( 'weights', 
        shape = [num_inputs, num_outputs],
        initializer = tf.contrib.layers.xavier_initializer()
      )
    
    biases = tf.get_variable( 'biases',
        shape = [num_outputs],
        initializer=tf.constant_initializer(0.0)
      )
        

    layer = tf.matmul(input, weights) + biases
    
    if use_relu:
        layer = tf.nn.relu(layer)
        #layer = lrelu(layer)
    
    layer = tf.cond(is_training, lambda: tf.nn.dropout(layer, keep_prob = dropout_keep_prob), lambda: layer)

    return layer

# %%
# build flatten layer function to flatten conv layer for the fully connected layer
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(layer, [-1, num_features])
    return layer_flat, num_features

# %%
#Base net 2 - Convolutional Neural Network
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            print('Epoch',epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
    
    if (epoch+1)%200 == 0:
            train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
            with open('net2_basic.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')

#Plot a graph of the train vs test loss data and some sample predictions:    
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

#Save the loss output and test predictions to an excel file.
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net2_base.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net2_base_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# Epoch 0 Train loss:0.173 Dev loss:0.174 ratio train/dev:0.99
# Epoch 20 Train loss:0.073 Dev loss:0.068 ratio train/dev:1.07
# Epoch 40 Train loss:0.069 Dev loss:0.066 ratio train/dev:1.06
# Epoch 60 Train loss:0.064 Dev loss:0.065 ratio train/dev:0.99
# Epoch 80 Train loss:0.061 Dev loss:0.064 ratio train/dev:0.95
# Epoch 100 Train loss:0.059 Dev loss:0.064 ratio train/dev:0.92
# Epoch 120 Train loss:0.064 Dev loss:0.063 ratio train/dev:1.01
# Epoch 140 Train loss:0.065 Dev loss:0.063 ratio train/dev:1.04
# Epoch 160 Train loss:0.059 Dev loss:0.062 ratio train/dev:0.95
# Epoch 180 Train loss:0.061 Dev loss:0.061 ratio train/dev:0.99
# Epoch 200 Train loss:0.057 Dev loss:0.061 ratio train/dev:0.93
# Epoch 220 Train loss:0.064 Dev loss:0.060 ratio train/dev:1.06
# Epoch 240 Train loss:0.060 Dev loss:0.059 ratio train/dev:1.01
# Epoch 260 Train loss:0.053 Dev loss:0.059 ratio train/dev:0.90
# Epoch 280 Train loss:0.057 Dev loss:0.058 ratio train/dev:0.99
# Epoch 300 Train loss:0.053 Dev loss:0.057 ratio train/dev:0.93
# Epoch 320 Train loss:0.056 Dev loss:0.056 ratio train/dev:1.00
# Epoch 340 Train loss:0.054 Dev loss:0.055 ratio train/dev:0.98
# Epoch 360 Train loss:0.050 Dev loss:0.054 ratio train/dev:0.93
# Epoch 380 Train loss:0.051 Dev loss:0.053 ratio train/dev:0.96
# Epoch 400 Train loss:0.050 Dev loss:0.052 ratio train/dev:0.95
# Epoch 420 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.93
# Epoch 440 Train loss:0.047 Dev loss:0.051 ratio train/dev:0.93
# Epoch 460 Train loss:0.046 Dev loss:0.050 ratio train/dev:0.92
# Epoch 480 Train loss:0.043 Dev loss:0.049 ratio train/dev:0.87
# Epoch 500 Train loss:0.049 Dev loss:0.049 ratio train/dev:1.00
# Epoch 520 Train loss:0.043 Dev loss:0.048 ratio train/dev:0.90
# Epoch 540 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.91
# Epoch 560 Train loss:0.043 Dev loss:0.047 ratio train/dev:0.92
# Epoch 580 Train loss:0.043 Dev loss:0.046 ratio train/dev:0.92
# Epoch 600 Train loss:0.045 Dev loss:0.046 ratio train/dev:0.98
# Epoch 620 Train loss:0.040 Dev loss:0.046 ratio train/dev:0.88
# Epoch 640 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.89
# Epoch 660 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.89
# Epoch 680 Train loss:0.038 Dev loss:0.045 ratio train/dev:0.85
# Epoch 700 Train loss:0.038 Dev loss:0.044 ratio train/dev:0.85
# Epoch 720 Train loss:0.035 Dev loss:0.044 ratio train/dev:0.80
# Epoch 740 Train loss:0.034 Dev loss:0.044 ratio train/dev:0.78
# Epoch 760 Train loss:0.040 Dev loss:0.044 ratio train/dev:0.92
# Epoch 780 Train loss:0.034 Dev loss:0.044 ratio train/dev:0.78
# Epoch 800 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.85
# Epoch 820 Train loss:0.034 Dev loss:0.043 ratio train/dev:0.79
# Epoch 840 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.85
# Epoch 860 Train loss:0.037 Dev loss:0.043 ratio train/dev:0.87
# Epoch 880 Train loss:0.038 Dev loss:0.043 ratio train/dev:0.89
# Epoch 900 Train loss:0.036 Dev loss:0.043 ratio train/dev:0.85
# Epoch 920 Train loss:0.034 Dev loss:0.043 ratio train/dev:0.80
# Epoch 940 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.82
# Epoch 960 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.77
# Epoch 980 Train loss:0.034 Dev loss:0.042 ratio train/dev:0.81
# Epoch 1000 Train loss:0.036 Dev loss:0.042 ratio train/dev:0.86
# Epoch 1020 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.79
# Epoch 1040 Train loss:0.031 Dev loss:0.042 ratio train/dev:0.74
# Epoch 1060 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.84
# Epoch 1080 Train loss:0.033 Dev loss:0.042 ratio train/dev:0.79
# Epoch 1100 Train loss:0.035 Dev loss:0.042 ratio train/dev:0.84
# Epoch 1120 Train loss:0.031 Dev loss:0.042 ratio train/dev:0.73
# Epoch 1140 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.78
# Epoch 1160 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.80
# Epoch 1180 Train loss:0.029 Dev loss:0.041 ratio train/dev:0.71
# Epoch 1200 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1220 Train loss:0.029 Dev loss:0.041 ratio train/dev:0.70
# Epoch 1240 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1260 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.78
# Epoch 1280 Train loss:0.033 Dev loss:0.041 ratio train/dev:0.81
# Epoch 1300 Train loss:0.032 Dev loss:0.041 ratio train/dev:0.77
# Epoch 1320 Train loss:0.031 Dev loss:0.041 ratio train/dev:0.76
# Epoch 1340 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1360 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.74
# Epoch 1380 Train loss:0.028 Dev loss:0.041 ratio train/dev:0.68
# Epoch 1400 Train loss:0.029 Dev loss:0.041 ratio train/dev:0.72
# Epoch 1420 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.74
# Epoch 1440 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.73
# Epoch 1460 Train loss:0.028 Dev loss:0.041 ratio train/dev:0.68
# Epoch 1480 Train loss:0.030 Dev loss:0.041 ratio train/dev:0.74
# Epoch 1500 Train loss:0.026 Dev loss:0.040 ratio train/dev:0.65
# Total time taken: 3636.441341161728

# %% [markdown]
# Helper function to flip the images and the keypoints. Takes one image at a time.

# %%
#Helper function to flip the images and the keypoints. Takes one image at a time.
def flip_horizontal(x,y):
    img = x.reshape(96,96)
    img1 = np.zeros(img.shape)
    #print(y.shape[0])
    y1 = y
    #print(y)
    for i in range(img.shape[1]):
        img1[:,95-i] = img[:,i]
        x1 = img1.reshape(9216)
    
    y1[::2] = y1[::2] * -1
    #print(y1)
    flip_indices = [
        (0, 2), (1, 3),
        (4, 8), (5, 9), (6, 10), (7, 11),
        (12, 16), (13, 17), (14, 18), (15, 19),
        (22, 24), (23, 25)]
    for a, b in flip_indices:
                y1[a], y1[b] = (y1[b], y1[a])
    #print(y1)
    return x1,y1

# %% [markdown]
# Function to create a shuffled batch with data augmentation with horizontal flip

# %%
#Function to create a shuffled batch with data augmentation with horizontal flip
np.random.seed(1)
def shuffle_run_batch_data_aug(Xnp, ynp, Xdev, ydev, batch_size, epoch):
    """function takes training and dev data, shuffle the train data and run TF optimizer in batches for a given epoch
    It returns the average loss for training and eval of all the batches ran in the epoch.
    It expects to run with tensorboard."""

     #Data augmentation with horizontal flips
    Xflip = np.zeros(Xnp.shape) #Array to store the horizontally flipped faces
    yflip = np.zeros(ynp.shape)

    for i in range(Xnp.shape[0]):
        Xflip[i],yflip[i] = flip_horizontal(Xnp[i],ynp[i])
        
    shuffle = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xnp, ynp = Xnp[shuffle], ynp[shuffle]
    shuffle1 = np.random.permutation(np.arange(Xnp.shape[0])) #shuffle the training data in each epoch
    Xflip,yflip = Xflip[shuffle1],yflip[shuffle1]

    # initialize variables to hold loss information for each epoch
    #loss_train = 0
    #loss_dev = 0
    batches = Xnp.shape[0]//batch_size


    for i in range(int(batches)): #run through most of the data points in each epoch
        X_batch = np.vstack((Xnp[i*batch_size//2:(i+1)*batch_size//2,:],Xflip[i*batch_size//2:(i+1)*batch_size//2,:]))
        y_batch = np.vstack((ynp[i*batch_size//2:(i+1)*batch_size//2],yflip[i*batch_size//2:(i+1)*batch_size//2]))
        if tensorboard_log:
            if i % 10 == 0:
                train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, current_epoch:epoch,training: True})
                dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, current_epoch:epoch,training: False})
                step = epoch * batches + i
                train_writer.add_summary(train_summary_str, step)
                dev_writer.add_summary(dev_summary_str, step)

        sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})

    

        loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
        loss_dev = loss.eval(feed_dict = {X:Xdev,y:ydev, training:False})

    
    return loss_train, loss_dev

# %% [markdown]
# ## Convolutional Neural Network(Net 2 architecture) with data augmentation(horizontal flip)

# %%
#Convolutional Neural Network with data augmentation(horizontal flip)
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch_data_aug (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

#Plot a graph of the train vs test loss data:
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

#Save the loss output and test predictions to an excel file.
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net2_data_aug.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net2_data_aug_test_pred.csv','wb') as fs:
    np.savetxt(fs,y_pred,fmt = '%0.4f')

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# 0 Train loss:0.2296 Dev loss:0.2290 ratio train/dev:1.00
# 20 Train loss:0.0688 Dev loss:0.0682 ratio train/dev:1.01
# 40 Train loss:0.0655 Dev loss:0.0664 ratio train/dev:0.99
# Total time taken: 149.8491497039795

# %% [markdown]
# ## CNN with data augmentation and increasing momentum(does not include horizontal flip)

# %%
#Tried a few variations. Only one variation is shown here. Output of the rest will be shown in the presentation.

np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    current_epoch = tf.Variable(0.0)
    m_min = 0.9
    m_max = 0.99
    momentum = m_min + (m_max-m_min)*current_epoch/n_epochs
    lr_min = 0.1
    lr_max = 0.3
    learning_rate = tf.train.exponential_decay(0.08, current_epoch, decay_steps=n_epochs, decay_rate=0.03)
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)
    

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    print('starting') 
    
    for epoch in range(n_epochs):
        loss_train,loss_dev = shuffle_run_batch_data_aug (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)
        
        if epoch%20 == 0:
            m = momentum.eval(feed_dict = {current_epoch:epoch})
            lr = learning_rate.eval(feed_dict = {current_epoch:epoch})
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev),'momentum:%0.4f'%m,'learning rate:%0.4f'%lr)
            
        if (epoch+1)%200 == 0:
            train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
            with open('net2_data_aug_momentum_lr_change_2.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
            with open('net2_data_aug_momentum_lr_change_2_test_pred.csv','wb') as fs:
                np.savetxt(fs,y_pred,fmt = '%0.4f')
        
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

#Plot a graph of the train vs test loss data:
    
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# starting
# 0 Train loss:0.0767 Dev loss:0.0779 ratio train/dev:0.98 momentum:0.9000 learning rate:0.1800
# 20 Train loss:0.0660 Dev loss:0.0655 ratio train/dev:1.01 momentum:0.9353 learning rate:0.1202
# 40 Train loss:0.0615 Dev loss:0.0631 ratio train/dev:0.98 momentum:0.9706 learning rate:0.1051
# Total time taken: 149.93563175201416

# %% [markdown]
# ## CNN with Leaky Relu Activation (alpha = 0.05)

# %%
#Note - in order to run this - we have to uncomment the line layer = lrelu(layer) in function new_conv_relu_layer and new_fc_layer
# and comment the line: layer = tf.nn.relu(layer)
np.random.seed(1)
graph_base = tf.Graph()
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    current_epoch = tf.Variable(0.0)
    m_min = 0.9
    m_max = 0.99
    momentum = m_min + (m_max-m_min)*current_epoch/n_epochs
    lr_min = 0.1
    lr_max = 0.3
    #learning_rate = lr_max - (lr_max-lr_min)*current_epoch/n_epochs
    learning_rate = tf.train.exponential_decay(0.08, current_epoch, decay_steps=n_epochs, decay_rate=0.03)
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch (x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            m = momentum.eval(feed_dict = {current_epoch:epoch})
            lr = learning_rate.eval(feed_dict = {current_epoch:epoch})
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                  'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev),'momentum:%0.4f'%m,'learning rate:%0.4f'%lr)
        
        if (epoch+1)%200 == 0:
            train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
            with open('net2_basic_leaky_relu_momentum3.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
                
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
            #Save the loss output and test predictions to an excel file.
    
    train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
    with open('net2_basic_leaky_relu_momentum3.csv', 'wb') as fp:
                np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
    with open('net2_basic_leaky_relu_momentum3_test_pred','wb') as fs:
        np.savetxt(fs,y_pred,fmt = '%0.4f')

#Plot a graph of the train vs test loss data:    
plot_loss (train_loss_data, dev_loss_data)
plot_pred (x_test, y_pred)

if tensorboard_log:
    train_writer.close()
    dev_writer.close()
# Out:
# 0 Train loss:0.0773 Dev loss:0.0750 ratio train/dev:1.03 momentum:0.9000 learning rate:0.0800
# 20 Train loss:0.0678 Dev loss:0.0641 ratio train/dev:1.06 momentum:0.9353 learning rate:0.0202
# 40 Train loss:0.0612 Dev loss:0.0592 ratio train/dev:1.03 momentum:0.9706 learning rate:0.0051
# Total time taken: 150.11001563072205

# %% [markdown]
# Helper Function to create CNN with different filter sizes, for testing different filter sizes

# %%
#Function to create CNN with different filter sizes, for testing different filter sizes
def createCNN(input,i,filter_size1=3,filter_size2=2,filter_size3=2):
    np.random.seed(1)
    #First convolutional layer
    with tf.variable_scope('conv1'+str(i)):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'+str(i)):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'+str(i)):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'+str(i)):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'+str(i)):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'+str(i)):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6) 
    return layer_f6

# %% [markdown]
# ## Trying different CNN filter sizes.
# Filter sizes (convolution layer1,2,3) of (3,2,2),(8,4,2),(20,10,2),(2,4,8),(2,10,20),(4,12,2),(6,18,2),(24,10,2)
# Concept is to try different filter sizers, and also different ordering of the filter sizes

# %%
#trying different CNN filter sizes.
#Trying filter sizes (convolution layer1,2,3) of (3,2,2),(8,4,2),(20,10,2),(2,4,8),(2,10,20),(4,12,2),(6,18,2),(24,10,2)
#Concept is to try different filter sizers, and also different ordering of the filter sizes
graph_base = tf.Graph()
n_epochs = 301 #Using fewer epochs to do coarse testing of several options. Should test with around 300-400 epochs
with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1])
    
    best_loss = 0.2
    best_filter = np.array((3,2,2))
    filters = np.array(((3,2,2),(8,4,2),(20,10,2),(2,4,8),(2,10,20),(4,12,2),(6,18,2),(24,10,2)))
    print('number of filter variations:',filters.shape[0])
    train_loss_data = np.zeros((n_epochs,filters.shape[0]+1))
    dev_loss_data = np.zeros((n_epochs,filters.shape[0]+1))
    
    for i in range(filters.shape[0]):
       
        filter_size1 = filters[i,0]         
        filter_size2 = filters[i,1]         
        filter_size3 = filters[i,2]  
        print('convolution filters',filter_size1,filter_size2,filter_size3)

        layer_f6 = createCNN(x_image,i,filter_size1,filter_size2,filter_size3)
        
        #loss function
        with tf.name_scope('loss'):
            loss = tf.reduce_mean(np.square(layer_f6 - y))
            sqrt_loss = tf.sqrt(loss)

        #for tensorboard
        with tf.name_scope('summaries'):
            sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)


        # optimizer
        current_epoch = tf.Variable(0.0)
        m_min = 0.9
        m_max = 0.99
        momentum = m_min + (m_max-m_min)*current_epoch/n_epochs
        lr_min = 0.1
        lr_max = 0.3
        #Note set initial learning rate to 0.06
        learning_rate = tf.train.exponential_decay(0.06, current_epoch, decay_steps=n_epochs, decay_rate=0.03)
        optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

        y_pred = np.zeros((x_test.shape[0],y.shape[1]))

        # logger
        if tensorboard_log:
            train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
            dev_writer =  tf.summary.FileWriter(logdir + '/dev')


        time_start = time.time()
        time_1000_start = time.time()


        with tf.Session(graph=graph_base) as sess:
            sess.run(tf.global_variables_initializer())
            print('starting') 

            for epoch in range(n_epochs):

                loss_train,loss_dev = shuffle_run_batch(x_train, y_train, x_dev, y_dev, batch_size, epoch)

                train_loss_data[epoch,0] = epoch
                dev_loss_data[epoch,0] = epoch
                train_loss_data[epoch,i+1] = np.sqrt(loss_train)
                dev_loss_data[epoch,i+1] = np.sqrt(loss_dev)

                if epoch%10 == 0:
                    m = momentum.eval(feed_dict = {current_epoch:epoch})
                    lr = learning_rate.eval(feed_dict = {current_epoch:epoch})
                    print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                          'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev),'momentum:%0.4f'%m,'learning rate:%0.4f'%lr)
                    
            if loss_dev < best_loss:
                best_loss = loss_dev
                best_filter = np.array((filter_size1,filter_size2,filter_size3))
                print('best filter:',best_filter.shape,best_filter)

            time_end = time.time()
            print('Total time taken for filter %d:'%i,time_end-time_start)
    
            for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
                    X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
                    y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
                    
        
    train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
    with open('net2_cnn_filter_sizes1.csv', 'wb') as fp:
        np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
    
    #Plot a graph of the train vs test loss data:
    plot_loss(train_loss_data, dev_loss_data) #need to figure a way to plot all the losses for all variations

    if tensorboard_log:
        train_writer.close()
        dev_writer.close()
# Out:
# number of filter variations: 8
# convolution filters 3 2 2
# starting
# 0 Train loss:0.0857 Dev loss:0.0835 ratio train/dev:1.03 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0681 Dev loss:0.0654 ratio train/dev:1.04 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0678 Dev loss:0.0645 ratio train/dev:1.05 momentum:0.9857 learning rate:0.0021
# best filter: (3,) [3 2 2]
# Total time taken for filter 0: 51.78359365463257
# convolution filters 8 4 2
# starting
# 0 Train loss:0.0864 Dev loss:0.0837 ratio train/dev:1.03 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0665 Dev loss:0.0640 ratio train/dev:1.04 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0645 Dev loss:0.0610 ratio train/dev:1.06 momentum:0.9857 learning rate:0.0021
# best filter: (3,) [8 4 2]
# Total time taken for filter 1: 62.74574875831604
# convolution filters 20 10 2
# starting
# 0 Train loss:0.2845 Dev loss:0.2843 ratio train/dev:1.00 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0687 Dev loss:0.0659 ratio train/dev:1.04 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0690 Dev loss:0.0659 ratio train/dev:1.05 momentum:0.9857 learning rate:0.0021
# Total time taken for filter 2: 106.83408737182617
# convolution filters 2 4 8
# starting
# 0 Train loss:0.0882 Dev loss:0.0863 ratio train/dev:1.02 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0677 Dev loss:0.0653 ratio train/dev:1.04 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0674 Dev loss:0.0640 ratio train/dev:1.05 momentum:0.9857 learning rate:0.0021
# Total time taken for filter 3: 66.28161120414734
# convolution filters 2 10 20
# starting
# 0 Train loss:0.0928 Dev loss:0.0882 ratio train/dev:1.05 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0680 Dev loss:0.0653 ratio train/dev:1.04 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0676 Dev loss:0.0643 ratio train/dev:1.05 momentum:0.9857 learning rate:0.0021
# Total time taken for filter 4: 100.56435012817383
# convolution filters 4 12 2
# starting
# 0 Train loss:0.0881 Dev loss:0.0852 ratio train/dev:1.03 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0685 Dev loss:0.0660 ratio train/dev:1.04 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0687 Dev loss:0.0654 ratio train/dev:1.05 momentum:0.9857 learning rate:0.0021
# Total time taken for filter 5: 70.87276864051819
# convolution filters 6 18 2
# starting
# 0 Train loss:0.0937 Dev loss:0.0921 ratio train/dev:1.02 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0684 Dev loss:0.0657 ratio train/dev:1.04 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0676 Dev loss:0.0645 ratio train/dev:1.05 momentum:0.9857 learning rate:0.0021
# Total time taken for filter 6: 127.01551389694214
# convolution filters 24 10 2
# starting
# 0 Train loss:0.1679 Dev loss:0.1615 ratio train/dev:1.04 momentum:0.9000 learning rate:0.0600
# 10 Train loss:0.0658 Dev loss:0.0636 ratio train/dev:1.03 momentum:0.9429 learning rate:0.0113
# 20 Train loss:0.0600 Dev loss:0.0573 ratio train/dev:1.05 momentum:0.9857 learning rate:0.0021
# best filter: (3,) [24 10  2]
# Total time taken for filter 7: 112.54655838012695
# [[  0.           0.08565401   0.08641633   0.28454721   0.08822203
#     0.0927582    0.08805394   0.09372124   0.16791101]
#  [  1.           0.07286627   0.06978521   0.08022998   0.07097955
#     0.06650595   0.07029851   0.07239348   0.07005256]
#  [  2.           0.07152684   0.07007764   0.07231597   0.07036351
#     0.07147323   0.0702662    0.07276499   0.07041632]
#  [  3.           0.06846114   0.06595232   0.06583166   0.0662054
#     0.06587834   0.06662967   0.06693009   0.06533921]
#  [  4.           0.06883485   0.06758402   0.06852279   0.06831934
#     0.0684147    0.06872281   0.06895885   0.06782078]
#  [  5.           0.06632878   0.06536192   0.06596838   0.06600109
#     0.06586134   0.06658883   0.06664278   0.06497926]
#  [  6.           0.06642395   0.06520507   0.0658511    0.06602564
#     0.06579936   0.06628706   0.06635697   0.06538798]
#  [  7.           0.06571057   0.06504506   0.06600473   0.06587868
#     0.06587862   0.06627721   0.06637298   0.06454151]
#  [  8.           0.06623704   0.06497499   0.06665639   0.06609261
#     0.06609566   0.06672582   0.0665731    0.06494844]
#  [  9.           0.06662112   0.06560719   0.06681815   0.06633518
#     0.0662904    0.06709702   0.06685293   0.06483287]
#  [ 10.           0.06806585   0.06647121   0.06865444   0.06771629
#     0.06798424   0.06851909   0.06838417   0.06581694]
#  [ 11.           0.06608455   0.06445085   0.06632352   0.06568055
#     0.06571228   0.06656992   0.06627619   0.06379422]
#  [ 12.           0.06814273   0.06618311   0.06882983   0.06758671
#     0.0677694    0.06871752   0.06826967   0.06518116]
#  [ 13.           0.06447128   0.06252832   0.06522764   0.06443335
#     0.06444397   0.06504982   0.0647442    0.06144747]
#  [ 14.           0.06521192   0.06300692   0.06610861   0.06509128
#     0.06513215   0.0657764    0.06535867   0.06144312]
#  [ 15.           0.06433485   0.06175039   0.06561703   0.06403854
#     0.06413569   0.06516882   0.06458877   0.05995531]
#  [ 16.           0.06499154   0.06203058   0.06626488   0.06457436
#     0.06476291   0.06574065   0.06482339   0.06002837]
#  [ 17.           0.05925988   0.05634008   0.06082329   0.05893893
#     0.05921806   0.06007888   0.05931249   0.0551539 ]
#  [ 18.           0.06044776   0.05775096   0.06236619   0.06018744
#     0.06047182   0.06146625   0.060727     0.05616241]
#  [ 19.           0.0561731    0.05236064   0.05794426   0.05532376
#     0.05568144   0.05687229   0.05594585   0.05031056]
#  [ 20.           0.06784096   0.06446681   0.06895688   0.06740733
#     0.06758167   0.06874519   0.06762429   0.05996763]] [[  0.           0.08352298   0.08370256   0.28428495   0.08632468
#     0.08820391   0.08521942   0.09206086   0.16146545]
#  [  1.           0.07248195   0.06954604   0.08069232   0.07097398
#     0.06642421   0.06991382   0.07340052   0.07021105]
#  [  2.           0.06860685   0.06663453   0.06728657   0.06776095
#     0.06779864   0.06710148   0.07127875   0.06579565]
#  [  3.           0.06698931   0.06583536   0.06615718   0.06637196
#     0.06606968   0.06654491   0.06709669   0.06551074]
#  [  4.           0.06625752   0.06554384   0.06592427   0.06624771
#     0.06587444   0.06648099   0.06673609   0.06524857]
#  [  5.           0.06593572   0.06524492   0.06592359   0.06605224
#     0.06584321   0.06632786   0.06657786   0.06508786]
#  [  6.           0.06583434   0.0650966    0.06589361   0.06597684
#     0.06588388   0.066297     0.06646951   0.06494226]
#  [  7.           0.06562445   0.06472913   0.06589938   0.06570439
#     0.06565043   0.06611481   0.06623931   0.06459762]
#  [  8.           0.0656935    0.06465477   0.0659195    0.06566247
#     0.06565867   0.06626333   0.0661136    0.06439024]
#  [  9.           0.06552319   0.0643757    0.0658846    0.06580161
#     0.06581028   0.0661431    0.06631695   0.06400456]
#  [ 10.           0.06540436   0.06401974   0.06593037   0.0652909
#     0.06533685   0.06596339   0.06574783   0.06362817]
#  [ 11.           0.0656542    0.06395468   0.06590687   0.06536353
#     0.06545398   0.06626916   0.065852     0.06340276]
#  [ 12.           0.06529753   0.0634515    0.06590192   0.06509554
#     0.06511219   0.06590112   0.06557293   0.06277449]
#  [ 13.           0.06518248   0.06324973   0.06588092   0.06504527
#     0.06515857   0.06586517   0.06556427   0.06218572]
#  [ 14.           0.06499872   0.06295376   0.06588503   0.0649756
#     0.06511474   0.06571177   0.06549422   0.06154619]
#  [ 15.           0.0648909    0.06251556   0.06589545   0.06458325
#     0.06473251   0.06560553   0.0650859    0.06088429]
#  [ 16.           0.06479219   0.06222131   0.06590028   0.06447317
#     0.06462289   0.06554174   0.06498329   0.06016476]
#  [ 17.           0.06490088   0.06206969   0.06590822   0.06446505
#     0.06464694   0.0656407    0.06490392   0.0597577 ]
#  [ 18.           0.06461542   0.06151768   0.06588364   0.06410484
#     0.0642693    0.06541403   0.06461108   0.05876429]
#  [ 19.           0.06458164   0.06118344   0.0658832    0.06401847
#     0.06424866   0.06533456   0.06453477   0.05815066]
#  [ 20.           0.06450218   0.06097015   0.06587823   0.06398712
#     0.06427431   0.06544041   0.06445016   0.05733367]] [[  0.           0.08565401   0.08641633   0.28454721   0.08822203
#     0.0927582    0.08805394   0.09372124   0.16791101   0.           0.08352298
#     0.08370256   0.28428495   0.08632468   0.08820391   0.08521942
#     0.09206086   0.16146545]
#  [  1.           0.07286627   0.06978521   0.08022998   0.07097955
#     0.06650595   0.07029851   0.07239348   0.07005256   1.           0.07248195
#     0.06954604   0.08069232   0.07097398   0.06642421   0.06991382
#     0.07340052   0.07021105]
#  [  2.           0.07152684   0.07007764   0.07231597   0.07036351
#     0.07147323   0.0702662    0.07276499   0.07041632   2.           0.06860685
#     0.06663453   0.06728657   0.06776095   0.06779864   0.06710148
#     0.07127875   0.06579565]
#  [  3.           0.06846114   0.06595232   0.06583166   0.0662054
#     0.06587834   0.06662967   0.06693009   0.06533921   3.           0.06698931
#     0.06583536   0.06615718   0.06637196   0.06606968   0.06654491
#     0.06709669   0.06551074]
#  [  4.           0.06883485   0.06758402   0.06852279   0.06831934
#     0.0684147    0.06872281   0.06895885   0.06782078   4.           0.06625752
#     0.06554384   0.06592427   0.06624771   0.06587444   0.06648099
#     0.06673609   0.06524857]
#  [  5.           0.06632878   0.06536192   0.06596838   0.06600109
#     0.06586134   0.06658883   0.06664278   0.06497926   5.           0.06593572
#     0.06524492   0.06592359   0.06605224   0.06584321   0.06632786
#     0.06657786   0.06508786]
#  [  6.           0.06642395   0.06520507   0.0658511    0.06602564
#     0.06579936   0.06628706   0.06635697   0.06538798   6.           0.06583434
#     0.0650966    0.06589361   0.06597684   0.06588388   0.066297
#     0.06646951   0.06494226]
#  [  7.           0.06571057   0.06504506   0.06600473   0.06587868
#     0.06587862   0.06627721   0.06637298   0.06454151   7.           0.06562445
#     0.06472913   0.06589938   0.06570439   0.06565043   0.06611481
#     0.06623931   0.06459762]
#  [  8.           0.06623704   0.06497499   0.06665639   0.06609261
#     0.06609566   0.06672582   0.0665731    0.06494844   8.           0.0656935
#     0.06465477   0.0659195    0.06566247   0.06565867   0.06626333
#     0.0661136    0.06439024]
#  [  9.           0.06662112   0.06560719   0.06681815   0.06633518
#     0.0662904    0.06709702   0.06685293   0.06483287   9.           0.06552319
#     0.0643757    0.0658846    0.06580161   0.06581028   0.0661431
#     0.06631695   0.06400456]
#  [ 10.           0.06806585   0.06647121   0.06865444   0.06771629
#     0.06798424   0.06851909   0.06838417   0.06581694  10.           0.06540436
#     0.06401974   0.06593037   0.0652909    0.06533685   0.06596339
#     0.06574783   0.06362817]
#  [ 11.           0.06608455   0.06445085   0.06632352   0.06568055
#     0.06571228   0.06656992   0.06627619   0.06379422  11.           0.0656542
#     0.06395468   0.06590687   0.06536353   0.06545398   0.06626916
#     0.065852     0.06340276]
#  [ 12.           0.06814273   0.06618311   0.06882983   0.06758671
#     0.0677694    0.06871752   0.06826967   0.06518116  12.           0.06529753
#     0.0634515    0.06590192   0.06509554   0.06511219   0.06590112
#     0.06557293   0.06277449]
#  [ 13.           0.06447128   0.06252832   0.06522764   0.06443335
#     0.06444397   0.06504982   0.0647442    0.06144747  13.           0.06518248
#     0.06324973   0.06588092   0.06504527   0.06515857   0.06586517
#     0.06556427   0.06218572]
#  [ 14.           0.06521192   0.06300692   0.06610861   0.06509128
#     0.06513215   0.0657764    0.06535867   0.06144312  14.           0.06499872
#     0.06295376   0.06588503   0.0649756    0.06511474   0.06571177
#     0.06549422   0.06154619]
#  [ 15.           0.06433485   0.06175039   0.06561703   0.06403854
#     0.06413569   0.06516882   0.06458877   0.05995531  15.           0.0648909
#     0.06251556   0.06589545   0.06458325   0.06473251   0.06560553
#     0.0650859    0.06088429]
#  [ 16.           0.06499154   0.06203058   0.06626488   0.06457436
#     0.06476291   0.06574065   0.06482339   0.06002837  16.           0.06479219
#     0.06222131   0.06590028   0.06447317   0.06462289   0.06554174
#     0.06498329   0.06016476]
#  [ 17.           0.05925988   0.05634008   0.06082329   0.05893893
#     0.05921806   0.06007888   0.05931249   0.0551539   17.           0.06490088
#     0.06206969   0.06590822   0.06446505   0.06464694   0.0656407
#     0.06490392   0.0597577 ]
#  [ 18.           0.06044776   0.05775096   0.06236619   0.06018744
#     0.06047182   0.06146625   0.060727     0.05616241  18.           0.06461542
#     0.06151768   0.06588364   0.06410484   0.0642693    0.06541403
#     0.06461108   0.05876429]
#  [ 19.           0.0561731    0.05236064   0.05794426   0.05532376
#     0.05568144   0.05687229   0.05594585   0.05031056  19.           0.06458164
#     0.06118344   0.0658832    0.06401847   0.06424866   0.06533456
#     0.06453477   0.05815066]
#  [ 20.           0.06784096   0.06446681   0.06895688   0.06740733
#     0.06758167   0.06874519   0.06762429   0.05996763  20.           0.06450218
#     0.06097015   0.06587823   0.06398712   0.06427431   0.06544041
#     0.06445016   0.05733367]]

# %% [markdown]
# # Individual Facial Parts Models

# %% [markdown]
# ## Individual model settings
#
# On examining the number of datapoints available for each feature, individual models are made by grouping similar features based on number of data points availabe. the main idea being to maximize use of data. Below is the reasoning behind combining different labels.
#
# 1. First I considered putting all eye data into one model, but as we can see above that left_eye_center_x, left_eye_center_y, right_eye_center_x , right_eye_center_y have more than 7000 data points while the remining
# eye data points only have 2267 - 2271 data points. So eye data points have been split into two models namely eye center and eye corner.
# left_eye_center_x            7039
# left_eye_center_y            7039
# right_eye_center_x           7036
# right_eye_center_y           7036
#
# #### Facial_group_models - Thirty keypoints have been grouped in six types to create specialized models
# #### These specialized models are eye_center, eye_corners, nose_tip, mouth_corner_top, mouth_bottom and eyebrow.

# %% [markdown]
# Net 2 as baseline and starting point for net 3
# Adds functionality to save the weights so they can be used to initialize the individual models in net3

# %%
#Net 2 as baseline and starting point for net 3
np.random.seed(1)
graph_base = tf.Graph()
n_epochs = 1501 # resetting n_epochs back to max after testing different filter sizes. needs to be consistent for this and net 3.
#changing keep_prob values
dropout_keep_prob1 = 1.0
dropout_keep_prob2 = 1.0
dropout_keep_prob3 = 1.0
dropout_keep_prob4 = 0.7
dropout_keep_prob5 = 0.7
#Setting filters to best value from trying with net 2
num_filters1 = 3
num_filters2 = 2
num_filters3 = 2

with graph_base.as_default():

    if tensorboard_log:
        now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
        logdir = "{}/run-{}/".format(root_logdir, now)

    # def 
    # is_train = True
    #input data
    X = tf.placeholder(tf.float32,[None,X.shape[1]])
    y = tf.placeholder(tf.float32,[None,y.shape[1]])
    training = tf.placeholder(tf.bool)
    
    current_epoch = tf.Variable(0)

    #convert x into 4-D input
    #2nd and 3rd dimension is image width and height, final dimension is number of color channels
    x_image = tf.reshape(X,[-1,96,96,1]) 

    #First convolutional layer
    with tf.variable_scope('conv1'):
        layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

    #Second convolutional layer
    with tf.variable_scope('conv2'):
        layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

    #Thrid convolutional layer
    with tf.variable_scope('conv3'):
        layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

    #Flatten conv3 output for dense nn layer 1
    layer_flat, num_features = flatten_layer(layer_conv3)

    #Densely connected layer1
    with tf.variable_scope('fc4'):
        layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

    #Densely connected layer2
    with tf.variable_scope('fc5'):
        layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

    #Densely connected output layer
    with tf.variable_scope('fc6'):
        layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = n_outputs,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


    #loss function
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(np.square(layer_f6 - y))
        sqrt_loss = tf.sqrt(loss)
        
    #for tensorboard
    with tf.name_scope('summaries'):
        sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)

        
    # optimizer
    current_epoch = tf.Variable(0.0)
    m_min = 0.9
    m_max = 0.99
    momentum = m_min + (m_max-m_min)*current_epoch/n_epochs
    lr_min = 0.01
    lr_max = 0.03
    learning_rate = tf.train.exponential_decay(0.03, current_epoch, decay_steps=n_epochs, decay_rate=0.03)
    optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

    train_loss_data = np.zeros((n_epochs,2))
    dev_loss_data = np.zeros((n_epochs,2))
    y_pred = np.zeros((x_test.shape[0],y.shape[1]))

    # logger
    if tensorboard_log:
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
time_start = time.time()
time_1000_start = time.time()

    
with tf.Session(graph=graph_base) as sess:
    sess.run(tf.global_variables_initializer())
    
    #for saving model 
    saver = tf.train.Saver()
    
    print('starting')
    
    for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
        
        loss_train,loss_dev = shuffle_run_batch(x_train, y_train, x_dev, y_dev, batch_size, epoch)

        train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
        dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

        
        if epoch%20 == 0:
            m = momentum.eval(feed_dict = {current_epoch:epoch})
            lr = learning_rate.eval(feed_dict = {current_epoch:epoch})
            print(epoch,'Train loss:%0.4f'%np.sqrt(loss_train),'Dev loss:%0.4f'%np.sqrt(loss_dev),
                          'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev),'momentum:%0.4f'%m,'learning rate:%0.4f'%lr)
                    
    time_end = time.time()
    print('Total time taken:',time_end-time_start)
    
    #Code to save models for future use
    #please give any unique name you want to give to the model for testing various paramaters.
    #It wil get appended to "basic_conv_net"
    unique_name = ""
    model_name = "basic_conv_net_" + unique_name
    model_path =  FROOT + "/models/"+ model_name + "/model.ckpt"
    train_history_path = FROOT + "/models/" + model_name + "/train_history"
    save_path = saver.save(sess, model_path)
    print("Model file: " + save_path)
    np.savez(train_history_path, train_loss_history = train_loss_data, valid_loss_history = dev_loss_data)
    print("Train history file: " + train_history_path)
    
    for i in range(int(x_test.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_test[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})
    print('done')

#Plot a graph of the train vs test loss data:
    

plot_loss (train_loss_data, dev_loss_data)
train_dev_loss = np.hstack((train_loss_data,dev_loss_data))
with open('net2_baseline_for_net3.csv', 'wb') as fp:
    np.savetxt(fp, train_dev_loss,fmt = '%0.4f')
with open('net2_baseline_for_net3_test_pred.csv','wb') as fs:
        np.savetxt(fs,y_pred,fmt = '%0.4f')

if tensorboard_log:
    train_writer.close()
    dev_writer.close()

plot_pred (x_test, y_pred)
# Out:
# starting
# 0 Train loss:0.1665 Dev loss:0.1067 ratio train/dev:1.56 momentum:0.9000 learning rate:0.0300
# 20 Train loss:0.0779 Dev loss:0.0666 ratio train/dev:1.17 momentum:0.9012 learning rate:0.0286
# 40 Train loss:0.0760 Dev loss:0.0660 ratio train/dev:1.15 momentum:0.9024 learning rate:0.0273
# 60 Train loss:0.0702 Dev loss:0.0656 ratio train/dev:1.07 momentum:0.9036 learning rate:0.0261
# 80 Train loss:0.0657 Dev loss:0.0652 ratio train/dev:1.01 momentum:0.9048 learning rate:0.0249
# 100 Train loss:0.0633 Dev loss:0.0649 ratio train/dev:0.98 momentum:0.9060 learning rate:0.0238
# 120 Train loss:0.0678 Dev loss:0.0644 ratio train/dev:1.05 momentum:0.9072 learning rate:0.0227
# 140 Train loss:0.0690 Dev loss:0.0640 ratio train/dev:1.08 momentum:0.9084 learning rate:0.0216
# 160 Train loss:0.0640 Dev loss:0.0635 ratio train/dev:1.01 momentum:0.9096 learning rate:0.0206
# 180 Train loss:0.0653 Dev loss:0.0630 ratio train/dev:1.04 momentum:0.9108 learning rate:0.0197
# 200 Train loss:0.0620 Dev loss:0.0624 ratio train/dev:0.99 momentum:0.9120 learning rate:0.0188
# 220 Train loss:0.0690 Dev loss:0.0619 ratio train/dev:1.12 momentum:0.9132 learning rate:0.0179
# 240 Train loss:0.0646 Dev loss:0.0612 ratio train/dev:1.05 momentum:0.9144 learning rate:0.0171
# 260 Train loss:0.0589 Dev loss:0.0607 ratio train/dev:0.97 momentum:0.9156 learning rate:0.0163
# 280 Train loss:0.0615 Dev loss:0.0601 ratio train/dev:1.02 momentum:0.9168 learning rate:0.0156
# 300 Train loss:0.0600 Dev loss:0.0595 ratio train/dev:1.01 momentum:0.9180 learning rate:0.0149
# 320 Train loss:0.0630 Dev loss:0.0590 ratio train/dev:1.07 momentum:0.9192 learning rate:0.0142
# 340 Train loss:0.0619 Dev loss:0.0584 ratio train/dev:1.06 momentum:0.9204 learning rate:0.0136
# 360 Train loss:0.0585 Dev loss:0.0580 ratio train/dev:1.01 momentum:0.9216 learning rate:0.0129
# 380 Train loss:0.0599 Dev loss:0.0575 ratio train/dev:1.04 momentum:0.9228 learning rate:0.0123
# 400 Train loss:0.0599 Dev loss:0.0570 ratio train/dev:1.05 momentum:0.9240 learning rate:0.0118
# 420 Train loss:0.0596 Dev loss:0.0566 ratio train/dev:1.05 momentum:0.9252 learning rate:0.0112
# 440 Train loss:0.0561 Dev loss:0.0562 ratio train/dev:1.00 momentum:0.9264 learning rate:0.0107
# 460 Train loss:0.0572 Dev loss:0.0558 ratio train/dev:1.03 momentum:0.9276 learning rate:0.0102
# 480 Train loss:0.0551 Dev loss:0.0554 ratio train/dev:1.00 momentum:0.9288 learning rate:0.0098
# 500 Train loss:0.0618 Dev loss:0.0550 ratio train/dev:1.12 momentum:0.9300 learning rate:0.0093
# 520 Train loss:0.0550 Dev loss:0.0546 ratio train/dev:1.01 momentum:0.9312 learning rate:0.0089
# 540 Train loss:0.0567 Dev loss:0.0542 ratio train/dev:1.05 momentum:0.9324 learning rate:0.0085
# 560 Train loss:0.0561 Dev loss:0.0538 ratio train/dev:1.04 momentum:0.9336 learning rate:0.0081
# 580 Train loss:0.0574 Dev loss:0.0535 ratio train/dev:1.07 momentum:0.9348 learning rate:0.0077
# 600 Train loss:0.0579 Dev loss:0.0531 ratio train/dev:1.09 momentum:0.9360 learning rate:0.0074
# 620 Train loss:0.0557 Dev loss:0.0528 ratio train/dev:1.06 momentum:0.9372 learning rate:0.0070
# 640 Train loss:0.0558 Dev loss:0.0525 ratio train/dev:1.06 momentum:0.9384 learning rate:0.0067
# 660 Train loss:0.0532 Dev loss:0.0522 ratio train/dev:1.02 momentum:0.9396 learning rate:0.0064
# 680 Train loss:0.0532 Dev loss:0.0518 ratio train/dev:1.03 momentum:0.9408 learning rate:0.0061
# 700 Train loss:0.0538 Dev loss:0.0515 ratio train/dev:1.05 momentum:0.9420 learning rate:0.0058
# 720 Train loss:0.0499 Dev loss:0.0512 ratio train/dev:0.98 momentum:0.9432 learning rate:0.0056
# 740 Train loss:0.0477 Dev loss:0.0509 ratio train/dev:0.94 momentum:0.9444 learning rate:0.0053
# 760 Train loss:0.0535 Dev loss:0.0507 ratio train/dev:1.06 momentum:0.9456 learning rate:0.0051
# 780 Train loss:0.0479 Dev loss:0.0505 ratio train/dev:0.95 momentum:0.9468 learning rate:0.0049
# 800 Train loss:0.0509 Dev loss:0.0503 ratio train/dev:1.01 momentum:0.9480 learning rate:0.0046
# 820 Train loss:0.0492 Dev loss:0.0500 ratio train/dev:0.98 momentum:0.9492 learning rate:0.0044
# 840 Train loss:0.0511 Dev loss:0.0498 ratio train/dev:1.03 momentum:0.9504 learning rate:0.0042
# 860 Train loss:0.0521 Dev loss:0.0496 ratio train/dev:1.05 momentum:0.9516 learning rate:0.0040
# 880 Train loss:0.0532 Dev loss:0.0494 ratio train/dev:1.08 momentum:0.9528 learning rate:0.0038
# 900 Train loss:0.0527 Dev loss:0.0493 ratio train/dev:1.07 momentum:0.9540 learning rate:0.0037
# 920 Train loss:0.0485 Dev loss:0.0491 ratio train/dev:0.99 momentum:0.9552 learning rate:0.0035
# 940 Train loss:0.0486 Dev loss:0.0489 ratio train/dev:0.99 momentum:0.9564 learning rate:0.0033
# 960 Train loss:0.0478 Dev loss:0.0488 ratio train/dev:0.98 momentum:0.9576 learning rate:0.0032
# 980 Train loss:0.0486 Dev loss:0.0486 ratio train/dev:1.00 momentum:0.9588 learning rate:0.0030
# 1000 Train loss:0.0519 Dev loss:0.0484 ratio train/dev:1.07 momentum:0.9600 learning rate:0.0029
# 1020 Train loss:0.0488 Dev loss:0.0483 ratio train/dev:1.01 momentum:0.9612 learning rate:0.0028
# 1040 Train loss:0.0445 Dev loss:0.0481 ratio train/dev:0.92 momentum:0.9624 learning rate:0.0026
# 1060 Train loss:0.0526 Dev loss:0.0480 ratio train/dev:1.10 momentum:0.9636 learning rate:0.0025
# 1080 Train loss:0.0486 Dev loss:0.0478 ratio train/dev:1.02 momentum:0.9648 learning rate:0.0024
# 1100 Train loss:0.0513 Dev loss:0.0477 ratio train/dev:1.08 momentum:0.9660 learning rate:0.0023
# 1120 Train loss:0.0469 Dev loss:0.0476 ratio train/dev:0.99 momentum:0.9672 learning rate:0.0022
# 1140 Train loss:0.0498 Dev loss:0.0474 ratio train/dev:1.05 momentum:0.9684 learning rate:0.0021
# 1160 Train loss:0.0483 Dev loss:0.0473 ratio train/dev:1.02 momentum:0.9696 learning rate:0.0020
# 1180 Train loss:0.0441 Dev loss:0.0471 ratio train/dev:0.94 momentum:0.9708 learning rate:0.0019
# 1200 Train loss:0.0466 Dev loss:0.0470 ratio train/dev:0.99 momentum:0.9720 learning rate:0.0018
# 1220 Train loss:0.0452 Dev loss:0.0469 ratio train/dev:0.96 momentum:0.9732 learning rate:0.0017
# 1240 Train loss:0.0464 Dev loss:0.0468 ratio train/dev:0.99 momentum:0.9744 learning rate:0.0017
# 1260 Train loss:0.0491 Dev loss:0.0467 ratio train/dev:1.05 momentum:0.9755 learning rate:0.0016
# 1280 Train loss:0.0506 Dev loss:0.0466 ratio train/dev:1.09 momentum:0.9767 learning rate:0.0015
# 1300 Train loss:0.0469 Dev loss:0.0464 ratio train/dev:1.01 momentum:0.9779 learning rate:0.0014
# 1320 Train loss:0.0484 Dev loss:0.0463 ratio train/dev:1.04 momentum:0.9791 learning rate:0.0014
# 1340 Train loss:0.0459 Dev loss:0.0462 ratio train/dev:0.99 momentum:0.9803 learning rate:0.0013
# 1360 Train loss:0.0477 Dev loss:0.0461 ratio train/dev:1.03 momentum:0.9815 learning rate:0.0013
# 1380 Train loss:0.0427 Dev loss:0.0460 ratio train/dev:0.93 momentum:0.9827 learning rate:0.0012
# 1400 Train loss:0.0456 Dev loss:0.0459 ratio train/dev:0.99 momentum:0.9839 learning rate:0.0011
# 1420 Train loss:0.0470 Dev loss:0.0458 ratio train/dev:1.03 momentum:0.9851 learning rate:0.0011
# 1440 Train loss:0.0453 Dev loss:0.0457 ratio train/dev:0.99 momentum:0.9863 learning rate:0.0010
# 1460 Train loss:0.0438 Dev loss:0.0456 ratio train/dev:0.96 momentum:0.9875 learning rate:0.0010
# 1480 Train loss:0.0461 Dev loss:0.0455 ratio train/dev:1.01 momentum:0.9887 learning rate:0.0009
# 1500 Train loss:0.0422 Dev loss:0.0454 ratio train/dev:0.93 momentum:0.9899 learning rate:0.0009
# Total time taken: 575.328334569931
# Model file: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/basic_conv_net_/train_history
# done

# %%
#Individual Facial Keypoints models
#Important to keep the same input as the baseline net 2 being used as starting point for weights
n_epochs = 1501
# dropout_keep_prob1 = 0.9
# dropout_keep_prob2 = 0.8
# dropout_keep_prob3 = 0.8
# dropout_keep_prob4 = 0.7

# %%
#Uncomment the dict to run a particular model
facial_group_labels = [
   
    dict(
        name = "mouth_corner_top",
        columns = (
            'mouth_left_corner_x', 'mouth_left_corner_y',
            'mouth_right_corner_x', 'mouth_right_corner_y',
            'mouth_center_top_lip_x', 'mouth_center_top_lip_y',
            )),
     
     dict(
         name = "nose_tip",
         columns = (
             'nose_tip_x', 'nose_tip_y',
             )),

    dict(
        name = "mouth_bottom",
        columns = (
            'mouth_center_bottom_lip_x',
            'mouth_center_bottom_lip_y',
            )),

    dict(
        name = "eye_corner",
        columns = (
            'left_eye_inner_corner_x', 'left_eye_inner_corner_y',
            'right_eye_inner_corner_x', 'right_eye_inner_corner_y',
            'left_eye_outer_corner_x', 'left_eye_outer_corner_y',
            'right_eye_outer_corner_x', 'right_eye_outer_corner_y',
            )),

    dict(
        name = "eyebrow",
        columns = (
            'left_eyebrow_inner_end_x', 'left_eyebrow_inner_end_y',
            'right_eyebrow_inner_end_x', 'right_eyebrow_inner_end_y',
            'left_eyebrow_outer_end_x', 'left_eyebrow_outer_end_y',
            'right_eyebrow_outer_end_x', 'right_eyebrow_outer_end_y',
            )),
    
     dict(
        name = "eye_center",
        columns = (
            'left_eye_center_x', 'left_eye_center_y',
            'right_eye_center_x', 'right_eye_center_y',
            )),
    ]

# %%
def train_individual_model(facial_model_label):
    
    np.random.seed(1)
    graph_base = tf.Graph()
    
    X, y = load(cols = facial_model_label['columns'])
    num_keypoints = y.shape[1]
    
    
    
    np.random.seed(0)
    dev_size = 0.2
    #setting aside a 20% sample for validation

    x_train, x_dev, y_train, y_dev = train_test_split(X, y, test_size = dev_size)

    x_test, _ = load(test=True)

    print('Training data split into train and dev data')
    print("x_train.shape = = {}; x_train.min == {:.3f}; x_train.max == {:.3f}".format(x_train.shape, x_train.min(),x_train.max()))
    print("y_train.shape = = {}; y_train.min == {:.3f}; y_train.max == {:.3f}".format(y_train.shape, y_train.min(),y_train.max()))
    print("x_dev.shape = = {}; x_dev.min == {:.3f}; x_dev.max == {:.3f}".format(x_dev.shape, x_dev.min(),x_dev.max()))
    print("y_dev.shape = = {}; y_dev.min == {:.3f}; y_dev.max == {:.3f}".format(y_dev.shape, y_dev.min(),y_dev.max()))
    
    with graph_base.as_default():

        if tensorboard_log:
            now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
            logdir = "{}/run-{}/".format(root_logdir, now)

    
        X = tf.placeholder(tf.float32,[None,X.shape[1]])
        y = tf.placeholder(tf.float32,[None,y.shape[1]])
        training = tf.placeholder(tf.bool)
        current_epoch = tf.Variable(0)  # count the number of epochs
    
        #convert x into 4-D input
        #2nd and 3rd dimension is image width and height, final dimension is number of color channels
        x_image = tf.reshape(X,[-1,96,96,1]) 
    
        

        #First convolutional layer
        with tf.variable_scope('conv1'):
            layer_conv1, weights_conv1 = new_conv_relu_layer (input = x_image, 
                                                          filter_size = filter_size1, 
                                                          num_filters = num_filters1, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob1)

        #Second convolutional layer
        with tf.variable_scope('conv2'):
            layer_conv2, weights_conv2 = new_conv_relu_layer (input = layer_conv1, 
                                                          filter_size = filter_size2, 
                                                          num_filters = num_filters2, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob2)

        #Thrid convolutional layer
        with tf.variable_scope('conv3'):
            layer_conv3, weights_conv3 = new_conv_relu_layer (input = layer_conv2, 
                                                          filter_size = filter_size3, 
                                                          num_filters = num_filters3, 
                                                          is_training = training,
                                                          dropout_keep_prob = dropout_keep_prob3)    

        #Flatten conv3 output for dense nn layer 1
        layer_flat, num_features = flatten_layer(layer_conv3)

        #Densely connected layer1
        with tf.variable_scope('fc4'):
            layer_fc4 = new_fc_layer(input =layer_flat,
                                num_inputs = num_features,
                                num_outputs = fc_size4,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob4)

        #Densely connected layer2
        with tf.variable_scope('fc5'):
            layer_fc5 = new_fc_layer(input =layer_fc4,
                                num_inputs = fc_size4,
                                num_outputs = fc_size5,
                                use_relu = True,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob5)    

        #Densely connected output layer
        with tf.variable_scope('fc6'):
            layer_f6 = new_fc_layer(input =layer_fc5,
                                num_inputs = fc_size5,
                                num_outputs = num_keypoints,
                                use_relu = False,
                                is_training = training,
                                dropout_keep_prob = dropout_keep_prob6)       


        #loss function
        with tf.name_scope('loss'):
            loss = tf.reduce_mean(np.square(layer_f6 - y))
            sqrt_loss = tf.sqrt(loss)
        
        #for tensorboard
        with tf.name_scope('summaries'):
            sqrt_loss_summary = tf.summary.scalar('sqrt_loss', sqrt_loss)
    
        # optimizer
        #making changes to learning rate and momentum for individual models
        # learning rate decay. - Idea is to start with high learning rate to speed up but decrease as we get closer to 
        #the local optimum so that we don't surpass it.
        learning_rate = tf.train.exponential_decay(0.03, current_epoch, decay_steps = n_epochs, decay_rate = 0.03)
        momentum = 0.9 + (0.99 - 0.9) * (current_epoch / n_epochs)
        optimizer = optimize_func(learning_rate = learning_rate,momentum = momentum,use_nesterov = True).minimize(loss)

        train_loss_data = np.zeros((n_epochs,2))
        dev_loss_data = np.zeros((n_epochs,2))
        y_pred = np.zeros((x_dev.shape[0],y.shape[1]))

        # logger
        if tensorboard_log:
            train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
            dev_writer =  tf.summary.FileWriter(logdir + '/dev')

    
    time_start = time.time()
    time_1000_start = time.time()

    
    with tf.Session(graph=graph_base) as sess:
        sess.run(tf.global_variables_initializer())
    
        #for saving model 
        saver = tf.train.Saver()
        
        #initializing weights from a previous session 
        initialising_model = "basic_conv_net_"
        print(" RESTORING SESSION FOR WEIGHTS INITIALIZATION")
        # Exclude output layer weights from variables we will restore
        variables_to_restore = [v for v in tf.global_variables() if "fc6" not in v.op.name]
        # Replace variables scope with that of the current model
        loader = tf.train.Saver({v.op.name.replace(facial_model_label['name'], initialising_model): v for v in variables_to_restore})
        load_path = FROOT + "/models/" + initialising_model + "/model.ckpt"
        loader.restore(sess, load_path)
        print(" Model loaded from: " + load_path)
    
        for epoch in range(n_epochs):
        #print('starting epoch:',epoch)
            current_epoch = epoch
            shuffle = np.random.permutation(np.arange(x_train.shape[0])) #shuffle the training data in each epoch
            x_train, y_train = x_train[shuffle], y_train[shuffle]

            # initialize variables to hold loss information for each epoch
    
            batches = x_train.shape[0]//batch_size

            
            
            for i in range(int(batches)): #run through most of the data points in each epoch
        
                X_batch,y_batch = x_train[i*batch_size:(i+1)*batch_size,:], y_train[i*batch_size:(i+1)*batch_size]
                sess.run(optimizer, feed_dict = {X:X_batch,y:y_batch, training:True})
        
                if tensorboard_log:
                    if i % 10 == 0:
                        train_summary_str = sqrt_loss_summary.eval(feed_dict={X: X_batch, y: y_batch, training: True})
                        dev_summary_str = sqrt_loss_summary.eval(feed_dict={X: Xdev, y: ydev, training: False})
                        step = epoch * batches + i
                        train_writer.add_summary(train_summary_str, step)
                        dev_writer.add_summary(dev_summary_str, step)

            loss_train = loss.eval(feed_dict = {X:X_batch,y:y_batch,  training:True})            
            loss_dev = loss.eval(feed_dict = {X:x_dev,y:y_dev, training:False})
            train_loss_data[epoch,:] = epoch,np.sqrt(loss_train)
            dev_loss_data[epoch,:] = epoch,np.sqrt(loss_dev)

            if epoch%20 == 0:
                print(epoch,'Train loss:%0.3f'%np.sqrt(loss_train),'Dev loss:%0.3f'%np.sqrt(loss_dev),'ratio train/dev:%0.2f'%np.sqrt(loss_train/loss_dev))
        
        time_end = time.time()
        print('Total time taken:',time_end-time_start)
    
        # Save model weights for future use.
        #please give any unique name you want to give to the model for testing various paramaters.
        #It wil get appended to ""basic_conv_net"
        model_name = "ind_model_" + facial_model_label['name'] + "_"
        model_path =  FROOT + "/models/"+ model_name + "/model.ckpt"
        train_history_path = FROOT + "/models/" + model_name + "/train_history"
        save_path = saver.save(sess, model_path)
        print("Model file: " + save_path)
        np.savez(train_history_path, train_loss_history = train_loss_data, valid_loss_history = dev_loss_data)
        print("Train history file: " + train_history_path)
    
        for i in range(int(x_dev.shape[0]//batch_size)): #doing predictions in batches
            X_batch = x_dev[i*batch_size:(i+1)*batch_size,:]
            y_pred [i*batch_size:(i+1)*batch_size] = sess.run(layer_f6,feed_dict = {X:X_batch, training:False})

    #Plot a graph of the train vs dev loss data:
    
    #plt.figure()
    plot_loss (train_loss_data, dev_loss_data)
    print("\n")
    plot_pred (x_dev, y_pred)
    print("\n")
    if tensorboard_log:
        train_writer.close()
        dev_writer.close()

# %%
start = time.time()

for facial_model_label in facial_group_labels:
    train_individual_model(facial_model_label)

time_stop = time.time()    
print(" Total time for all models: " , time_stop - start)
# Out:
# Count of observations in training data by features
# mouth_left_corner_x       2269
# mouth_left_corner_y       2269
# mouth_right_corner_x      2270
# mouth_right_corner_y      2270
# mouth_center_top_lip_x    2275
# mouth_center_top_lip_y    2275
# Image                     7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1808, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1808, 6); y_train.min == -0.942; y_train.max == 0.990
# x_dev.shape = = (452, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (452, 6); y_dev.min == -0.953; y_dev.max == 0.961
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.128 Dev loss:0.127 ratio train/dev:1.01
# 20 Train loss:0.064 Dev loss:0.069 ratio train/dev:0.94
# 40 Train loss:0.058 Dev loss:0.066 ratio train/dev:0.89
# 60 Train loss:0.068 Dev loss:0.064 ratio train/dev:1.06
# 80 Train loss:0.050 Dev loss:0.063 ratio train/dev:0.79
# 100 Train loss:0.053 Dev loss:0.062 ratio train/dev:0.85
# 120 Train loss:0.056 Dev loss:0.062 ratio train/dev:0.90
# 140 Train loss:0.050 Dev loss:0.061 ratio train/dev:0.82
# 160 Train loss:0.062 Dev loss:0.061 ratio train/dev:1.02
# 180 Train loss:0.047 Dev loss:0.060 ratio train/dev:0.77
# 200 Train loss:0.049 Dev loss:0.060 ratio train/dev:0.82
# 220 Train loss:0.051 Dev loss:0.060 ratio train/dev:0.86
# 240 Train loss:0.056 Dev loss:0.059 ratio train/dev:0.95
# 260 Train loss:0.044 Dev loss:0.059 ratio train/dev:0.75
# 280 Train loss:0.053 Dev loss:0.058 ratio train/dev:0.91
# 300 Train loss:0.046 Dev loss:0.058 ratio train/dev:0.78
# 320 Train loss:0.043 Dev loss:0.058 ratio train/dev:0.74
# 340 Train loss:0.046 Dev loss:0.058 ratio train/dev:0.80
# 360 Train loss:0.043 Dev loss:0.058 ratio train/dev:0.74
# 380 Train loss:0.050 Dev loss:0.057 ratio train/dev:0.87
# 400 Train loss:0.042 Dev loss:0.057 ratio train/dev:0.74
# 420 Train loss:0.041 Dev loss:0.057 ratio train/dev:0.72
# 440 Train loss:0.039 Dev loss:0.057 ratio train/dev:0.70
# 460 Train loss:0.042 Dev loss:0.057 ratio train/dev:0.74
# 480 Train loss:0.038 Dev loss:0.056 ratio train/dev:0.67
# 500 Train loss:0.043 Dev loss:0.056 ratio train/dev:0.77
# 520 Train loss:0.038 Dev loss:0.056 ratio train/dev:0.69
# 540 Train loss:0.039 Dev loss:0.056 ratio train/dev:0.69
# 560 Train loss:0.041 Dev loss:0.056 ratio train/dev:0.74
# 580 Train loss:0.037 Dev loss:0.055 ratio train/dev:0.67
# 600 Train loss:0.042 Dev loss:0.055 ratio train/dev:0.76
# 620 Train loss:0.045 Dev loss:0.055 ratio train/dev:0.81
# 640 Train loss:0.037 Dev loss:0.055 ratio train/dev:0.67
# 660 Train loss:0.041 Dev loss:0.055 ratio train/dev:0.74
# 680 Train loss:0.038 Dev loss:0.055 ratio train/dev:0.70
# 700 Train loss:0.041 Dev loss:0.055 ratio train/dev:0.75
# 720 Train loss:0.037 Dev loss:0.055 ratio train/dev:0.67
# 740 Train loss:0.038 Dev loss:0.055 ratio train/dev:0.70
# 760 Train loss:0.038 Dev loss:0.055 ratio train/dev:0.69
# 780 Train loss:0.036 Dev loss:0.055 ratio train/dev:0.66
# 800 Train loss:0.033 Dev loss:0.055 ratio train/dev:0.60
# 820 Train loss:0.039 Dev loss:0.054 ratio train/dev:0.72
# 840 Train loss:0.037 Dev loss:0.054 ratio train/dev:0.68
# 860 Train loss:0.039 Dev loss:0.054 ratio train/dev:0.72
# 880 Train loss:0.036 Dev loss:0.054 ratio train/dev:0.66
# 900 Train loss:0.036 Dev loss:0.054 ratio train/dev:0.66
# 920 Train loss:0.037 Dev loss:0.054 ratio train/dev:0.68
# 940 Train loss:0.037 Dev loss:0.054 ratio train/dev:0.69
# 960 Train loss:0.037 Dev loss:0.054 ratio train/dev:0.68
# 980 Train loss:0.034 Dev loss:0.054 ratio train/dev:0.64
# 1000 Train loss:0.034 Dev loss:0.054 ratio train/dev:0.63
# 1020 Train loss:0.035 Dev loss:0.054 ratio train/dev:0.66
# 1040 Train loss:0.031 Dev loss:0.054 ratio train/dev:0.57
# 1060 Train loss:0.035 Dev loss:0.054 ratio train/dev:0.65
# 1080 Train loss:0.034 Dev loss:0.054 ratio train/dev:0.64
# 1100 Train loss:0.033 Dev loss:0.054 ratio train/dev:0.61
# 1120 Train loss:0.033 Dev loss:0.053 ratio train/dev:0.63
# 1140 Train loss:0.032 Dev loss:0.053 ratio train/dev:0.61
# 1160 Train loss:0.034 Dev loss:0.054 ratio train/dev:0.64
# 1180 Train loss:0.040 Dev loss:0.053 ratio train/dev:0.76
# 1200 Train loss:0.040 Dev loss:0.053 ratio train/dev:0.75
# 1220 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.59
# 1240 Train loss:0.034 Dev loss:0.053 ratio train/dev:0.64
# 1260 Train loss:0.039 Dev loss:0.053 ratio train/dev:0.72
# 1280 Train loss:0.037 Dev loss:0.053 ratio train/dev:0.69
# 1300 Train loss:0.034 Dev loss:0.053 ratio train/dev:0.63
# 1320 Train loss:0.034 Dev loss:0.053 ratio train/dev:0.64
# 1340 Train loss:0.033 Dev loss:0.053 ratio train/dev:0.62
# 1360 Train loss:0.030 Dev loss:0.053 ratio train/dev:0.56
# 1380 Train loss:0.036 Dev loss:0.053 ratio train/dev:0.68
# 1400 Train loss:0.035 Dev loss:0.053 ratio train/dev:0.66
# 1420 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.58
# 1440 Train loss:0.032 Dev loss:0.053 ratio train/dev:0.60
# 1460 Train loss:0.038 Dev loss:0.053 ratio train/dev:0.71
# 1480 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.59
# 1500 Train loss:0.031 Dev loss:0.053 ratio train/dev:0.58
# Total time taken: 350.082487821579
# Model file: /home/ubuntu/notebooks/models/ind_model_mouth_corner_top_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_mouth_corner_top_/train_history
# Count of observations in training data by features
# nose_tip_x    7049
# nose_tip_y    7049
# Image         7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (5639, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (5639, 2); y_train.min == -0.730; y_train.max == 0.955
# x_dev.shape = = (1410, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (1410, 2); y_dev.min == -0.682; y_dev.max == 0.999
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.108 Dev loss:0.095 ratio train/dev:1.15
# 20 Train loss:0.086 Dev loss:0.076 ratio train/dev:1.13
# 40 Train loss:0.095 Dev loss:0.073 ratio train/dev:1.31
# 60 Train loss:0.067 Dev loss:0.071 ratio train/dev:0.94
# 80 Train loss:0.075 Dev loss:0.070 ratio train/dev:1.07
# 100 Train loss:0.058 Dev loss:0.069 ratio train/dev:0.84
# 120 Train loss:0.065 Dev loss:0.069 ratio train/dev:0.95
# 140 Train loss:0.072 Dev loss:0.068 ratio train/dev:1.06
# 160 Train loss:0.057 Dev loss:0.068 ratio train/dev:0.84
# 180 Train loss:0.068 Dev loss:0.068 ratio train/dev:1.00
# 200 Train loss:0.064 Dev loss:0.068 ratio train/dev:0.94
# 220 Train loss:0.056 Dev loss:0.068 ratio train/dev:0.83
# 240 Train loss:0.055 Dev loss:0.067 ratio train/dev:0.81
# 260 Train loss:0.049 Dev loss:0.067 ratio train/dev:0.73
# 280 Train loss:0.052 Dev loss:0.067 ratio train/dev:0.78
# 300 Train loss:0.055 Dev loss:0.067 ratio train/dev:0.83
# 320 Train loss:0.052 Dev loss:0.067 ratio train/dev:0.78
# 340 Train loss:0.051 Dev loss:0.067 ratio train/dev:0.76
# 360 Train loss:0.044 Dev loss:0.067 ratio train/dev:0.66
# 380 Train loss:0.043 Dev loss:0.067 ratio train/dev:0.64
# 400 Train loss:0.046 Dev loss:0.066 ratio train/dev:0.70
# 420 Train loss:0.047 Dev loss:0.066 ratio train/dev:0.71
# 440 Train loss:0.046 Dev loss:0.066 ratio train/dev:0.69
# 460 Train loss:0.061 Dev loss:0.066 ratio train/dev:0.92
# 480 Train loss:0.042 Dev loss:0.066 ratio train/dev:0.64
# 500 Train loss:0.041 Dev loss:0.066 ratio train/dev:0.63
# 520 Train loss:0.037 Dev loss:0.066 ratio train/dev:0.56
# 540 Train loss:0.055 Dev loss:0.066 ratio train/dev:0.84
# 560 Train loss:0.042 Dev loss:0.066 ratio train/dev:0.64
# 580 Train loss:0.035 Dev loss:0.066 ratio train/dev:0.53
# 600 Train loss:0.040 Dev loss:0.066 ratio train/dev:0.60
# 620 Train loss:0.043 Dev loss:0.066 ratio train/dev:0.66
# 640 Train loss:0.041 Dev loss:0.066 ratio train/dev:0.62
# 660 Train loss:0.037 Dev loss:0.066 ratio train/dev:0.57
# 680 Train loss:0.039 Dev loss:0.065 ratio train/dev:0.59
# 700 Train loss:0.041 Dev loss:0.065 ratio train/dev:0.62
# 720 Train loss:0.035 Dev loss:0.065 ratio train/dev:0.53
# 740 Train loss:0.039 Dev loss:0.065 ratio train/dev:0.59
# 760 Train loss:0.038 Dev loss:0.065 ratio train/dev:0.59
# 780 Train loss:0.035 Dev loss:0.065 ratio train/dev:0.53
# 800 Train loss:0.037 Dev loss:0.065 ratio train/dev:0.57
# 820 Train loss:0.038 Dev loss:0.065 ratio train/dev:0.59
# 840 Train loss:0.036 Dev loss:0.065 ratio train/dev:0.56
# 860 Train loss:0.034 Dev loss:0.065 ratio train/dev:0.52
# 880 Train loss:0.041 Dev loss:0.065 ratio train/dev:0.63
# 900 Train loss:0.036 Dev loss:0.065 ratio train/dev:0.55
# 920 Train loss:0.041 Dev loss:0.065 ratio train/dev:0.64
# 940 Train loss:0.036 Dev loss:0.065 ratio train/dev:0.56
# 960 Train loss:0.028 Dev loss:0.065 ratio train/dev:0.43
# 980 Train loss:0.034 Dev loss:0.065 ratio train/dev:0.52
# 1000 Train loss:0.033 Dev loss:0.065 ratio train/dev:0.51
# 1020 Train loss:0.033 Dev loss:0.065 ratio train/dev:0.51
# 1040 Train loss:0.036 Dev loss:0.064 ratio train/dev:0.56
# 1060 Train loss:0.035 Dev loss:0.065 ratio train/dev:0.54
# 1080 Train loss:0.052 Dev loss:0.065 ratio train/dev:0.80
# 1100 Train loss:0.033 Dev loss:0.065 ratio train/dev:0.52
# 1120 Train loss:0.046 Dev loss:0.065 ratio train/dev:0.72
# 1140 Train loss:0.036 Dev loss:0.065 ratio train/dev:0.56
# 1160 Train loss:0.033 Dev loss:0.065 ratio train/dev:0.51
# 1180 Train loss:0.030 Dev loss:0.065 ratio train/dev:0.47
# 1200 Train loss:0.031 Dev loss:0.064 ratio train/dev:0.47
# 1220 Train loss:0.032 Dev loss:0.065 ratio train/dev:0.49
# 1240 Train loss:0.032 Dev loss:0.064 ratio train/dev:0.50
# 1260 Train loss:0.033 Dev loss:0.064 ratio train/dev:0.51
# 1280 Train loss:0.032 Dev loss:0.064 ratio train/dev:0.50
# 1300 Train loss:0.053 Dev loss:0.064 ratio train/dev:0.82
# 1320 Train loss:0.031 Dev loss:0.064 ratio train/dev:0.48
# 1340 Train loss:0.028 Dev loss:0.064 ratio train/dev:0.43
# 1360 Train loss:0.032 Dev loss:0.065 ratio train/dev:0.50
# 1380 Train loss:0.029 Dev loss:0.064 ratio train/dev:0.45
# 1400 Train loss:0.032 Dev loss:0.064 ratio train/dev:0.50
# 1420 Train loss:0.044 Dev loss:0.064 ratio train/dev:0.69
# 1440 Train loss:0.030 Dev loss:0.064 ratio train/dev:0.47
# 1460 Train loss:0.048 Dev loss:0.065 ratio train/dev:0.75
# 1480 Train loss:0.030 Dev loss:0.064 ratio train/dev:0.46
# 1500 Train loss:0.029 Dev loss:0.064 ratio train/dev:0.45
# Total time taken: 1097.7803843021393
# Model file: /home/ubuntu/notebooks/models/ind_model_nose_tip_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_nose_tip_/train_history
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:1376: UserWarning: aspect is not supported for Axes with xscale=linear, yscale=log
#   'yscale=%s' % (xscale, yscale))
# Count of observations in training data by features
# mouth_center_bottom_lip_x    7016
# mouth_center_bottom_lip_y    7016
# Image                        7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (5612, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (5612, 2); y_train.min == -0.739; y_train.max == 0.996
# x_dev.shape = = (1404, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (1404, 2); y_dev.min == -0.620; y_dev.max == 0.991
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.108 Dev loss:0.102 ratio train/dev:1.06
# 20 Train loss:0.067 Dev loss:0.080 ratio train/dev:0.84
# 40 Train loss:0.066 Dev loss:0.075 ratio train/dev:0.88
# 60 Train loss:0.066 Dev loss:0.073 ratio train/dev:0.90
# 80 Train loss:0.059 Dev loss:0.071 ratio train/dev:0.82
# 100 Train loss:0.059 Dev loss:0.071 ratio train/dev:0.83
# 120 Train loss:0.050 Dev loss:0.071 ratio train/dev:0.71
# 140 Train loss:0.057 Dev loss:0.069 ratio train/dev:0.83
# 160 Train loss:0.078 Dev loss:0.070 ratio train/dev:1.12
# 180 Train loss:0.058 Dev loss:0.069 ratio train/dev:0.84
# 200 Train loss:0.058 Dev loss:0.070 ratio train/dev:0.83
# 220 Train loss:0.057 Dev loss:0.070 ratio train/dev:0.82
# 240 Train loss:0.058 Dev loss:0.070 ratio train/dev:0.84
# 260 Train loss:0.057 Dev loss:0.070 ratio train/dev:0.82
# 280 Train loss:0.044 Dev loss:0.070 ratio train/dev:0.63
# 300 Train loss:0.047 Dev loss:0.069 ratio train/dev:0.67
# 320 Train loss:0.048 Dev loss:0.069 ratio train/dev:0.69
# 340 Train loss:0.047 Dev loss:0.069 ratio train/dev:0.68
# 360 Train loss:0.052 Dev loss:0.070 ratio train/dev:0.75
# 380 Train loss:0.043 Dev loss:0.069 ratio train/dev:0.63
# 400 Train loss:0.048 Dev loss:0.069 ratio train/dev:0.69
# 420 Train loss:0.041 Dev loss:0.069 ratio train/dev:0.60
# 440 Train loss:0.041 Dev loss:0.069 ratio train/dev:0.59
# 460 Train loss:0.044 Dev loss:0.069 ratio train/dev:0.63
# 480 Train loss:0.046 Dev loss:0.069 ratio train/dev:0.67
# 500 Train loss:0.044 Dev loss:0.069 ratio train/dev:0.64
# 520 Train loss:0.043 Dev loss:0.069 ratio train/dev:0.62
# 540 Train loss:0.043 Dev loss:0.069 ratio train/dev:0.62
# 560 Train loss:0.043 Dev loss:0.069 ratio train/dev:0.62
# 580 Train loss:0.040 Dev loss:0.069 ratio train/dev:0.58
# 600 Train loss:0.043 Dev loss:0.069 ratio train/dev:0.63
# 620 Train loss:0.035 Dev loss:0.069 ratio train/dev:0.50
# 640 Train loss:0.040 Dev loss:0.069 ratio train/dev:0.58
# 660 Train loss:0.039 Dev loss:0.069 ratio train/dev:0.57
# 680 Train loss:0.040 Dev loss:0.069 ratio train/dev:0.59
# 700 Train loss:0.040 Dev loss:0.069 ratio train/dev:0.57
# 720 Train loss:0.035 Dev loss:0.069 ratio train/dev:0.52
# 740 Train loss:0.040 Dev loss:0.069 ratio train/dev:0.58
# 760 Train loss:0.035 Dev loss:0.069 ratio train/dev:0.51
# 780 Train loss:0.038 Dev loss:0.069 ratio train/dev:0.56
# 800 Train loss:0.038 Dev loss:0.069 ratio train/dev:0.55
# 820 Train loss:0.035 Dev loss:0.068 ratio train/dev:0.51
# 840 Train loss:0.045 Dev loss:0.068 ratio train/dev:0.65
# 860 Train loss:0.040 Dev loss:0.068 ratio train/dev:0.59
# 880 Train loss:0.045 Dev loss:0.068 ratio train/dev:0.66
# 900 Train loss:0.036 Dev loss:0.068 ratio train/dev:0.53
# 920 Train loss:0.035 Dev loss:0.068 ratio train/dev:0.51
# 940 Train loss:0.035 Dev loss:0.069 ratio train/dev:0.52
# 960 Train loss:0.033 Dev loss:0.068 ratio train/dev:0.49
# 980 Train loss:0.032 Dev loss:0.068 ratio train/dev:0.47
# 1000 Train loss:0.036 Dev loss:0.068 ratio train/dev:0.52
# 1020 Train loss:0.033 Dev loss:0.068 ratio train/dev:0.49
# 1040 Train loss:0.033 Dev loss:0.068 ratio train/dev:0.48
# 1060 Train loss:0.034 Dev loss:0.068 ratio train/dev:0.51
# 1080 Train loss:0.034 Dev loss:0.068 ratio train/dev:0.50
# 1100 Train loss:0.036 Dev loss:0.068 ratio train/dev:0.52
# 1120 Train loss:0.033 Dev loss:0.068 ratio train/dev:0.48
# 1140 Train loss:0.029 Dev loss:0.068 ratio train/dev:0.43
# 1160 Train loss:0.035 Dev loss:0.068 ratio train/dev:0.51
# 1180 Train loss:0.033 Dev loss:0.068 ratio train/dev:0.48
# 1200 Train loss:0.034 Dev loss:0.068 ratio train/dev:0.50
# 1220 Train loss:0.033 Dev loss:0.068 ratio train/dev:0.48
# 1240 Train loss:0.032 Dev loss:0.068 ratio train/dev:0.47
# 1260 Train loss:0.034 Dev loss:0.068 ratio train/dev:0.50
# 1280 Train loss:0.032 Dev loss:0.068 ratio train/dev:0.48
# 1300 Train loss:0.029 Dev loss:0.068 ratio train/dev:0.42
# 1320 Train loss:0.031 Dev loss:0.068 ratio train/dev:0.46
# 1340 Train loss:0.031 Dev loss:0.068 ratio train/dev:0.45
# 1360 Train loss:0.032 Dev loss:0.068 ratio train/dev:0.47
# 1380 Train loss:0.029 Dev loss:0.068 ratio train/dev:0.43
# 1400 Train loss:0.031 Dev loss:0.068 ratio train/dev:0.45
# 1420 Train loss:0.031 Dev loss:0.068 ratio train/dev:0.46
# 1440 Train loss:0.032 Dev loss:0.068 ratio train/dev:0.47
# 1460 Train loss:0.030 Dev loss:0.068 ratio train/dev:0.44
# 1480 Train loss:0.035 Dev loss:0.068 ratio train/dev:0.51
# 1500 Train loss:0.032 Dev loss:0.068 ratio train/dev:0.47
# Total time taken: 1075.6537456512451
# Model file: /home/ubuntu/notebooks/models/ind_model_mouth_bottom_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_mouth_bottom_/train_history
# Count of observations in training data by features
# left_eye_inner_corner_x     2271
# left_eye_inner_corner_y     2271
# right_eye_inner_corner_x    2268
# right_eye_inner_corner_y    2268
# left_eye_outer_corner_x     2267
# left_eye_outer_corner_y     2267
# right_eye_outer_corner_x    2268
# right_eye_outer_corner_y    2268
# Image                       7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1797, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1797, 8); y_train.min == -0.908; y_train.max == 0.985
# x_dev.shape = = (450, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (450, 8); y_dev.min == -0.917; y_dev.max == 0.781
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.074 Dev loss:0.071 ratio train/dev:1.04
# 20 Train loss:0.044 Dev loss:0.044 ratio train/dev:1.00
# 40 Train loss:0.049 Dev loss:0.041 ratio train/dev:1.20
# 60 Train loss:0.043 Dev loss:0.040 ratio train/dev:1.09
# 80 Train loss:0.040 Dev loss:0.039 ratio train/dev:1.03
# 100 Train loss:0.039 Dev loss:0.039 ratio train/dev:1.02
# 120 Train loss:0.056 Dev loss:0.038 ratio train/dev:1.45
# 140 Train loss:0.037 Dev loss:0.038 ratio train/dev:0.97
# 160 Train loss:0.038 Dev loss:0.038 ratio train/dev:1.00
# 180 Train loss:0.057 Dev loss:0.038 ratio train/dev:1.51
# 200 Train loss:0.040 Dev loss:0.037 ratio train/dev:1.07
# 220 Train loss:0.061 Dev loss:0.037 ratio train/dev:1.64
# 240 Train loss:0.058 Dev loss:0.037 ratio train/dev:1.55
# 260 Train loss:0.035 Dev loss:0.037 ratio train/dev:0.95
# 280 Train loss:0.040 Dev loss:0.037 ratio train/dev:1.08
# 300 Train loss:0.044 Dev loss:0.037 ratio train/dev:1.19
# 320 Train loss:0.058 Dev loss:0.037 ratio train/dev:1.59
# 340 Train loss:0.035 Dev loss:0.037 ratio train/dev:0.94
# 360 Train loss:0.040 Dev loss:0.036 ratio train/dev:1.10
# 380 Train loss:0.031 Dev loss:0.036 ratio train/dev:0.86
# 400 Train loss:0.044 Dev loss:0.036 ratio train/dev:1.21
# 420 Train loss:0.032 Dev loss:0.036 ratio train/dev:0.88
# 440 Train loss:0.053 Dev loss:0.036 ratio train/dev:1.47
# 460 Train loss:0.034 Dev loss:0.036 ratio train/dev:0.95
# 480 Train loss:0.035 Dev loss:0.036 ratio train/dev:0.98
# 500 Train loss:0.033 Dev loss:0.036 ratio train/dev:0.92
# 520 Train loss:0.036 Dev loss:0.036 ratio train/dev:1.02
# 540 Train loss:0.035 Dev loss:0.036 ratio train/dev:0.98
# 560 Train loss:0.029 Dev loss:0.035 ratio train/dev:0.81
# 580 Train loss:0.058 Dev loss:0.035 ratio train/dev:1.63
# 600 Train loss:0.037 Dev loss:0.035 ratio train/dev:1.06
# 620 Train loss:0.038 Dev loss:0.035 ratio train/dev:1.09
# 640 Train loss:0.035 Dev loss:0.035 ratio train/dev:1.00
# 660 Train loss:0.030 Dev loss:0.035 ratio train/dev:0.86
# 680 Train loss:0.032 Dev loss:0.035 ratio train/dev:0.90
# 700 Train loss:0.033 Dev loss:0.035 ratio train/dev:0.94
# 720 Train loss:0.040 Dev loss:0.035 ratio train/dev:1.14
# 740 Train loss:0.047 Dev loss:0.035 ratio train/dev:1.35
# 760 Train loss:0.037 Dev loss:0.035 ratio train/dev:1.07
# 780 Train loss:0.029 Dev loss:0.035 ratio train/dev:0.85
# 800 Train loss:0.030 Dev loss:0.035 ratio train/dev:0.88
# 820 Train loss:0.035 Dev loss:0.034 ratio train/dev:1.01
# 840 Train loss:0.032 Dev loss:0.034 ratio train/dev:0.92
# 860 Train loss:0.038 Dev loss:0.034 ratio train/dev:1.09
# 880 Train loss:0.039 Dev loss:0.034 ratio train/dev:1.12
# 900 Train loss:0.031 Dev loss:0.034 ratio train/dev:0.90
# 920 Train loss:0.053 Dev loss:0.034 ratio train/dev:1.55
# 940 Train loss:0.036 Dev loss:0.034 ratio train/dev:1.06
# 960 Train loss:0.032 Dev loss:0.034 ratio train/dev:0.93
# 980 Train loss:0.034 Dev loss:0.034 ratio train/dev:0.99
# 1000 Train loss:0.034 Dev loss:0.034 ratio train/dev:1.02
# 1020 Train loss:0.032 Dev loss:0.034 ratio train/dev:0.95
# 1040 Train loss:0.033 Dev loss:0.034 ratio train/dev:0.96
# 1060 Train loss:0.031 Dev loss:0.034 ratio train/dev:0.92
# 1080 Train loss:0.046 Dev loss:0.034 ratio train/dev:1.36
# 1100 Train loss:0.034 Dev loss:0.034 ratio train/dev:1.02
# 1120 Train loss:0.027 Dev loss:0.034 ratio train/dev:0.82
# 1140 Train loss:0.032 Dev loss:0.033 ratio train/dev:0.96
# 1160 Train loss:0.027 Dev loss:0.033 ratio train/dev:0.82
# 1180 Train loss:0.030 Dev loss:0.033 ratio train/dev:0.91
# 1200 Train loss:0.029 Dev loss:0.033 ratio train/dev:0.87
# 1220 Train loss:0.031 Dev loss:0.033 ratio train/dev:0.93
# 1240 Train loss:0.030 Dev loss:0.033 ratio train/dev:0.89
# 1260 Train loss:0.030 Dev loss:0.033 ratio train/dev:0.91
# 1280 Train loss:0.029 Dev loss:0.033 ratio train/dev:0.88
# 1300 Train loss:0.040 Dev loss:0.033 ratio train/dev:1.20
# 1320 Train loss:0.027 Dev loss:0.033 ratio train/dev:0.82
# 1340 Train loss:0.031 Dev loss:0.033 ratio train/dev:0.94
# 1360 Train loss:0.037 Dev loss:0.033 ratio train/dev:1.13
# 1380 Train loss:0.029 Dev loss:0.033 ratio train/dev:0.89
# 1400 Train loss:0.030 Dev loss:0.033 ratio train/dev:0.90
# 1420 Train loss:0.030 Dev loss:0.033 ratio train/dev:0.92
# 1440 Train loss:0.026 Dev loss:0.033 ratio train/dev:0.78
# 1460 Train loss:0.027 Dev loss:0.033 ratio train/dev:0.82
# 1480 Train loss:0.028 Dev loss:0.033 ratio train/dev:0.86
# 1500 Train loss:0.027 Dev loss:0.033 ratio train/dev:0.82
# Total time taken: 349.4650559425354
# Model file: /home/ubuntu/notebooks/models/ind_model_eye_corner_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_eye_corner_/train_history
# Count of observations in training data by features
# left_eyebrow_inner_end_x     2270
# left_eyebrow_inner_end_y     2270
# right_eyebrow_inner_end_x    2270
# right_eyebrow_inner_end_y    2270
# left_eyebrow_outer_end_x     2225
# left_eyebrow_outer_end_y     2225
# right_eyebrow_outer_end_x    2236
# right_eyebrow_outer_end_y    2236
# Image                        7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (1752, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (1752, 8); y_train.min == -0.920; y_train.max == 0.964
# x_dev.shape = = (438, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (438, 8); y_dev.min == -0.916; y_dev.max == 0.889
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.118 Dev loss:0.112 ratio train/dev:1.05
# 20 Train loss:0.065 Dev loss:0.066 ratio train/dev:0.97
# 40 Train loss:0.060 Dev loss:0.061 ratio train/dev:0.99
# 60 Train loss:0.058 Dev loss:0.059 ratio train/dev:0.99
# 80 Train loss:0.054 Dev loss:0.058 ratio train/dev:0.93
# 100 Train loss:0.050 Dev loss:0.057 ratio train/dev:0.88
# 120 Train loss:0.060 Dev loss:0.057 ratio train/dev:1.05
# 140 Train loss:0.049 Dev loss:0.056 ratio train/dev:0.87
# 160 Train loss:0.051 Dev loss:0.056 ratio train/dev:0.92
# 180 Train loss:0.053 Dev loss:0.055 ratio train/dev:0.96
# 200 Train loss:0.055 Dev loss:0.055 ratio train/dev:1.00
# 220 Train loss:0.044 Dev loss:0.055 ratio train/dev:0.81
# 240 Train loss:0.046 Dev loss:0.055 ratio train/dev:0.85
# 260 Train loss:0.049 Dev loss:0.054 ratio train/dev:0.90
# 280 Train loss:0.051 Dev loss:0.054 ratio train/dev:0.94
# 300 Train loss:0.054 Dev loss:0.054 ratio train/dev:1.00
# 320 Train loss:0.059 Dev loss:0.054 ratio train/dev:1.09
# 340 Train loss:0.050 Dev loss:0.054 ratio train/dev:0.94
# 360 Train loss:0.054 Dev loss:0.053 ratio train/dev:1.01
# 380 Train loss:0.042 Dev loss:0.053 ratio train/dev:0.79
# 400 Train loss:0.043 Dev loss:0.053 ratio train/dev:0.81
# 420 Train loss:0.059 Dev loss:0.053 ratio train/dev:1.11
# 440 Train loss:0.060 Dev loss:0.053 ratio train/dev:1.13
# 460 Train loss:0.046 Dev loss:0.053 ratio train/dev:0.87
# 480 Train loss:0.047 Dev loss:0.053 ratio train/dev:0.90
# 500 Train loss:0.057 Dev loss:0.052 ratio train/dev:1.09
# 520 Train loss:0.044 Dev loss:0.052 ratio train/dev:0.84
# 540 Train loss:0.044 Dev loss:0.052 ratio train/dev:0.83
# 560 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.92
# 580 Train loss:0.046 Dev loss:0.052 ratio train/dev:0.89
# 600 Train loss:0.046 Dev loss:0.052 ratio train/dev:0.89
# 620 Train loss:0.044 Dev loss:0.052 ratio train/dev:0.85
# 640 Train loss:0.043 Dev loss:0.052 ratio train/dev:0.83
# 660 Train loss:0.043 Dev loss:0.052 ratio train/dev:0.84
# 680 Train loss:0.048 Dev loss:0.052 ratio train/dev:0.93
# 700 Train loss:0.046 Dev loss:0.052 ratio train/dev:0.90
# 720 Train loss:0.043 Dev loss:0.052 ratio train/dev:0.84
# 740 Train loss:0.044 Dev loss:0.051 ratio train/dev:0.85
# 760 Train loss:0.042 Dev loss:0.051 ratio train/dev:0.82
# 780 Train loss:0.044 Dev loss:0.051 ratio train/dev:0.85
# 800 Train loss:0.051 Dev loss:0.051 ratio train/dev:1.00
# 820 Train loss:0.041 Dev loss:0.051 ratio train/dev:0.79
# 840 Train loss:0.042 Dev loss:0.051 ratio train/dev:0.82
# 860 Train loss:0.042 Dev loss:0.051 ratio train/dev:0.82
# 880 Train loss:0.039 Dev loss:0.051 ratio train/dev:0.77
# 900 Train loss:0.043 Dev loss:0.051 ratio train/dev:0.85
# 920 Train loss:0.038 Dev loss:0.051 ratio train/dev:0.75
# 940 Train loss:0.040 Dev loss:0.051 ratio train/dev:0.79
# 960 Train loss:0.036 Dev loss:0.051 ratio train/dev:0.70
# 980 Train loss:0.041 Dev loss:0.051 ratio train/dev:0.81
# 1000 Train loss:0.040 Dev loss:0.051 ratio train/dev:0.79
# 1020 Train loss:0.038 Dev loss:0.051 ratio train/dev:0.75
# 1040 Train loss:0.037 Dev loss:0.051 ratio train/dev:0.74
# 1060 Train loss:0.040 Dev loss:0.051 ratio train/dev:0.79
# 1080 Train loss:0.040 Dev loss:0.050 ratio train/dev:0.80
# 1100 Train loss:0.037 Dev loss:0.050 ratio train/dev:0.73
# 1120 Train loss:0.036 Dev loss:0.050 ratio train/dev:0.72
# 1140 Train loss:0.040 Dev loss:0.050 ratio train/dev:0.80
# 1160 Train loss:0.039 Dev loss:0.050 ratio train/dev:0.78
# 1180 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.76
# 1200 Train loss:0.036 Dev loss:0.050 ratio train/dev:0.71
# 1220 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.76
# 1240 Train loss:0.037 Dev loss:0.050 ratio train/dev:0.74
# 1260 Train loss:0.033 Dev loss:0.050 ratio train/dev:0.67
# 1280 Train loss:0.037 Dev loss:0.050 ratio train/dev:0.75
# 1300 Train loss:0.036 Dev loss:0.050 ratio train/dev:0.71
# 1320 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.75
# 1340 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.76
# 1360 Train loss:0.037 Dev loss:0.050 ratio train/dev:0.74
# 1380 Train loss:0.039 Dev loss:0.050 ratio train/dev:0.79
# 1400 Train loss:0.037 Dev loss:0.050 ratio train/dev:0.74
# 1420 Train loss:0.035 Dev loss:0.050 ratio train/dev:0.70
# 1440 Train loss:0.038 Dev loss:0.050 ratio train/dev:0.77
# 1460 Train loss:0.035 Dev loss:0.050 ratio train/dev:0.70
# 1480 Train loss:0.035 Dev loss:0.050 ratio train/dev:0.71
# 1500 Train loss:0.044 Dev loss:0.050 ratio train/dev:0.89
# Total time taken: 327.3270299434662
# Model file: /home/ubuntu/notebooks/models/ind_model_eyebrow_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_eyebrow_/train_history
# Count of observations in training data by features
# left_eye_center_x     7039
# left_eye_center_y     7039
# right_eye_center_x    7036
# right_eye_center_y    7036
# Image                 7049
# dtype: int64
# done
# Count of observations in training data by features
# ImageId    1783
# Image      1783
# dtype: int64
# done
# Training data split into train and dev data
# x_train.shape = = (5626, 9216); x_train.min == 0.000; x_train.max == 1.000
# y_train.shape = = (5626, 4); y_train.min == -0.986; y_train.max == 0.973
# x_dev.shape = = (1407, 9216); x_dev.min == 0.000; x_dev.max == 1.000
# y_dev.shape = = (1407, 4); y_dev.min == -0.888; y_dev.max == 0.637
#  RESTORING SESSION FOR WEIGHTS INITIALIZATION
# INFO:tensorflow:Restoring parameters from /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
#  Model loaded from: /home/ubuntu/notebooks/models/basic_conv_net_/model.ckpt
# 0 Train loss:0.062 Dev loss:0.064 ratio train/dev:0.96
# 20 Train loss:0.072 Dev loss:0.055 ratio train/dev:1.32
# 40 Train loss:0.076 Dev loss:0.053 ratio train/dev:1.43
# 60 Train loss:0.042 Dev loss:0.053 ratio train/dev:0.80
# 80 Train loss:0.059 Dev loss:0.052 ratio train/dev:1.14
# 100 Train loss:0.039 Dev loss:0.051 ratio train/dev:0.77
# 120 Train loss:0.045 Dev loss:0.050 ratio train/dev:0.89
# 140 Train loss:0.052 Dev loss:0.050 ratio train/dev:1.04
# 160 Train loss:0.042 Dev loss:0.049 ratio train/dev:0.87
# 180 Train loss:0.072 Dev loss:0.049 ratio train/dev:1.49
# 200 Train loss:0.042 Dev loss:0.048 ratio train/dev:0.88
# 220 Train loss:0.041 Dev loss:0.048 ratio train/dev:0.87
# 240 Train loss:0.044 Dev loss:0.047 ratio train/dev:0.93
# 260 Train loss:0.037 Dev loss:0.047 ratio train/dev:0.78
# 280 Train loss:0.035 Dev loss:0.047 ratio train/dev:0.75
# 300 Train loss:0.039 Dev loss:0.047 ratio train/dev:0.83
# 320 Train loss:0.048 Dev loss:0.047 ratio train/dev:1.02
# 340 Train loss:0.054 Dev loss:0.046 ratio train/dev:1.17
# 360 Train loss:0.042 Dev loss:0.046 ratio train/dev:0.90
# 380 Train loss:0.045 Dev loss:0.046 ratio train/dev:0.98
# 400 Train loss:0.058 Dev loss:0.046 ratio train/dev:1.26
# 420 Train loss:0.035 Dev loss:0.046 ratio train/dev:0.77
# 440 Train loss:0.033 Dev loss:0.046 ratio train/dev:0.73
# 460 Train loss:0.038 Dev loss:0.046 ratio train/dev:0.82
# 480 Train loss:0.035 Dev loss:0.046 ratio train/dev:0.77
# 500 Train loss:0.037 Dev loss:0.046 ratio train/dev:0.81
# 520 Train loss:0.048 Dev loss:0.046 ratio train/dev:1.05
# 540 Train loss:0.046 Dev loss:0.046 ratio train/dev:1.02
# 560 Train loss:0.035 Dev loss:0.046 ratio train/dev:0.78
# 580 Train loss:0.035 Dev loss:0.045 ratio train/dev:0.76
# 600 Train loss:0.032 Dev loss:0.045 ratio train/dev:0.71
# 620 Train loss:0.035 Dev loss:0.045 ratio train/dev:0.76
# 640 Train loss:0.033 Dev loss:0.045 ratio train/dev:0.72
# 660 Train loss:0.035 Dev loss:0.045 ratio train/dev:0.76
# 680 Train loss:0.033 Dev loss:0.045 ratio train/dev:0.74
# 700 Train loss:0.039 Dev loss:0.045 ratio train/dev:0.87
# 720 Train loss:0.034 Dev loss:0.045 ratio train/dev:0.76
# 740 Train loss:0.036 Dev loss:0.045 ratio train/dev:0.79
# 760 Train loss:0.038 Dev loss:0.045 ratio train/dev:0.84
# 780 Train loss:0.036 Dev loss:0.045 ratio train/dev:0.81
# 800 Train loss:0.032 Dev loss:0.045 ratio train/dev:0.71
# 820 Train loss:0.034 Dev loss:0.045 ratio train/dev:0.75
# 840 Train loss:0.040 Dev loss:0.045 ratio train/dev:0.88
# 860 Train loss:0.031 Dev loss:0.045 ratio train/dev:0.69
# 880 Train loss:0.033 Dev loss:0.045 ratio train/dev:0.73
# 900 Train loss:0.033 Dev loss:0.045 ratio train/dev:0.73
# 920 Train loss:0.030 Dev loss:0.045 ratio train/dev:0.66
# 940 Train loss:0.030 Dev loss:0.045 ratio train/dev:0.67
# 960 Train loss:0.038 Dev loss:0.045 ratio train/dev:0.84
# 980 Train loss:0.031 Dev loss:0.045 ratio train/dev:0.69
# 1000 Train loss:0.036 Dev loss:0.045 ratio train/dev:0.79
# 1020 Train loss:0.034 Dev loss:0.045 ratio train/dev:0.75
# 1040 Train loss:0.035 Dev loss:0.045 ratio train/dev:0.78
# 1060 Train loss:0.030 Dev loss:0.045 ratio train/dev:0.67
# 1080 Train loss:0.031 Dev loss:0.045 ratio train/dev:0.68
# 1100 Train loss:0.031 Dev loss:0.045 ratio train/dev:0.69
# 1120 Train loss:0.029 Dev loss:0.045 ratio train/dev:0.65
# 1140 Train loss:0.035 Dev loss:0.045 ratio train/dev:0.79
# 1160 Train loss:0.030 Dev loss:0.045 ratio train/dev:0.67
# 1180 Train loss:0.030 Dev loss:0.045 ratio train/dev:0.66
# 1200 Train loss:0.032 Dev loss:0.045 ratio train/dev:0.71
# 1220 Train loss:0.032 Dev loss:0.045 ratio train/dev:0.71
# 1240 Train loss:0.036 Dev loss:0.045 ratio train/dev:0.79
# 1260 Train loss:0.033 Dev loss:0.045 ratio train/dev:0.73
# 1280 Train loss:0.030 Dev loss:0.045 ratio train/dev:0.68
# 1300 Train loss:0.036 Dev loss:0.045 ratio train/dev:0.79
# 1320 Train loss:0.028 Dev loss:0.045 ratio train/dev:0.63
# 1340 Train loss:0.051 Dev loss:0.045 ratio train/dev:1.15
# 1360 Train loss:0.030 Dev loss:0.045 ratio train/dev:0.67
# 1380 Train loss:0.029 Dev loss:0.045 ratio train/dev:0.64
# 1400 Train loss:0.034 Dev loss:0.045 ratio train/dev:0.75
# 1420 Train loss:0.028 Dev loss:0.045 ratio train/dev:0.62
# 1440 Train loss:0.031 Dev loss:0.045 ratio train/dev:0.69
# 1460 Train loss:0.033 Dev loss:0.045 ratio train/dev:0.73
# 1480 Train loss:0.044 Dev loss:0.045 ratio train/dev:0.99
# 1500 Train loss:0.028 Dev loss:0.045 ratio train/dev:0.63
# Total time taken: 1079.5281007289886
# Model file: /home/ubuntu/notebooks/models/ind_model_eye_center_/model.ckpt
# Train history file: /home/ubuntu/notebooks/models/ind_model_eye_center_/train_history
#  Total time for all models:  4386.884194850922

# %%
# Plots history of learning curves for individual features  model. 
def plot_ind_model_curves(spec_name, color):
    
    train_history_path = FROOT + "/models/" + "ind_model_" + spec_name + "_"  + "/train_history"
    model_history = np.load(train_history_path + ".npz")
    train_loss = model_history["train_loss_history"][:,1]
    
    valid_loss = model_history["valid_loss_history"][:,1]
    
    x_axis = np.arange(n_epochs)
    
    label_name = spec_name.replace("_", " ")
    plt.plot(x_axis[train_loss > 0], train_loss[train_loss > 0], color + "--", linewidth=2, label = label_name)
    plt.plot(x_axis[valid_loss > 0], valid_loss[valid_loss > 0], color + "-", linewidth=2)
    
    return valid_loss

# %%
#Get mean loss from individual models 

colors = ["b", "g", "r", "c", "m", "y"]
weighted_valid_loss = np.zeros(n_epochs)
total_features = 0
for facial_model_label in facial_group_labels:
    valid_loss_ind = plot_ind_model_curves(facial_model_label['name'], colors[facial_group_labels.index(facial_model_label) % len(colors)])
    
    weighted_valid_loss += valid_loss_ind * len(facial_model_label['columns'])
    
    total_features += len(facial_model_label['columns'])
                               
    mean_loss = weighted_valid_loss/total_features

print("Mean loss from individual models: %0.4f"% mean_loss[-1])
x_axis = np.arange(n_epochs)
   

plt.plot(x_axis[mean_loss > 0], mean_loss[mean_loss > 0], "k" + "--", linewidth=2, label = "mean loss")
                                

plt.grid()
plt.legend()
plt.xlabel("epoch")
plt.ylabel("loss")
#plt.ylim(0.0003, 0.1)
plt.xlim(0, n_epochs)
plt.yscale("log")
plt.show()
# Out:
# Mean loss from individual models: 0.0474
